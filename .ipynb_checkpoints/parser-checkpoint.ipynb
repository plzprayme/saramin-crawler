# %%
from os import getcwd, listdir
print(getcwd())
print(listdir())
# Out:
# C:\Users\prayme\workspace\selenium
# ['.git', '.ipynb_checkpoints', 'debug.log', 'parser.ipynb', 'parser.py', 'README.md']

# %%
# %run parser.py

# %%
from bs4 import BeautifulSoup as bs4
import requests

html = requests.get("http://www.saramin.co.kr/zf_user/jobs/relay/view?view_type=list&rec_idx=38750834")

# %%
print(html)

# %%
soup = bs4(html, 'html.parser')

# %%
print(soup)

# %%
str = """<html lang="ko"><head>
        <title>[(주)매그파이소프트]
                        웹 /응용프로그램  개발자  모집         (D-11) - 사람인</title>    <meta http-equiv="X-UA-Compatible" content="IE=Edge">
<meta http-equiv="Content-Type" content="text/html; charset=utf-8"><script type="text/javascript" src="https://bam.nr-data.net/1/03a1f7dfe5?a=443261373&amp;v=1177.96a4d39&amp;to=YFJaMkNTDBIFAUJfWVkYeQVFWw0PSwhZVEUYRV0KUEtNFw0HQQ%3D%3D&amp;rst=1948&amp;ck=1&amp;ref=http://www.saramin.co.kr/zf_user/jobs/relay/view&amp;ap=462&amp;be=821&amp;fe=1945&amp;dc=1107&amp;af=err,xhr,stn,ins&amp;perf=%7B%22timing%22:%7B%22of%22:1599630516992,%22n%22:0,%22u%22:789,%22r%22:1,%22ue%22:789,%22re%22:252,%22f%22:252,%22dn%22:252,%22dne%22:252,%22c%22:252,%22ce%22:252,%22rq%22:253,%22rp%22:784,%22rpe%22:891,%22dl%22:806,%22di%22:1108,%22ds%22:1108,%22de%22:1125,%22dc%22:1945,%22l%22:1945,%22le%22:1947%7D,%22navigation%22:%7B%22rc%22:1%7D%7D&amp;fp=1036&amp;fcp=1036&amp;at=TBVZRAtJHxw%3D&amp;jsonp=NREUM.setToken"></script><script src="https://js-agent.newrelic.com/nr-1177.min.js"></script><script type="text/javascript" async="" src="https://www.google-analytics.com/analytics.js"></script><script type="text/javascript" async="" src="https://www.google-analytics.com/plugins/ua/ec.js"></script><script src="https://www.googletagservices.com/activeview/js/current/osd.js?cb=%2Fr20100101"></script><script async="" src="https://www.googletagmanager.com/gtm.js?id=GTM-MK2GBBH"></script><script type="text/javascript" async="" src="https://www.google-analytics.com/gtm/js?id=GTM-KN35GK2&amp;cid=155534941.1599630511"></script><script type="text/javascript" async="" src="https://www.google-analytics.com/plugins/ua/linkid.js"></script><script async="" src="https://www.google-analytics.com/analytics.js"></script><script type="text/javascript">(window.NREUM||(NREUM={})).loader_config={xpid:"VgMEUFRbDRAEUFJQAQAEUVc=",licenseKey:"03a1f7dfe5",applicationID:"443261373"};window.NREUM||(NREUM={}),__nr_require=function(t,e,n){function r(n){if(!e[n]){var i=e[n]={exports:{}};t[n][0].call(i.exports,function(e){var i=t[n][1][e];return r(i||e)},i,i.exports)}return e[n].exports}if("function"==typeof __nr_require)return __nr_require;for(var i=0;i<n.length;i++)r(n[i]);return r}({1:[function(t,e,n){function r(t){try{c.console&&console.log(t)}catch(e){}}var i,o=t("ee"),a=t(22),c={};try{i=localStorage.getItem("__nr_flags").split(","),console&&"function"==typeof console.log&&(c.console=!0,i.indexOf("dev")!==-1&&(c.dev=!0),i.indexOf("nr_dev")!==-1&&(c.nrDev=!0))}catch(s){}c.nrDev&&o.on("internal-error",function(t){r(t.stack)}),c.dev&&o.on("fn-err",function(t,e,n){r(n.stack)}),c.dev&&(r("NR AGENT IN DEVELOPMENT MODE"),r("flags: "+a(c,function(t,e){return t}).join(", ")))},{}],2:[function(t,e,n){function r(t,e,n,r,c){try{p?p-=1:i(c||new UncaughtException(t,e,n),!0)}catch(f){try{o("ierr",[f,s.now(),!0])}catch(d){}}return"function"==typeof u&&u.apply(this,a(arguments))}function UncaughtException(t,e,n){this.message=t||"Uncaught error with no additional information",this.sourceURL=e,this.line=n}function i(t,e){var n=e?null:s.now();o("err",[t,n])}var o=t("handle"),a=t(23),c=t("ee"),s=t("loader"),f=t("gos"),u=window.onerror,d=!1,l="nr@seenError",p=0;s.features.err=!0,t(1),window.onerror=r;try{throw new Error}catch(h){"stack"in h&&(t(9),t(8),"addEventListener"in window&&t(5),s.xhrWrappable&&t(10),d=!0)}c.on("fn-start",function(t,e,n){d&&(p+=1)}),c.on("fn-err",function(t,e,n){d&&!n[l]&&(f(n,l,function(){return!0}),this.thrown=!0,i(n))}),c.on("fn-end",function(){d&&!this.thrown&&p>0&&(p-=1)}),c.on("internal-error",function(t){o("ierr",[t,s.now(),!0])})},{}],3:[function(t,e,n){t("loader").features.ins=!0},{}],4:[function(t,e,n){function r(t){}if(window.performance&&window.performance.timing&&window.performance.getEntriesByType){var i=t("ee"),o=t("handle"),a=t(9),c=t(8),s="learResourceTimings",f="addEventListener",u="resourcetimingbufferfull",d="bstResource",l="resource",p="-start",h="-end",m="fn"+p,w="fn"+h,v="bstTimer",g="pushState",y=t("loader");y.features.stn=!0,t(7),"addEventListener"in window&&t(5);var x=NREUM.o.EV;i.on(m,function(t,e){var n=t[0];n instanceof x&&(this.bstStart=y.now())}),i.on(w,function(t,e){var n=t[0];n instanceof x&&o("bst",[n,e,this.bstStart,y.now()])}),a.on(m,function(t,e,n){this.bstStart=y.now(),this.bstType=n}),a.on(w,function(t,e){o(v,[e,this.bstStart,y.now(),this.bstType])}),c.on(m,function(){this.bstStart=y.now()}),c.on(w,function(t,e){o(v,[e,this.bstStart,y.now(),"requestAnimationFrame"])}),i.on(g+p,function(t){this.time=y.now(),this.startPath=location.pathname+location.hash}),i.on(g+h,function(t){o("bstHist",[location.pathname+location.hash,this.startPath,this.time])}),f in window.performance&&(window.performance["c"+s]?window.performance[f](u,function(t){o(d,[window.performance.getEntriesByType(l)]),window.performance["c"+s]()},!1):window.performance[f]("webkit"+u,function(t){o(d,[window.performance.getEntriesByType(l)]),window.performance["webkitC"+s]()},!1)),document[f]("scroll",r,{passive:!0}),document[f]("keypress",r,!1),document[f]("click",r,!1)}},{}],5:[function(t,e,n){function r(t){for(var e=t;e&&!e.hasOwnProperty(u);)e=Object.getPrototypeOf(e);e&&i(e)}function i(t){c.inPlace(t,[u,d],"-",o)}function o(t,e){return t[1]}var a=t("ee").get("events"),c=t("wrap-function")(a,!0),s=t("gos"),f=XMLHttpRequest,u="addEventListener",d="removeEventListener";e.exports=a,"getPrototypeOf"in Object?(r(document),r(window),r(f.prototype)):f.prototype.hasOwnProperty(u)&&(i(window),i(f.prototype)),a.on(u+"-start",function(t,e){var n=t[1],r=s(n,"nr@wrapped",function(){function t(){if("function"==typeof n.handleEvent)return n.handleEvent.apply(n,arguments)}var e={object:t,"function":n}[typeof n];return e?c(e,"fn-",null,e.name||"anonymous"):n});this.wrapped=t[1]=r}),a.on(d+"-start",function(t){t[1]=this.wrapped||t[1]})},{}],6:[function(t,e,n){function r(t,e,n){var r=t[e];"function"==typeof r&&(t[e]=function(){var t=o(arguments),e={};i.emit(n+"before-start",[t],e);var a;e[m]&&e[m].dt&&(a=e[m].dt);var c=r.apply(this,t);return i.emit(n+"start",[t,a],c),c.then(function(t){return i.emit(n+"end",[null,t],c),t},function(t){throw i.emit(n+"end",[t],c),t})})}var i=t("ee").get("fetch"),o=t(23),a=t(22);e.exports=i;var c=window,s="fetch-",f=s+"body-",u=["arrayBuffer","blob","json","text","formData"],d=c.Request,l=c.Response,p=c.fetch,h="prototype",m="nr@context";d&&l&&p&&(a(u,function(t,e){r(d[h],e,f),r(l[h],e,f)}),r(c,"fetch",s),i.on(s+"end",function(t,e){var n=this;if(e){var r=e.headers.get("content-length");null!==r&&(n.rxSize=r),i.emit(s+"done",[null,e],n)}else i.emit(s+"done",[t],n)}))},{}],7:[function(t,e,n){var r=t("ee").get("history"),i=t("wrap-function")(r);e.exports=r;var o=window.history&&window.history.constructor&&window.history.constructor.prototype,a=window.history;o&&o.pushState&&o.replaceState&&(a=o),i.inPlace(a,["pushState","replaceState"],"-")},{}],8:[function(t,e,n){var r=t("ee").get("raf"),i=t("wrap-function")(r),o="equestAnimationFrame";e.exports=r,i.inPlace(window,["r"+o,"mozR"+o,"webkitR"+o,"msR"+o],"raf-"),r.on("raf-start",function(t){t[0]=i(t[0],"fn-")})},{}],9:[function(t,e,n){function r(t,e,n){t[0]=a(t[0],"fn-",null,n)}function i(t,e,n){this.method=n,this.timerDuration=isNaN(t[1])?0:+t[1],t[0]=a(t[0],"fn-",this,n)}var o=t("ee").get("timer"),a=t("wrap-function")(o),c="setTimeout",s="setInterval",f="clearTimeout",u="-start",d="-";e.exports=o,a.inPlace(window,[c,"setImmediate"],c+d),a.inPlace(window,[s],s+d),a.inPlace(window,[f,"clearImmediate"],f+d),o.on(s+u,r),o.on(c+u,i)},{}],10:[function(t,e,n){function r(t,e){d.inPlace(e,["onreadystatechange"],"fn-",c)}function i(){var t=this,e=u.context(t);t.readyState>3&&!e.resolved&&(e.resolved=!0,u.emit("xhr-resolved",[],t)),d.inPlace(t,g,"fn-",c)}function o(t){y.push(t),h&&(b?b.then(a):w?w(a):(E=-E,R.data=E))}function a(){for(var t=0;t<y.length;t++)r([],y[t]);y.length&&(y=[])}function c(t,e){return e}function s(t,e){for(var n in t)e[n]=t[n];return e}t(5);var f=t("ee"),u=f.get("xhr"),d=t("wrap-function")(u),l=NREUM.o,p=l.XHR,h=l.MO,m=l.PR,w=l.SI,v="readystatechange",g=["onload","onerror","onabort","onloadstart","onloadend","onprogress","ontimeout"],y=[];e.exports=u;var x=window.XMLHttpRequest=function(t){var e=new p(t);try{u.emit("new-xhr",[e],e),e.addEventListener(v,i,!1)}catch(n){try{u.emit("internal-error",[n])}catch(r){}}return e};if(s(p,x),x.prototype=p.prototype,d.inPlace(x.prototype,["open","send"],"-xhr-",c),u.on("send-xhr-start",function(t,e){r(t,e),o(e)}),u.on("open-xhr-start",r),h){var b=m&&m.resolve();if(!w&&!m){var E=1,R=document.createTextNode(E);new h(a).observe(R,{characterData:!0})}}else f.on("fn-end",function(t){t[0]&&t[0].type===v||a()})},{}],11:[function(t,e,n){function r(t){if(!c(t))return null;var e=window.NREUM;if(!e.loader_config)return null;var n=(e.loader_config.accountID||"").toString()||null,r=(e.loader_config.agentID||"").toString()||null,f=(e.loader_config.trustKey||"").toString()||null;if(!n||!r)return null;var h=p.generateSpanId(),m=p.generateTraceId(),w=Date.now(),v={spanId:h,traceId:m,timestamp:w};return(t.sameOrigin||s(t)&&l())&&(v.traceContextParentHeader=i(h,m),v.traceContextStateHeader=o(h,w,n,r,f)),(t.sameOrigin&&!u()||!t.sameOrigin&&s(t)&&d())&&(v.newrelicHeader=a(h,m,w,n,r,f)),v}function i(t,e){return"00-"+e+"-"+t+"-01"}function o(t,e,n,r,i){var o=0,a="",c=1,s="",f="";return i+"@nr="+o+"-"+c+"-"+n+"-"+r+"-"+t+"-"+a+"-"+s+"-"+f+"-"+e}function a(t,e,n,r,i,o){var a="btoa"in window&&"function"==typeof window.btoa;if(!a)return null;var c={v:[0,1],d:{ty:"Browser",ac:r,ap:i,id:t,tr:e,ti:n}};return o&&r!==o&&(c.d.tk=o),btoa(JSON.stringify(c))}function c(t){return f()&&s(t)}function s(t){var e=!1,n={};if("init"in NREUM&&"distributed_tracing"in NREUM.init&&(n=NREUM.init.distributed_tracing),t.sameOrigin)e=!0;else if(n.allowed_origins instanceof Array)for(var r=0;r<n.allowed_origins.length;r++){var i=h(n.allowed_origins[r]);if(t.hostname===i.hostname&&t.protocol===i.protocol&&t.port===i.port){e=!0;break}}return e}function f(){return"init"in NREUM&&"distributed_tracing"in NREUM.init&&!!NREUM.init.distributed_tracing.enabled}function u(){return"init"in NREUM&&"distributed_tracing"in NREUM.init&&!!NREUM.init.distributed_tracing.exclude_newrelic_header}function d(){return"init"in NREUM&&"distributed_tracing"in NREUM.init&&NREUM.init.distributed_tracing.cors_use_newrelic_header!==!1}function l(){return"init"in NREUM&&"distributed_tracing"in NREUM.init&&!!NREUM.init.distributed_tracing.cors_use_tracecontext_headers}var p=t(19),h=t(13);e.exports={generateTracePayload:r,shouldGenerateTrace:c}},{}],12:[function(t,e,n){function r(t){var e=this.params,n=this.metrics;if(!this.ended){this.ended=!0;for(var r=0;r<l;r++)t.removeEventListener(d[r],this.listener,!1);e.aborted||(n.duration=a.now()-this.startTime,this.loadCaptureCalled||4!==t.readyState?null==e.status&&(e.status=0):o(this,t),n.cbTime=this.cbTime,u.emit("xhr-done",[t],t),c("xhr",[e,n,this.startTime]))}}function i(t,e){var n=s(e),r=t.params;r.host=n.hostname+":"+n.port,r.pathname=n.pathname,t.parsedOrigin=s(e),t.sameOrigin=t.parsedOrigin.sameOrigin}function o(t,e){t.params.status=e.status;var n=w(e,t.lastSize);if(n&&(t.metrics.rxSize=n),t.sameOrigin){var r=e.getResponseHeader("X-NewRelic-App-Data");r&&(t.params.cat=r.split(", ").pop())}t.loadCaptureCalled=!0}var a=t("loader");if(a.xhrWrappable){var c=t("handle"),s=t(13),f=t(11).generateTracePayload,u=t("ee"),d=["load","error","abort","timeout"],l=d.length,p=t("id"),h=t(17),m=t(16),w=t(14),v=window.XMLHttpRequest;a.features.xhr=!0,t(10),t(6),u.on("new-xhr",function(t){var e=this;e.totalCbs=0,e.called=0,e.cbTime=0,e.end=r,e.ended=!1,e.xhrGuids={},e.lastSize=null,e.loadCaptureCalled=!1,t.addEventListener("load",function(n){o(e,t)},!1),h&&(h>34||h<10)||window.opera||t.addEventListener("progress",function(t){e.lastSize=t.loaded},!1)}),u.on("open-xhr-start",function(t){this.params={method:t[0]},i(this,t[1]),this.metrics={}}),u.on("open-xhr-end",function(t,e){"loader_config"in NREUM&&"xpid"in NREUM.loader_config&&this.sameOrigin&&e.setRequestHeader("X-NewRelic-ID",NREUM.loader_config.xpid);var n=f(this.parsedOrigin);if(n){var r=!1;n.newrelicHeader&&(e.setRequestHeader("newrelic",n.newrelicHeader),r=!0),n.traceContextParentHeader&&(e.setRequestHeader("traceparent",n.traceContextParentHeader),n.traceContextStateHeader&&e.setRequestHeader("tracestate",n.traceContextStateHeader),r=!0),r&&(this.dt=n)}}),u.on("send-xhr-start",function(t,e){var n=this.metrics,r=t[0],i=this;if(n&&r){var o=m(r);o&&(n.txSize=o)}this.startTime=a.now(),this.listener=function(t){try{"abort"!==t.type||i.loadCaptureCalled||(i.params.aborted=!0),("load"!==t.type||i.called===i.totalCbs&&(i.onloadCalled||"function"!=typeof e.onload))&&i.end(e)}catch(n){try{u.emit("internal-error",[n])}catch(r){}}};for(var c=0;c<l;c++)e.addEventListener(d[c],this.listener,!1)}),u.on("xhr-cb-time",function(t,e,n){this.cbTime+=t,e?this.onloadCalled=!0:this.called+=1,this.called!==this.totalCbs||!this.onloadCalled&&"function"==typeof n.onload||this.end(n)}),u.on("xhr-load-added",function(t,e){var n=""+p(t)+!!e;this.xhrGuids&&!this.xhrGuids[n]&&(this.xhrGuids[n]=!0,this.totalCbs+=1)}),u.on("xhr-load-removed",function(t,e){var n=""+p(t)+!!e;this.xhrGuids&&this.xhrGuids[n]&&(delete this.xhrGuids[n],this.totalCbs-=1)}),u.on("addEventListener-end",function(t,e){e instanceof v&&"load"===t[0]&&u.emit("xhr-load-added",[t[1],t[2]],e)}),u.on("removeEventListener-end",function(t,e){e instanceof v&&"load"===t[0]&&u.emit("xhr-load-removed",[t[1],t[2]],e)}),u.on("fn-start",function(t,e,n){e instanceof v&&("onload"===n&&(this.onload=!0),("load"===(t[0]&&t[0].type)||this.onload)&&(this.xhrCbStart=a.now()))}),u.on("fn-end",function(t,e){this.xhrCbStart&&u.emit("xhr-cb-time",[a.now()-this.xhrCbStart,this.onload,e],e)}),u.on("fetch-before-start",function(t){function e(t,e){var n=!1;return e.newrelicHeader&&(t.set("newrelic",e.newrelicHeader),n=!0),e.traceContextParentHeader&&(t.set("traceparent",e.traceContextParentHeader),e.traceContextStateHeader&&t.set("tracestate",e.traceContextStateHeader),n=!0),n}var n,r=t[1]||{};"string"==typeof t[0]?n=t[0]:t[0]&&t[0].url&&(n=t[0].url),n&&(this.parsedOrigin=s(n),this.sameOrigin=this.parsedOrigin.sameOrigin);var i=f(this.parsedOrigin);if(i&&(i.newrelicHeader||i.traceContextParentHeader))if("string"==typeof t[0]){var o={};for(var a in r)o[a]=r[a];o.headers=new Headers(r.headers||{}),e(o.headers,i)&&(this.dt=i),t.length>1?t[1]=o:t.push(o)}else t[0]&&t[0].headers&&e(t[0].headers,i)&&(this.dt=i)})}},{}],13:[function(t,e,n){var r={};e.exports=function(t){if(t in r)return r[t];var e=document.createElement("a"),n=window.location,i={};e.href=t,i.port=e.port;var o=e.href.split("://");!i.port&&o[1]&&(i.port=o[1].split("/")[0].split("@").pop().split(":")[1]),i.port&&"0"!==i.port||(i.port="https"===o[0]?"443":"80"),i.hostname=e.hostname||n.hostname,i.pathname=e.pathname,i.protocol=o[0],"/"!==i.pathname.charAt(0)&&(i.pathname="/"+i.pathname);var a=!e.protocol||":"===e.protocol||e.protocol===n.protocol,c=e.hostname===document.domain&&e.port===n.port;return i.sameOrigin=a&&(!e.hostname||c),"/"===i.pathname&&(r[t]=i),i}},{}],14:[function(t,e,n){function r(t,e){var n=t.responseType;return"json"===n&&null!==e?e:"arraybuffer"===n||"blob"===n||"json"===n?i(t.response):"text"===n||""===n||void 0===n?i(t.responseText):void 0}var i=t(16);e.exports=r},{}],15:[function(t,e,n){function r(){}function i(t,e,n){return function(){return o(t,[f.now()].concat(c(arguments)),e?null:this,n),e?void 0:this}}var o=t("handle"),a=t(22),c=t(23),s=t("ee").get("tracer"),f=t("loader"),u=NREUM;"undefined"==typeof window.newrelic&&(newrelic=u);var d=["setPageViewName","setCustomAttribute","setErrorHandler","finished","addToTrace","inlineHit","addRelease"],l="api-",p=l+"ixn-";a(d,function(t,e){u[e]=i(l+e,!0,"api")}),u.addPageAction=i(l+"addPageAction",!0),u.setCurrentRouteName=i(l+"routeName",!0),e.exports=newrelic,u.interaction=function(){return(new r).get()};var h=r.prototype={createTracer:function(t,e){var n={},r=this,i="function"==typeof e;return o(p+"tracer",[f.now(),t,n],r),function(){if(s.emit((i?"":"no-")+"fn-start",[f.now(),r,i],n),i)try{return e.apply(this,arguments)}catch(t){throw s.emit("fn-err",[arguments,this,t],n),t}finally{s.emit("fn-end",[f.now()],n)}}}};a("actionText,setName,setAttribute,save,ignore,onEnd,getContext,end,get".split(","),function(t,e){h[e]=i(p+e)}),newrelic.noticeError=function(t,e){"string"==typeof t&&(t=new Error(t)),o("err",[t,f.now(),!1,e])}},{}],16:[function(t,e,n){e.exports=function(t){if("string"==typeof t&&t.length)return t.length;if("object"==typeof t){if("undefined"!=typeof ArrayBuffer&&t instanceof ArrayBuffer&&t.byteLength)return t.byteLength;if("undefined"!=typeof Blob&&t instanceof Blob&&t.size)return t.size;if(!("undefined"!=typeof FormData&&t instanceof FormData))try{return JSON.stringify(t).length}catch(e){return}}}},{}],17:[function(t,e,n){var r=0,i=navigator.userAgent.match(/Firefox[\/\s](\d+\.\d+)/);i&&(r=+i[1]),e.exports=r},{}],18:[function(t,e,n){function r(t,e){var n=t.getEntries();n.forEach(function(t){"first-paint"===t.name?d("timing",["fp",Math.floor(t.startTime)]):"first-contentful-paint"===t.name&&d("timing",["fcp",Math.floor(t.startTime)])})}function i(t,e){var n=t.getEntries();n.length>0&&d("lcp",[n[n.length-1]])}function o(t){t.getEntries().forEach(function(t){t.hadRecentInput||d("cls",[t])})}function a(t){if(t instanceof h&&!w){var e=Math.round(t.timeStamp),n={type:t.type};e<=l.now()?n.fid=l.now()-e:e>l.offset&&e<=Date.now()?(e-=l.offset,n.fid=l.now()-e):e=l.now(),w=!0,d("timing",["fi",e,n])}}function c(t){d("pageHide",[l.now(),t])}if(!("init"in NREUM&&"page_view_timing"in NREUM.init&&"enabled"in NREUM.init.page_view_timing&&NREUM.init.page_view_timing.enabled===!1)){var s,f,u,d=t("handle"),l=t("loader"),p=t(21),h=NREUM.o.EV;if("PerformanceObserver"in window&&"function"==typeof window.PerformanceObserver){s=new PerformanceObserver(r);try{s.observe({entryTypes:["paint"]})}catch(m){}f=new PerformanceObserver(i);try{f.observe({entryTypes:["largest-contentful-paint"]})}catch(m){}u=new PerformanceObserver(o);try{u.observe({type:"layout-shift",buffered:!0})}catch(m){}}if("addEventListener"in document){var w=!1,v=["click","keydown","mousedown","pointerdown","touchstart"];v.forEach(function(t){document.addEventListener(t,a,!1)})}p(c)}},{}],19:[function(t,e,n){function r(){function t(){return e?15&e[n++]:16*Math.random()|0}var e=null,n=0,r=window.crypto||window.msCrypto;r&&r.getRandomValues&&(e=r.getRandomValues(new Uint8Array(31)));for(var i,o="xxxxxxxx-xxxx-4xxx-yxxx-xxxxxxxxxxxx",a="",c=0;c<o.length;c++)i=o[c],"x"===i?a+=t().toString(16):"y"===i?(i=3&t()|8,a+=i.toString(16)):a+=i;return a}function i(){return a(16)}function o(){return a(32)}function a(t){function e(){return n?15&n[r++]:16*Math.random()|0}var n=null,r=0,i=window.crypto||window.msCrypto;i&&i.getRandomValues&&Uint8Array&&(n=i.getRandomValues(new Uint8Array(31)));for(var o=[],a=0;a<t;a++)o.push(e().toString(16));return o.join("")}e.exports={generateUuid:r,generateSpanId:i,generateTraceId:o}},{}],20:[function(t,e,n){function r(t,e){if(!i)return!1;if(t!==i)return!1;if(!e)return!0;if(!o)return!1;for(var n=o.split("."),r=e.split("."),a=0;a<r.length;a++)if(r[a]!==n[a])return!1;return!0}var i=null,o=null,a=/Version\/(\S+)\s+Safari/;if(navigator.userAgent){var c=navigator.userAgent,s=c.match(a);s&&c.indexOf("Chrome")===-1&&c.indexOf("Chromium")===-1&&(i="Safari",o=s[1])}e.exports={agent:i,version:o,match:r}},{}],21:[function(t,e,n){function r(t){function e(){t(a&&document[a]?document[a]:document[i]?"hidden":"visible")}"addEventListener"in document&&o&&document.addEventListener(o,e,!1)}e.exports=r;var i,o,a;"undefined"!=typeof document.hidden?(i="hidden",o="visibilitychange",a="visibilityState"):"undefined"!=typeof document.msHidden?(i="msHidden",o="msvisibilitychange"):"undefined"!=typeof document.webkitHidden&&(i="webkitHidden",o="webkitvisibilitychange",a="webkitVisibilityState")},{}],22:[function(t,e,n){function r(t,e){var n=[],r="",o=0;for(r in t)i.call(t,r)&&(n[o]=e(r,t[r]),o+=1);return n}var i=Object.prototype.hasOwnProperty;e.exports=r},{}],23:[function(t,e,n){function r(t,e,n){e||(e=0),"undefined"==typeof n&&(n=t?t.length:0);for(var r=-1,i=n-e||0,o=Array(i<0?0:i);++r<i;)o[r]=t[e+r];return o}e.exports=r},{}],24:[function(t,e,n){e.exports={exists:"undefined"!=typeof window.performance&&window.performance.timing&&"undefined"!=typeof window.performance.timing.navigationStart}},{}],ee:[function(t,e,n){function r(){}function i(t){function e(t){return t&&t instanceof r?t:t?s(t,c,o):o()}function n(n,r,i,o){if(!l.aborted||o){t&&t(n,r,i);for(var a=e(i),c=m(n),s=c.length,f=0;f<s;f++)c[f].apply(a,r);var d=u[y[n]];return d&&d.push([x,n,r,a]),a}}function p(t,e){g[t]=m(t).concat(e)}function h(t,e){var n=g[t];if(n)for(var r=0;r<n.length;r++)n[r]===e&&n.splice(r,1)}function m(t){return g[t]||[]}function w(t){return d[t]=d[t]||i(n)}function v(t,e){f(t,function(t,n){e=e||"feature",y[n]=e,e in u||(u[e]=[])})}var g={},y={},x={on:p,addEventListener:p,removeEventListener:h,emit:n,get:w,listeners:m,context:e,buffer:v,abort:a,aborted:!1};return x}function o(){return new r}function a(){(u.api||u.feature)&&(l.aborted=!0,u=l.backlog={})}var c="nr@context",s=t("gos"),f=t(22),u={},d={},l=e.exports=i();l.backlog=u},{}],gos:[function(t,e,n){function r(t,e,n){if(i.call(t,e))return t[e];var r=n();if(Object.defineProperty&&Object.keys)try{return Object.defineProperty(t,e,{value:r,writable:!0,enumerable:!1}),r}catch(o){}return t[e]=r,r}var i=Object.prototype.hasOwnProperty;e.exports=r},{}],handle:[function(t,e,n){function r(t,e,n,r){i.buffer([t],r),i.emit(t,e,n)}var i=t("ee").get("handle");e.exports=r,r.ee=i},{}],id:[function(t,e,n){function r(t){var e=typeof t;return!t||"object"!==e&&"function"!==e?-1:t===window?0:a(t,o,function(){return i++})}var i=1,o="nr@id",a=t("gos");e.exports=r},{}],loader:[function(t,e,n){function r(){if(!E++){var t=b.info=NREUM.info,e=p.getElementsByTagName("script")[0];if(setTimeout(u.abort,3e4),!(t&&t.licenseKey&&t.applicationID&&e))return u.abort();f(y,function(e,n){t[e]||(t[e]=n)});var n=a();s("mark",["onload",n+b.offset],null,"api"),s("timing",["load",n]);var r=p.createElement("script");r.src="https://"+t.agent,e.parentNode.insertBefore(r,e)}}function i(){"complete"===p.readyState&&o()}function o(){s("mark",["domContent",a()+b.offset],null,"api")}function a(){return R.exists&&performance.now?Math.round(performance.now()):(c=Math.max((new Date).getTime(),c))-b.offset}var c=(new Date).getTime(),s=t("handle"),f=t(22),u=t("ee"),d=t(20),l=window,p=l.document,h="addEventListener",m="attachEvent",w=l.XMLHttpRequest,v=w&&w.prototype;NREUM.o={ST:setTimeout,SI:l.setImmediate,CT:clearTimeout,XHR:w,REQ:l.Request,EV:l.Event,PR:l.Promise,MO:l.MutationObserver};var g=""+location,y={beacon:"bam.nr-data.net",errorBeacon:"bam.nr-data.net",agent:"js-agent.newrelic.com/nr-1177.min.js"},x=w&&v&&v[h]&&!/CriOS/.test(navigator.userAgent),b=e.exports={offset:c,now:a,origin:g,features:{},xhrWrappable:x,userAgent:d};t(15),t(18),p[h]?(p[h]("DOMContentLoaded",o,!1),l[h]("load",r,!1)):(p[m]("onreadystatechange",i),l[m]("onload",r)),s("mark",["firstbyte",c],null,"api");var E=0,R=t(24)},{}],"wrap-function":[function(t,e,n){function r(t){return!(t&&t instanceof Function&&t.apply&&!t[a])}var i=t("ee"),o=t(23),a="nr@original",c=Object.prototype.hasOwnProperty,s=!1;e.exports=function(t,e){function n(t,e,n,i){function nrWrapper(){var r,a,c,s;try{a=this,r=o(arguments),c="function"==typeof n?n(r,a):n||{}}catch(f){l([f,"",[r,a,i],c])}u(e+"start",[r,a,i],c);try{return s=t.apply(a,r)}catch(d){throw u(e+"err",[r,a,d],c),d}finally{u(e+"end",[r,a,s],c)}}return r(t)?t:(e||(e=""),nrWrapper[a]=t,d(t,nrWrapper),nrWrapper)}function f(t,e,i,o){i||(i="");var a,c,s,f="-"===i.charAt(0);for(s=0;s<e.length;s++)c=e[s],a=t[c],r(a)||(t[c]=n(a,f?c+i:i,o,c))}function u(n,r,i){if(!s||e){var o=s;s=!0;try{t.emit(n,r,i,e)}catch(a){l([a,n,r,i])}s=o}}function d(t,e){if(Object.defineProperty&&Object.keys)try{var n=Object.keys(t);return n.forEach(function(n){Object.defineProperty(e,n,{get:function(){return t[n]},set:function(e){return t[n]=e,e}})}),e}catch(r){l([r])}for(var i in t)c.call(t,i)&&(e[i]=t[i]);return e}function l(e){try{t.emit("internal-error",e)}catch(n){}}return t||(t=i),n.inPlace=f,n.flag=a,n}},{}]},{},["loader",2,12,4,3]);</script>
<meta http-equiv="Content-Language" content="ko-KR">
<meta name="description" content="(주)매그파이소프트, 웹 /응용프로그램  개발자  모집, 경력:신입/경력, 학력:대학교졸업(4 년)이상, 연봉:면접 후 결정 , 홈페이지:">
<meta name="keywords" content="SI·시스템통합, 솔루션업체, 소프트웨어개발, SM, Java·JSP, .NET, Ajax, Python, 프론트엔드, Java, OpenGL, Oracle, .NET, C#, 토목, 측량·계측, 도로·상하수도, 토목기사, 구조해석, 웹개발, 응용프로그램개발, 토목·조경·도시·측량, 솔루션·SI·ERP·CRM">
<meta name="writer" content="사람인">    <meta property="og:description" content="(주)매그파이소프트, 웹 /응용프로그램  개발자  모집, 경력:신입/경력, 학력:대학교졸업(4년)이상, 연봉:면접 후 결정 , 홈페이지:">
<meta property="og:title" content="[(주)매그파이소프트] 웹 /응용프로그램  개발자  모집(D-11) - 사람인">
<meta property="og:image" content="//www.saraminimage.co.kr/logo/saraminsnslogo.png">
<meta property="og:site_name" content="사람인">
<meta property="og:type" content="website">
<meta property="og:locale" content="ko_KR">
<meta property="fb:app_id" content="1593727887570039">
<meta property="og:image:width" content="200">
<meta property="og:image:height" content="200">    <link href="android-app://kr.co.saramin.brandapp/http/m.saramin.co.kr/job-search/view?rec_idx=38655001&amp;is_apply_statics_auto_focus=" rel="alternate">
<link href="/sri_css/sticky_assist.css?v=20200908103206" media="all" rel="stylesheet" type="text/css">
<link href="ios-app://739013038/http/m.saramin.co.kr/job-search/view?rec_idx=38655001&amp;is_apply_statics_auto_focus=" rel="alternate">
<link href="http://m.saramin.co.kr/job-search/view?rec_idx=38655001&amp;is_apply_statics_auto_focus=" rel="alternate" type="text/html" title="mobile optimized version" media="only screen and (max-width: 640px)">
<link href="/sri_css/layout.css?v=20200908103206" media="all" rel="stylesheet" type="text/css">
<link href="/sri_css/common_ui_keeping.css?v=20200908103206" media="all" rel="stylesheet" type="text/css">
<link href="/sri_css/components.css?v=20200908103206" media="all" rel="stylesheet" type="text/css">
<link href="/sri_css/jobs-view.css?v=20200908103206" media="all" rel="stylesheet" type="text/css">
<link href="/css/sri_mapapi.css?v=20200908103206" media="all" rel="stylesheet" type="text/css">
<link href="/css/nudge/content.css?v=20200908103206" media="all" rel="stylesheet" type="text/css">
<link href="/sri_css/recruit-template.css?v=20200908103206" media="all" rel="stylesheet" type="text/css">
<link href="http://www.saramin.co.kr/zf_user/jobs/view?rec_idx=38655001" rel="canonical">
<link href="/favicon.ico?ver=2" rel="favicon">
<link href="/favicon.ico?ver=2" rel="icon" type="image/x-icon">
<link href="/favicon.ico?ver=2" rel="shortcut icon" type="image/x-icon">        <script type="text/javascript" src="//www.saraminimage.co.kr/js/libs/jquery-1.11.1.min.js"></script>
    <script type="text/javascript">var $j = jQuery.noConflict();</script>
    <script type="text/javascript" src="/js/libs/saramin/common.js?v=20200908163120"></script>
    <!--[if lt IE 9]> <script type="text/javascript" src="//www.saramin.co.kr/js/html5shiv.min.js"></script><![endif]-->
    <script type="text/javascript" src="//www.saraminimage.co.kr/js/libs/jquery.tinyscrollbar.min.js"></script>
    <script type="text/javascript" src="/js/ui-component.js?v=20200908163120"></script>
    <script type="text/javascript" src="/js/layout/default-layout.js?v=20200908163120"></script>
    <script type="text/javascript" src="/js/map/mapRelayControl.js?ts=20200908163120"></script>
<script type="text/javascript" src="/js/libs/gnb-mobile-banner-sms.js?ts=20200908163120"></script>        <script type="text/javascript">
var googleSlotList = {};

var googletag = googletag || {};
googletag.cmd = googletag.cmd || [];

(function() {
var useSSL = 'https:' == document.location.protocol;
var src = (useSSL ? 'https:' : 'http:') + '//www.googletagservices.com/tag/js/gpt.js';
document.write('<scr' + 'ipt src="' + src + '"></scr' + 'ipt>');
})();
</script><script src="http://www.googletagservices.com/tag/js/gpt.js"></script><script src="https://securepubads.g.doubleclick.net/gpt/pubads_impl_2020090201.js?21067391" id="gpt-impl-0.808714624751377" nonce=""></script>

<script type="text/javascript">
googletag.cmd.push(function() {
                        googleSlotList['div-gpt-ad-1511847708022-0'] = googletag.defineSlot('/61280259/1000-list_120x240', [120, 240], 'div-gpt-ad-1511847708022-0').addService(googletag.pubads());
                    googleSlotList['div-gpt-ad-1400664864294-0'] = googletag.defineSlot('/61280259/1000-list_120x600', [120, 600], 'div-gpt-ad-1400664864294-0').addService(googletag.pubads());
                    googleSlotList['div-gpt-ad-1511846653839-0'] = googletag.defineSlot('/61280259/area-list_120x240', [120, 240], 'div-gpt-ad-1511846653839-0').addService(googletag.pubads());
                    googleSlotList['div-gpt-ad-1400664864294-2'] = googletag.defineSlot('/61280259/area-list_120x600', [120, 600], 'div-gpt-ad-1400664864294-2').addService(googletag.pubads());
                    googleSlotList['div-gpt-ad-1400664864294-3'] = googletag.defineSlot('/61280259/area-list_728x90', [728, 90], 'div-gpt-ad-1400664864294-3').addService(googletag.pubads());
                    googleSlotList['div-gpt-ad-1511845706684-0'] = googletag.defineSlot('/61280259/category-list_120x240', [120, 240], 'div-gpt-ad-1511845706684-0').addService(googletag.pubads());
                    googleSlotList['div-gpt-ad-1400664864294-4'] = googletag.defineSlot('/61280259/category-list_120x600', [120, 600], 'div-gpt-ad-1400664864294-4').addService(googletag.pubads());
                    googleSlotList['div-gpt-ad-1400664864294-5'] = googletag.defineSlot('/61280259/category-list_728x90', [728, 90], 'div-gpt-ad-1400664864294-5').addService(googletag.pubads());
                    googleSlotList['div-gpt-ad-1426214085634-0'] = googletag.defineSlot('/61280259/Contest-box_left_307x281', [307, 281], 'div-gpt-ad-1426214085634-0').addService(googletag.pubads());
                    googleSlotList['div-gpt-ad-1426214150723-0'] = googletag.defineSlot('/61280259/Contest-box_middle_307x281', [307, 281], 'div-gpt-ad-1426214150723-0').addService(googletag.pubads());
                    googleSlotList['div-gpt-ad-1426214197444-0'] = googletag.defineSlot('/61280259/Contest-box_right_307x281', [307, 281], 'div-gpt-ad-1426214197444-0').addService(googletag.pubads());
                    googleSlotList['div-gpt-ad-1511845587070-0'] = googletag.defineSlot('/61280259/CS_120x240', [120, 240], 'div-gpt-ad-1511845587070-0').addService(googletag.pubads());
                    googleSlotList['div-gpt-ad-1400664864294-6'] = googletag.defineSlot('/61280259/CS_120x600', [120, 600], 'div-gpt-ad-1400664864294-6').addService(googletag.pubads());
                    googleSlotList['div-gpt-ad-1400664864294-7'] = googletag.defineSlot('/61280259/CS_728x90', [728, 90], 'div-gpt-ad-1400664864294-7').addService(googletag.pubads());
                    googleSlotList['div-gpt-ad-1511846339912-0'] = googletag.defineSlot('/61280259/etc_120x240', [120, 240], 'div-gpt-ad-1511846339912-0').addService(googletag.pubads());
                    googleSlotList['div-gpt-ad-1400664864294-10'] = googletag.defineSlot('/61280259/etc_120x600', [120, 600], 'div-gpt-ad-1400664864294-10').addService(googletag.pubads());
                    googleSlotList['div-gpt-ad-1400664864294-11'] = googletag.defineSlot('/61280259/etc_728x90', [728, 90], 'div-gpt-ad-1400664864294-11').addService(googletag.pubads());
                    googleSlotList['div-gpt-ad-1580945710799-0'] = googletag.defineSlot('/61280259/etc_office_worker_in_120x600', [120, 600], 'div-gpt-ad-1580945710799-0').addService(googletag.pubads());
                    googleSlotList['div-gpt-ad-1550638948072-0'] = googletag.defineSlot('/61280259/Login_728x90', [728, 90], 'div-gpt-ad-1550638948072-0').addService(googletag.pubads());
                    googleSlotList['div-gpt-ad-1400664864294-12'] = googletag.defineSlot('/61280259/logout_120x600', [120, 600], 'div-gpt-ad-1400664864294-12').addService(googletag.pubads());
                    googleSlotList['div-gpt-ad-1400664864294-13'] = googletag.defineSlot('/61280259/logout_728x90', [728, 90], 'div-gpt-ad-1400664864294-13').addService(googletag.pubads());
                    googleSlotList['div-gpt-ad-1594859543669-0'] = googletag.defineSlot('/61280259/Main-Big_468x60', [468, 60], 'div-gpt-ad-1594859543669-0').addService(googletag.pubads());
                    googleSlotList['div-gpt-ad-1425521803564-0'] = googletag.defineSlot('/61280259/Main-Big_543x113', [543, 113], 'div-gpt-ad-1425521803564-0').addService(googletag.pubads());
                    googleSlotList['div-gpt-ad-1426837722822-0'] = googletag.defineSlot('/61280259/Main-image_230x142', [230, 142], 'div-gpt-ad-1426837722822-0').addService(googletag.pubads());
                    googleSlotList['div-gpt-ad-1553056482914-0'] = googletag.defineSlot('/61280259/member_120x240', [120, 240], 'div-gpt-ad-1553056482914-0').addService(googletag.pubads());
                    googleSlotList['div-gpt-ad-1400664864294-14'] = googletag.defineSlot('/61280259/member_120x600', [120, 600], 'div-gpt-ad-1400664864294-14').addService(googletag.pubads());
                    googleSlotList['div-gpt-ad-1400664864294-15'] = googletag.defineSlot('/61280259/member_728x90', [728, 90], 'div-gpt-ad-1400664864294-15').addService(googletag.pubads());
                    googleSlotList['div-gpt-ad-1550543155169-0'] = googletag.defineSlot('/61280259/memcom_120x240', [120, 240], 'div-gpt-ad-1550543155169-0').addService(googletag.pubads());
                    googleSlotList['div-gpt-ad-1400664864294-16'] = googletag.defineSlot('/61280259/memcom_120x600', [120, 600], 'div-gpt-ad-1400664864294-16').addService(googletag.pubads());
                    googleSlotList['div-gpt-ad-1571807667744-0'] = googletag.defineSlot('/61280259/memcom_264x264', [264, 264], 'div-gpt-ad-1571807667744-0').addService(googletag.pubads());
                    googleSlotList['div-gpt-ad-1400664864294-17'] = googletag.defineSlot('/61280259/memcom_728x90', [728, 90], 'div-gpt-ad-1400664864294-17').addService(googletag.pubads());
                    googleSlotList['div-gpt-ad-1511846020570-0'] = googletag.defineSlot('/61280259/profession-list_120x240', [120, 240], 'div-gpt-ad-1511846020570-0').addService(googletag.pubads());
                    googleSlotList['div-gpt-ad-1400664864294-18'] = googletag.defineSlot('/61280259/profession-list_120x600', [120, 600], 'div-gpt-ad-1400664864294-18').addService(googletag.pubads());
                    googleSlotList['div-gpt-ad-1400664864294-19'] = googletag.defineSlot('/61280259/profession-list_728x90', [728, 90], 'div-gpt-ad-1400664864294-19').addService(googletag.pubads());
                    googleSlotList['div-gpt-ad-1400664864294-20'] = googletag.defineSlot('/61280259/rapid-view_120x600', [120, 600], 'div-gpt-ad-1400664864294-20').addService(googletag.pubads());
                    googleSlotList['div-gpt-ad-1511933728215-0'] = googletag.defineSlot('/61280259/recruit-view_120x240', [120, 240], 'div-gpt-ad-1511933728215-0').addService(googletag.pubads());
                    googleSlotList['div-gpt-ad-1400664864294-22'] = googletag.defineSlot('/61280259/recruit-view_120x600', [120, 600], 'div-gpt-ad-1400664864294-22').addService(googletag.pubads());
                    googleSlotList['div-gpt-ad-1547596188605-0'] = googletag.defineSlot('/61280259/recruit-view_250x250', [250, 250], 'div-gpt-ad-1547596188605-0').addService(googletag.pubads());
                    googleSlotList['div-gpt-ad-1400664864294-23'] = googletag.defineSlot('/61280259/recruit-view_728x90', [728, 90], 'div-gpt-ad-1400664864294-23').addService(googletag.pubads());
                    googleSlotList['div-gpt-ad-1374566074903-2'] = googletag.defineSlot('/61280259/SearchLeft120x600', [120, 600], 'div-gpt-ad-1374566074903-2').addService(googletag.pubads());
                    googleSlotList['div-gpt-ad-1384850668630-1'] = googletag.defineSlot('/61280259/SearchTop_468x60', [468, 60], 'div-gpt-ad-1384850668630-1').addService(googletag.pubads());
                    googleSlotList['div-gpt-ad-1550638841234-0'] = googletag.defineSlot('/61280259/successHelper_728x90', [728, 90], 'div-gpt-ad-1550638841234-0').addService(googletag.pubads());
                    googleSlotList['div-gpt-ad-1553056822382-0'] = googletag.defineSlot('/61280259/talent_120x240', [120, 240], 'div-gpt-ad-1553056822382-0').addService(googletag.pubads());
                    googleSlotList['div-gpt-ad-1400664864294-24'] = googletag.defineSlot('/61280259/talent_120x600', [120, 600], 'div-gpt-ad-1400664864294-24').addService(googletag.pubads());
                    googleSlotList['div-gpt-ad-1400664864294-25'] = googletag.defineSlot('/61280259/talent_728x90', [728, 90], 'div-gpt-ad-1400664864294-25').addService(googletag.pubads());
                googletag.enableServices();
    googletag.pubads().addEventListener('slotRenderEnded', function(event) {
        if (!event.isEmpty) {
            var domId = event.slot.getSlotId().getDomId();
            if (!!document.getElementById(domId + '-wrapper')) {
                document.getElementById(domId + '-wrapper').querySelector('.google-standby-banner').style.display = 'none';
                document.getElementById(domId + '-inner').style.display = '';
            }
        }
    });
});
</script>
    <script>

  (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
  (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
  m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
  })(window,document,'script','https://www.google-analytics.com/analytics.js','ga');

  ga('create', 'UA-12546634-1', 'saramin.co.kr');
  ga('require', 'GTM-KN35GK2');
  ga('require','displayfeatures');
  ga('require', 'linkid');
  ga('send', 'pageview');

</script><link rel="preload" href="https://adservice.google.co.kr/adsid/integrator.js?domain=www.saramin.co.kr" as="script"><script type="text/javascript" src="https://adservice.google.co.kr/adsid/integrator.js?domain=www.saramin.co.kr"></script><link rel="preload" href="https://adservice.google.com/adsid/integrator.js?domain=www.saramin.co.kr" as="script"><script type="text/javascript" src="https://adservice.google.com/adsid/integrator.js?domain=www.saramin.co.kr"></script><link rel="prefetch" href="https://4224729d33c9e9c1c3893920c77c0d17.safeframe.googlesyndication.com/safeframe/1-0-37/html/container.html"><link rel="prefetch" href="https://tpc.googlesyndication.com/safeframe/1-0-37/html/container.html"></head>
<body>
    <!-- skip navi -->
    <div id="skipnavigation">
        <a href="#content">본문 바로가기</a>
    </div>
    <!--// skip navi -->
        <header id="sri_header" class="narrow">
    <div class="wrap_logo">
    <a href="/zf_user/" class="link" title="취업의 기준 사람인">
        <img src="http://www.saraminimage.co.kr/sri/common/layout/logo_saramin_201808.png" class="track_event" data-track_event="section|gnb|menu|ci" alt="취업의 기준 사람인">
    </a>
    </div>    <div class="wrap_header">
        <div id="sri_gnb" class="wrap_nav primary">
    <div class="blind">주요서비스</div>
    <ul id="top_menu" class="list_gnb ahm nav" role="navigation">
        <li id="area-nav" class="depth1 is_depth2">
    <a href="/zf_user/area-recruit" class="depth1_link track_event" onfocus="area_nav.focusMenu();" data-track_event="section|gnb|menu|area">지역별</a>
    <div class="wrap_depth2 gnb_sub_menu">
        <div class="gnb_sub_home">
            <div><a href="/zf_user/area-recruit">지역별 홈</a></div>
        </div>
        <div class="column">
            <ul class="list_column_link">
                <li class="mhover" id="">
                    <a href="/zf_user/jobs/list/domestic?loc_mcd=101000" class="depth2_link track_event" data-track_event="main|gnb|area_layer|a101000">서울특별시</a>
                    <ul class="list_depth3 type2">
                        <li><a href="/zf_user/jobs/list/domestic?loc_cd=101010" class="track_event" data-track_event="main|gnb|area_layer|a101010">강남구</a></li>
                        <li><a href="/zf_user/jobs/list/domestic?loc_cd=101020" class="track_event" data-track_event="main|gnb|area_layer|a101020">강동구</a></li>
                        <li><a href="/zf_user/jobs/list/domestic?loc_cd=101030" class="track_event" data-track_event="main|gnb|area_layer|a101030">강북구</a></li>
                        <li><a href="/zf_user/jobs/list/domestic?loc_cd=101040" class="track_event" data-track_event="main|gnb|area_layer|a101040">강서구</a></li>
                        <li><a href="/zf_user/jobs/list/domestic?loc_cd=101050" class="track_event" data-track_event="main|gnb|area_layer|a101050">관악구</a></li>
                        <li><a href="/zf_user/jobs/list/domestic?loc_cd=101060" class="track_event" data-track_event="main|gnb|area_layer|a101060">광진구</a></li>
                        <li><a href="/zf_user/jobs/list/domestic?loc_cd=101070" class="track_event" data-track_event="main|gnb|area_layer|a101070">구로구</a></li>
                        <li><a href="/zf_user/jobs/list/domestic?loc_cd=101080" class="track_event" data-track_event="main|gnb|area_layer|a101080">금천구</a></li>
                        <li><a href="/zf_user/jobs/list/domestic?loc_cd=101090" class="track_event" data-track_event="main|gnb|area_layer|a101090">노원구</a></li>
                        <li><a href="/zf_user/jobs/list/domestic?loc_cd=101100" class="track_event" data-track_event="main|gnb|area_layer|a101100">도봉구</a></li>
                        <li><a href="/zf_user/jobs/list/domestic?loc_cd=101110" class="track_event" data-track_event="main|gnb|area_layer|a101110">동대문구</a></li>
                        <li><a href="/zf_user/jobs/list/domestic?loc_cd=101120" class="track_event" data-track_event="main|gnb|area_layer|a101120">동작구</a></li>
                        <li><a href="/zf_user/jobs/list/domestic?loc_cd=101130" class="track_event" data-track_event="main|gnb|area_layer|a101130">마포구</a></li>
                        <li><a href="/zf_user/jobs/list/domestic?loc_cd=101140" class="track_event" data-track_event="main|gnb|area_layer|a101140">서대문구</a></li>
                        <li><a href="/zf_user/jobs/list/domestic?loc_cd=101150" class="track_event" data-track_event="main|gnb|area_layer|a101150">서초구</a></li>
                        <li><a href="/zf_user/jobs/list/domestic?loc_cd=101160" class="track_event" data-track_event="main|gnb|area_layer|a101160">성동구</a></li>
                        <li><a href="/zf_user/jobs/list/domestic?loc_cd=101170" class="track_event" data-track_event="main|gnb|area_layer|a101170">성북구</a></li>
                        <li><a href="/zf_user/jobs/list/domestic?loc_cd=101180" class="track_event" data-track_event="main|gnb|area_layer|a101180">송파구</a></li>
                        <li><a href="/zf_user/jobs/list/domestic?loc_cd=101190" class="track_event" data-track_event="main|gnb|area_layer|a101190">양천구</a></li>
                        <li><a href="/zf_user/jobs/list/domestic?loc_cd=101200" class="track_event" data-track_event="main|gnb|area_layer|a101200">영등포구</a></li>
                        <li><a href="/zf_user/jobs/list/domestic?loc_cd=101210" class="track_event" data-track_event="main|gnb|area_layer|a101210">용산구</a></li>
                        <li><a href="/zf_user/jobs/list/domestic?loc_cd=101220" class="track_event" data-track_event="main|gnb|area_layer|a101220">은평구</a></li>
                        <li><a href="/zf_user/jobs/list/domestic?loc_cd=101230" class="track_event" data-track_event="main|gnb|area_layer|a101230">종로구</a></li>
                        <li><a href="/zf_user/jobs/list/domestic?loc_cd=101240" class="track_event" data-track_event="main|gnb|area_layer|a101240">중구</a></li>
                        <li><a href="/zf_user/jobs/list/domestic?loc_cd=101250" class="track_event" data-track_event="main|gnb|area_layer|a101250">중랑구</a></li>
                    </ul>
                </li>
                <li id="kyunggido">
                    <a href="/zf_user/jobs/list/domestic?loc_mcd=102000" class="depth2_link track_event" data-track_event="main|gnb|area_layer|a102000">경기도</a>
                    <ul class="list_depth3 type2">
                        <li><a href="/zf_user/jobs/list/domestic?loc_cd=102010" class="track_event" data-track_event="main|gnb|area_layer|a102010">가평군</a></li>
                        <li><a href="/zf_user/jobs/list/domestic?loc_cd=102020" class="track_event" data-track_event="main|gnb|area_layer|a102020">고양시</a></li>
                        <li><a href="/zf_user/jobs/list/domestic?loc_cd=102030" class="track_event" data-track_event="main|gnb|area_layer|a102030">고양시 덕양구</a></li>
                        <li><a href="/zf_user/jobs/list/domestic?loc_cd=102040" class="track_event" data-track_event="main|gnb|area_layer|a102040">고양시 일산동구</a></li>
                        <li><a href="/zf_user/jobs/list/domestic?loc_cd=102050" class="track_event" data-track_event="main|gnb|area_layer|a102050">고양시 일산서구</a></li>
                        <li><a href="/zf_user/jobs/list/domestic?loc_cd=102060" class="track_event" data-track_event="main|gnb|area_layer|a102060">과천시</a></li>
                        <li><a href="/zf_user/jobs/list/domestic?loc_cd=102070" class="track_event" data-track_event="main|gnb|area_layer|a102070">광명시</a></li>
                        <li><a href="/zf_user/jobs/list/domestic?loc_cd=102080" class="track_event" data-track_event="main|gnb|area_layer|a102080">광주시</a></li>
                        <li><a href="/zf_user/jobs/list/domestic?loc_cd=102090" class="track_event" data-track_event="main|gnb|area_layer|a102090">구리시</a></li>
                        <li><a href="/zf_user/jobs/list/domestic?loc_cd=102100" class="track_event" data-track_event="main|gnb|area_layer|a102100">군포시</a></li>
                        <li><a href="/zf_user/jobs/list/domestic?loc_cd=102110" class="track_event" data-track_event="main|gnb|area_layer|a102110">김포시</a></li>
                        <li><a href="/zf_user/jobs/list/domestic?loc_cd=102120" class="track_event" data-track_event="main|gnb|area_layer|a102120">남양주시</a></li>
                        <li><a href="/zf_user/jobs/list/domestic?loc_cd=102130" class="track_event" data-track_event="main|gnb|area_layer|a102130">동두천시</a></li>
                        <li><a href="/zf_user/jobs/list/domestic?loc_cd=102140" class="track_event" data-track_event="main|gnb|area_layer|a102140">부천시</a></li>
                        <li><a href="/zf_user/jobs/list/domestic?loc_cd=102150" class="track_event" data-track_event="main|gnb|area_layer|a102150">부천시 소사구</a></li>
                        <li><a href="/zf_user/jobs/list/domestic?loc_cd=102160" class="track_event" data-track_event="main|gnb|area_layer|a102160">부천시 오정구</a></li>
                        <li><a href="/zf_user/jobs/list/domestic?loc_cd=102170" class="track_event" data-track_event="main|gnb|area_layer|a102170">부천시 원미구</a></li>
                        <li><a href="/zf_user/jobs/list/domestic?loc_cd=102180" class="track_event" data-track_event="main|gnb|area_layer|a102180">성남시</a></li>
                        <li><a href="/zf_user/jobs/list/domestic?loc_cd=102190" class="track_event" data-track_event="main|gnb|area_layer|a102190">성남시 분당구</a></li>
                        <li><a href="/zf_user/jobs/list/domestic?loc_cd=102200" class="track_event" data-track_event="main|gnb|area_layer|a102200">성남시 수정구</a></li>
                        <li><a href="/zf_user/jobs/list/domestic?loc_cd=102210" class="track_event" data-track_event="main|gnb|area_layer|a102210">성남시 중원구</a></li>
                        <li><a href="/zf_user/jobs/list/domestic?loc_cd=102220" class="track_event" data-track_event="main|gnb|area_layer|a102220">수원시</a></li>
                        <li><a href="/zf_user/jobs/list/domestic?loc_cd=102230" class="track_event" data-track_event="main|gnb|area_layer|a102230">수원시 권선구</a></li>
                        <li><a href="/zf_user/jobs/list/domestic?loc_cd=102240" class="track_event" data-track_event="main|gnb|area_layer|a102240">수원시 영통구</a></li>
                        <li><a href="/zf_user/jobs/list/domestic?loc_cd=102250" class="track_event" data-track_event="main|gnb|area_layer|a102250">수원시 장안구</a></li>
                        <li><a href="/zf_user/jobs/list/domestic?loc_cd=102260" class="track_event" data-track_event="main|gnb|area_layer|a102260">수원시 팔달구</a></li>
                        <li><a href="/zf_user/jobs/list/domestic?loc_cd=102270" class="track_event" data-track_event="main|gnb|area_layer|a102270">시흥시</a></li>
                        <li><a href="/zf_user/jobs/list/domestic?loc_cd=102280" class="track_event" data-track_event="main|gnb|area_layer|a102280">안산시</a></li>
                        <li><a href="/zf_user/jobs/list/domestic?loc_cd=102290" class="track_event" data-track_event="main|gnb|area_layer|a102290">안산시 단원구</a></li>
                        <li><a href="/zf_user/jobs/list/domestic?loc_cd=102300" class="track_event" data-track_event="main|gnb|area_layer|a102300">안산시 상록구</a></li>
                        <li><a href="/zf_user/jobs/list/domestic?loc_cd=102310" class="track_event" data-track_event="main|gnb|area_layer|a102310">안성시</a></li>
                        <li><a href="/zf_user/jobs/list/domestic?loc_cd=102320" class="track_event" data-track_event="main|gnb|area_layer|a102320">안양시</a></li>
                        <li><a href="/zf_user/jobs/list/domestic?loc_cd=102330" class="track_event" data-track_event="main|gnb|area_layer|a102330">안양시 동안구</a></li>
                        <li><a href="/zf_user/jobs/list/domestic?loc_cd=102340" class="track_event" data-track_event="main|gnb|area_layer|a102340">안양시 만안구</a></li>
                        <li><a href="/zf_user/jobs/list/domestic?loc_cd=102350" class="track_event" data-track_event="main|gnb|area_layer|a102350">양주시</a></li>
                        <li><a href="/zf_user/jobs/list/domestic?loc_cd=102360" class="track_event" data-track_event="main|gnb|area_layer|a102360">양평군</a></li>
                        <li><a href="/zf_user/jobs/list/domestic?loc_cd=102370" class="track_event" data-track_event="main|gnb|area_layer|a102370">여주시</a></li>
                        <li><a href="/zf_user/jobs/list/domestic?loc_cd=102380" class="track_event" data-track_event="main|gnb|area_layer|a102380">연천군</a></li>
                        <li><a href="/zf_user/jobs/list/domestic?loc_cd=102390" class="track_event" data-track_event="main|gnb|area_layer|a102390">오산시</a></li>
                        <li><a href="/zf_user/jobs/list/domestic?loc_cd=102400" class="track_event" data-track_event="main|gnb|area_layer|a102400">용인시</a></li>
                        <li><a href="/zf_user/jobs/list/domestic?loc_cd=102410" class="track_event" data-track_event="main|gnb|area_layer|a102410">용인시 기흥구</a></li>
                        <li><a href="/zf_user/jobs/list/domestic?loc_cd=102420" class="track_event" data-track_event="main|gnb|area_layer|a102420">용인시 수지구</a></li>
                        <li><a href="/zf_user/jobs/list/domestic?loc_cd=102430" class="track_event" data-track_event="main|gnb|area_layer|a102430">용인시 처인구</a></li>
                        <li><a href="/zf_user/jobs/list/domestic?loc_cd=102440" class="track_event" data-track_event="main|gnb|area_layer|a102440">의왕시</a></li>
                        <li><a href="/zf_user/jobs/list/domestic?loc_cd=102450" class="track_event" data-track_event="main|gnb|area_layer|a102450">의정부시</a></li>
                        <li><a href="/zf_user/jobs/list/domestic?loc_cd=102460" class="track_event" data-track_event="main|gnb|area_layer|a102460">이천시</a></li>
                        <li><a href="/zf_user/jobs/list/domestic?loc_cd=102470" class="track_event" data-track_event="main|gnb|area_layer|a102470">파주시</a></li>
                        <li><a href="/zf_user/jobs/list/domestic?loc_cd=102480" class="track_event" data-track_event="main|gnb|area_layer|a102480">평택시</a></li>
                        <li><a href="/zf_user/jobs/list/domestic?loc_cd=102490" class="track_event" data-track_event="main|gnb|area_layer|a102490">포천시</a></li>
                        <li><a href="/zf_user/jobs/list/domestic?loc_cd=102500" class="track_event" data-track_event="main|gnb|area_layer|a102500">하남시</a></li>
                        <li><a href="/zf_user/jobs/list/domestic?loc_cd=102510" class="track_event" data-track_event="main|gnb|area_layer|a102510">화성시</a></li>
                    </ul>
                </li>
                <li>
                    <a href="/zf_user/jobs/list/domestic?loc_mcd=108000" class="depth2_link track_event" data-track_event="main|gnb|area_layer|a108000">인천광역시</a>
                    <ul class="list_depth3 type2">
                        <li><a href="/zf_user/jobs/list/domestic?loc_cd=108010" class="track_event" data-track_event="main|gnb|area_layer|a108010">강화군</a></li>
                        <li><a href="/zf_user/jobs/list/domestic?loc_cd=108020" class="track_event" data-track_event="main|gnb|area_layer|a108020">계양구</a></li>
                        <li><a href="/zf_user/jobs/list/domestic?loc_cd=108030" class="track_event" data-track_event="main|gnb|area_layer|a108030">미추홀구</a></li>
                        <li><a href="/zf_user/jobs/list/domestic?loc_cd=108040" class="track_event" data-track_event="main|gnb|area_layer|a108040">남동구</a></li>
                        <li><a href="/zf_user/jobs/list/domestic?loc_cd=108050" class="track_event" data-track_event="main|gnb|area_layer|a108050">동구</a></li>
                        <li><a href="/zf_user/jobs/list/domestic?loc_cd=108060" class="track_event" data-track_event="main|gnb|area_layer|a108060">부평구</a></li>
                        <li><a href="/zf_user/jobs/list/domestic?loc_cd=108070" class="track_event" data-track_event="main|gnb|area_layer|a108070">서구</a></li>
                        <li><a href="/zf_user/jobs/list/domestic?loc_cd=108080" class="track_event" data-track_event="main|gnb|area_layer|a108080">연수구</a></li>
                        <li><a href="/zf_user/jobs/list/domestic?loc_cd=108090" class="track_event" data-track_event="main|gnb|area_layer|a108090">옹진군</a></li>
                        <li><a href="/zf_user/jobs/list/domestic?loc_cd=108100" class="track_event" data-track_event="main|gnb|area_layer|a108100">중구</a></li>
                    </ul>
                </li>
                <li>
                    <a href="/zf_user/jobs/list/domestic?loc_mcd=106000" class="depth2_link track_event" data-track_event="main|gnb|area_layer|a106000">부산광역시</a>
                    <ul class="list_depth3 type2">
                        <li><a href="/zf_user/jobs/list/domestic?loc_cd=106010" class="track_event" data-track_event="main|gnb|area_layer|a106010">강서구</a></li>
                        <li><a href="/zf_user/jobs/list/domestic?loc_cd=106020" class="track_event" data-track_event="main|gnb|area_layer|a106020">금정구</a></li>
                        <li><a href="/zf_user/jobs/list/domestic?loc_cd=106030" class="track_event" data-track_event="main|gnb|area_layer|a106030">기장군</a></li>
                        <li><a href="/zf_user/jobs/list/domestic?loc_cd=106040" class="track_event" data-track_event="main|gnb|area_layer|a106040">남구</a></li>
                        <li><a href="/zf_user/jobs/list/domestic?loc_cd=106050" class="track_event" data-track_event="main|gnb|area_layer|a106050">동구</a></li>
                        <li><a href="/zf_user/jobs/list/domestic?loc_cd=106060" class="track_event" data-track_event="main|gnb|area_layer|a106060">동래구</a></li>
                        <li><a href="/zf_user/jobs/list/domestic?loc_cd=106070" class="track_event" data-track_event="main|gnb|area_layer|a106070">부산진구</a></li>
                        <li><a href="/zf_user/jobs/list/domestic?loc_cd=106080" class="track_event" data-track_event="main|gnb|area_layer|a106080">북구</a></li>
                        <li><a href="/zf_user/jobs/list/domestic?loc_cd=106090" class="track_event" data-track_event="main|gnb|area_layer|a106090">사상구</a></li>
                        <li><a href="/zf_user/jobs/list/domestic?loc_cd=106100" class="track_event" data-track_event="main|gnb|area_layer|a106100">사하구</a></li>
                        <li><a href="/zf_user/jobs/list/domestic?loc_cd=106110" class="track_event" data-track_event="main|gnb|area_layer|a106110">서구</a></li>
                        <li><a href="/zf_user/jobs/list/domestic?loc_cd=106120" class="track_event" data-track_event="main|gnb|area_layer|a106120">수영구</a></li>
                        <li><a href="/zf_user/jobs/list/domestic?loc_cd=106130" class="track_event" data-track_event="main|gnb|area_layer|a106130">연제구</a></li>
                        <li><a href="/zf_user/jobs/list/domestic?loc_cd=106140" class="track_event" data-track_event="main|gnb|area_layer|a106140">영도구</a></li>
                        <li><a href="/zf_user/jobs/list/domestic?loc_cd=106150" class="track_event" data-track_event="main|gnb|area_layer|a106150">중구</a></li>
                        <li><a href="/zf_user/jobs/list/domestic?loc_cd=106160" class="track_event" data-track_event="main|gnb|area_layer|a106160">해운대구</a></li>
                    </ul>
                </li>
                <li>
                    <a href="/zf_user/jobs/list/domestic?loc_mcd=104000" class="depth2_link track_event" data-track_event="main|gnb|area_layer|a104000">대구광역시</a>
                    <ul class="list_depth3 type2">
                        <li><a href="/zf_user/jobs/list/domestic?loc_cd=104010" class="track_event" data-track_event="main|gnb|area_layer|a104010">남구</a></li>
                        <li><a href="/zf_user/jobs/list/domestic?loc_cd=104020" class="track_event" data-track_event="main|gnb|area_layer|a104020">달서구</a></li>
                        <li><a href="/zf_user/jobs/list/domestic?loc_cd=104030" class="track_event" data-track_event="main|gnb|area_layer|a104030">달성군</a></li>
                        <li><a href="/zf_user/jobs/list/domestic?loc_cd=104040" class="track_event" data-track_event="main|gnb|area_layer|a104040">동구</a></li>
                        <li><a href="/zf_user/jobs/list/domestic?loc_cd=104050" class="track_event" data-track_event="main|gnb|area_layer|a104050">북구</a></li>
                        <li><a href="/zf_user/jobs/list/domestic?loc_cd=104060" class="track_event" data-track_event="main|gnb|area_layer|a104060">서구</a></li>
                        <li><a href="/zf_user/jobs/list/domestic?loc_cd=104070" class="track_event" data-track_event="main|gnb|area_layer|a104070">수성구</a></li>
                        <li><a href="/zf_user/jobs/list/domestic?loc_cd=104080" class="track_event" data-track_event="main|gnb|area_layer|a104080">중구</a></li>
                    </ul>
                </li>
                <li>
                    <a href="/zf_user/jobs/list/domestic?loc_mcd=105000" class="depth2_link track_event" data-track_event="main|gnb|area_layer|a105000">대전광역시</a>
                    <ul class="list_depth3 type2">
                        <li><a href="/zf_user/jobs/list/domestic?loc_cd=105010" class="track_event" data-track_event="main|gnb|area_layer|a105010">대덕구</a></li>
                        <li><a href="/zf_user/jobs/list/domestic?loc_cd=105020" class="track_event" data-track_event="main|gnb|area_layer|a105020">동구</a></li>
                        <li><a href="/zf_user/jobs/list/domestic?loc_cd=105030" class="track_event" data-track_event="main|gnb|area_layer|a105030">서구</a></li>
                        <li><a href="/zf_user/jobs/list/domestic?loc_cd=105040" class="track_event" data-track_event="main|gnb|area_layer|a105040">유성구</a></li>
                        <li><a href="/zf_user/jobs/list/domestic?loc_cd=105050" class="track_event" data-track_event="main|gnb|area_layer|a105050">중구</a></li>
                    </ul>
                </li>
                <li>
                    <a href="/zf_user/jobs/list/domestic?loc_mcd=103000" class="depth2_link track_event" data-track_event="main|gnb|area_layer|a103000">광주광역시</a>
                    <ul class="list_depth3 type2">
                        <li><a href="/zf_user/jobs/list/domestic?loc_cd=103010" class="track_event" data-track_event="main|gnb|area_layer|a103010">광산구</a></li>
                        <li><a href="/zf_user/jobs/list/domestic?loc_cd=103020" class="track_event" data-track_event="main|gnb|area_layer|a103020">남구</a></li>
                        <li><a href="/zf_user/jobs/list/domestic?loc_cd=103030" class="track_event" data-track_event="main|gnb|area_layer|a103030">동구</a></li>
                        <li><a href="/zf_user/jobs/list/domestic?loc_cd=103040" class="track_event" data-track_event="main|gnb|area_layer|a103040">북구</a></li>
                        <li><a href="/zf_user/jobs/list/domestic?loc_cd=103050" class="track_event" data-track_event="main|gnb|area_layer|a103050">서구</a></li>
                    </ul>
                </li>
                <li>
                    <a href="/zf_user/jobs/list/domestic?loc_mcd=107000" class="depth2_link track_event" data-track_event="main|gnb|area_layer|a107000">울산광역시</a>
                    <ul class="list_depth3 type2">
                        <li><a href="/zf_user/jobs/list/domestic?loc_cd=107010" class="track_event" data-track_event="main|gnb|area_layer|a107010">남구</a></li>
                        <li><a href="/zf_user/jobs/list/domestic?loc_cd=107020" class="track_event" data-track_event="main|gnb|area_layer|a107020">동구</a></li>
                        <li><a href="/zf_user/jobs/list/domestic?loc_cd=107030" class="track_event" data-track_event="main|gnb|area_layer|a107030">북구</a></li>
                        <li><a href="/zf_user/jobs/list/domestic?loc_cd=107040" class="track_event" data-track_event="main|gnb|area_layer|a107040">울주군</a></li>
                        <li><a href="/zf_user/jobs/list/domestic?loc_cd=107050" class="track_event" data-track_event="main|gnb|area_layer|a107050">중구</a></li>
                    </ul>
                </li>
                <li class="reduce_ltp" id="">
                    <a href="/zf_user/jobs/list/domestic?loc_mcd=118000" class="depth2_link track_event" data-track_event="main|gnb|area_layer|a118000">세종특별자치시</a>
                    <ul class="list_depth3 type2">
                        <li><a href="/zf_user/jobs/list/domestic?loc_cd=118000" class="track_event" data-track_event="main|gnb|area_layer|a118000">세종특별자치시</a></li>
                    </ul>
                </li>
                <li>
                    <a href="/zf_user/jobs/list/domestic?loc_mcd=109000" class="depth2_link track_event" data-track_event="main|gnb|area_layer|a109000">강원도</a>
                    <ul class="list_depth3 type2">
                        <li><a href="/zf_user/jobs/list/domestic?loc_cd=109010" class="track_event" data-track_event="main|gnb|area_layer|a109010">강릉시</a></li>
                        <li><a href="/zf_user/jobs/list/domestic?loc_cd=109020" class="track_event" data-track_event="main|gnb|area_layer|a109020">고성군</a></li>
                        <li><a href="/zf_user/jobs/list/domestic?loc_cd=109030" class="track_event" data-track_event="main|gnb|area_layer|a109030">동해시</a></li>
                        <li><a href="/zf_user/jobs/list/domestic?loc_cd=109040" class="track_event" data-track_event="main|gnb|area_layer|a109040">삼척시</a></li>
                        <li><a href="/zf_user/jobs/list/domestic?loc_cd=109050" class="track_event" data-track_event="main|gnb|area_layer|a109050">속초시</a></li>
                        <li><a href="/zf_user/jobs/list/domestic?loc_cd=109060" class="track_event" data-track_event="main|gnb|area_layer|a109060">양구군</a></li>
                        <li><a href="/zf_user/jobs/list/domestic?loc_cd=109070" class="track_event" data-track_event="main|gnb|area_layer|a109070">양양군</a></li>
                        <li><a href="/zf_user/jobs/list/domestic?loc_cd=109080" class="track_event" data-track_event="main|gnb|area_layer|a109080">영월군</a></li>
                        <li><a href="/zf_user/jobs/list/domestic?loc_cd=109090" class="track_event" data-track_event="main|gnb|area_layer|a109090">원주시</a></li>
                        <li><a href="/zf_user/jobs/list/domestic?loc_cd=109100" class="track_event" data-track_event="main|gnb|area_layer|a109100">인제군</a></li>
                        <li><a href="/zf_user/jobs/list/domestic?loc_cd=109110" class="track_event" data-track_event="main|gnb|area_layer|a109110">정선군</a></li>
                        <li><a href="/zf_user/jobs/list/domestic?loc_cd=109120" class="track_event" data-track_event="main|gnb|area_layer|a109120">철원군</a></li>
                        <li><a href="/zf_user/jobs/list/domestic?loc_cd=109130" class="track_event" data-track_event="main|gnb|area_layer|a109130">춘천시</a></li>
                        <li><a href="/zf_user/jobs/list/domestic?loc_cd=109140" class="track_event" data-track_event="main|gnb|area_layer|a109140">태백시</a></li>
                        <li><a href="/zf_user/jobs/list/domestic?loc_cd=109150" class="track_event" data-track_event="main|gnb|area_layer|a109150">평창군</a></li>
                        <li><a href="/zf_user/jobs/list/domestic?loc_cd=109160" class="track_event" data-track_event="main|gnb|area_layer|a109160">홍천군</a></li>
                        <li><a href="/zf_user/jobs/list/domestic?loc_cd=109170" class="track_event" data-track_event="main|gnb|area_layer|a109170">화천군</a></li>
                        <li><a href="/zf_user/jobs/list/domestic?loc_cd=109180" class="track_event" data-track_event="main|gnb|area_layer|a109180">횡성군</a></li>
                    </ul>
                </li>
                <li>
                    <a href="/zf_user/jobs/list/domestic?loc_mcd=110000" class="depth2_link track_event" data-track_event="main|gnb|area_layer|a110000">경상남도</a>
                    <ul class="list_depth3 type2">
                        <li><a href="/zf_user/jobs/list/domestic?loc_cd=110010" class="track_event" data-track_event="main|gnb|area_layer|a110010">거제시</a></li>
                        <li><a href="/zf_user/jobs/list/domestic?loc_cd=110020" class="track_event" data-track_event="main|gnb|area_layer|a110020">거창군</a></li>
                        <li><a href="/zf_user/jobs/list/domestic?loc_cd=110030" class="track_event" data-track_event="main|gnb|area_layer|a110030">고성군</a></li>
                        <li><a href="/zf_user/jobs/list/domestic?loc_cd=110040" class="track_event" data-track_event="main|gnb|area_layer|a110040">김해시</a></li>
                        <li><a href="/zf_user/jobs/list/domestic?loc_cd=110050" class="track_event" data-track_event="main|gnb|area_layer|a110050">남해군</a></li>
                        <li><a href="/zf_user/jobs/list/domestic?loc_cd=110053" class="track_event" data-track_event="main|gnb|area_layer|a110060">창원시 마산회원구</a></li>
                        <li><a href="/zf_user/jobs/list/domestic?loc_cd=110055" class="track_event" data-track_event="main|gnb|area_layer|a110070">창원시 마산합포구</a></li>
                        <li><a href="/zf_user/jobs/list/domestic?loc_cd=110057" class="track_event" data-track_event="main|gnb|area_layer|a110080">창원시 성산구</a></li>
                        <li><a href="/zf_user/jobs/list/domestic?loc_cd=110059" class="track_event" data-track_event="main|gnb|area_layer|a110090">창원시 의창구</a></li>
                        <li><a href="/zf_user/jobs/list/domestic?loc_cd=110070" class="track_event" data-track_event="main|gnb|area_layer|a110100">밀양시</a></li>
                        <li><a href="/zf_user/jobs/list/domestic?loc_cd=110080" class="track_event" data-track_event="main|gnb|area_layer|a110110">사천시</a></li>
                        <li><a href="/zf_user/jobs/list/domestic?loc_cd=110090" class="track_event" data-track_event="main|gnb|area_layer|a110120">산청군</a></li>
                        <li><a href="/zf_user/jobs/list/domestic?loc_cd=110100" class="track_event" data-track_event="main|gnb|area_layer|a110130">양산시</a></li>
                        <li><a href="/zf_user/jobs/list/domestic?loc_cd=110110" class="track_event" data-track_event="main|gnb|area_layer|a110140">의령군</a></li>
                        <li><a href="/zf_user/jobs/list/domestic?loc_cd=110120" class="track_event" data-track_event="main|gnb|area_layer|a110150">진주시</a></li>
                        <li><a href="/zf_user/jobs/list/domestic?loc_cd=110130" class="track_event" data-track_event="main|gnb|area_layer|a110160">창원시 진해구</a></li>
                        <li><a href="/zf_user/jobs/list/domestic?loc_cd=110140" class="track_event" data-track_event="main|gnb|area_layer|a110170">창녕군</a></li>
                        <li><a href="/zf_user/jobs/list/domestic?loc_cd=110150" class="track_event" data-track_event="main|gnb|area_layer|a110180">창원시</a></li>
                        <li><a href="/zf_user/jobs/list/domestic?loc_cd=110160" class="track_event" data-track_event="main|gnb|area_layer|a110190">통영시</a></li>
                        <li><a href="/zf_user/jobs/list/domestic?loc_cd=110170" class="track_event" data-track_event="main|gnb|area_layer|a110200">하동군</a></li>
                        <li><a href="/zf_user/jobs/list/domestic?loc_cd=110180" class="track_event" data-track_event="main|gnb|area_layer|a110210">함안군</a></li>
                        <li><a href="/zf_user/jobs/list/domestic?loc_cd=110190" class="track_event" data-track_event="main|gnb|area_layer|a110220">함양군</a></li>
                        <li><a href="/zf_user/jobs/list/domestic?loc_cd=110200" class="track_event" data-track_event="main|gnb|area_layer|a110230">합천군</a></li>
                    </ul>
                </li>
                <li>
                    <a href="/zf_user/jobs/list/domestic?loc_mcd=111000" class="depth2_link track_event" data-track_event="main|gnb|area_layer|a111000">경상북도</a>
                    <ul class="list_depth3 type2">
                        <li><a href="/zf_user/jobs/list/domestic?loc_cd=111010" class="track_event" data-track_event="main|gnb|area_layer|a111010">경산시</a></li>
                        <li><a href="/zf_user/jobs/list/domestic?loc_cd=111020" class="track_event" data-track_event="main|gnb|area_layer|a111020">경주시</a></li>
                        <li><a href="/zf_user/jobs/list/domestic?loc_cd=111030" class="track_event" data-track_event="main|gnb|area_layer|a111030">고령군</a></li>
                        <li><a href="/zf_user/jobs/list/domestic?loc_cd=111040" class="track_event" data-track_event="main|gnb|area_layer|a111040">구미시</a></li>
                        <li><a href="/zf_user/jobs/list/domestic?loc_cd=111050" class="track_event" data-track_event="main|gnb|area_layer|a111050">군위군</a></li>
                        <li><a href="/zf_user/jobs/list/domestic?loc_cd=111060" class="track_event" data-track_event="main|gnb|area_layer|a111060">김천시</a></li>
                        <li><a href="/zf_user/jobs/list/domestic?loc_cd=111070" class="track_event" data-track_event="main|gnb|area_layer|a111070">문경시</a></li>
                        <li><a href="/zf_user/jobs/list/domestic?loc_cd=111080" class="track_event" data-track_event="main|gnb|area_layer|a111080">봉화군</a></li>
                        <li><a href="/zf_user/jobs/list/domestic?loc_cd=111090" class="track_event" data-track_event="main|gnb|area_layer|a111090">상주시</a></li>
                        <li><a href="/zf_user/jobs/list/domestic?loc_cd=111100" class="track_event" data-track_event="main|gnb|area_layer|a111100">성주군</a></li>
                        <li><a href="/zf_user/jobs/list/domestic?loc_cd=111110" class="track_event" data-track_event="main|gnb|area_layer|a111110">안동시</a></li>
                        <li><a href="/zf_user/jobs/list/domestic?loc_cd=111120" class="track_event" data-track_event="main|gnb|area_layer|a111120">영덕군</a></li>
                        <li><a href="/zf_user/jobs/list/domestic?loc_cd=111130" class="track_event" data-track_event="main|gnb|area_layer|a111130">영양군</a></li>
                        <li><a href="/zf_user/jobs/list/domestic?loc_cd=111140" class="track_event" data-track_event="main|gnb|area_layer|a111140">영주시</a></li>
                        <li><a href="/zf_user/jobs/list/domestic?loc_cd=111150" class="track_event" data-track_event="main|gnb|area_layer|a111150">영천시</a></li>
                        <li><a href="/zf_user/jobs/list/domestic?loc_cd=111160" class="track_event" data-track_event="main|gnb|area_layer|a111160">예천군</a></li>
                        <li><a href="/zf_user/jobs/list/domestic?loc_cd=111170" class="track_event" data-track_event="main|gnb|area_layer|a111170">울릉군</a></li>
                        <li><a href="/zf_user/jobs/list/domestic?loc_cd=111180" class="track_event" data-track_event="main|gnb|area_layer|a111180">울진군</a></li>
                        <li><a href="/zf_user/jobs/list/domestic?loc_cd=111190" class="track_event" data-track_event="main|gnb|area_layer|a111190">의성군</a></li>
                        <li><a href="/zf_user/jobs/list/domestic?loc_cd=111200" class="track_event" data-track_event="main|gnb|area_layer|a111200">청도군</a></li>
                        <li><a href="/zf_user/jobs/list/domestic?loc_cd=111210" class="track_event" data-track_event="main|gnb|area_layer|a111210">청송군</a></li>
                        <li><a href="/zf_user/jobs/list/domestic?loc_cd=111220" class="track_event" data-track_event="main|gnb|area_layer|a111220">칠곡군</a></li>
                        <li><a href="/zf_user/jobs/list/domestic?loc_cd=111230" class="track_event" data-track_event="main|gnb|area_layer|a111230">포항시</a></li>
                        <li><a href="/zf_user/jobs/list/domestic?loc_cd=111240" class="track_event" data-track_event="main|gnb|area_layer|a111240">포항시 남구</a></li>
                        <li><a href="/zf_user/jobs/list/domestic?loc_cd=111250" class="track_event" data-track_event="main|gnb|area_layer|a111250">포항시 북구</a></li>
                    </ul>
                </li>
                <li>
                    <a href="/zf_user/jobs/list/domestic?loc_mcd=112000" class="depth2_link track_event" data-track_event="main|gnb|area_layer|a112000">전라남도</a>
                    <ul class="list_depth3 type2">
                        <li><a href="/zf_user/jobs/list/domestic?loc_cd=112010" class="track_event" data-track_event="main|gnb|area_layer|a112010">강진군</a></li>
                        <li><a href="/zf_user/jobs/list/domestic?loc_cd=112020" class="track_event" data-track_event="main|gnb|area_layer|a112020">고흥군</a></li>
                        <li><a href="/zf_user/jobs/list/domestic?loc_cd=112030" class="track_event" data-track_event="main|gnb|area_layer|a112030">곡성군</a></li>
                        <li><a href="/zf_user/jobs/list/domestic?loc_cd=112040" class="track_event" data-track_event="main|gnb|area_layer|a112040">광양시</a></li>
                        <li><a href="/zf_user/jobs/list/domestic?loc_cd=112050" class="track_event" data-track_event="main|gnb|area_layer|a112050">구례군</a></li>
                        <li><a href="/zf_user/jobs/list/domestic?loc_cd=112060" class="track_event" data-track_event="main|gnb|area_layer|a112060">나주시</a></li>
                        <li><a href="/zf_user/jobs/list/domestic?loc_cd=112070" class="track_event" data-track_event="main|gnb|area_layer|a112070">담양군</a></li>
                        <li><a href="/zf_user/jobs/list/domestic?loc_cd=112080" class="track_event" data-track_event="main|gnb|area_layer|a112080">목포시</a></li>
                        <li><a href="/zf_user/jobs/list/domestic?loc_cd=112090" class="track_event" data-track_event="main|gnb|area_layer|a112090">무안군</a></li>
                        <li><a href="/zf_user/jobs/list/domestic?loc_cd=112100" class="track_event" data-track_event="main|gnb|area_layer|a112100">보성군</a></li>
                        <li><a href="/zf_user/jobs/list/domestic?loc_cd=112110" class="track_event" data-track_event="main|gnb|area_layer|a112110">순천시</a></li>
                        <li><a href="/zf_user/jobs/list/domestic?loc_cd=112120" class="track_event" data-track_event="main|gnb|area_layer|a112120">신안군</a></li>
                        <li><a href="/zf_user/jobs/list/domestic?loc_cd=112130" class="track_event" data-track_event="main|gnb|area_layer|a112130">여수시</a></li>
                        <li><a href="/zf_user/jobs/list/domestic?loc_cd=112140" class="track_event" data-track_event="main|gnb|area_layer|a112140">영광군</a></li>
                        <li><a href="/zf_user/jobs/list/domestic?loc_cd=112150" class="track_event" data-track_event="main|gnb|area_layer|a112150">영암군</a></li>
                        <li><a href="/zf_user/jobs/list/domestic?loc_cd=112160" class="track_event" data-track_event="main|gnb|area_layer|a112160">완도군</a></li>
                        <li><a href="/zf_user/jobs/list/domestic?loc_cd=112170" class="track_event" data-track_event="main|gnb|area_layer|a112170">장성군</a></li>
                        <li><a href="/zf_user/jobs/list/domestic?loc_cd=112180" class="track_event" data-track_event="main|gnb|area_layer|a112180">장흥군</a></li>
                        <li><a href="/zf_user/jobs/list/domestic?loc_cd=112190" class="track_event" data-track_event="main|gnb|area_layer|a112190">진도군</a></li>
                        <li><a href="/zf_user/jobs/list/domestic?loc_cd=112200" class="track_event" data-track_event="main|gnb|area_layer|a112200">함평군</a></li>
                        <li><a href="/zf_user/jobs/list/domestic?loc_cd=112210" class="track_event" data-track_event="main|gnb|area_layer|a112210">해남군</a></li>
                        <li><a href="/zf_user/jobs/list/domestic?loc_cd=112220" class="track_event" data-track_event="main|gnb|area_layer|a112220">화순군</a></li>
                    </ul>
                </li>
                <li>
                    <a href="/zf_user/jobs/list/domestic?loc_mcd=113000" class="depth2_link track_event" data-track_event="main|gnb|area_layer|a113000">전라북도</a>
                    <ul class="list_depth3 type2">
                        <li><a href="/zf_user/jobs/list/domestic?loc_cd=113010" class="track_event" data-track_event="main|gnb|area_layer|a113010">고창군</a></li>
                        <li><a href="/zf_user/jobs/list/domestic?loc_cd=113020" class="track_event" data-track_event="main|gnb|area_layer|a113020">군산시</a></li>
                        <li><a href="/zf_user/jobs/list/domestic?loc_cd=113030" class="track_event" data-track_event="main|gnb|area_layer|a113030">김제시</a></li>
                        <li><a href="/zf_user/jobs/list/domestic?loc_cd=113040" class="track_event" data-track_event="main|gnb|area_layer|a113040">남원시</a></li>
                        <li><a href="/zf_user/jobs/list/domestic?loc_cd=113050" class="track_event" data-track_event="main|gnb|area_layer|a113050">무주군</a></li>
                        <li><a href="/zf_user/jobs/list/domestic?loc_cd=113060" class="track_event" data-track_event="main|gnb|area_layer|a113060">부안군</a></li>
                        <li><a href="/zf_user/jobs/list/domestic?loc_cd=113070" class="track_event" data-track_event="main|gnb|area_layer|a113070">순창군</a></li>
                        <li><a href="/zf_user/jobs/list/domestic?loc_cd=113080" class="track_event" data-track_event="main|gnb|area_layer|a113080">완주군</a></li>
                        <li><a href="/zf_user/jobs/list/domestic?loc_cd=113090" class="track_event" data-track_event="main|gnb|area_layer|a113090">익산시</a></li>
                        <li><a href="/zf_user/jobs/list/domestic?loc_cd=113100" class="track_event" data-track_event="main|gnb|area_layer|a113100">임실군</a></li>
                        <li><a href="/zf_user/jobs/list/domestic?loc_cd=113110" class="track_event" data-track_event="main|gnb|area_layer|a113110">장수군</a></li>
                        <li><a href="/zf_user/jobs/list/domestic?loc_cd=113120" class="track_event" data-track_event="main|gnb|area_layer|a113120">전주시</a></li>
                        <li><a href="/zf_user/jobs/list/domestic?loc_cd=113130" class="track_event" data-track_event="main|gnb|area_layer|a113130">전주시 덕진구</a></li>
                        <li><a href="/zf_user/jobs/list/domestic?loc_cd=113140" class="track_event" data-track_event="main|gnb|area_layer|a113140">전주시 완산구</a></li>
                        <li><a href="/zf_user/jobs/list/domestic?loc_cd=113150" class="track_event" data-track_event="main|gnb|area_layer|a113150">정읍시</a></li>
                        <li><a href="/zf_user/jobs/list/domestic?loc_cd=113160" class="track_event" data-track_event="main|gnb|area_layer|a113160">진안군</a></li>
                    </ul>
                </li>
                <li>
                    <a href="/zf_user/jobs/list/domestic?loc_mcd=115000" class="depth2_link track_event" data-track_event="main|gnb|area_layer|a115000">충청남도</a>
                    <ul class="list_depth3 type2">
                        <li><a href="/zf_user/jobs/list/domestic?loc_cd=115010" class="track_event" data-track_event="main|gnb|area_layer|a115010">계룡시</a></li>
                        <li><a href="/zf_user/jobs/list/domestic?loc_cd=115020" class="track_event" data-track_event="main|gnb|area_layer|a115020">공주시</a></li>
                        <li><a href="/zf_user/jobs/list/domestic?loc_cd=115030" class="track_event" data-track_event="main|gnb|area_layer|a115030">금산군</a></li>
                        <li><a href="/zf_user/jobs/list/domestic?loc_cd=115040" class="track_event" data-track_event="main|gnb|area_layer|a115040">논산시</a></li>
                        <li><a href="/zf_user/jobs/list/domestic?loc_cd=115050" class="track_event" data-track_event="main|gnb|area_layer|a115050">당진시</a></li>
                        <li><a href="/zf_user/jobs/list/domestic?loc_cd=115060" class="track_event" data-track_event="main|gnb|area_layer|a115060">보령시</a></li>
                        <li><a href="/zf_user/jobs/list/domestic?loc_cd=115070" class="track_event" data-track_event="main|gnb|area_layer|a115070">부여군</a></li>
                        <li><a href="/zf_user/jobs/list/domestic?loc_cd=115080" class="track_event" data-track_event="main|gnb|area_layer|a115080">서산시</a></li>
                        <li><a href="/zf_user/jobs/list/domestic?loc_cd=115090" class="track_event" data-track_event="main|gnb|area_layer|a115090">서천군</a></li>
                        <li><a href="/zf_user/jobs/list/domestic?loc_cd=115100" class="track_event" data-track_event="main|gnb|area_layer|a115100">아산시</a></li>
                        <li><a href="/zf_user/jobs/list/domestic?loc_cd=115120" class="track_event" data-track_event="main|gnb|area_layer|a115110">예산군</a></li>
                        <li><a href="/zf_user/jobs/list/domestic?loc_cd=115130" class="track_event" data-track_event="main|gnb|area_layer|a115120">천안시</a></li>
                        <li><a href="/zf_user/jobs/list/domestic?loc_cd=115133" class="track_event" data-track_event="main|gnb|area_layer|a115130">천안시 동남구</a></li>
                        <li><a href="/zf_user/jobs/list/domestic?loc_cd=115135" class="track_event" data-track_event="main|gnb|area_layer|a115140">천안시 서북구</a></li>
                        <li><a href="/zf_user/jobs/list/domestic?loc_cd=115140" class="track_event" data-track_event="main|gnb|area_layer|a115150">청양군</a></li>
                        <li><a href="/zf_user/jobs/list/domestic?loc_cd=115150" class="track_event" data-track_event="main|gnb|area_layer|a115160">태안군</a></li>
                        <li><a href="/zf_user/jobs/list/domestic?loc_cd=115160" class="track_event" data-track_event="main|gnb|area_layer|a115170">홍성군</a></li>
                    </ul>
                </li>
                <li>
                    <a href="/zf_user/jobs/list/domestic?loc_mcd=114000" class="depth2_link track_event" data-track_event="main|gnb|area_layer|a114000">충청북도</a>
                    <ul class="list_depth3 type2">
                        <li><a href="/zf_user/jobs/list/domestic?loc_cd=114010" class="track_event" data-track_event="main|gnb|area_layer|a114010">괴산군</a></li>
                        <li><a href="/zf_user/jobs/list/domestic?loc_cd=114020" class="track_event" data-track_event="main|gnb|area_layer|a114020">단양군</a></li>
                        <li><a href="/zf_user/jobs/list/domestic?loc_cd=114030" class="track_event" data-track_event="main|gnb|area_layer|a114030">보은군</a></li>
                        <li><a href="/zf_user/jobs/list/domestic?loc_cd=114040" class="track_event" data-track_event="main|gnb|area_layer|a114040">영동군</a></li>
                        <li><a href="/zf_user/jobs/list/domestic?loc_cd=114050" class="track_event" data-track_event="main|gnb|area_layer|a114050">옥천군</a></li>
                        <li><a href="/zf_user/jobs/list/domestic?loc_cd=114060" class="track_event" data-track_event="main|gnb|area_layer|a114060">음성군</a></li>
                        <li><a href="/zf_user/jobs/list/domestic?loc_cd=114070" class="track_event" data-track_event="main|gnb|area_layer|a114070">제천시</a></li>
                        <li><a href="/zf_user/jobs/list/domestic?loc_cd=114080" class="track_event" data-track_event="main|gnb|area_layer|a114080">증평군</a></li>
                        <li><a href="/zf_user/jobs/list/domestic?loc_cd=114090" class="track_event" data-track_event="main|gnb|area_layer|a114090">진천군</a></li>
                        <li><a href="/zf_user/jobs/list/domestic?loc_cd=114110" class="track_event" data-track_event="main|gnb|area_layer|a114100">청주시</a></li>
                        <li><a href="/zf_user/jobs/list/domestic?loc_cd=114120" class="track_event" data-track_event="main|gnb|area_layer|a114110">청주시 상당구</a></li>
                        <li><a href="/zf_user/jobs/list/domestic?loc_cd=114130" class="track_event" data-track_event="main|gnb|area_layer|a114120">청주시 흥덕구</a></li>
                        <li><a href="/zf_user/jobs/list/domestic?loc_cd=114140" class="track_event" data-track_event="main|gnb|area_layer|a114130">충주시</a></li>
                        <li><a href="/zf_user/jobs/list/domestic?loc_cd=114150" class="track_event" data-track_event="main|gnb|area_layer|a114140">청주시 청원구</a></li>
                        <li><a href="/zf_user/jobs/list/domestic?loc_cd=114160" class="track_event" data-track_event="main|gnb|area_layer|a114150">청주시 서원구</a></li>
                    </ul>
                </li>
                <li class="reduce_ltp" id="">
                    <a href="/zf_user/jobs/list/domestic?loc_mcd=116000" class="depth2_link track_event" data-track_event="main|gnb|area_layer|a116000">제주특별자치도</a>
                    <ul class="list_depth3 type2">
                        <li><a href="/zf_user/jobs/list/domestic?loc_cd=116030" class="track_event" data-track_event="main|gnb|area_layer|a116010">서귀포시</a></li>
                        <li><a href="/zf_user/jobs/list/domestic?loc_cd=116040" class="track_event" data-track_event="main|gnb|area_layer|a116020">제주시</a></li>
                    </ul>
                </li>
                <li>
                    <a href="/zf_user/jobs/list/domestic?loc_mcd=117000" class="depth2_link track_event" data-track_event="main|gnb|area_layer|a117000">전국</a>
                    <ul class="list_depth3 type2">
                        <li><a href="/zf_user/jobs/list/domestic?loc_cd=117000" class="track_event" data-track_event="main|gnb|area_layer|a117000">전국</a></li>
                    </ul>
                </li>
            </ul>
        </div>
        <div class="link_subway"><a href="/zf_user/jobs/list/subway" title="역세권별 바로가기" class="btn_subway_recruit">역세권으로 찾는 채용공고</a></div>
    </div>
</li>        <li id="job-category-nav" class="depth1 is_depth2 job_category">
    <a href="/zf_user/upjikjong-recruit/select-upjikjong/recruitform_type/classified" class="depth1_link track_event" onfocus="cate_nav.focusMenu();" data-track_event="section|gnb|menu|job">직업별</a>
    <div class="wrap_depth2 gnb_sub_menu">
        <div class="gnb_sub_home">
            <div><a href="/zf_user/upjikjong-recruit/select-upjikjong/recruitform_type/classified">직업별 홈</a></div>
        </div>
        <div class="column">
            <ul class="list_column_link">
                <li class="mhover">
                    <a href="/zf_user/jobs/list/job-category?cat_bcd=1" class="depth2_link track_event" data-track_event="main|gnb|upjikjong_layer|u101">경영∙사무</a>
                    <ul class="list_depth3">
                        <li><a href="/zf_user/jobs/list/job-category?cat_cd=101" class="track_event" data-track_event="main|gnb|upjikjong_layer|u102">기획∙전략∙경영</a></li>
                        <li><a href="/zf_user/jobs/list/job-category?cat_cd=119" class="track_event" data-track_event="main|gnb|upjikjong_layer|u102">마케팅∙광고∙분석</a></li>
                        <li><a href="/zf_user/jobs/list/job-category?cat_cd=104" class="track_event" data-track_event="main|gnb|upjikjong_layer|u102">홍보∙PR∙사보</a></li>
                        <li><a href="/zf_user/jobs/list/job-category?cat_cd=103" class="track_event" data-track_event="main|gnb|upjikjong_layer|u102">경리∙출납∙결산</a></li>
                        <li><a href="/zf_user/jobs/list/job-category?cat_cd=114" class="track_event" data-track_event="main|gnb|upjikjong_layer|u102">회계∙재무∙세무∙IR</a></li>
                        <li><a href="/zf_user/jobs/list/job-category?cat_cd=102" class="track_event" data-track_event="main|gnb|upjikjong_layer|u102">총무∙법무∙사무</a></li>
                        <li><a href="/zf_user/jobs/list/job-category?cat_cd=107" class="track_event" data-track_event="main|gnb|upjikjong_layer|u102">비서∙안내∙수행원</a></li>
                        <li><a href="/zf_user/jobs/list/job-category?cat_cd=113" class="track_event" data-track_event="main|gnb|upjikjong_layer|u102">인사∙교육∙노무</a></li>
                        <li><a href="/zf_user/jobs/list/job-category?cat_cd=108" class="track_event" data-track_event="main|gnb|upjikjong_layer|u102">사무보조∙문서작성</a></li>
                        <li><a href="/zf_user/jobs/list/job-category?cat_cd=120" class="track_event" data-track_event="main|gnb|upjikjong_layer|u102">전시∙컨벤션∙세미나</a></li>
                    </ul>
                </li>
                <li>
                    <a href="/zf_user/jobs/list/job-category?cat_bcd=2" class="depth2_link track_event" data-track_event="main|gnb|upjikjong_layer|u101">영업∙고객상담</a>
                    <ul class="list_depth3">
                        <li><a href="/zf_user/jobs/list/job-category?cat_cd=202" class="track_event" data-track_event="main|gnb|upjikjong_layer|u102">일반영업</a></li>
                        <li><a href="/zf_user/jobs/list/job-category?cat_cd=209" class="track_event" data-track_event="main|gnb|upjikjong_layer|u102">영업기획∙관리∙지원</a></li>
                        <li><a href="/zf_user/jobs/list/job-category?cat_cd=208" class="track_event" data-track_event="main|gnb|upjikjong_layer|u102">기술영업</a></li>
                        <li><a href="/zf_user/jobs/list/job-category?cat_cd=205" class="track_event" data-track_event="main|gnb|upjikjong_layer|u102">IT∙솔루션영업</a></li>
                        <li><a href="/zf_user/jobs/list/job-category?cat_cd=207" class="track_event" data-track_event="main|gnb|upjikjong_layer|u102">광고영업</a></li>
                        <li><a href="/zf_user/jobs/list/job-category?cat_cd=206" class="track_event" data-track_event="main|gnb|upjikjong_layer|u102">금융∙보험영업</a></li>
                        <li><a href="/zf_user/jobs/list/job-category?cat_cd=203" class="track_event" data-track_event="main|gnb|upjikjong_layer|u102">판매∙매장관리</a></li>
                        <li><a href="/zf_user/jobs/list/job-category?cat_cd=210" class="track_event" data-track_event="main|gnb|upjikjong_layer|u102">TM∙아웃바운드</a></li>
                        <li><a href="/zf_user/jobs/list/job-category?cat_cd=211" class="track_event" data-track_event="main|gnb|upjikjong_layer|u102">TM∙인바운드</a></li>
                        <li><a href="/zf_user/jobs/list/job-category?cat_cd=212" class="track_event" data-track_event="main|gnb|upjikjong_layer|u102">고객센터∙CS</a></li>
                        <li><a href="/zf_user/jobs/list/job-category?cat_cd=213" class="track_event" data-track_event="main|gnb|upjikjong_layer|u102">QA∙CS강사∙수퍼바이저</a></li>
                    </ul>
                </li>
                <li>
                    <a href="/zf_user/jobs/list/job-category?cat_bcd=4" class="depth2_link track_event" data-track_event="main|gnb|upjikjong_layer|u101">IT∙인터넷</a>
                    <ul class="list_depth3">
                        <li><a href="/zf_user/jobs/list/job-category?cat_cd=404" class="track_event" data-track_event="main|gnb|upjikjong_layer|u102">웹개발</a></li>
                        <li><a href="/zf_user/jobs/list/job-category?cat_cd=407" class="track_event" data-track_event="main|gnb|upjikjong_layer|u102">응용프로그램개발</a></li>
                        <li><a href="/zf_user/jobs/list/job-category?cat_cd=408" class="track_event" data-track_event="main|gnb|upjikjong_layer|u102">시스템개발</a></li>
                        <li><a href="/zf_user/jobs/list/job-category?cat_cd=402" class="track_event" data-track_event="main|gnb|upjikjong_layer|u102">서버∙네트워크∙보안</a></li>
                        <li><a href="/zf_user/jobs/list/job-category?cat_cd=409" class="track_event" data-track_event="main|gnb|upjikjong_layer|u102">ERP∙시스템분석∙설계</a></li>
                        <li><a href="/zf_user/jobs/list/job-category?cat_cd=416" class="track_event" data-track_event="main|gnb|upjikjong_layer|u102">데이터베이스∙DBA</a></li>
                        <li><a href="/zf_user/jobs/list/job-category?cat_cd=413" class="track_event" data-track_event="main|gnb|upjikjong_layer|u102">퍼블리싱∙UI개발</a></li>
                        <li><a href="/zf_user/jobs/list/job-category?cat_cd=412" class="track_event" data-track_event="main|gnb|upjikjong_layer|u102">웹디자인</a></li>
                        <li><a href="/zf_user/jobs/list/job-category?cat_cd=411" class="track_event" data-track_event="main|gnb|upjikjong_layer|u102">하드웨어∙소프트웨어</a></li>
                        <li><a href="/zf_user/jobs/list/job-category?cat_cd=410" class="track_event" data-track_event="main|gnb|upjikjong_layer|u102">통신∙모바일</a></li>
                        <li><a href="/zf_user/jobs/list/job-category?cat_cd=403" class="track_event" data-track_event="main|gnb|upjikjong_layer|u102">웹기획∙PM</a></li>
                        <li><a href="/zf_user/jobs/list/job-category?cat_cd=401" class="track_event" data-track_event="main|gnb|upjikjong_layer|u102">웹마스터∙QA∙테스터</a></li>
                        <li><a href="/zf_user/jobs/list/job-category?cat_cd=406" class="track_event" data-track_event="main|gnb|upjikjong_layer|u102">컨텐츠∙사이트운영</a></li>
                        <li><a href="/zf_user/jobs/list/job-category?cat_cd=405" class="track_event" data-track_event="main|gnb|upjikjong_layer|u102">게임∙Game</a></li>
                        <li><a href="/zf_user/jobs/list/job-category?cat_cd=415" class="track_event" data-track_event="main|gnb|upjikjong_layer|u102">IT∙디자인∙컴퓨터교육</a></li>
                        <li><a href="/zf_user/jobs/list/job-category?cat_cd=414" class="track_event" data-track_event="main|gnb|upjikjong_layer|u102">동영상∙편집∙코덱</a></li>
                        <li><a href="/zf_user/jobs/list/job-category?cat_cd=417" class="track_event" data-track_event="main|gnb|upjikjong_layer|u102">인공지능(AI)∙빅데이터</a></li>
                    </ul>
                </li>
                <li>
                    <a href="/zf_user/jobs/list/job-category?cat_bcd=12" class="depth2_link track_event" data-track_event="main|gnb|upjikjong_layer|u101">디자인</a>
                    <ul class="list_depth3">
                        <li><a href="/zf_user/jobs/list/job-category?cat_cd=1201" class="track_event" data-track_event="main|gnb|upjikjong_layer|u102">그래픽디자인∙CG</a></li>
                        <li><a href="/zf_user/jobs/list/job-category?cat_cd=1202" class="track_event" data-track_event="main|gnb|upjikjong_layer|u102">출판∙편집디자인</a></li>
                        <li><a href="/zf_user/jobs/list/job-category?cat_cd=1203" class="track_event" data-track_event="main|gnb|upjikjong_layer|u102">제품∙산업디자인</a></li>
                        <li><a href="/zf_user/jobs/list/job-category?cat_cd=1204" class="track_event" data-track_event="main|gnb|upjikjong_layer|u102">캐릭터∙만화∙애니</a></li>
                        <li><a href="/zf_user/jobs/list/job-category?cat_cd=1205" class="track_event" data-track_event="main|gnb|upjikjong_layer|u102">의류∙패션∙잡화디자인</a></li>
                        <li><a href="/zf_user/jobs/list/job-category?cat_cd=1208" class="track_event" data-track_event="main|gnb|upjikjong_layer|u102">전시∙공간디자인</a></li>
                        <li><a href="/zf_user/jobs/list/job-category?cat_cd=1209" class="track_event" data-track_event="main|gnb|upjikjong_layer|u102">광고∙시각디자인</a></li>
                        <li><a href="/zf_user/jobs/list/job-category?cat_cd=1207" class="track_event" data-track_event="main|gnb|upjikjong_layer|u102">디자인기타</a></li>
                    </ul>
                </li>
                <li>
                    <a href="/zf_user/jobs/list/job-category?cat_bcd=11" class="depth2_link track_event" data-track_event="main|gnb|upjikjong_layer|u101">서비스</a>
                    <ul class="list_depth3">
                        <li><a href="/zf_user/jobs/list/job-category?cat_cd=1101" class="track_event" data-track_event="main|gnb|upjikjong_layer|u102">웨딩∙행사∙이벤트</a></li>
                        <li><a href="/zf_user/jobs/list/job-category?cat_cd=1102" class="track_event" data-track_event="main|gnb|upjikjong_layer|u102">안내∙도우미∙나레이터</a></li>
                        <li><a href="/zf_user/jobs/list/job-category?cat_cd=1103" class="track_event" data-track_event="main|gnb|upjikjong_layer|u102">보안∙경호∙안전</a></li>
                        <li><a href="/zf_user/jobs/list/job-category?cat_cd=1104" class="track_event" data-track_event="main|gnb|upjikjong_layer|u102">주차∙세차∙주유</a></li>
                        <li><a href="/zf_user/jobs/list/job-category?cat_cd=1105" class="track_event" data-track_event="main|gnb|upjikjong_layer|u102">AS∙서비스∙수리</a></li>
                        <li><a href="/zf_user/jobs/list/job-category?cat_cd=1107" class="track_event" data-track_event="main|gnb|upjikjong_layer|u102">외식∙식음료</a></li>
                        <li><a href="/zf_user/jobs/list/job-category?cat_cd=1108" class="track_event" data-track_event="main|gnb|upjikjong_layer|u102">호텔∙카지노∙콘도</a></li>
                        <li><a href="/zf_user/jobs/list/job-category?cat_cd=1109" class="track_event" data-track_event="main|gnb|upjikjong_layer|u102">여행∙관광∙항공</a></li>
                        <li><a href="/zf_user/jobs/list/job-category?cat_cd=1110" class="track_event" data-track_event="main|gnb|upjikjong_layer|u102">레저∙스포츠</a></li>
                        <li><a href="/zf_user/jobs/list/job-category?cat_cd=1111" class="track_event" data-track_event="main|gnb|upjikjong_layer|u102">미용∙피부관리∙애견</a></li>
                        <li><a href="/zf_user/jobs/list/job-category?cat_cd=1112" class="track_event" data-track_event="main|gnb|upjikjong_layer|u102">요리∙제빵사∙영양사</a></li>
                        <li><a href="/zf_user/jobs/list/job-category?cat_cd=1113" class="track_event" data-track_event="main|gnb|upjikjong_layer|u102">가사∙청소∙육아</a></li>
                    </ul>
                </li>
                <li>
                    <a href="/zf_user/jobs/list/job-category?cat_bcd=5" class="depth2_link track_event" data-track_event="main|gnb|upjikjong_layer|u101">전문직</a>
                    <ul class="list_depth3">
                        <li><a href="/zf_user/jobs/list/job-category?cat_cd=501" class="track_event" data-track_event="main|gnb|upjikjong_layer|u102">경영분석∙컨설턴트</a></li>
                        <li><a href="/zf_user/jobs/list/job-category?cat_cd=502" class="track_event" data-track_event="main|gnb|upjikjong_layer|u102">증권∙투자∙펀드∙외환</a></li>
                        <li><a href="/zf_user/jobs/list/job-category?cat_cd=505" class="track_event" data-track_event="main|gnb|upjikjong_layer|u102">설문∙통계∙리서치</a></li>
                        <li class="reduce_ltp"><a href="/zf_user/jobs/list/job-category?cat_cd=504" class="track_event" data-track_event="main|gnb|upjikjong_layer|u102">헤드헌팅∙노무∙직업상담</a></li>
                        <li><a href="/zf_user/jobs/list/job-category?cat_cd=509" class="track_event" data-track_event="main|gnb|upjikjong_layer|u102">외국어∙번역∙통역</a></li>
                        <li><a href="/zf_user/jobs/list/job-category?cat_cd=510" class="track_event" data-track_event="main|gnb|upjikjong_layer|u102">법률∙특허∙상표</a></li>
                        <li><a href="/zf_user/jobs/list/job-category?cat_cd=511" class="track_event" data-track_event="main|gnb|upjikjong_layer|u102">세무∙회계∙CPA</a></li>
                        <li><a href="/zf_user/jobs/list/job-category?cat_cd=512" class="track_event" data-track_event="main|gnb|upjikjong_layer|u102">채권∙보험∙보상∙심사</a></li>
                        <li><a href="/zf_user/jobs/list/job-category?cat_cd=513" class="track_event" data-track_event="main|gnb|upjikjong_layer|u102">도서관사서</a></li>
                        <li><a href="/zf_user/jobs/list/job-category?cat_cd=518" class="track_event" data-track_event="main|gnb|upjikjong_layer|u102">연구소∙R&amp;D</a></li>
                        <li><a href="/zf_user/jobs/list/job-category?cat_cd=522" class="track_event" data-track_event="main|gnb|upjikjong_layer|u102">문화∙예술∙종교</a></li>
                        <li><a href="/zf_user/jobs/list/job-category?cat_cd=524" class="track_event" data-track_event="main|gnb|upjikjong_layer|u102">임원∙CEO</a></li>
                        <li><a href="/zf_user/jobs/list/job-category?cat_cd=523" class="track_event" data-track_event="main|gnb|upjikjong_layer|u102">특수직</a></li>
                    </ul>
                </li>
                <li>
                    <a href="/zf_user/jobs/list/job-category?cat_bcd=13" class="depth2_link track_event" data-track_event="main|gnb|upjikjong_layer|u101">의료</a>
                    <ul class="list_depth3">
                        <li><a href="/zf_user/jobs/list/job-category?cat_cd=1301" class="track_event" data-track_event="main|gnb|upjikjong_layer|u102">의사∙치과∙한의사</a></li>
                        <li><a href="/zf_user/jobs/list/job-category?cat_cd=1302" class="track_event" data-track_event="main|gnb|upjikjong_layer|u102">수의사</a></li>
                        <li><a href="/zf_user/jobs/list/job-category?cat_cd=1303" class="track_event" data-track_event="main|gnb|upjikjong_layer|u102">약사</a></li>
                        <li><a href="/zf_user/jobs/list/job-category?cat_cd=1304" class="track_event" data-track_event="main|gnb|upjikjong_layer|u102">간호사</a></li>
                        <li><a href="/zf_user/jobs/list/job-category?cat_cd=1305" class="track_event" data-track_event="main|gnb|upjikjong_layer|u102">간호조무사</a></li>
                        <li><a href="/zf_user/jobs/list/job-category?cat_cd=1306" class="track_event" data-track_event="main|gnb|upjikjong_layer|u102">의료기사</a></li>
                        <li><a href="/zf_user/jobs/list/job-category?cat_cd=1307" class="track_event" data-track_event="main|gnb|upjikjong_layer|u102">사무∙원무∙코디</a></li>
                        <li><a href="/zf_user/jobs/list/job-category?cat_cd=1308" class="track_event" data-track_event="main|gnb|upjikjong_layer|u102">보험심사과</a></li>
                        <li><a href="/zf_user/jobs/list/job-category?cat_cd=1309" class="track_event" data-track_event="main|gnb|upjikjong_layer|u102">의료기타직</a></li>
                    </ul>
                </li>
                <li>
                    <a href="/zf_user/jobs/list/job-category?cat_bcd=3" class="depth2_link track_event" data-track_event="main|gnb|upjikjong_layer|u101">생산∙제조</a>
                    <ul class="list_depth3">
                        <li><a href="/zf_user/jobs/list/job-category?cat_cd=315" class="track_event" data-track_event="main|gnb|upjikjong_layer|u102">생산∙제조∙포장∙조립</a></li>
                        <li><a href="/zf_user/jobs/list/job-category?cat_cd=309" class="track_event" data-track_event="main|gnb|upjikjong_layer|u102">생산관리∙품질관리</a></li>
                        <li><a href="/zf_user/jobs/list/job-category?cat_cd=302" class="track_event" data-track_event="main|gnb|upjikjong_layer|u102">기계∙기계설비</a></li>
                        <li><a href="/zf_user/jobs/list/job-category?cat_cd=301" class="track_event" data-track_event="main|gnb|upjikjong_layer|u102">금속∙금형</a></li>
                        <li><a href="/zf_user/jobs/list/job-category?cat_cd=316" class="track_event" data-track_event="main|gnb|upjikjong_layer|u102">비금속∙요업∙신소재</a></li>
                        <li><a href="/zf_user/jobs/list/job-category?cat_cd=308" class="track_event" data-track_event="main|gnb|upjikjong_layer|u102">전기∙전자∙제어</a></li>
                        <li><a href="/zf_user/jobs/list/job-category?cat_cd=314" class="track_event" data-track_event="main|gnb|upjikjong_layer|u102">반도체∙디스플레이∙LCD</a></li>
                        <li><a href="/zf_user/jobs/list/job-category?cat_cd=303" class="track_event" data-track_event="main|gnb|upjikjong_layer|u102">화학∙에너지</a></li>
                        <li><a href="/zf_user/jobs/list/job-category?cat_cd=304" class="track_event" data-track_event="main|gnb|upjikjong_layer|u102">섬유∙의류∙패션</a></li>
                        <li><a href="/zf_user/jobs/list/job-category?cat_cd=317" class="track_event" data-track_event="main|gnb|upjikjong_layer|u102">바이오∙제약∙식품</a></li>
                        <li><a href="/zf_user/jobs/list/job-category?cat_cd=318" class="track_event" data-track_event="main|gnb|upjikjong_layer|u102">설계∙CAD∙CAM</a></li>
                        <li><a href="/zf_user/jobs/list/job-category?cat_cd=319" class="track_event" data-track_event="main|gnb|upjikjong_layer|u102">안경∙렌즈∙광학</a></li>
                    </ul>
                </li>
                <li>
                    <a href="/zf_user/jobs/list/job-category?cat_bcd=9" class="depth2_link track_event" data-track_event="main|gnb|upjikjong_layer|u101">건설</a>
                    <ul class="list_depth3">
                        <li><a href="/zf_user/jobs/list/job-category?cat_cd=901" class="track_event" data-track_event="main|gnb|upjikjong_layer|u102">토목∙조경∙도시∙측량</a></li>
                        <li><a href="/zf_user/jobs/list/job-category?cat_cd=902" class="track_event" data-track_event="main|gnb|upjikjong_layer|u102">건축∙인테리어∙설계</a></li>
                        <li><a href="/zf_user/jobs/list/job-category?cat_cd=903" class="track_event" data-track_event="main|gnb|upjikjong_layer|u102">전기∙소방∙통신∙설비</a></li>
                        <li><a href="/zf_user/jobs/list/job-category?cat_cd=904" class="track_event" data-track_event="main|gnb|upjikjong_layer|u102">환경∙플랜트</a></li>
                        <li><a href="/zf_user/jobs/list/job-category?cat_cd=905" class="track_event" data-track_event="main|gnb|upjikjong_layer|u102">현장∙시공∙감리∙공무</a></li>
                        <li><a href="/zf_user/jobs/list/job-category?cat_cd=906" class="track_event" data-track_event="main|gnb|upjikjong_layer|u102">안전∙품질∙검사∙관리</a></li>
                        <li class="reduce_ltp"><a href="/zf_user/jobs/list/job-category?cat_cd=908" class="track_event" data-track_event="main|gnb|upjikjong_layer|u102">부동산∙개발∙경매∙분양</a></li>
                        <li><a href="/zf_user/jobs/list/job-category?cat_cd=909" class="track_event" data-track_event="main|gnb|upjikjong_layer|u102">본사∙관리∙전산</a></li>
                    </ul>
                </li>
                <li>
                    <a href="/zf_user/jobs/list/job-category?cat_bcd=10" class="depth2_link track_event" data-track_event="main|gnb|upjikjong_layer|u101">유통∙무역</a>
                    <ul class="list_depth3">
                        <li><a href="/zf_user/jobs/list/job-category?cat_cd=1001" class="track_event" data-track_event="main|gnb|upjikjong_layer|u102">물류∙유통∙운송</a></li>
                        <li><a href="/zf_user/jobs/list/job-category?cat_cd=1002" class="track_event" data-track_event="main|gnb|upjikjong_layer|u102">해외영업∙무역영업</a></li>
                        <li><a href="/zf_user/jobs/list/job-category?cat_cd=1003" class="track_event" data-track_event="main|gnb|upjikjong_layer|u102">구매∙자재∙재고</a></li>
                        <li><a href="/zf_user/jobs/list/job-category?cat_cd=1004" class="track_event" data-track_event="main|gnb|upjikjong_layer|u102">납품∙배송∙택배</a></li>
                        <li><a href="/zf_user/jobs/list/job-category?cat_cd=1005" class="track_event" data-track_event="main|gnb|upjikjong_layer|u102">상품기획∙MD</a></li>
                        <li><a href="/zf_user/jobs/list/job-category?cat_cd=1006" class="track_event" data-track_event="main|gnb|upjikjong_layer|u102">무역사무∙수출입</a></li>
                        <li><a href="/zf_user/jobs/list/job-category?cat_cd=1007" class="track_event" data-track_event="main|gnb|upjikjong_layer|u102">운전∙기사</a></li>
                        <li><a href="/zf_user/jobs/list/job-category?cat_cd=1008" class="track_event" data-track_event="main|gnb|upjikjong_layer|u102">중장비∙화물</a></li>
                    </ul>
                </li>
                <li>
                    <a href="/zf_user/jobs/list/job-category?cat_bcd=7" class="depth2_link track_event" data-track_event="main|gnb|upjikjong_layer|u101">미디어</a>
                    <ul class="list_depth3">
                        <li><a href="/zf_user/jobs/list/job-category?cat_cd=711" class="track_event" data-track_event="main|gnb|upjikjong_layer|u102">방송연출∙PD∙감독</a></li>
                        <li><a href="/zf_user/jobs/list/job-category?cat_cd=703" class="track_event" data-track_event="main|gnb|upjikjong_layer|u102">카메라∙조명∙미술</a></li>
                        <li><a href="/zf_user/jobs/list/job-category?cat_cd=712" class="track_event" data-track_event="main|gnb|upjikjong_layer|u102">진행∙아나운서</a></li>
                        <li><a href="/zf_user/jobs/list/job-category?cat_cd=705" class="track_event" data-track_event="main|gnb|upjikjong_layer|u102">작가∙시나리오</a></li>
                        <li><a href="/zf_user/jobs/list/job-category?cat_cd=710" class="track_event" data-track_event="main|gnb|upjikjong_layer|u102">기자</a></li>
                        <li><a href="/zf_user/jobs/list/job-category?cat_cd=702" class="track_event" data-track_event="main|gnb|upjikjong_layer|u102">연예∙엔터테인먼트</a></li>
                        <li><a href="/zf_user/jobs/list/job-category?cat_cd=704" class="track_event" data-track_event="main|gnb|upjikjong_layer|u102">공연∙무대∙스텝</a></li>
                        <li><a href="/zf_user/jobs/list/job-category?cat_cd=708" class="track_event" data-track_event="main|gnb|upjikjong_layer|u102">영화제작∙배급</a></li>
                        <li><a href="/zf_user/jobs/list/job-category?cat_cd=709" class="track_event" data-track_event="main|gnb|upjikjong_layer|u102">광고∙카피∙CF</a></li>
                        <li><a href="/zf_user/jobs/list/job-category?cat_cd=713" class="track_event" data-track_event="main|gnb|upjikjong_layer|u102">음악∙음향∙사운드</a></li>
                        <li><a href="/zf_user/jobs/list/job-category?cat_cd=714" class="track_event" data-track_event="main|gnb|upjikjong_layer|u102">인쇄∙출판∙편집</a></li>
                        <li><a href="/zf_user/jobs/list/job-category?cat_cd=715" class="track_event" data-track_event="main|gnb|upjikjong_layer|u102">사진∙포토그라퍼</a></li>
                    </ul>
                </li>
                <li>
                    <a href="/zf_user/jobs/list/job-category?cat_bcd=6" class="depth2_link track_event" data-track_event="main|gnb|upjikjong_layer|u101">교육</a>
                    <ul class="list_depth3">
                        <li><a href="/zf_user/jobs/list/job-category?cat_cd=604" class="track_event" data-track_event="main|gnb|upjikjong_layer|u102">유치원∙보육</a></li>
                        <li><a href="/zf_user/jobs/list/job-category?cat_cd=602" class="track_event" data-track_event="main|gnb|upjikjong_layer|u102">초중고∙특수학교</a></li>
                        <li><a href="/zf_user/jobs/list/job-category?cat_cd=606" class="track_event" data-track_event="main|gnb|upjikjong_layer|u102">입시∙보습∙속셈학원</a></li>
                        <li><a href="/zf_user/jobs/list/job-category?cat_cd=611" class="track_event" data-track_event="main|gnb|upjikjong_layer|u102">외국어∙어학원</a></li>
                        <li><a href="/zf_user/jobs/list/job-category?cat_cd=603" class="track_event" data-track_event="main|gnb|upjikjong_layer|u102">학습지∙과외∙방문</a></li>
                        <li><a href="/zf_user/jobs/list/job-category?cat_cd=605" class="track_event" data-track_event="main|gnb|upjikjong_layer|u102">전문직업∙IT강사</a></li>
                        <li><a href="/zf_user/jobs/list/job-category?cat_cd=610" class="track_event" data-track_event="main|gnb|upjikjong_layer|u102">대학교수∙행정직</a></li>
                        <li><a href="/zf_user/jobs/list/job-category?cat_cd=601" class="track_event" data-track_event="main|gnb|upjikjong_layer|u102">교육기획∙교재</a></li>
                        <li><a href="/zf_user/jobs/list/job-category?cat_cd=609" class="track_event" data-track_event="main|gnb|upjikjong_layer|u102">학원관리∙운영∙상담</a></li>
                    </ul>
                </li>
                <li>
                    <a href="/zf_user/jobs/list/job-category?cat_bcd=8" class="depth2_link track_event" data-track_event="main|gnb|upjikjong_layer|u101">특수계층∙공공</a>
                    <ul class="list_depth3">
                        <li><a href="/zf_user/jobs/list/job-category?cat_cd=810" class="track_event" data-track_event="main|gnb|upjikjong_layer|u102">공무원</a></li>
                        <li><a href="/zf_user/jobs/list/job-category?cat_cd=813" class="track_event" data-track_event="main|gnb|upjikjong_layer|u102">장교∙군인∙부사관</a></li>
                        <li><a href="/zf_user/jobs/list/job-category?cat_cd=809" class="track_event" data-track_event="main|gnb|upjikjong_layer|u102">병역특례</a></li>
                        <li><a href="/zf_user/jobs/list/job-category?cat_cd=807" class="track_event" data-track_event="main|gnb|upjikjong_layer|u102">중장년∙고령인∙실버</a></li>
                        <li><a href="/zf_user/jobs/list/job-category?cat_cd=808" class="track_event" data-track_event="main|gnb|upjikjong_layer|u102">장애인∙국가유공자</a></li>
                        <li><a href="/zf_user/jobs/list/job-category?cat_cd=812" class="track_event" data-track_event="main|gnb|upjikjong_layer|u102">사회복지∙요양∙봉사</a></li>
                    </ul>
                </li>
            </ul>
        </div>
    </div>
</li>        <li class="depth1"><a href="/zf_user/jobs/hot100" class="depth1_link track_event" data-track_event="section|gnb|menu|hot100">HOT100</a></li>
        <li id="curation-level" class="depth1 is_depth2">
    <a href="/zf_user/curation" class="depth1_link track_event" onfocus="curation_nav.focusMenu();" data-track_event="section|gnb|menu|curation">큐레이션</a>
    <div class="wrap_depth2 gnb_sub_menu">
        <div class="gnb_sub_home">
            <div><a href="/zf_user/curation" class="depth_menu nav_title track_event" data-track_event="main|gnb|curation_layer|curation_main"><strong>큐레이션 홈</strong></a></div>
        </div>
        <ul class="curation_level_nav depth1">
                                <li class="column">
                        <div class="column_tit"><a href="/zf_user/jobs/list/curation?category_seq=30" data-track_event="main|gnb|curation_layer|a030" class="track_event curation_link">크고 소중한 연봉</a></div>
                                                    <ul class="column_list">
                                                                                                                                        <li><a href="/zf_user/jobs/list/curation?curation_seq=283" data-track_event="main|gnb|curation_layer|a030_0283" class="track_event">IT급상승! 연봉 5,000이상 기업</a></li>
                                                                                                                                            <li><a href="/zf_user/jobs/list/curation?curation_seq=281" data-track_event="main|gnb|curation_layer|a030_0281" class="track_event">연봉 3,600이상 강소·중견기업</a></li>
                                                                                                </ul>
                                            </li>
                                        <li class="column">
                        <div class="column_tit"><a href="/zf_user/jobs/list/curation?category_seq=31" data-track_event="main|gnb|curation_layer|b031" class="track_event curation_link">알짜배기 복지관</a></div>
                                                    <ul class="column_list">
                                                                                                                                        <li><a href="/zf_user/jobs/list/curation?curation_seq=282" data-track_event="main|gnb|curation_layer|b031_0282" class="track_event">정규직X상여금,행복이 배가 되는 기업</a></li>
                                                                                                                                            <li><a href="/zf_user/jobs/list/curation?curation_seq=280" data-track_event="main|gnb|curation_layer|b031_0280" class="track_event">꿈의 직장 '주 4일 근무'는 여기!</a></li>
                                                                                                </ul>
                                            </li>
                                        <li class="column">
                        <div class="column_tit"><a href="/zf_user/jobs/list/curation?category_seq=33" data-track_event="main|gnb|curation_layer|c033" class="track_event curation_link">실시간 HOT 공고</a></div>
                                                    <ul class="column_list">
                                                                                                                                        <li><a href="/zf_user/jobs/list/curation?curation_seq=286" data-track_event="main|gnb|curation_layer|c033_0286" class="track_event">[LIVE] 공고 생중계</a></li>
                                                                                                                                            <li><a href="/zf_user/jobs/list/curation?curation_seq=245" data-track_event="main|gnb|curation_layer|c033_0245" class="track_event">사람인이 추천하는 HOT공고</a></li>
                                                                                                </ul>
                                            </li>
                            </ul>
            </div>
</li>        <li id="public-level" class="depth1 is_depth2">
    <a href="/zf_user/jobs/public/list" class="depth1_link track_event" onfocus="public_nav.focusMenu();" data-track_event="section|gnb|menu|public">공채</a>
    <div class="wrap_depth2 gnb_sub_menu">
        <div class="gnb_sub_home">
            <div><a href="/zf_user/jobs/public/list" class="depth_menu nav_title track_event" data-track_event="main|gnb|public_layer|s100"><em class="icon_title">신입<span>/</span>경력</em><strong>1000대기업 채용속보 </strong></a></div>
        </div>
        <ul class="public_level_nav depth1">
            <li class="column recruit_category">
                <div class="column_tit no_link">기업으로 보는 채용</div>
                <ul class="list_category">
                    <li><a href="/zf_user/jobs/public/top-group" class="track_event public_link" data-track_event="main|gnb|public_layer|s121">그룹사별 채용속보</a></li>
                    <li class="top_line">
                        <div class="category_tit tit_top">기업형태별 채용속보</div>
                        <ul>
                            <li><a href="/zf_user/jobs/public/list?company_scale%5B%5D=1#searchTitle" class="track_event" data-track_event="main|gnb|public_layer|s101">대기업</a></li>
                            <li><a href="/zf_user/jobs/public/list?company_scale%5B%5D=2#searchTitle" class="track_event" data-track_event="main|gnb|public_layer|s103">매출 1000대기업</a></li>
                            <li><a href="/zf_user/jobs/public/list?company_scale%5B%5D=3#searchTitle" class="track_event" data-track_event="main|gnb|public_layer|s104">중견기업</a></li>
                            <li><a href="/zf_user/jobs/public/list?company_scale%5B%5D=4#searchTitle" class="track_event" data-track_event="main|gnb|public_layer|s102">공사 ∙ 공기업</a></li>
                            <li><a href="/zf_user/jobs/public/list?company_scale%5B%5D=5&amp;company_scale%5B%5D=6#searchTitle" class="track_event" data-track_event="main|gnb|public_layer|s105">코스닥 ∙ 코스피</a></li>
                            <li class="block"><a href="/zf_user/jobs/public/list?company_scale%5B%5D=7#searchTitle" class="track_event" data-track_event="main|gnb|public_layer|s106">외국계기업</a></li>
                        </ul>
                    </li>
                </ul>
                <div class="box_btn">
                    <a class="btn_type" href="http://www.saramin.co.kr/zf_user/jobs/public/list?jobtype%5B%5D=4#listTop" target="_top" onmousedown="try{n_trackEvent('main', 'gnb', 'public_layer', 'intern');}catch(e){};"><span class="point">인턴</span> 공채속보 모음</a>                </div>
            </li>
            <li class="column recruit_category">
                <div class="column_tit"><a href="/zf_user/jobs/major-public/list" class="public_link track_event" data-track_event="main|gnb|public_layer|s200">전공으로 보는 채용</a></div>
                <ul class="list_category">
                    <li><a href="/zf_user/jobs/major-public/list?mj_cd%5B%5D=1#searchTitle" class="track_event" data-track_event="main|gnb|public_layer|s201">기계 ∙ 자동차 ∙ 조선공학</a></li>
                    <li><a href="/zf_user/jobs/major-public/list?mj_cd%5B%5D=2#searchTitle" class="track_event" data-track_event="main|gnb|public_layer|s202">전기 ∙ 전자 ∙ 반도체공학</a></li>
                    <li><a href="/zf_user/jobs/major-public/list?mj_cd%5B%5D=3#searchTitle" class="track_event" data-track_event="main|gnb|public_layer|s203">컴퓨터 ∙ 정보통신공학</a></li>
                    <li><a href="/zf_user/jobs/major-public/list?mj_cd%5B%5D=4#searchTitle" class="track_event" data-track_event="main|gnb|public_layer|s204">건축 ∙ 토목 ∙ 도시 ∙ 환경공학</a></li>
                    <li><a href="/zf_user/jobs/major-public/list?mj_cd%5B%5D=5#searchTitle" class="track_event" data-track_event="main|gnb|public_layer|s205">법학 ∙ 상경 ∙ 사회 ∙ 무역</a></li>
                    <li><a href="/zf_user/jobs/major-public/list?mj_cd%5B%5D=6#searchTitle" class="track_event" data-track_event="main|gnb|public_layer|s206">화학 ∙ 화학공학</a></li>
                    <li><a href="/zf_user/jobs/major-public/list?mj_cd%5B%5D=7#searchTitle" class="track_event" data-track_event="main|gnb|public_layer|s207">재료 ∙ 금속 ∙ 고분자공학</a></li>
                    <li><a href="/zf_user/jobs/major-public/list?mj_cd%5B%5D=8#searchTitle" class="track_event" data-track_event="main|gnb|public_layer|s208">생명공학 ∙ 생물학</a></li>
                    <li><a href="/zf_user/jobs/major-public/list?mj_cd%5B%5D=9#searchTitle" class="track_event" data-track_event="main|gnb|public_layer|s209">어문학</a></li>
                    <li><a href="/zf_user/jobs/major-public/list?mj_cd%5B%5D=10#searchTitle" class="track_event" data-track_event="main|gnb|public_layer|s210">산업공학</a></li>
                    <li><a href="/zf_user/jobs/major-public/list?mj_cd%5B%5D=11#searchTitle" class="track_event" data-track_event="main|gnb|public_layer|s211">교육학</a></li>
                </ul>
                <div class="box_btn">
                    <a class="btn_type" href="http://www.saramin.co.kr/zf_user/jobs/public/list?final_edu%5B%5D=1#listTop" target="_top" onmousedown="try{n_trackEvent('main', 'gnb', 'public_layer', 'highscool');}catch(e){};"><span class="point">고졸</span> 공채속보 모음</a>                </div>
            </li>
            <li class="column">
                <div class="column_tit no_link">일정으로 보는 채용</div>
                <ul class="list_category">
        <li>
        <div class="category_tit">
            <strong>이번주 마감 대기업</strong>
            <a href="/zf_user/calendar#listTop" onmousedown="try{n_trackEvent('main', 'gnb', 'public_layer', 's301');}catch(e){}" class="btn_more"><span class="blind">더보기</span></a>
        </div>
                <ul class="calendar_info">
                        <li><a href="/zf_user/jobs/public/view?rec_idx=38734536" onmousedown="try{n_trackEvent('main','gnb','public_layer','s301-1');}catch(e){};">삼성그룹</a></li>
                        <li><a href="/zf_user/jobs/public/view?rec_idx=38747907" onmousedown="try{n_trackEvent('main','gnb','public_layer','s301-2');}catch(e){};">(주)LG화학</a></li>
                        <li><a href="/zf_user/jobs/public/view?rec_idx=38745700" onmousedown="try{n_trackEvent('main','gnb','public_layer','s301-3');}catch(e){};">디아이웨어(주)</a></li>
                    </ul>
            </li>
        <li class="top_line">
        <div class="category_tit">
            <strong>이번주 마감 중견기업</strong>
            <a href="/zf_user/calendar#listTop" onmousedown="try{n_trackEvent('main', 'gnb', 'public_layer', 's302');}catch(e){}" class="btn_more"><span class="blind">더보기</span></a>
        </div>
                <ul class="calendar_info">
                        <li><a href="/zf_user/jobs/public/view?rec_idx=38748738" onmousedown="try{n_trackEvent('main','gnb','public_layer','s302-1');}catch(e){};">(주)화이트스톤</a></li>
                        <li><a href="/zf_user/jobs/public/view?rec_idx=38745403" onmousedown="try{n_trackEvent('main','gnb','public_layer','s302-2');}catch(e){};">사조동아원(주)</a></li>
                        <li><a href="/zf_user/jobs/public/view?rec_idx=38743689" onmousedown="try{n_trackEvent('main','gnb','public_layer','s302-3');}catch(e){};">국제약품(주)</a></li>
                    </ul>
            </li>
        <li class="top_line">
        <a href="/zf_user/help/live" class="public_link" onmousedown="try{n_trackEvent('main', 'gnb', 'public_layer', 's501');}catch(e){}">취업생중계</a>
    </li>
</ul>                <div class="box_btn">
                    <a class="btn_type" href="http://www.saramin.co.kr/zf_user/curation" target="_top" onmousedown="try{n_trackEvent('main', 'gnb', 'public_layer', 'public-organization-recruitment-schedule');}catch(e){};"><span class="point">New</span> 큐레이션</a>                    <a class="btn_type" href="http://www.saramin.co.kr/zf_user/public-recruit/job-fair-schedule" target="_top" onmousedown="try{n_trackEvent('main', 'gnb', 'public_layer', 'job-fair-schedule');}catch(e){};"><span class="point">채용설명회</span> 일정</a>                </div>
            </li>
            <li class="column">
                <div class="column_tit no_link">연봉으로 보는 채용</div>
                <ul class="list_category salary">
                    <li class="category_tit"><a href="/zf_user/salaries/1000/starting-list" class="track_event public_link" data-track_event="main|gnb|public_layer|s401">1000대기업 대졸초임</a></li>
                    <li class="category_tit top_line last_line"><a href="/zf_user/salaries/1000/public-list" class="track_event public_link" data-track_event="main|gnb|public_layer|s402">공사∙공기업 대졸초임</a></li>
                </ul>
                <div class="banner">
                    <a href="/zf_user" target="_blank" onmousedown="try{n_trackEvent('main', 'gnb', 'public_layer', 'banner05');}catch(e){};"><img src="//www.saraminimage.co.kr/sri/common/dummy_banner_wide.png" alt="" width="200" height="202"></a>                </div>
            </li>
        </ul>
        <div class="area_pass_refer">
            <h4 class="tit">공채 합격자료</h4>
            <ul>
                <li><a href="/zf_user/public-recruit/coverletter-list" class="coverletter track_event" data-track_event="main|gnb|public_layer|contents01">합격자소서</a></li>
                <li><a href="/zf_user/educe/spec-information" class="spec_info track_event" data-track_event="main|gnb|public_layer|contents02">합격스펙</a></li>
                <li><a href="/zf_user/public-recruit/job-fair" class="job_fair track_event" data-track_event="main|gnb|public_layer|contents03">채용설명회</a></li>
                <li><a href="/zf_user/career-information/senior-list" class="senior_list track_event" data-track_event="main|gnb|public_layer|contents07">직무인터뷰</a></li>
                <li><a href="/zf_user/member/self-introduction" class="self_introduction track_event" data-track_event="main|gnb|public_layer|contents08" target="_blank">자소서작성</a></li>
            </ul>
        </div>
    </div>
</li>        <li id="comsalary-level" class="depth1 is_depth2">
    <a href="/zf_user/companylab" class="depth1_link track_event" onfocus="comsalary_nav.focusMenu();" data-track_event="section|gnb|menu|comsalary">기업연구소</a>
    <div class="wrap_depth2 gnb_sub_menu">
        <div class="gnb_sub_home">
            <div><a href="/zf_user/companylab" class="depth_menu nav_title track_event" data-track_event="">기업연구소  홈</a></div>
        </div>
        <ul class="comsalary_level_nav depth1">
            <li class="column">
                <div class="column_tit">이직연구소</div>
                <ul class="column_list">
                    <li><a href="/zf_user/company-review" class="track_event" data-track_event="main|gnb|company_salary_layer|lnb1311">기업리뷰 등록</a></li>
                    <li><a href="/zf_user/company-review-report" class="track_event" data-track_event="main|gnb|company_salary_layer|lnb1314">기업리뷰 리포트</a></li>
                    <li><a href="/zf_user/interview-review" class="track_event" data-track_event="main|gnb|company_salary_layer|lnb1312">면접 경험 공유</a></li>
                    <li><a href="/zf_user/company-section/road-map" class="track_event" data-track_event="section|lnb|salaries|lnb1320">이직로드맵</a></li>
                </ul>
                <div class="column_tit">자료실</div>
                <ul class="column_list">
                    <li><a href="/zf_user/career-information/senior-list" class="track_event" data-track_event="section|lnb|jobarchive|lnb1415">직무인터뷰</a></li>
                    <li><a href="/zf_user/white-paper/office" class="track_event" data-track_event="section|lnb|jobarchive|lnb1419">직장in 생활백서</a></li>
                    <li><a href="/zf_user/help/live?category=10" class="track_event" data-track_event="section|lnb|jobarchive|lnb1416">취업뉴스</a></li>
                    <li><a href="/zf_user/jobarchive/company-news" class="track_event" data-track_event="section|lnb|salaries|lnb1360">기업뉴스</a></li>
                    <li><a href="/zf_user/guide/movie/fun" class="track_event" data-track_event="section|lnb|jobarchive|lnb1407">Fun한 취업 동영상</a></li>
                    <li><a href="/zf_user/pds-resume/resume-download" class="track_event" data-track_event="section|lnb|jobarchive|lnb1404">이력서 양식 다운로드</a></li>
                    <li><a href="/zf_user/business-form-templates/list?sort_key=hif003" class="track_event" onmousedown="try{n_trackEvent('section_lnb', 'jobarchive' , 'hr-magazine', 'hr-templates');}catch(e){}">무료 서식 다운로드</a></li>
                    <li><a href="/zf_user/persons/job-search-land" class="track_event" data-track_event="section|lnb|jobarchive|lnb1402">구직활동 확인서</a></li>
                </ul>
            </li>
            <li class="column">
                <div class="column_tit">연봉연구소</div>
                <ul class="column_list">
                    <li><a href="/zf_user/salaries/total-salary/list" class="track_event" data-track_event="main|gnb|company_salary_layer|lnb1331">전체 연봉정보</a></li>
                    <li><a href="/zf_user/salaries/company/enterprise-list" class="track_event" data-track_event="main|gnb|company_salary_layer|lnb1332">기업형태별 평균연봉</a></li>
                    <li><a href="/zf_user/salaries/industry/service-list" class="track_event" data-track_event="main|gnb|company_salary_layer|lnb1333">산업(업종)별 평균연봉</a></li>
                    <li><a href="/zf_user/salaries/1000/starting-list" class="track_event" data-track_event="main|gnb|company_salary_layer|lnb1334">대졸초임</a></li>
                    <li><a href="/zf_user/salaries/total-salary/faq" class="track_event" data-track_event="main|gnb|company_salary_layer|lnb1335">연봉정보 FAQ</a></li>
                </ul>
                <div class="column_tit">HR매거진</div>
                <ul class="column_list">
                    <li><a href="/zf_user/hr-magazine/list" class="track_event" onmousedown="try{n_trackEvent('section_lnb', 'jobarchive' , 'hr-magazine', 'hr-magazine');}catch(e){}">HR매거진</a></li>
                    <li><a href="/zf_user/hr-magazine/series-list" class="track_event" onmousedown="try{n_trackEvent('section_lnb', 'jobarchive' , 'hr-magazine', 'hr-series');}catch(e){}">HR시리즈</a></li>
                    <li><a href="/zf_user/cms/labor-counsel/list" class="track_event" onmousedown="try{n_trackEvent('section_lnb', 'jobarchive' , 'hr-magazine', 'labor-counsel');}catch(e){}">HR법률상담</a></li>
                    <li><a href="/zf_user/hr-magazine/news-list?category=news&amp;subject_type=manage" class="track_event" onmousedown="try{n_trackEvent('section_lnb', 'jobarchive' , 'hr-magazine', 'news');}catch(e){}">News</a></li>
                </ul>
            </li>
            <li class="column">
                <div class="column_tit">취업 TOOL</div>
                <ul class="column_list">
                    <li><a href="/zf_user/tools/character-counter" class="track_event" data-track_event="section|lnb|jobarchive|lnb1402">글자수세기/맞춤법</a></li>
                    <li><a href="/zf_user/tools/photo-cropper" class="track_event" data-track_event="section|lnb|jobarchive|lnb1402">사진크기조정</a></li>
                    <li><a href="/zf_user/tools/salary-calculator" class="track_event" data-track_event="section|lnb|jobarchive|lnb1402">연봉계산기</a></li>
                    <li><a href="/zf_user/tools/reverse-salary-calculator" class="track_event" data-track_event="section|lnb|jobarchive|lnb1402">실수령액 계산기</a></li>
                    <li><a href="/zf_user/tools/retire-calculator" class="track_event" data-track_event="section|lnb|jobarchive|lnb1402">퇴직금 계산기</a></li>
                    <li><a href="/zf_user/tools/unemp-calculator" class="track_event" data-track_event="section|lnb|jobarchive|lnb1402">실업급여 계산기</a></li>
                    <li><a href="/zf_user/tools/holi-calculator" class="track_event" data-track_event="section|lnb|jobarchive|lnb1402">연차/휴가 계산기</a></li>
                    <li><a href="/zf_user/tools/gradu-calculator" class="track_event" data-track_event="section|lnb|jobarchive|lnb1402">졸업/전역연도 계산기</a></li>
                    <li><a href="/zf_user/tools/grade-converter" class="track_event" data-track_event="section|lnb|jobarchive|lnb1402">학점 변환기</a></li>
                    <li><a href="/zf_user/tools/score-converter" class="track_event" data-track_event="section|lnb|jobarchive|lnb1402">어학점수 변환기</a></li>
                </ul>
                <div class="box_banner">
                    <a href="/zf_user/company-review-qst-and-ans/">
                        <img src="//www.saraminimage.co.kr/sri/common/company_review_banner.png" alt="궁금했던 기업과 직무, 취준진담에서 물어보세요!">
                    </a>
                </div>
            </li>
        </ul>
        <div class="companylab_refer">
            <h4 class="tit"><a href="/zf_user/company-review-qst-and-ans" class="track_event" data-track_event="main|gnb|qna_layer|qna">취준진담</a></h4>
            <h4 class="tit curation">기업큐레이션</h4>
            <ul class="depth_menu_inner">
                                        <li><a href="/zf_user/company-info/sri-certification?seq=216" target="_blank" class="track_event" data-track_event="section|lnb|salaries|lnb1341">상위0.1%</a>
                        </li>
                                            <li><a href="/zf_user/company-info/sri-certification?seq=1062" target="_blank" class="track_event" data-track_event="section|lnb|salaries|lnb1342">상장된 중소기업</a>
                        </li>
                                            <li><a href="/zf_user/company-info/sri-certification?seq=173" target="_blank" class="track_event" data-track_event="section|lnb|salaries|lnb1343">깜짝! 업계신흥강자</a>
                        </li>
                                </ul>
        </div>
    </div>
</li>
                    <li class="depth1"><a href="/zf_user/memcom/talent-pool/main#/recommend" class="depth1_link track_event" data-track_event="section|gnb|menu|talent-pool">인재Pool</a></li>
            </ul>
</div>
<div id="srch_wrap" class="wrap_search">
    <form id="AKCFrm" name="search" action="/zf_user/search">
        <fieldset class="fieldset">
            <legend class="blind">검색 폼</legend>
            <div class="box_search">
                <label for="combineSearchWord" class="blind">검색어입력</label>
                <span id="search_wrap_span" class="box_search_input banner-on">
                    <input type="text" name="searchword" id="combineSearchWord" placeholder="검색어를 입력하세요" class="placeholder" accesskey="s" autocomplete="off" size="20" value="">
                </span>
                <button type="submit" id="submit_button" name="go" class="btn_search track_event" data-track_event="section|gnb|menu|search"><span>검색</span></button>
            </div>
        </fieldset>
        <input type="hidden" name="flag" value="n">
        <input type="hidden" name="searchMode" value="1">
        <input type="hidden" name="searchType" id="searchType" value="">
        <input type="hidden" name="search_done" id="search_done" value="y">
        <input type="hidden" name="" id="search_optional_item" value="">
    </form>

    <div id="wrapAutoComplete" class="wrap_auto_complete"><div id="searchAutoCompleteResult" class="quick-search test" style="display:none;">
    <div class="quick-lists">
        <div class="list-keyword">
            <div class="list-keyword-recent" style="display:block;">
                <span id="recentlySearchWordTitle"><h4>최근검색어</h4></span>
                <ul id="listKeyword">
                </ul>
            </div>
        </div>
        <div class="list-recruitment">
            <ul id="listRecruitment" style="display:none;">
                <li id="listRecruitmentMore" class="more" style="display:none">
                    <p><strong><em id="searchWordRecruitment"></em></strong>의<br><em id="exceedRecommendCount"></em>개 공고를 모두 확인하세요.</p>
                    <a id="searchSubmit" class="btn_more">검색결과 보기</a>
                </li>
            </ul>
            <div id="listRecruitmentNull" class="no-result" style="display:none;"><strong><span id="searchWordRecruitmentNull"></span></strong>에 대한<br>채��정보 검색 결과가 없습니다.</div>
        </div>
    </div>
    <div class="quick-links" style="display:none;">
        <h4>바로가기</h4>
        <ul id="listShortCut">
        </ul>
    </div>
    <div class="quick-guide"><p>적합한 검색어와 채용공고를 추천해 드립니다.<br><a href="javascript:void(0)" onclick="SearchAutoComplete.toggleAutoCompleteCookie(); return false;">자동완성 켜기</a></p></div>
    <div class="quick-utils">
        <a href="javascript:void(0)" onclick="SearchAutoComplete.toggleAutoCompleteCookie(); return false;" class="btn_onoff">자동완성 <strong class="btn_on">끄기</strong><strong class="btn_off">켜기</strong></a>
        <a href="javascript:void(0)" onclick="SearchAutoComplete.hideResult(); return false;" class="btn_close"><span>닫기</span></a>
    </div>
</div>

<script type="text/template" id="listKeywordRecentTemplate">
    <li class="listKeywordRow {{lastCss}}" data-type="listKeywordRecent" data-value="{{keywordRecentValue}}" title="{{keywordRecentValue}}"><a href="javascript:void(0)" onclick="SearchAutoComplete.setAndShowRecruitment('{{keywordRecentValue}}'); return false;">{{keywordRecent}}</a> <button class="btn_delete" data-value="{{keywordRecentValue}}"></button></li>
</script>

<script type="text/template" id="listKeywordSuggestTemplate">
    <li class="listKeywordRow rel" data-type="listKeywordSuggest" data-value="{{keywordSuggestValue}}" title="{{keywordSuggestValue}}"><a href="javascript:void(0)" onclick="SearchAutoComplete.setAndShowRecruitment('{{keywordSuggestValue}}'); return false;">{{keywordSuggest}}</a></li>
</script>

<script type="text/template" id="listRecruitmentTemplate">
    <li data-type="listRecruitment">
        <a href="{{urlRecruit}}" class="link" target="_blank">
            <span class="corp">{{companyName}}</span>
            <span class="subject">{{recruitSubject}}</span>
            <span class="meta">{{recruitInfo}}</span>
        </a>
        {{button}}
        <span class="dday {{finalCss}}">{{d-day}}</span>
    </li>
</script>

<script type="text/template" id="listShortCutTemplate">
    <li><a href="{{urlShortCut}}" class="fcy" target="_blank" onmousedown="try{n_trackEvent('quick_search', 'balogo' , 'list', '');}catch(e){}">{{shortCut}}</a></li>
</script>

<script type="text/template" id="scrapBtnTemplate">
    <a href="javascript:void(0)" class="scrap" onclick="SearchAutoComplete.scrapRecruit('{{recIdx}}'); return false;" onmousedown="try{n_trackEvent('quick_search', 'scrap' , 'button', '');}catch(e){}"><img src="//www.saraminimage.co.kr/ui/common/header/btn_scrap_txt2.png" alt="scrap" /></a>
</script>

<script type="text/template" id="quickApplyBtnTemplate">
    <button class="sri_btn_xs" onclick="try{quickApplyForm('{{recIdx}}', '', 't_category=search&t_content=quick_search','searchType=quick_search&searchWord={{keyword}}');return false;}catch(e){}; return false;" onmousedown="try{n_trackEvent('apply', 'quick_search', 'quick_apply', '');}catch(e){}" title="클릭하면 입사지원할 수 있는 창이 뜹니다."><span class="sri_btn_immediately">즉시지원</span></button>
</script>

<script type="text/template" id="quickApplyEtcBtnTemplate">
    <a class="sri_btn_xs" href="{{applyEtcRecUrl}}" target="_blank" title="{{applyTitle}}"><span class="{{applyClass}}">{{applyName}}</span></a>
</script></div>
    <div id="searchAutoCompleteTemplate" style="display:none"></div>
</div>
        <div class="wrap_member">
    <div class="member_option">
    <div id="nologin_area" class="box_member">
        <a href="/zf_user/auth?url=%2Fzf_user%2Fjobs%2Frelay%2Fview%3FisMypage%3Dno%26rec_idx%3D38655001%26recommend_ids%3DeJxNj8ERAzEIA6vJH5AR8E4h7r%252BL2PGNuecyEixIZilqxohPfPHCOf6DMCZsevlBBbUmiwcBpjdaaEmHbaT4dOrTZQ656LQSrlOnyxGSu%252FugSFaHRwTULlK5RBojodHIFOC1yrfz1RBQsiUvPh%252FTuFx6WS0vtPVKu15rB5bYxh8IoEhm%26view_type%3Dlist%26gz%3D1" class="link_login track_event" data-track_event="section|gnb|layer_sign|signin">
            <span class="photo"></span>
            <span class="name">로그인하세요</span>
        </a>
        <div class="layer_box_member">
            <ul class="list nologin">
                <li class="btn_link"><a href="/zf_user/auth?ut=p" class="track_event" data-track_event="section|gnb|layer_sign|signin01"><strong>개인서비스</strong> 바로가기<span class="sri_gnb_option ic_go_arrow"></span></a></li>
                <li><a href="/zf_user/member/resume-manage/write?template_cd=1&amp;ref_menu=gnb" class="track_event" data-track_event="section|gnb|layer_sign|signin02">이력서 관리</a></li>
                <li><a href="/zf_user/member/avatar/list" class="track_event ico_recommend" data-track_event="section|gnb|layer_sign|signin03">추천</a></li>
                <li><a href="/zf_user/member/suited-recruit-mail/list" class="track_event" data-track_event="section|gnb|layer_sign|signin04">맞춤채용 정보</a></li>
            </ul>
            <ul class="list nologin">
                <li class="btn_link"><a href="/zf_user/auth?ut=c" class="track_event" data-track_event="section|gnb|layer_sign|signin05"><strong>기업서비스</strong> 바로가기<span class="sri_gnb_option ic_go_arrow"></span></a></li>
                <li><a href="/zf_user/recruit-manage" class="track_event" data-track_event="section|gnb|layer_sign|signin06">채용공고 등록</a></li>
                <li><a href="/zf_user/company/recruit-manage" class="track_event" data-track_event="section|gnb|layer_sign|signin07">공고/지원자 관리</a></li>
                <li><a href="/zf_user/service/products?part_id=recruit_ads" class="track_event" data-track_event="section|gnb|layer_comp|signin08">채용 상품 안내</a></li>
                <li class="com_member_link"><a href="/zf_user/event/company-encourage?inner_source=saramin&amp;inner_medium=banner&amp;inner_campaign=sub_top_login&amp;inner_term=com_encourage" target="_blank" title="기업 안내 페이지로 이동합니다."><img src="//www.saraminimage.co.kr/sri/common/img/img_member_menu.png" width="164" height="52" alt="딱 맞는 인 재추천부터 입사제의까지!"></a></li>
            </ul>
        </div>
    </div>
    <div class="box_member join_member">
        <a href="/zf_user/member/registration/join" class="track_event" data-track_event="section|gnb|layer_sign|signup">회원가입</a>
    </div>
</div>
</div>        <div id="sri_gnb_whole" class="wrap_nav whole">
            <div class="blind">전체채용정보</div>
            <ul id="" class="list_gnb ahm nav" role="navigation">
                <li id="recruit-nav" class="depth1 is_depth2">
    <a href="/zf_user/curation" class="depth1_link track_event total_menu" onfocus="job_nav.focusMenu();" data-track_event="section|gnb|menu|total"><span class="blind ic_total_menu">전체 채용정보</span></a>
    <div class="wrap_depth2 gnb_sub_menu">
        <div class="gnb_sub_home">
            <div><a href="/zf_user/curation" class="track_event" data-track_event="section|gnb|public|m900"><strong>전체 채용정보 홈</strong></a></div>
        </div>
        <ul class="recruit_info_nav depth1">
            <li class="depth2">
                <div class="title_depth2"><a href="/zf_user/area-recruit" class="track_event" data-track_event="section|gnb|public|m021">지역별</a></div>
                <ul class="depth3">
                    <li>
                        <a href="/zf_user/jobs/list/domestic?loc_mcd=101000" class="track_event" data-track_event="section|gnb|public|m021">서울</a> <span class="separate"></span>
                        <a href="/zf_user/jobs/list/domestic?loc_mcd=102000" class="track_event" data-track_event="section|gnb|public|m021">경기</a> <span class="separate"></span>
                        <a href="/zf_user/jobs/list/domestic?loc_mcd=108000" class="track_event" data-track_event="section|gnb|public|m021">인천</a> <span class="separate"></span>
                        <a href="/zf_user/jobs/list/domestic?loc_mcd=106000" class="track_event" data-track_event="section|gnb|public|m021">부산</a>
                    </li>
                    <li>
                        <a href="/zf_user/jobs/list/domestic?loc_mcd=104000" class="track_event" data-track_event="section|gnb|public|m021">대구</a> <span class="separate"></span>
                        <a href="/zf_user/jobs/list/domestic?loc_mcd=105000" class="track_event" data-track_event="section|gnb|public|m021">대전</a> <span class="separate"></span>
                        <a href="/zf_user/jobs/list/domestic?loc_mcd=103000" class="track_event" data-track_event="section|gnb|public|m021">광주</a> <span class="separate"></span>
                        <a href="/zf_user/jobs/list/domestic?loc_mcd=107000" class="track_event" data-track_event="section|gnb|public|m021">울산</a>
                    </li>
                    <li>
                        <a href="/zf_user/jobs/list/domestic?loc_mcd=118000" class="track_event" data-track_event="section|gnb|public|m021">세종</a> <span class="separate"></span>
                        <a href="/zf_user/jobs/list/domestic?loc_mcd=109000" class="track_event" data-track_event="section|gnb|public|m021">강원</a> <span class="separate"></span>
                        <a href="/zf_user/jobs/list/domestic?loc_mcd=110000" class="track_event" data-track_event="section|gnb|public|m021">경남</a> <span class="separate"></span>
                        <a href="/zf_user/jobs/list/domestic?loc_mcd=111000" class="track_event" data-track_event="section|gnb|public|m021">경북</a>
                    </li>
                    <li>
                        <a href="/zf_user/jobs/list/domestic?loc_mcd=112000" class="track_event" data-track_event="section|gnb|public|m021">전남</a> <span class="separate"></span>
                        <a href="/zf_user/jobs/list/domestic?loc_mcd=113000" class="track_event" data-track_event="section|gnb|public|m021">전북</a> <span class="separate"></span>
                        <a href="/zf_user/jobs/list/domestic?loc_mcd=115000" class="track_event" data-track_event="section|gnb|public|m021">충남</a> <span class="separate"></span>
                        <a href="/zf_user/jobs/list/domestic?loc_mcd=114000" class="track_event" data-track_event="section|gnb|public|m021">충북</a>

                    </li>
                    <li>
                        <a href="/zf_user/jobs/list/domestic?loc_mcd=116000" class="track_event" data-track_event="section|gnb|public|m021">제주</a> <span class="separate"></span>
                        <a href="/zf_user/area-recruit/index-foreign-map" class="track_event" data-track_event="section|gnb|public|m022">해외</a> <span class="separate"></span>
                        <a href="/zf_user/jobs/list/subway" class="track_event" data-track_event="">역세권별 <img class="icon_new" width="13" height="12" alt="new" src="http://www.saraminimage.co.kr/ui/common/nav/ico_new_170105.gif"></a>
                    </li>
                </ul>
            </li>
            <li class="depth2">
                <div class="title_depth2"><a href="/zf_user/upjikjong-recruit/select-upjikjong/recruitform_type/classified" class="track_event" data-track_event="section|gnb|public|m030">직업별(직종)</a></div>
                <ul class="depth3">
                    <li>
                        <a href="/zf_user/jobs/list/job-category?cat_bcd=1" class="track_event" data-track_event="section|gnb|public|m030">경영∙사무</a> <span class="separate"></span>
                        <a href="/zf_user/jobs/list/job-category?cat_bcd=2" class="track_event" data-track_event="section|gnb|public|m030">영업∙고객상담</a>
                    </li>
                    <li>
                        <a href="/zf_user/jobs/list/job-category?cat_bcd=4" class="track_event" data-track_event="section|gnb|public|m030">IT∙인터넷</a> <span class="separate"></span>
                        <a href="/zf_user/jobs/list/job-category?cat_bcd=12" class="track_event" data-track_event="section|gnb|public|m030">디자인</a> <span class="separate"></span>
                        <a href="/zf_user/jobs/list/job-category?cat_bcd=11" class="track_event" data-track_event="section|gnb|public|m030">서비스</a>
                    </li>
                    <li>
                        <a href="/zf_user/jobs/list/job-category?cat_bcd=5" class="track_event" data-track_event="section|gnb|public|m030">전문직</a> <span class="separate"></span>
                        <a href="/zf_user/jobs/list/job-category?cat_bcd=13" class="track_event" data-track_event="section|gnb|public|m030">의료</a> <span class="separate"></span>
                        <a href="/zf_user/jobs/list/job-category?cat_bcd=3" class="track_event" data-track_event="section|gnb|public|m030">생산∙제조</a>
                    </li>
                    <li>
                        <a href="/zf_user/jobs/list/job-category?cat_bcd=9" class="track_event" data-track_event="section|gnb|public|m030">건설</a> <span class="separate"></span>
                        <a href="/zf_user/jobs/list/job-category?cat_bcd=10" class="track_event" data-track_event="section|gnb|public|m030">유통∙무역</a> <span class="separate"></span>
                        <a href="/zf_user/jobs/list/job-category?cat_bcd=7" class="track_event" data-track_event="section|gnb|public|m030">미디어</a>
                    </li>
                    <li>
                        <a href="/zf_user/jobs/list/job-category?cat_bcd=6" class="track_event" data-track_event="section|gnb|public|m030">교육</a> <span class="separate"></span>
                        <a href="/zf_user/jobs/list/job-category?cat_bcd=8" class="track_event" data-track_event="section|gnb|public|m030">특수계층∙공공</a>
                    </li>
                </ul>
            </li>
            <li class="depth2">
                <div class="title_depth2"><a href="/zf_user/curation" class="track_event" data-track_event="section|gnb|public|curation">큐레이션</a></div>
                <ul class="depth3">
                                                <li>
                                                                    <a href="/zf_user/jobs/list/curation?category_seq=30" class="track_event" data-track_event="section|gnb|public|cu030">연봉관</a>
                                                                                                    <span class="separate"></span>
                                    <a href="/zf_user/jobs/list/curation?category_seq=31" class="track_event" data-track_event="section|gnb|public|cu030">복지관</a>
                                                            </li>
                                                        <li>
                                                                    <a href="/zf_user/jobs/list/curation?category_seq=33" class="track_event" data-track_event="section|gnb|public|cu033">HOT공고</a>
                                                                                            </li>
                                            </ul>
            </li>
            <li class="depth2">
                <div class="title_depth2"><a href="/zf_user/jobs/public/list" target="_blank" class="track_event" data-track_event="section|gnb|public|m011">공채의 명가</a></div>
                <ul class="depth3">
                    <li><a href="/zf_user/jobs/public/list" class="track_event" data-track_event="section|gnb|public|m012">1000대기업 공채</a></li>
                    <li><a href="/zf_user/jobs/public/list?sort=ud&amp;quick_apply=&amp;search_day=&amp;keyword=&amp;company_scale%5B%5D=3#listTop" class="track_event" data-track_event="">중견기업 공채</a></li>
                    <li>
                        <a href="/zf_user/calendar" target="_blank" class="track_event" data-track_event="section|gnb|public|m013">공채 달력</a> <span class="separate"></span>
                        <a href="/zf_user/public-recruit/coverletter-list" class="track_event" data-track_event="section|gnb|public|m014">합격자소서</a>
                    </li>
                    <li>
                        <a href="/zf_user/educe/spec-information" class="track_event" data-track_event="section|gnb|public|m016">합격스펙</a>
                    </li>
                </ul>
            </li>
            <li class="depth2 type_long_height">
                <div class="title_depth2">기업별</div>
                <ul class="depth3">
                    <li>
                        <a href="/zf_user/search?company_type=scale001&amp;open_search_detail=y" class="track_event" data-track_event="section|gnb|public|m050">대기업</a> <span class="separate"></span>
                        <a href="/zf_user/search?company_type=foreign&amp;open_search_detail=y" class="track_event" data-track_event="section|gnb|public|m050">외국계 기업</a>
                    </li>
                    <li><a href="/zf_user/search?company_type=public&amp;open_search_detail=y" class="track_event" data-track_event="section|gnb|public|m050">공사∙공기업∙공공기관</a></li>
                    <li>
                        <a href="/zf_user/search?company_type=kosdaq%2Ckospi%2Ckonex&amp;open_search_detail=y" class="track_event" data-track_event="section|gnb|public|m050">상장기업</a> <span class="separate"></span>
                        <a href="/zf_user/search?company_type=goodcompany%2Cmain-biz%2Cinnobiz%2Cventure%2Cw-small-giant&amp;open_search_detail=y" class="track_event" data-track_event="section|gnb|public|m050">강소∙인증기업</a>
                    </li>
                </ul>
            </li>
            <li class="depth2 type_long_height">
                <div class="title_depth2"><a href="/zf_user/upjikjong-recruit/select-upjikjong/recruitform_type/industrial" class="track_event" data-track_event="section|gnb|public|m040">산업별(업종)</a></div>
                <ul class="depth3">
                    <li>
                        <a href="/zf_user/jobs/list/industry?ind_bcd=1" class="track_event" data-track_event="section|gnb|public|m040">서비스업</a> <span class="separate"></span>
                        <a href="/zf_user/jobs/list/industry?ind_bcd=7" class="track_event" data-track_event="section|gnb|public|m040">의료∙제약∙복지</a>
                    </li>
                    <li>
                        <a href="/zf_user/jobs/list/industry?ind_bcd=2" class="track_event" data-track_event="section|gnb|public|m040">제조∙화학</a> <span class="separate"></span>
                        <a href="/zf_user/jobs/list/industry?ind_bcd=8" class="track_event" data-track_event="section|gnb|public|m040">판매∙유통</a>
                    </li>
                    <li>
                        <a href="/zf_user/jobs/list/industry?ind_bcd=3" class="track_event" data-track_event="section|gnb|public|m040">IT∙웹∙통신</a> <span class="separate"></span>
                        <a href="/zf_user/jobs/list/industry?ind_bcd=9" class="track_event" data-track_event="section|gnb|public|m040">건설업</a>
                    </li>
                    <li>
                        <a href="/zf_user/jobs/list/industry?ind_bcd=6" class="track_event" data-track_event="section|gnb|public|m040">교육업</a> <span class="separate"></span>
                        <a href="/zf_user/jobs/list/industry?ind_bcd=5" class="track_event" data-track_event="section|gnb|public|m040">미디어∙디자인</a>
                    </li>
                    <li>
                        <a href="/zf_user/jobs/list/industry?ind_bcd=4" class="track_event" data-track_event="section|gnb|public|m040">은행∙금융업</a> <span class="separate"></span>
                        <a href="/zf_user/jobs/list/industry?ind_bcd=10" class="track_event" data-track_event="section|gnb|public|m040">기관∙협회</a>
                    </li>
                </ul>
            </li>
            <li class="depth2 type_long_height">
                <div class="title_depth2">전공별</div>
                <ul class="depth3">
                    <li>
                        <a href="/zf_user/search?major_cd=maj021&amp;open_search_detail=y" class="track_event" data-track_event="section|gnb|public|m080">기계공학</a> <span class="separate"></span>
                        <a href="/zf_user/search?major_cd=maj014%2Cmaj055&amp;open_search_detail=y" class="track_event" data-track_event="section|gnb|public|m080">전기공학</a>
                    </li>
                    <li>
                        <a href="/zf_user/search?major_cd=maj015&amp;open_search_detail=y" class="track_event" data-track_event="section|gnb|public|m080">컴퓨터공학</a> <span class="separate"></span>
                        <a href="/zf_user/search?major_cd=maj018&amp;open_search_detail=y" class="track_event" data-track_event="section|gnb|public|m080">건축∙토목</a>
                    </li>
                    <li>
                        <a href="/zf_user/search?major_cd=maj016%2Cmaj022&amp;open_search_detail=y" class="track_event" data-track_event="section|gnb|public|m080">재료∙금속</a><span class="separate"></span>
                        <a href="/zf_user/search?major_cd=maj017%2Cmaj049&amp;open_search_detail=y" class="track_event" data-track_event="section|gnb|public|m080">화학공학</a>

                    </li>
                    <li>
                        <a href="/zf_user/search?major_cd=maj054%2Cmaj050&amp;open_search_detail=y" class="track_event" data-track_event="section|gnb|public|m080">생물∙생명</a> <span class="separate"></span>
                        <a href="/zf_user/search?major_cd=maj020&amp;open_search_detail=y" class="track_event" data-track_event="section|gnb|public|m080">산업공학</a>
                    </li>
                    <li>
                        <a href="/zf_user/search?major_cd=maj003%2Cmaj004&amp;open_search_detail=y" class="track_event" data-track_event="section|gnb|public|m080">인문∙사회</a> <span class="separate"></span>
                        <a href="/zf_user/search?major_cd=maj008&amp;open_search_detail=y" class="track_event" data-track_event="section|gnb|public|m080">상경</a> <span class="separate"></span><a href="/zf_user/search?major_cd=maj002&amp;open_search_detail=y" class="track_event" data-track_event="section|gnb|public|m080">어학</a>
                    </li>
                    <li>
                        <a href="/zf_user/search?major_cd=maj009&amp;open_search_detail=y" class="track_event" data-track_event="section|gnb|public|m080">법학</a> <span class="separate"></span>
                        <a href="/zf_user/search?major_cd=maj010&amp;open_search_detail=y" class="track_event" data-track_event="section|gnb|public|m080">사범</a> <span class="separate"></span>
                        <a href="/zf_user/search?major_cd=maj006&amp;open_search_detail=y" class="track_event" data-track_event="section|gnb|public|m080">예체능</a>
                    </li>
                </ul>
            </li>
            <li class="depth2 type_long_height">
                <div class="title_depth2">학력별</div>
                <ul class="depth3">
                    <li><a href="/zf_user/jobs/list/highschool" class="track_event" data-track_event="section|gnb|public|m060">고졸채용</a></li>
                    <li><a href="/zf_user/search?edu_min=7&amp;edu_max=10&amp;preview_fl=y" class="track_event" data-track_event="section|gnb|public|m060">2,3년제 채용</a></li>
                    <li><a href="/zf_user/search?edu_min=9&amp;edu_max=13&amp;preview_fl=y" class="track_event" data-track_event="section|gnb|public|m060">석박사 채용</a></li>
                </ul>
            </li>
            <li class="depth2 direct_link_menu">
                    <div class="title_depth2">사람인 서비스</div>
                <ul class="link_menu">
                    <li>
                                                                            <a href="/zf_user/member/avatar/list" class="track_event ico_recommend" data-track_event="">추천</a>
                                                                    <a href="/zf_user/companylab" class="track_event ico_salary" data-track_event="section|gnb|public|m180">기업연구소</a>
                                    <a href="/zf_user/talent/search" class="track_event ico_talent" data-track_event="section|gnb|public|m150">인재검색</a>
                                            <a href="/zf_user/member/profile/svq-view" class="track_event ico_svq" data-track_event="section|gnb|public|svq">인적성검사</a>

                            </li>
                    </ul>
                <ul class="link_menu">
                    <li>
                        <a href="/zf_user/jobs/list/highschool" class="track_event" data-track_event="section|gnb|public|m090">고졸채용 <img class="icon_new" width="13" height="12" alt="new" src="//www.saraminimage.co.kr/ui/common/nav/ico_renew.png"></a>
                        <a href="/zf_user/jobs/theme/main" class="track_event" data-track_event="section|gnb|theme|m180">채용관 <img class="icon_new" width="13" height="12" alt="new" src="http://www.saraminimage.co.kr/ui/common/nav/ico_new_170105.gif"></a>
                        <a href="/zf_user/jobs/list/headhunting" class="track_event" data-track_event="section|gnb|public|m110">헤드헌팅</a>
                        <a href="/zf_user/jobs/list/dispatch" class="track_event" data-track_event="section|gnb|public|m120">파견/대행</a>
                    </li>
                </ul>
                <ul class="link_menu">
                    <li>
                        <a href="/zf_user/help" class="track_event" data-track_event="section|gnb|public|m170">고객센터</a>
                        <a href="https://play.google.com/store/apps/details?id=kr.co.saramin.brandapp&amp;referer=utm_source%3Dsaramin%26utm_medium%3Dreferral%26utm_campaign%3Dsaramin-app%26utm_content%3Dmobile_layer" target="_blank" class="new_window track_event" data-track_event="section|gnb|public|m160">사람인 앱 설치</a>
                        <a href="http://www.otwojob.com/" class="new_window track_event" target="_blank" data-track_event="section|gnb|public|banner">재능마켓 오투잡</a>
                    </li>
                    <li><a href="/zf_user/jobs/hot100" class="btn_hightschool_saramin track_event" data-track_event="section|gnb|public|hot100">인기공고 <strong class="point">HOT100</strong></a></li>
                </ul>
            </li>
        </ul>
    </div>
</li>            </ul>
        </div>
    </div>
</header>    <div id="sri_section">
                <div id="sri_wrap">
            <div id="content">

    <div class="jview_progress" style="display: none;">
        <div class="row">
        </div>
        <!--
        <div class="on"></div>
        <div></div>
        -->
    </div>
    <div class="wrap_jview">
            <div class="jview jview-0-38655001"><div class="wrap_jv_cont"><input type="hidden" name="track_url_0" value="t_category=relay_view&amp;t_content=relay_view_list&amp;t_ref=&amp;t_ref_content=&amp;t_ref_scnid=&amp;dpId=" class="track_url" data-view_type="list" id="track_url_0"><input type="hidden" name="logging_url_38655001" value="" class="logging-url" id="logging_url_38655001"><div class="wrap_jv_header"><div class="jv_header" data-rec_idx="38655001" data-rec_seq="0"><a href="/zf_user/company-info/view?csn=5508800070&amp;popup_yn=y" class="company" target="_blank" onclick="window.open(this.href, ''); return false;" onmousedown="try{n_trackEvent('relay_view', 'title', 'company', '');}catch(e){}">
                (주)매그파이소프트            </a><button type="button" csn="5508800070" title="관심기업 등록" del_fl="n" class="btn_jview spr_jview btn_interest" onclick="try{Saramin.btnJob('favor', this, '', 'quick_login');}catch(e){}" onmousedown="try {n_trackEvent('relay_view', 'title', 'favor', '');}catch(e){}" first_nudge="off"><span>관심기업 등록</span></button><h1 class="tit_job">
                        웹 /응용프로그램  개발자  모집        </h1><button type="button" class="btn_scrap  scrap-38655001" title="공고스크랩" onclick="Saramin.btnJob('scrap', this, '', 'quick_login');" scraped="n" rec_idx="38655001" imgtype="button" onmousedown="try{n_trackEvent('relay_view', 'summary', 'scrap', '');}catch(e){}"><span class="txt_scrap">3</span></button><div class="btn_apply"><span class="dday">D-11</span><button class="sri_btn_lg for_btn_event" title="클릭하 면 입사지원할 수 있는 창이 뜹니다." onclick="try{quickApplyForm('38655001','','t_category=relay_view&amp;t_content=relay_view_list&amp;t_ref=&amp;t_ref_content=&amp;t_ref_scnid=&amp;dpId=&amp;inner_source=saramin&amp;inner_medium=pattern&amp;inner_campaign=relay_view_apply_0&amp;inner_term=list', ''); return false;} catch (e) {}; return false;" onmousedown="try{n_trackEvent('relay_view','summary','quick_apply','');}catch(e){}"><span class="sri_btn_immediately">즉시지원</span></button></div></div></div><div class="jv_cont jv_summary"><div class="jv_title blind">핵심 정보</div><div class="cont"><div class="col"><dl><dt>경력</dt><dd><strong>신입·경력 1~10년</strong></dd></dl><dl><dt>학력</dt><dd><strong>대졸(4년 제) 이상(예정자 가능)</strong></dd></dl><dl><dt>근무형태</dt><dd><strong>정규직</strong> 수습기간 3개월                    </dd></dl><dl><dt>우대사항</dt><dd class="preferred"><div class="toolTipWrap"><button type="button" title="상세보기" class="spr_jview btn_jview btn_tooltip"><span>상세보기</span></button><div class="toolTip"><span class="tail tail_top_left"></span><div class="toolTipCont txtLeft"><ul class="toolTipTxt"><li><span>전공</span>컴퓨터/시스템공학</li><li><span>자격증</span>정보처리기사, 정보처리산업기사</li><li><span>활동/경험</span>해당직무 근무경험</li></ul><p class="txt_noti">※ 지원부문별 상이할 수 있으니, 상세요강에서 확인해주세요.</p></div><button type="button" class="btnClose"><span class="blind">닫기</span></button></div></div></dd></dl></div><div class="col"><dl><dt>급여</dt><dd>면접 후 결정                    </dd></dl><dl><dt>직급/직책</dt><dd>
            면접 후 결정        </dd></dl><dl><dt>근무일시</dt><dd>주 5일(월~금) 오전 9시~오후 6시</dd></dl><dl><dt>근무지역</dt><dd>
            대전 중구                            <button type="button" title="지도" class="spr_jview btn_jview btn_move_map"><span>지도</span></button></dd></dl></div><ul class="meta"><li>조회수 <strong>289</strong></li><li class="wrap_share"><div class="share"><button type="button" class="spr_jview btn_jview btn_share"><span>공유하기</span></button><ul class="spr_jview list_share"><li><a href="http://www.facebook.com/share.php?api_key=137906922916817&amp;display=popup&amp;u=http%3A%2F%2Fwww.saramin.co.kr%2Fzf_user%2Fjobs%2Frelay%2Fview%3Frec_idx%3D38655001%26view_type%3Dlist" class="spr_jview facebook" onclick="window.open(this.href, this.target, 'width=578,height=380'); return false;" onmousedown="try{n_trackEvent('relay_view', 'top', 'facebook', '');}catch(e){}" title="페이스북 공유하기"><span class="blind">페이스북</span></a></li><li><a href="http://twitter.com/share?url=http%3A%2F%2Fwww.saramin.co.kr%2Fzf_user%2Fjobs%2Frelay%2Fview%3Frec_idx%3D38655001%26view_type%3Dlist&amp;text=%EC%9B%B9%20%2F%EC%9D%91%EC%9A%A9%ED%94%84%EB%A1%9C%EA%B7%B8%EB%9E%A8%20%EA%B0%9C%EB%B0%9C%EC%9E%90%20%EB%AA%A8%EC%A7%91%20-%20%28%EC%A3%BC%29%EB%A7%A4%EA%B7%B8%ED%8C%8C%EC%9D%B4%EC%86%8C%ED%94%84%ED%8A%B8%20%23saramin" class="spr_jview twitter" onclick="window.open(this.href, this.target, 'width=554,height=454'); return false;" onmousedown="try{n_trackEvent('relay_view', 'top', 'twitter', '');}catch(e){}" title="트위터 공유하기"><span class="blind">트위터</span></a></li><li><button type="button" class="spr_jview copy_url" title="공고 주소 복사하기" onclick="JobsView.copyUrl('http://www.saramin.co.kr/zf_user/jobs/relay/view?rec_idx=38655001&amp;view_type=list');" onmousedown="try{n_trackEvent('relay_view', 'top', 'copyurl', '' );}catch(e){}"><span class="blind">URL복사</span></button></li><li><button type="button" class="spr_jview send_sms" title="이 공고 내 폰으로 전송하기" onclick="Saramin.showQuickLogin();" onmousedown="try{n_trackEvent('relay_view', 'top', 'sendsms', '');}catch(e){}"><span class="blind">SMS발송</span></button></li></ul></div></li></ul></div></div><div class="jv_cont jv_detail"><div class="jv_title blind">상세요강</div><div class="cont"><iframe name="iframe_content_0" id="iframe_content_0" class="iframe_content" width="860" scrolling="no" frameborder="0" marginheight="0" marginwidth="0" src="/zf_user/jobs/relay/view-detail?rec_idx=38655001&amp;rec_seq=0" title="상세요강" height="2043px"></iframe></div></div><script type="text/javascript">
    var i;

    window.onload = function () {
        var aTagList = document.querySelectorAll('.user_content a,area');
        for (i = 0; i < aTagList.length; i++ ){
            aTagList[i].addEventListener('mousedown', function (e) {
                var item = e.currentTarget;
                var href = item.getAttribute('href') || '';

                checkUpdateHomepage(href);
            });
        }

        var checkUpdateHomepage = function (href) {
            var isFile = false,
                urlLastSpiceByDot = href.split('.').pop().toLowerCase(),
                fileExtWord = ['hwp', 'doc', 'docx', 'ppt', 'pptx', 'pdf', 'xls', 'xlsx', 'rtf', 'gul'],
                fileExtCompress = ['zip', 'alz', 'rar', 'lzh', 'arj', 'egg', 'tar', 'sit'],
                fileExtImageFlash = ['jpg', 'gif', 'png', 'psd', 'fla', 'ai', 'jpe', 'jpeg', 'tif', 'tiff', 'pcx', 'swf'],
                fileExt;

            fileExt = fileExtWord.concat(fileExtCompress).concat(fileExtImageFlash);
            isFile = (fileExt.indexOf(urlLastSpiceByDot) !== -1);

            if (href != '' && isFile === false && href.indexOf('mailto:') === -1
                && href.indexOf('pds.saramin.co.kr') === -1 && href.indexOf('uf.daum.net') === -1 && href.indexOf('drive.google.com') === -1
            ) {
                try { Saramin.updateHomepageLink('38655001', 'homepage'); } catch (e) {}
            }
        }
    }
</script><div class="jv_cont jv_benefit"><div class="jv_title">복리후생</div><div class="cont"><div class="layer_group"><div class="layer"><div class="row"><dl class="col"><dt>지원금/보험</dt><dd data-origin="각종 경조사 지원">
                                각종 경조사 지원                            </dd></dl><dl class="col"><dt>급여제도</dt><dd data-origin="퇴직연금, 인센티브제, 장기근속자 포상, 우수사원포상, 퇴직금, 4대 보험">
                                퇴직연금, 인센티브제, 장기근속자 포상, 우수사원포상, 퇴직금, 4대 보험                            </dd></dl><dl class="col"><dt>선물</dt><dd data-origin="명절선물/귀향비">
                                명절선물/귀향비                            </dd></dl></div><div class="row"><dl class="col"><dt>교육/생활</dt><dd data-origin="우수사원시상식, 워크샵, 도서구입비지원, 자격증취득지원, 교육비 지원, 저녁식사 제 공, 음료제공(차, 커피)">
                                우수사원시상식, 워크샵, 도서구입비지원, 자격증취득지원, 교육비 지원, 저녁식사...                            </dd></dl><dl class="col"><dt>근무 환경</dt><dd data-origin="회의실, 노트북, 사무용품 지급">
                                회의실, 노트북, 사무용품 지급                            </dd></dl><dl class="col"><dt> 조직문화</dt><dd data-origin="회식강요 안함, 야근강요 안함, 자유복장">
                                회식강요 안함, 야근강요 안함, 자유복장                            </dd></dl></div><div class="row"><dl class="col"><dt>리프레시</dt><dd data-origin="연차, 경조휴가제, 반차, Refresh휴가, 근로자의 날 휴무, 포상휴가">
                                연차, 경조휴가제, 반차, Refresh휴가, 근로자의 날 휴무, 포상휴가                            </dd></dl><dl class="col"></dl><dl class="col"></dl></div></div></div><button type="button" class="btn_more_cont" onmousedown="try{n_trackEvent('relay_view', 'welfare', 'welfare_more', '');}catch(e){}"><span class="spr_jview">내용 전체보기</span></button></div></div><div id="map_0" class="jv_cont jv_location" data-company-name="(주)매그파이소프트" data-address="(34955) 대전 중구 계룡로 910,  7층(문화동)" data-latitude="36.321097134618476" data-longitude="127.41353275265021" data-hide_fl="n" data-disable_fl="n"><h2 class="jv_title">근무지위치</h2><div class="cont box"><address class="address"><span class="spr_jview txt_adr">(34955) 대전 중구 계룡로 910,  7층(문화동)</span><span class="spr_jview txt_subway">대전 1호선 서대전네거리역에서 200m 이내</span></address><button type="button" class="btn_mapview relay_map" onclick="JobsView.moveMapPage('0', '38655001');" data-type="open"><span class="spr_jview">지도 보기</span></button><div id="mapContainerPop_0" class="layer_pop_manage layer_map" data-loaded="n"><h4>지도 보기</h4><div class="container_map"><div class="wrap_mapapi" id="mapArea_0"><div class="map_view_wrap"><div id="mapContainer_0" class="map_view"><div id="mapWrapper_0" class="view"><div id="mapView_0" style="width: 100%; height: 100%;"></div><div id="roadView_0" style="height:100%; text-align: left;"></div></div></div><div class="btn_map_switch" data-seq="0"><button type="button" class="btn_mapview on" data-type="mapview" onmousedown="try{n_trackEvent('relay_view', 'map', 'open', '');}catch(e){}">지도</button><button type="button" class="btn_skyview" data-type="skyview" onmousedown="try{n_trackEvent('relay_view', 'map', 'skyview', '');}catch(e){}">스카이뷰</button></div><div class="desc"><div class="btns"><button type="button" class="reset">지도초기화</button><button type="button" class="big_map" data-type="wideview" onmousedown="try{n_trackEvent('relay_view', 'map', 'wideview', '');}catch(e){}">크게보기</button><button type="button" class="route" data-type="findtheway" onmousedown="try{n_trackEvent('relay_view', 'map', 'findtheway', '');}catch(e){}">길찾기</button></div></div></div></div></div><button type="button" class="btn_layer_close" onclick="jQuery(this).closest('.jv_location').removeClass('expand');"><span>닫기</span></button></div></div></div><div class="jv_cont jv_howto"><div class="jv_title">접수기간 및 방법</div><div class="cont box"><div class="status"><div class="info_timer" data-remain-time="983481"><span class="txt">남은 기간</span><span class="day">11</span><span class="txt_day">일</span><span class="time">09:11:12</span></div><dl class="info_period"><dt>시작일</dt><dd>2020.08.21 18:00</dd><dt class="end">마감일</dt><dd>2020.09.20 23:59</dd></dl><button class="sri_btn_lg for_btn_event" title="클릭하면 입사지원할 수 있는 창이 뜹니다." onclick="try{quickApplyForm('38655001','','t_category=relay_view&amp;t_content=relay_view_list&amp;t_ref=&amp;t_ref_content=&amp;t_ref_scnid=&amp;dpId=&amp;inner_source=saramin&amp;inner_medium=pattern&amp;inner_campaign=relay_view_apply_0&amp;inner_term=list', ''); return false;} catch (e) {}; return false;" onmousedown="try{n_trackEvent('relay_view','contacts','quick_apply_bt','');}catch(e){}"><span class="sri_btn_immediately">즉시지원</span></button></div><dl class="guide"><dt>지원방법</dt><dd class="method"><button class="sri_btn_1 for_btn_event" title="클릭하면 입사지원할 수 있는 창이 뜹니다." onclick="try{quickApplyForm('38655001','','t_category=relay_view&amp;t_content=relay_view_list&amp;t_ref=&amp;t_ref_content=&amp;t_ref_scnid=&amp;dpId=&amp;inner_source=saramin&amp;inner_medium=pattern&amp;inner_campaign=relay_view_apply_0&amp;inner_term=list', ''); return false;} catch (e) {}; return false;" onmousedown="try{n_trackEvent('relay_view','contacts','quick_apply','');}catch(e){}"><span class="sri_btn_immediately">사람인 즉시지원</span></button></dd><dt>접수양식</dt><dd class="template">
                            사람인 이력서 양식                                                            <div class="toolTipWrap"><button type="button" title="제출서류 보기" class="spr_jview btn_jview btn_tooltip"><span>제출서류 보기</span></button><div class="toolTip"><span class="tail tail_top_center"></span><div class="toolTipCont txtLeft"><strong class="toolTipTit">제출서류</strong><p>1. 입사지원서 : 사진삽입, 연락처, 해당업무 근수년수, 희망연봉 필히 게재<br>
- 사람인 양식 제출<br><br>
2. 경력기술서(경력대상자)<br>
- 경력 : 프로젝트 담당업무 상세 기술 요망<br><br>
3. 자기소개서 <br>
- 사람인 양식 제출</p></div><button type="button" class="btnClose"><span class="blind">닫기</span></button></div></div></dd><dt>담당자</dt><dd class="manager">김형기 (인사팀)</dd><dt>연락처</dt><dd class="info">042-626-0501</dd></dl><p class="noti">마감일은 기업의 사정, 조기마감 등으로 변경될 수 있습니다.</p></div></div><div class="jv_cont jv_statics"><div class="jv_title">지원자 통계</div><div class="cont"><div class="layer_group"><div class="layer"><div class="box_chart narrow count sub"><dl class="total"><dt>지원자수</dt><dd><span>6</span>명</dd></dl><div class="scroll"><dl class="detail"><dt title="웹시스템 개발">웹시스템 개발</dt><dd><span>4</span>명</dd><dt title="응용프로그램  개발">응용프로그램  개발</dt><dd><span>2</span>명</dd></dl></div></div><div class="box_chart narrow"><strong class="tit_stats">경력별 현황</strong><div class="chart_line "><div class="col emph"><em class="legend">신입</em><div class="bar"><div class="fill" style="height:50%"><span class="value">3</span></div></div></div><div class="col "><em class="legend">1년 미만</em><div class="bar"><div class="fill" style="height:0%"><span class="value">0</span></div></div></div><div class="col "><em class="legend">1~3년</em><div class="bar"><div class="fill" style="height:17%"><span class="value">1</span></div></div></div><div class="col "><em class="legend">3~5년</em><div class="bar"><div class="fill" style="height:17%"><span class="value">1</span></div></div></div><div class="col "><em class="legend">5년 이상</em><div class="bar"><div class="fill" style="height:17%"><span class="value">1</span></div></div></div></div></div><div class="box_chart narrow"><strong class="tit_stats">연봉별 현황</strong><div class="chart_line "><div class="col "><em class="legend">2,200<br>미만</em><div class="bar"><div class="fill" style="height:0%"><span class="value">0</span></div></div></div><div class="col emph"><em class="legend">2,200<br>~2,600</em><div class="bar"><div class="fill" style="height:17%"><span class="value">1</span></div></div></div><div class="col emph"><em class="legend">2,600<br>~3,000</em><div class="bar"><div class="fill" style="height:17%"><span class="value">1</span></div></div></div><div class="col emph"><em class="legend">3,000<br>~4,000</em><div class="bar"><div class="fill" style="height:17%"><span class="value">1</span></div></div></div><div class="col emph"><em class="legend">4,000<br>이상</em><div class="bar"><div class="fill" style="height:17%"><span class="value">1</span></div></div></div></div></div><div class="box_chart "><strong class="tit_stats">성별 현황</strong><div class="chart_donut"><!-- donut chart  일때 --><svg class="donut" width="172" height="172" viewBox="0 0 172 172"><circle cx="86" cy="86" r="76" fill="transparent" stroke-width="20" stroke="#acd9f8"></circle><circle cx="86" cy="86" r="76" fill="transparent" stroke-width="20" stroke="#fa6a71" stroke-dasharray="477.521984" stroke-dashoffset="319.93972928"></circle><rect x="151" y="84" width="22" height="4" fill="white"></rect><rect x="151" y="84" width="22" height="4" fill="white" transform="rotate(118.8 86 86)"></rect></svg><div class="legend"><div class="total"><span>지원자수</span></div><dl class="male"><dt class="spr_jview">남자</dt><dd class="perc"><span>67</span>%</dd><dd>4 명</dd></dl><dl class="female"><dt class="spr_jview">여자</dt><dd class="perc"><span>33</span>%</dd><dd>2 명</dd></dl></div></div></div><div class="box_chart "><strong class="tit_stats">연령별 현황</strong><div class="chart_line "><div class="col emph"><em class="legend">20대</em><div class="bar"><div class="fill" style="height:67%"><span class="value">4</span></div></div></div><div class="col "><em class="legend">30대</em><div class="bar"><div class="fill" style="height:17%"><span class="value">1</span></div></div></div><div class="col "><em class="legend">40대</em><div class="bar"><div class="fill" style="height:17%"><span class="value">1</span></div></div></div><div class="col "><em class="legend">50대</em><div class="bar"><div class="fill" style="height:0%"><span class="value">0</span></div></div></div><div class="col "><em class="legend">60대 이상</em><div class="bar"><div class="fill" style="height:0%"><span class="value">0</span></div></div></div></div></div><div class="box_chart "><strong class="tit_stats">학 력별 현황</strong><div class="chart_line "><div class="col "><em class="legend">고졸이하</em><div class="bar"><div class="fill" style="height:0%"><span class="value">0</span></div></div></div><div class="col "><em class="legend">2~3년제</em><div class="bar"><div class="fill" style="height:17%"><span class="value">1</span></div></div></div><div class="col emph"><em class="legend">4년제</em><div class="bar"><div class="fill" style="height:67%"><span class="value">4</span></div></div></div><div class="col "><em class="legend">석사</em><div class="bar"><div class="fill" style="height:17%"><span class="value">1</span></div></div></div><div class="col "><em class="legend">박사</em><div class="bar"><div class="fill" style="height:0%"><span class="value">0</span></div></div></div></div></div><div class="box_chart "><strong class="tit_stats">외국어 현황</strong><div class="chart_line sub"><div class="col "><em class="legend">TOEIC</em><div class="bar"><div class="fill" style="height:17%"><span class="value">1</span></div></div></div><div class="col "><em class="legend">TOEFL</em><div class="bar"><div class="fill" style="height:0%"><span class="value">0</span></div></div></div><div class="col "><em class="legend">TEPS</em><div class="bar"><div class="fill" style="height:0%"><span class="value">0</span></div></div></div><div class="col "><em class="legend">TOEIC Speaking</em><div class="bar"><div class="fill" style="height:0%"><span class="value">0</span></div></div></div><div class="col "><em class="legend">OPIC</em><div class="bar"><div class="fill" style="height:17%"><span class="value">1</span></div></div></div><div class="col "><em class="legend">JPT</em><div class="bar"><div class="fill" style="height:17%"><span class="value">1</span></div></div></div><div class="col "><em class="legend">HSK</em><div class="bar"><div class="fill" style="height:0%"><span class="value">0</span></div></div></div><div class="col emph"><em class="legend">기타</em><div class="bar"><div class="fill" style="height:50%"><span class="value">3</span></div></div></div></div></div><div class="box_chart "><strong class="tit_stats">TOEIC</strong><div class="chart_line sub"><div class="col "><em class="legend">600<br>미만</em><div class="bar"><div class="fill" style="height:0%"><span class="value">0</span></div></div></div><div class="col "><em class="legend">700<br>미만</em><div class="bar"><div class="fill" style="height:0%"><span class="value">0</span></div></div></div><div class="col "><em class="legend">800<br>미만</em><div class="bar"><div class="fill" style="height:0%"><span class="value">0</span></div></div></div><div class="col "><em class="legend">900<br>미만</em><div class="bar"><div class="fill" style="height:0%"><span class="value">0</span></div></div></div><div class="col emph"><em class="legend">900<br>이상</em><div class="bar"><div class="fill" style="height:100%"><span class="value">1</span></div></div></div></div></div><div class="box_chart "><strong class="tit_stats">OPIC</strong><div class="chart_line sub"><div class="col "><em class="legend">IL이하</em><div class="bar"><div class="fill" style="height:0%"><span class="value">0</span></div></div></div><div class="col "><em class="legend">IM1</em><div class="bar"><div class="fill" style="height:0%"><span class="value">0</span></div></div></div><div class="col emph"><em class="legend">IM2</em><div class="bar"><div class="fill" style="height:100%"><span class="value">1</span></div></div></div><div class="col "><em class="legend">IM3</em><div class="bar"><div class="fill" style="height:0%"><span class="value">0</span></div></div></div><div class="col "><em class="legend">IH</em><div class="bar"><div class="fill" style="height:0%"><span class="value">0</span></div></div></div><div class="col "><em class="legend">AL</em><div class="bar"><div class="fill" style="height:0%"><span class="value">0</span></div></div></div></div></div><div class="box_chart "><strong class="tit_stats">JPT</strong><div class="chart_line sub"><div class="col "><em class="legend">600<br>미만</em><div class="bar"><div class="fill" style="height:0%"><span class="value">0</span></div></div></div><div class="col "><em class="legend">700<br>미만</em><div class="bar"><div class="fill" style="height:0%"><span class="value">0</span></div></div></div><div class="col "><em class="legend">800<br>미만</em><div class="bar"><div class="fill" style="height:0%"><span class="value">0</span></div></div></div><div class="col emph"><em class="legend">900<br>미만</em><div class="bar"><div class="fill" style="height:100%"><span class="value">1</span></div></div></div><div class="col "><em class="legend">900<br>이상</em><div class="bar"><div class="fill" style="height:0%"><span class="value">0</span></div></div></div></div></div></div></div><button type="button" class="btn_more_cont" onmousedown="try{n_trackEvent('relay_view', 'statistics', 'statistics_more', '');}catch(e){}"><span class="spr_jview">내용 전체보기</span></button></div></div><div class="jv_cont jv_insatong"><div class="jv_title">인사통</div><div class="cont"><div class="layer_group"><div class="layer"><p class="txt_qna"><span class="company">(주)매그파이소프트</span> 인사담당자님이 <span class="num">3개의</span> 질문에 답변한 내용입니다.
                        <span class="date">20.08.21 18:31</span></p><div class="item item_qna"><dl><dt><span>Q1.</span><strong>근무 환경</strong>은 어떤가요?</dt><dd>내근 100%</dd><dd>비즈니스 캐주얼</dd><dd>분기 1회 회식</dd><dd>대부분 20 ·30대</dd></dl><button type="button" class="btn_like spr_jview " data-idx="38655001-198315260" data-cnt="0" onmousedown="try{n_trackEvent('relay_view', 'insatong', 'insatong_like', '');}catch(e){}">유용해요<span class="count " id="useful-198315260">0</span></button></div><div class="item item_qna"><dl><dt><span>Q2.</span><strong>복지 및 처우</strong>는 어떻게 되나요?</dt><dd>수습기간 급여 100%</dd></dl><button type="button" class="btn_like spr_jview " data-idx="38655001-198315261" data-cnt="0" onmousedown="try{n_trackEvent('relay_view', 'insatong', 'insatong_like', '');}catch(e){}">유용해요<span class="count " id="useful-198315261">0</span></button></div><div class="cont_more"><div class="item item_qna"><dl><dt><span>Q3.</span><strong>면접 및 입사</strong>는 어떻게 진행되나요?</dt><dd>접수기간 중 수시 면접</dd></dl><button type="button" class="btn_like spr_jview " data-idx="38655001-198315262" data-cnt="0" onmousedown="try{n_trackEvent('relay_view', 'insatong', 'insatong_like', '');}catch(e){}">유용해요<span class="count " id="useful-198315262">0</span></button></div></div></div></div><button type="button" class="btn_more_cont" onmousedown="try{n_trackEvent('relay_view', 'insatong', 'insatong_all', '');}catch(e){}"><span class="spr_jview">내용 전체보기</span></button></div></div><div class="jv_cont jv_company"><div class="jv_title">기업정보
                </div><div class="cont box"><div class="logo"><img id="(주)매그파이소프트" alt="(주)매그파이소프트" src="http://pds.saramin.co.kr/company/logo/201712/05/p0hcz4_sfdi-xn74qu_logo.png" width="252" height="70"></div><div class="wrap_info"><div class="title"><span class="company_name">(주)매그파이소프트</span><button type="button" csn="5508800070" title="관심기업 등록" del_fl="n" class="btn_jview spr_jview btn_interest" onclick="try{Saramin.btnJob('favor', this, '', 'quick_login');}catch(e){}" onmousedown="try {n_trackEvent('relay_view', 'companyinfo', 'favor', '');}catch(e){}" first_nudge="off"><span>관심기업 등록</span></button><a href="/zf_user/company-info/view?csn=5508800070" title="기업정보로  이동" class="spr_jview btn_jview btn_link" onclick="window.open(this.href, ''); return false;" onmousedown="try{n_trackEvent('relay_view', 'companyinfo', 'company_more', '');}catch(e){}"><strong>기업정보</strong></a><a target="_blank" href="/zf_user/salaries/total-salary/view?csn=5508800070" title="연봉정보 이동" class="spr_jview btn_jview btn_link" onmousedown="try{n_trackEvent('relay_view', 'salary', 'salary_more', '');}catch(e){}"><span>연봉정보</span></a></div><div class="info"><dl><dt>기업형태</dt><dd>중소기업</dd></dl><dl><dt>사원수<sup>*</sup></dt><dd>18 명 <span>
                             (2019년 기준)</span></dd></dl><dl><dt>업종</dt><dd>응용 소프트웨어 개발 및 공급업</dd></dl><dl><dt>설립일<sup>*</sup></dt><dd>2015년 5월 15일 (업력 5년) </dd></dl><dl><dt>매출액<sup>*</sup></dt><dd>
                                 10억 2,600만원                                                                                                    <span>(2019년 기준)</span></dd></dl><dl><dt>대표자명<sup>*</sup></dt><dd>조화연</dd></dl><dl><dt>홈페이지</dt><dd><a href="http://www.magpiesoft.co.kr" target="_blank">
                                    http://www.magpiesoft.co.kr                                </a></dd></dl><dl class="wide"><dt>기업주소</dt><dd>대전 중구 계룡로 910, 7층 매그파이소프트</dd></dl></div></div><p class="noti"><sup>*</sup> 항목은 본사정보와 다를 수 있습니다.</p></div><div class="cont box sub"><div class="sub_header"><strong>(주)매그파이소프트</strong>기업이 부여받은 기업 인증을 확인해보세요!
        </div><ul class="mark_list"><li onclick="window.open('/zf_user/company-info/sri-certification?seq=212'); return false;"><span>명절에도 풍요롭게</span></li><li onclick="window.open('/zf_user/company-info/sri-certification?seq=1012'); return false;"><span>든든한 퇴근길</span></li><li onclick="window.open('/zf_user/company-info/sri-certification?seq=867'); return false;"><span>플레이샵 지원 기업!</span></li><li onclick="window.open('/zf_user/company-info/sri-certification?seq=219'); return false;"><span>야근 눈치 보지마요</span></li></ul></div></div><div class="wrap_recommend_slide type02 hot_slide" id="hot100-top10-list-38655001"><div class="hot_slide_tit">
    <h4 class="tit">웹개발 <em>HOT100</em></h4>
    <a href="/zf_user/jobs/hot100?cat_cd=404&amp;career_cd=1" target="_blank" class="more_btn hot1000-more" title="더보 기" onmousedown="try{ gtmDataLayerPush('ga_lead', 'hot100', 'jobcategory_recruit', 'more');} catch(e){}">더보기</a>
</div>
<div class="box_recommend_slide">
    <p class="slide_num"><em>1</em>/<span class="slide_total">3</span></p>
    <button type="button" id="recom_btn_prev" class="btn_prev" style="display: none;"><span class="blind">이전</span></button>
    <div class="recommend_list">
        <ul class="list_recomm" style="width: 2628px;">
                                                    <li class="recruit_summary_basic">
                    <a href="/zf_user/jobs/relay/view?rec_idx=38704572&amp;t_ref=jobcategory_recruit&amp;t_ref_content=hot100" class="link_recomm" target="_blank" title="2020년 하반기 현대오트론 신입사원 채용" onmousedown="try{ gtmDataLayerPush('ga_lead', 'hot100', 'jobcategory_recruit', 'view');} catch(e){}"></a>
                    <strong class="recomm_name">현대오트론(주)</strong>
                    <span class="recomm_desc">2020년 하반기 현대오트론 신입사원 채용</span>
                    <span class="recomm_info">
                        <span class="txt_info"><span class="blind">직종</span>#정규직</span>
                        <span class="txt_info"><span class="blind">지역</span>#서울 강남구</span>
                    </span>
                                        <a title="스크랩" style="cursor:pointer" onclick="Saramin.btnJob('scrap',this,'','list');" scraped="n" imgtype="" rec_idx="38704572" class="btn_scrap scrap-38704572">
                        <img src="//www.saraminimage.co.kr/common/bul_sri_star.png">
                    </a>
                    <span class="recruit_func">
                        <span class="blind">공고 마감일</span>
                        <span class="num_dday last">~ 09/21(월)</span>
                        <a class="sri_btn_xs" href="/zf_user/jobs/relay/view?view_type=list&amp;rec_idx=38704572" target="_blank" title="홈페이지 지원" onclick="try{s_trackApply(this, 'relay_view', 'hot100');}catch(e){};" onmousedown="try{ pushDataLayer('ga.lead', 'hot100',jobcategory_recruit, 'apply') } catch(e){}"><span class="sri_btn_homepage_apply">홈페 이지 지원</span></a>                    </span>
                </li>
                                        <li class="recruit_summary_basic">
                    <a href="/zf_user/jobs/relay/view?rec_idx=38681431&amp;t_ref=jobcategory_recruit&amp;t_ref_content=hot100" class="link_recomm" target="_blank" title="2020년 하반기 DB그룹 신입사원 모집 공고" onmousedown="try{ gtmDataLayerPush('ga_lead', 'hot100', 'jobcategory_recruit', 'view');} catch(e){}"></a>
                    <strong class="recomm_name">DB그룹</strong>
                    <span class="recomm_desc">2020년 하반기 DB그룹 신입사원 모집 공고</span>
                    <span class="recomm_info">
                        <span class="txt_info"><span class="blind">직종</span>#정규직</span>
                        <span class="txt_info"><span class="blind">지역</span>#서울전체</span>
                    </span>
                                        <a title="스크랩" style="cursor:pointer" onclick="Saramin.btnJob('scrap',this,'','list');" scraped="n" imgtype="" rec_idx="38681431" class="btn_scrap scrap-38681431">
                        <img src="//www.saraminimage.co.kr/common/bul_sri_star.png">
                    </a>
                    <span class="recruit_func">
                        <span class="blind">공고 마감일</span>
                        <span class="num_dday last">~ 10/06(화)</span>
                        <a class="sri_btn_xs" href="/zf_user/jobs/relay/view?view_type=list&amp;rec_idx=38681431" target="_blank" title="홈페이지 지원" onclick="try{s_trackApply(this, 'relay_view', 'hot100');}catch(e){};" onmousedown="try{ pushDataLayer('ga.lead', 'hot100',jobcategory_recruit, 'apply') } catch(e){}"><span class="sri_btn_homepage_apply">홈페 이지 지원</span></a>                    </span>
                </li>
                                        <li class="recruit_summary_basic">
                    <a href="/zf_user/jobs/relay/view?rec_idx=38704335&amp;t_ref=jobcategory_recruit&amp;t_ref_content=hot100" class="link_recomm" target="_blank" title="한미금융그룹 채용 (부동산 매각, 분양, 영업, 물류센터 개발, PF, 리츠,  구조화 금융,  온라인 마케팅)" onmousedown="try{ gtmDataLayerPush('ga_lead', 'hot100', 'jobcategory_recruit', 'view');} catch(e){}"></a>
                    <strong class="recomm_name">주식회사 한미금융그룹</strong>
                    <span class="recomm_desc">한미금융그룹 채용 (부동산 매각, 분양, 영업, 물류센터 개발, PF, 리츠, 구조 화 금융,  온라인 마케팅)</span>
                    <span class="recomm_info">
                        <span class="txt_info"><span class="blind">직종</span>#정규직</span>
                        <span class="txt_info"><span class="blind">지역</span>#서울 서초구</span>
                    </span>
                                        <a title="스크랩" style="cursor:pointer" onclick="Saramin.btnJob('scrap',this,'','list');" scraped="n" imgtype="" rec_idx="38704335" class="btn_scrap scrap-38704335">
                        <img src="//www.saraminimage.co.kr/common/bul_sri_star.png">
                    </a>
                    <span class="recruit_func">
                        <span class="blind">공고 마감일</span>
                        <span class="num_dday last">~ 09/29(화)</span>
                        <button class="sri_btn_xs" title="클릭하면 입사지원할 수 있는 창이 뜹니다." onclick="try{quickApplyForm('38704335','','t_category=relay_view&amp;t_content=hot100', ''); return false;} catch (e) {}; return false;" onmousedown="try{n_trackEvent('apply','list','quick_apply');}catch(e){}"><span class="sri_btn_immediately">즉시지원</span></button>                    </span>
                </li>
                                        <li class="recruit_summary_basic">
                    <a href="/zf_user/jobs/relay/view?rec_idx=38727042&amp;t_ref=jobcategory_recruit&amp;t_ref_content=hot100" class="link_recomm" target="_blank" title="2020 쉬플리코리아(휴넷 자회사) 채용연계형 인턴십 모집" onmousedown="try{ gtmDataLayerPush('ga_lead', 'hot100', 'jobcategory_recruit', 'view');} catch(e){}"></a>
                    <strong class="recomm_name">쉬플리코리아(주)</strong>
                    <span class="recomm_desc">2020 쉬플리코리아(휴넷 자회사) 채용연계형 인턴십 모집</span>
                    <span class="recomm_info">
                        <span class="txt_info"><span class="blind">직종</span>#인턴직</span>
                        <span class="txt_info"><span class="blind">지역</span>#서울 구로구</span>
                    </span>
                                        <a title="스크랩" style="cursor:pointer" onclick="Saramin.btnJob('scrap',this,'','list');" scraped="n" imgtype="" rec_idx="38727042" class="btn_scrap scrap-38727042">
                        <img src="//www.saraminimage.co.kr/common/bul_sri_star.png">
                    </a>
                    <span class="recruit_func">
                        <span class="blind">공고 마감일</span>
                        <span class="num_dday last">~ 09/20(일)</span>
                        <button class="sri_btn_xs" title="클릭하면 입사지원할 수 있는 창이 뜹니다." onclick="try{quickApplyForm('38727042','','t_category=relay_view&amp;t_content=hot100', ''); return false;} catch (e) {}; return false;" onmousedown="try{n_trackEvent('apply','list','quick_apply');}catch(e){}"><span class="sri_btn_immediately">즉시지원</span></button>                    </span>
                </li>
                                        <li class="recruit_summary_basic">
                    <a href="/zf_user/jobs/relay/view?rec_idx=38721163&amp;t_ref=jobcategory_recruit&amp;t_ref_content=hot100" class="link_recomm" target="_blank" title="2020년 하반기 신입/경력 각 부문 채용" onmousedown="try{ gtmDataLayerPush('ga_lead', 'hot100', 'jobcategory_recruit', 'view');} catch(e){}"></a>
                    <strong class="recomm_name">엔아이티서비스(주)</strong>
                    <span class="recomm_desc">2020년 하반기 신입/경력 각 부문 채용</span>
                    <span class="recomm_info">
                        <span class="txt_info"><span class="blind">직종</span>#정규직</span>
                        <span class="txt_info"><span class="blind">지역</span>#경기 성남시 분당구</span>
                    </span>
                                        <a title="스크랩" style="cursor:pointer" onclick="Saramin.btnJob('scrap',this,'','list');" scraped="n" imgtype="" rec_idx="38721163" class="btn_scrap scrap-38721163">
                        <img src="//www.saraminimage.co.kr/common/bul_sri_star.png">
                    </a>
                    <span class="recruit_func">
                        <span class="blind">공고 마감일</span>
                        <span class="num_dday last">~ 09/11(금)</span>
                        <a class="sri_btn_xs" href="/zf_user/jobs/relay/view?view_type=list&amp;rec_idx=38721163" target="_blank" title="홈페이지 지원" onclick="try{s_trackApply(this, 'relay_view', 'hot100');}catch(e){};" onmousedown="try{ pushDataLayer('ga.lead', 'hot100',jobcategory_recruit, 'apply') } catch(e){}"><span class="sri_btn_homepage_apply">홈페 이지 지원</span></a>                    </span>
                </li>
                                        <li class="recruit_summary_basic">
                    <a href="/zf_user/jobs/relay/view?rec_idx=38709341&amp;t_ref=jobcategory_recruit&amp;t_ref_content=hot100" class="link_recomm" target="_blank" title="2020 휴넷 채용연계형 인턴십 모집" onmousedown="try{ gtmDataLayerPush('ga_lead', 'hot100', 'jobcategory_recruit', 'view');} catch(e){}"></a>
                    <strong class="recomm_name">(주)휴넷</strong>
                    <span class="recomm_desc">2020 휴넷 채용연계형 인턴십 모집</span>
                    <span class="recomm_info">
                        <span class="txt_info"><span class="blind">직종</span>#인턴직</span>
                        <span class="txt_info"><span class="blind">지역</span>#서울 구로구</span>
                    </span>
                                        <a title="스크랩" style="cursor:pointer" onclick="Saramin.btnJob('scrap',this,'','list');" scraped="n" imgtype="" rec_idx="38709341" class="btn_scrap scrap-38709341">
                        <img src="//www.saraminimage.co.kr/common/bul_sri_star.png">
                    </a>
                    <span class="recruit_func">
                        <span class="blind">공고 마감일</span>
                        <span class="num_dday last">~ 09/16(수)</span>
                        <button class="sri_btn_xs" title="클릭하면 입사지원할 수 있는 창이 뜹니다." onclick="try{quickApplyForm('38709341','','t_category=relay_view&amp;t_content=hot100', ''); return false;} catch (e) {}; return false;" onmousedown="try{n_trackEvent('apply','list','quick_apply');}catch(e){}"><span class="sri_btn_immediately">즉시지원</span></button>                    </span>
                </li>
                                        <li class="recruit_summary_basic">
                    <a href="/zf_user/jobs/relay/view?rec_idx=38647327&amp;t_ref=jobcategory_recruit&amp;t_ref_content=hot100" class="link_recomm" target="_blank" title="(재)대구테크노파크 각 부문 직원 채용 공고" onmousedown="try{ gtmDataLayerPush('ga_lead', 'hot100', 'jobcategory_recruit', 'view');} catch(e){}"></a>
                    <strong class="recomm_name">(재)대구테크노파크</strong>
                    <span class="recomm_desc">(재)대구테크노파크 각 부문 직원 채용 공고</span>
                    <span class="recomm_info">
                        <span class="txt_info"><span class="blind">직종</span>#계약직</span>
                        <span class="txt_info"><span class="blind">지역</span>#대구 달서구</span>
                    </span>
                                        <a title="스크랩" style="cursor:pointer" onclick="Saramin.btnJob('scrap',this,'','list');" scraped="n" imgtype="" rec_idx="38647327" class="btn_scrap scrap-38647327">
                        <img src="//www.saraminimage.co.kr/common/bul_sri_star.png">
                    </a>
                    <span class="recruit_func">
                        <span class="blind">공고 마감일</span>
                        <span class="num_dday last">~ 09/11(금)</span>
                        <a class="sri_btn_xs" href="/zf_user/jobs/relay/view?view_type=list&amp;rec_idx=38647327" target="_blank" title="홈페이지 지원" onclick="try{s_trackApply(this, 'relay_view', 'hot100');}catch(e){};" onmousedown="try{ pushDataLayer('ga.lead', 'hot100',jobcategory_recruit, 'apply') } catch(e){}"><span class="sri_btn_homepage_apply">홈페 이지 지원</span></a>                    </span>
                </li>
                                        <li class="recruit_summary_basic">
                    <a href="/zf_user/jobs/relay/view?rec_idx=38726025&amp;t_ref=jobcategory_recruit&amp;t_ref_content=hot100" class="link_recomm" target="_blank" title="2020 신입 개발자 공개채용" onmousedown="try{ gtmDataLayerPush('ga_lead', 'hot100', 'jobcategory_recruit', 'view');} catch(e){}"></a>
                    <strong class="recomm_name">네이버(주)</strong>
                    <span class="recomm_desc">2020 신입 개발자 공개채용</span>
                    <span class="recomm_info">
                        <span class="txt_info"><span class="blind">직종</span>#</span>
                        <span class="txt_info"><span class="blind">지역</span>#경기 성남시</span>
                    </span>
                                        <a title="스크랩" style="cursor:pointer" onclick="Saramin.btnJob('scrap',this,'','list');" scraped="n" imgtype="" rec_idx="38726025" class="btn_scrap scrap-38726025">
                        <img src="//www.saraminimage.co.kr/common/bul_sri_star.png">
                    </a>
                    <span class="recruit_func">
                        <span class="blind">공고 마감일</span>
                        <span class="num_dday last">~ 09/18(금)</span>
                        <a class="sri_btn_xs" href="/zf_user/jobs/relay/view?view_type=list&amp;rec_idx=38726025" target="_blank" title="홈페이지 지원" onclick="try{s_trackApply(this, 'relay_view', 'hot100');}catch(e){};" onmousedown="try{ pushDataLayer('ga.lead', 'hot100',jobcategory_recruit, 'apply') } catch(e){}"><span class="sri_btn_homepage_apply">홈페 이지 지원</span></a>                    </span>
                </li>
                                        <li class="recruit_summary_basic">
                    <a href="/zf_user/jobs/relay/view?rec_idx=38735056&amp;t_ref=jobcategory_recruit&amp;t_ref_content=hot100" class="link_recomm" target="_blank" title="[토스뱅크팀] 코어뱅킹 개발자 적극 채용" onmousedown="try{ gtmDataLayerPush('ga_lead', 'hot100', 'jobcategory_recruit', 'view');} catch(e){}"></a>
                    <strong class="recomm_name">채용디자인</strong>
                    <span class="recomm_desc">[토스뱅크팀] 코어뱅킹 개발자 적극 채용</span>
                    <span class="recomm_info">
                        <span class="txt_info"><span class="blind">직종</span>#정규직</span>
                        <span class="txt_info"><span class="blind">지역</span>#서울 강남구</span>
                    </span>
                                        <a title="스크랩" style="cursor:pointer" onclick="Saramin.btnJob('scrap',this,'','list');" scraped="n" imgtype="" rec_idx="38735056" class="btn_scrap scrap-38735056">
                        <img src="//www.saraminimage.co.kr/common/bul_sri_star.png">
                    </a>
                    <span class="recruit_func">
                        <span class="blind">공고 마감일</span>
                        <span class="num_dday last">~ 09/16(수)</span>
                        <a class="sri_btn_xs" href="/zf_user/jobs/relay/view?view_type=list&amp;rec_idx=38735056" target="_blank" title="홈페이지 지원" onclick="try{s_trackApply(this, 'relay_view', 'hot100');}catch(e){};" onmousedown="try{ pushDataLayer('ga.lead', 'hot100',jobcategory_recruit, 'apply') } catch(e){}"><span class="sri_btn_homepage_apply">홈페 이지 지원</span></a>                    </span>
                </li>
                    </ul>
    </div>
    <button type="button" id="recom_btn_next" class="btn_next on"><span class="blind">다음</span></button>
</div>
</div><script type="text/javascript">
$j(document).ready(function () {
    var data = JSON.parse('{"t_ref":"jobcategory_recruit","t_ref_content":"hot100","t_category":"relay_view","t_content":"hot100","cat_cd":"404","career_cd":1,"rec_idx":"38655001"}') || {};
    var paramStr = '';

    if (Object.keys(data).length > 0) {
        Object.keys(data).forEach(function (key) {
            var prefix = (paramStr !== '') ? '&' : '';
            paramStr += prefix + key + '=' + data[key];
        });
    }
    var recIdx = (data.rec_idx !== '' && typeof data.rec_idx !== 'undefined') ? ('-' + data.rec_idx) : '';
    var params = ((paramStr !== '') ? ('?' + paramStr) : '');
    var pageCount = recIdx ? 9 : 10; // 공고뷰는 3개씩 보여줘서 9개만 요청

    $j.ajax({
        type: 'get',
        url: '/zf_user/jobs/hot100/get-top10' + params + (((params !== '') ? '&' : '?') + 'page_count=' + pageCount),
        dataType: 'json',
        success: function (response) {
            if (response.result === 'success') {
                $j('#hot100-top10-list' + recIdx).html(response.content);
                slideEventBind();
            }
        },
        fail: function (error) {
            console.log(error);
        }
    });

    var slideEventBind = function () {
        var slideElement = $j('.list_recomm', '#hot100-top10-list' + recIdx);
        var recruitBox = $j('.recruit_summary_basic', slideElement),
            recruitLength = recruitBox.size(),
            boxWrap = slideElement.parents('.box_recommend_slide');

        var box = recruitBox.outerWidth(),
            visibleCount = Math.ceil(boxWrap.outerWidth() / box),
            btnNext = boxWrap.find('.btn_next'),
            btnPrev = boxWrap.find('.btn_prev');

        if (recruitLength <= visibleCount) {
            return;
        }
        var num = (recruitLength / visibleCount) - 1,
            count = 0,
            moving = false,
            slideNum = 1,
            totalPage = Math.ceil(recruitLength / visibleCount),
            term = 1,
            totalText = boxWrap.find('.slide_total');

        totalText.html(totalPage);
        slideElement.css('width', (box * recruitLength) + (term * (recruitLength)));
        btnNext.addClass('on');

        btnNext.on('click', function () {
            btnPrev.show();
            if (moving) {
                return false;
            }
            moving = true;
            slide(1);
            if (count >= Math.ceil(num)) {
                $j(this).hide();
            }
        });

        btnPrev.on('click', function () {
            btnNext.show();
            if (moving) {
                return false;
            }
            moving = true;
            slide(-1);
            if (count === 0) {
                $j(this).hide();
            }
        });

        var slide = function (dir) {
            count = count + dir;
            var leftValue = ((box * (visibleCount - 1)) * -count) - (term * visibleCount * -count) + (count > 0 ? -1 : 0) + 'px';
            if (recIdx !== '') {
                leftValue = ((box * visibleCount - 1) * -count) - (term * visibleCount * -count) + 'px';
            }
            slideElement.stop().animate({ left: leftValue }, {
                complete: function () {
                    moving = false;
                }
            });
            slideNum = slideNum + dir;
            boxWrap.find('em').html(slideNum);
        };
    }
});
</script><div class="jv_cont jv_footer"><div class="jv_title blind">관련 태그</div><div class="cont"><div class="tags"><ul class="scroll"><li><a href="/zf_user/jobs/list/job-category?cat_bcd=4" target="_blank" onmousedown="try{n_trackEvent('relay_view', 'tag', 'occupation', '');}catch(e){}">#IT·인터넷</a></li><li><a href="/zf_user/jobs/list/job-category?cat_cd=404" target="_blank" onmousedown="try{n_trackEvent('relay_view', 'tag', 'occupation', '');}catch(e){}">#웹개발</a></li><li><a href="/zf_user/jobs/list/job-category?cat_key=40404" target="_blank" onmousedown="try{n_trackEvent('relay_view', 'tag', 'occupation', '');}catch(e){}">#Java·JSP</a></li><li><a href="/zf_user/jobs/list/job-category?cat_key=40416" target="_blank" onmousedown="try{n_trackEvent('relay_view', 'tag', 'occupation', '');}catch(e){}">#.NET</a></li><li><a href="/zf_user/jobs/list/job-category?cat_key=40421" target="_blank" onmousedown="try{n_trackEvent('relay_view', 'tag', 'occupation', '');}catch(e){}">#Ajax</a></li><li><a href="/zf_user/jobs/list/job-category?cat_key=40426" target="_blank" onmousedown="try{n_trackEvent('relay_view', 'tag', 'occupation', '');}catch(e){}">#Python</a></li><li><a href="/zf_user/jobs/list/job-category?cat_key=40427" target="_blank" onmousedown="try{n_trackEvent('relay_view', 'tag', 'occupation', '');}catch(e){}">#프론트엔드</a></li><li><a href="/zf_user/jobs/list/job-category?cat_cd=407" target="_blank" onmousedown="try{n_trackEvent('relay_view', 'tag', 'occupation', '');}catch(e){}">#응용프로그램개발</a></li><li><a href="/zf_user/jobs/list/job-category?cat_key=40716" target="_blank" onmousedown="try{n_trackEvent('relay_view', 'tag', 'occupation', '');}catch(e){}">#Java</a></li><li><a href="/zf_user/jobs/list/job-category?cat_key=40719" target="_blank" onmousedown="try{n_trackEvent('relay_view', 'tag', 'occupation', '');}catch(e){}">#OpenGL</a></li><li><a href="/zf_user/jobs/list/job-category?cat_key=40720" target="_blank" onmousedown="try{n_trackEvent('relay_view', 'tag', 'occupation', '');}catch(e){}">#Oracle</a></li><li><a href="/zf_user/jobs/list/job-category?cat_key=40722" target="_blank" onmousedown="try{n_trackEvent('relay_view', 'tag', 'occupation', '');}catch(e){}">#.NET</a></li><li><a href="/zf_user/jobs/list/job-category?cat_key=40728" target="_blank" onmousedown="try{n_trackEvent('relay_view', 'tag', 'occupation', '');}catch(e){}">#C#</a></li><li><a href="/zf_user/jobs/list/job-category?cat_bcd=9" target="_blank" onmousedown="try{n_trackEvent('relay_view', 'tag', 'occupation', '');}catch(e){}">#건설</a></li><li><a href="/zf_user/jobs/list/job-category?cat_cd=901" target="_blank" onmousedown="try{n_trackEvent('relay_view', 'tag', 'occupation', '');}catch(e){}">#토목·조경·도시·측량</a></li><li><a href="/zf_user/jobs/list/job-category?cat_key=90101" target="_blank" onmousedown="try{n_trackEvent('relay_view', 'tag', 'occupation', '');}catch(e){}">#토목</a></li><li><a href="/zf_user/jobs/list/job-category?cat_key=90104" target="_blank" onmousedown="try{n_trackEvent('relay_view', 'tag', 'occupation', '');}catch(e){}">#측량·계측</a></li><li><a href="/zf_user/jobs/list/job-category?cat_key=90106" target="_blank" onmousedown="try{n_trackEvent('relay_view', 'tag', 'occupation', '');}catch(e){}">#도로·상하수도</a></li><li><a href="/zf_user/jobs/list/job-category?cat_key=90109" target="_blank" onmousedown="try{n_trackEvent('relay_view', 'tag', 'occupation', '');}catch(e){}">#토목기사</a></li><li><a href="/zf_user/jobs/list/job-category?cat_key=90113" target="_blank" onmousedown="try{n_trackEvent('relay_view', 'tag', 'occupation', '');}catch(e){}">#구조해석</a></li><li><a href="/zf_user/jobs/list/domestic?loc_cd=105000" target="_blank" onmousedown="try{n_trackEvent('relay_view', 'tag', 'area', '');}catch(e){}">#대전</a></li><li><a href="/zf_user/jobs/list/domestic?loc_cd=105050" target="_blank" onmousedown="try{n_trackEvent('relay_view', 'tag', 'area', '');}catch(e){}">#중구</a></li></ul><button type="button" class="btn_tags" style="display: inline-block;"><span class="blind">태그 더보기</span></button></div><div class="utils"><p class="copy">본 채용 정보에 불법·허위·과장 또는 잘못된 내용이 있을 경우 <a target="_blank" href="/zf_user/help/inquery/email-inquiry-write?rec_idx=38655001&amp;view_type=list" onmousedown="try{n_trackEvent('relay_view', 'warning', 'report', '');}catch(e){}">문의</a>해 주세요!</p><div class="share"><button type="button" class="spr_jview btn_jview btn_share"><span>공유하기</span></button><ul class="spr_jview list_share"><li><a href="http://www.facebook.com/share.php?api_key=137906922916817&amp;display=popup&amp;u=http%3A%2F%2Fwww.saramin.co.kr%2Fzf_user%2Fjobs%2Frelay%2Fview%3Frec_idx%3D38655001%26view_type%3Dlist" class="spr_jview facebook" onclick="window.open(this.href, this.target, 'width=578,height=380'); return false;" onmousedown="try{n_trackEvent('relay_view', 'bottom', 'facebook', '');}catch(e){}" title="페이스북 공유하기"><span class="blind">페이스북</span></a></li><li><a href="http://twitter.com/share?url=http%3A%2F%2Fwww.saramin.co.kr%2Fzf_user%2Fjobs%2Frelay%2Fview%3Frec_idx%3D38655001%26view_type%3Dlist&amp;text=%EC%9B%B9%20%2F%EC%9D%91%EC%9A%A9%ED%94%84%EB%A1%9C%EA%B7%B8%EB%9E%A8%20%EA%B0%9C%EB%B0%9C%EC%9E%90%20%EB%AA%A8%EC%A7%91%20-%20%28%EC%A3%BC%29%EB%A7%A4%EA%B7%B8%ED%8C%8C%EC%9D%B4%EC%86%8C%ED%94%84%ED%8A%B8%20%23saramin" class="spr_jview twitter" onclick="window.open(this.href, this.target, 'width=554,height=454'); return false;" onmousedown="try{n_trackEvent('relay_view', 'bottom', 'twitter', '');}catch(e){}" title="트위터 공유하기"><span class="blind">트위터</span></a></li><li><button type="button" class="spr_jview copy_url" title="공고 주소 복사하기" onclick="JobsView.copyUrl('http://www.saramin.co.kr/zf_user/jobs/relay/view?rec_idx=38655001&amp;view_type=list');" onmousedown="try{n_trackEvent('relay_view', 'bottom', 'copyurl', '' );}catch(e){}"><span class="blind">URL복사</span></button></li><li><button type="button" class="spr_jview send_sms" title="이 공고 내 폰으로 전송하기" onclick="Saramin.showQuickLogin();" onmousedown="try{n_trackEvent('relay_view', 'bottom', 'sendsms', '');}catch(e){}"><span class="blind">SMS발송</span></button></li></ul></div><button type="button" class="spr_jview btn_jview btn_print" onmousedown="try{n_trackEvent('relay_view', 'bottom', 'print', '');}catch(e){}"><span>인쇄하기</span></button></div></div></div></div><div class="jv_ads bottom_ads"><div class="div-gpt-ad-1400664864294-23-wrapper" style="width:728px; height:90px;"><div class="google-standby-banner"><a href="http://www.saramin.co.kr/avatar-branding/?inner_source=saramin&amp;inner_medium=banner&amp;inner_campaign=Waiting_Main_BigBanner&amp;inner_term=avatar_introduce" target="_blank"><img src="http://www.saraminbanner.co.kr/adserver/default/2019/01/pm0hyu_6urf-2rxiej_pekafl4i9h2rxelk728x90.png" alt="인공지능 취업플랫폼 사람인"></a></div><div class="div-gpt-ad-1400664864294-23-inner" style="display:none;"><div class="div-gpt-ad-1400664864294-23"></div></div></div></div>
    </div><div class="jview jview-1-38689139"><div class="wrap_jv_cont"><input type="hidden" name="track_url_1" value="t_category=relay_view&amp;t_content=relay_view_list&amp;t_ref=relay_view&amp;t_ref_content=SRI_050_VIEW_MTRX_RCT_NOINFO&amp;t_ref_scnid=747&amp;dpId=" class="track_url" data-view_type="list" id="track_url_1"><input type="hidden" name="logging_url_38689139" value="http://rcmd-log.saramin.co.kr:9020/so-logging/log/client?custId=&amp;pcId=15996305088133198347523&amp;nonce=619018ee5c79e6f565ab&amp;dpId=SRI_050_VIEW_MTRX_RCT_NOINFO&amp;scnId=747&amp;tgId=0&amp;itemSetId=0&amp;itemValue=38689139&amp;click=1" class="logging-url" id="logging_url_38689139"><div class="wrap_jv_header"><div class="jv_header" data-rec_idx="38689139" data-rec_seq="1"><a href="/zf_user/company-info/view?csn=1208208049&amp;popup_yn=y" class="company" target="_blank" onclick="window.open(this.href, ''); return false;" onmousedown="try{n_trackEvent('relay_view', 'title', 'company', '');}catch(e){}">
                (재)국가관세종합정보망운영연합회            </a><button type="button" csn="1208208049" title="관심기업  등록" del_fl="n" class="btn_jview spr_jview btn_interest" onclick="try{Saramin.btnJob('favor', this, '', 'quick_login');}catch(e){}" onmousedown="try {n_trackEvent('relay_view', 'title', 'favor', '');}catch(e){}" first_nudge="off"><span>관 심기업 등록</span></button><h1 class="tit_job">
                        대전 관세청 전자통관시스템 운영(개발) 경력직원 채용        </h1><button type="button" class="btn_scrap  scrap-38689139" title="공고스크랩" onclick="Saramin.btnJob('scrap', this, '', 'quick_login');" scraped="n" rec_idx="38689139" imgtype="button" onmousedown="try{n_trackEvent('relay_view', 'summary', 'scrap', '');}catch(e){}"><span class="txt_scrap">10</span></button><div class="btn_apply"><span class="dday">D-2</span><button class="sri_btn_lg for_btn_event" title="클릭하면 입사지원할 수 있는 창이 뜹니다." onclick="try{quickApplyForm('38689139','','t_category=relay_view&amp;t_content=relay_view_list&amp;t_ref=relay_view&amp;t_ref_content=SRI_050_VIEW_MTRX_RCT_NOINFO&amp;t_ref_scnid=747&amp;dpId=&amp;inner_source=saramin&amp;inner_medium=pattern&amp;inner_campaign=relay_view_apply_1&amp;inner_term=list', ''); return false;} catch (e) {}; return false;" onmousedown="try{n_trackEvent('relay_view','summary','quick_apply','');}catch(e){}"><span class="sri_btn_immediately">즉시지원</span></button></div></div></div><div class="jv_cont jv_summary"><div class="jv_title blind">핵심 정보</div><div class="cont"><div class="col"><dl><dt>경력</dt><dd><strong>경력 3~5년</strong></dd></dl><dl><dt>학력</dt><dd><strong>대졸(2,3년제) 이상</strong></dd></dl><dl><dt>근무형태</dt><dd><strong>정규 직</strong></dd></dl><dl><dt>필수사항</dt><dd class="preferred"><div class="toolTipWrap"><button type="button" title="상세보기" class="spr_jview btn_jview btn_tooltip"><span>상세보기</span></button><div class="toolTip"><span class="tail tail_top_left"></span><div class="toolTipCont txtLeft"><ul class="toolTipTxt"><li><span>자격증</span>정보처리기사</li></ul></div><button type="button" class="btnClose"><span class="blind">닫기</span></button></div></div></dd></dl><dl><dt>우대 사항</dt><dd class="preferred"><div class="toolTipWrap"><button type="button" title="상세보기" class="spr_jview btn_jview btn_tooltip"><span>상세보기</span></button><div class="toolTip"><span class="tail tail_top_left"></span><div class="toolTipCont txtLeft"><ul class="toolTipTxt"><li><span>전공</span>컴퓨터/시스템공학, 공학계열</li></ul></div><button type="button" class="btnClose"><span class="blind">닫기</span></button></div></div></dd></dl></div><div class="col"><dl><dt>급여</dt><dd>회사내규에 따름                    </dd></dl><dl><dt>직급/직책</dt><dd>
            면접 후 결정 / 팀원        </dd></dl><dl><dt>근무일시</dt><dd>주 5일(월~금) </dd></dl><dl><dt>근무지역</dt><dd>
            대전 서구                    </dd></dl></div><ul class="meta"><li>조회수 <strong>981</strong></li><li class="wrap_share"><div class="share"><button type="button" class="spr_jview btn_jview btn_share"><span>공유하기</span></button><ul class="spr_jview list_share"><li><a href="http://www.facebook.com/share.php?api_key=137906922916817&amp;display=popup&amp;u=http%3A%2F%2Fwww.saramin.co.kr%2Fzf_user%2Fjobs%2Frelay%2Fview%3Frec_idx%3D38689139%26view_type%3Dlist" class="spr_jview facebook" onclick="window.open(this.href, this.target, 'width=578,height=380'); return false;" onmousedown="try{n_trackEvent('relay_view', 'top', 'facebook', '');}catch(e){}" title="페이스북 공유하기"><span class="blind">페이스북</span></a></li><li><a href="http://twitter.com/share?url=http%3A%2F%2Fwww.saramin.co.kr%2Fzf_user%2Fjobs%2Frelay%2Fview%3Frec_idx%3D38689139%26view_type%3Dlist&amp;text=%EB%8C%80%EC%A0%84%20%EA%B4%80%EC%84%B8%EC%B2%AD%20%EC%A0%84%EC%9E%90%ED%86%B5%EA%B4%80%EC%8B%9C%EC%8A%A4%ED%85%9C%20%EC%9A%B4%EC%98%81%28%EA%B0%9C%EB%B0%9C%29%20%EA%B2%BD%EB%A0%A5%EC%A7%81%EC%9B%90%20%EC%B1%84%EC%9A%A9%20-%20%28%EC%9E%AC%29%EA%B5%AD%EA%B0%80%EA%B4%80%EC%84%B8%EC%A2%85%ED%95%A9%EC%A0%95%EB%B3%B4%EB%A7%9D%EC%9A%B4%EC%98%81%EC%97%B0%ED%95%A9%ED%9A%8C%20%23saramin" class="spr_jview twitter" onclick="window.open(this.href, this.target, 'width=554,height=454'); return false;" onmousedown="try{n_trackEvent('relay_view', 'top', 'twitter', '');}catch(e){}" title="트위터 공유하기"><span class="blind">트위터</span></a></li><li><button type="button" class="spr_jview copy_url" title="공고 주소 복사하기" onclick="JobsView.copyUrl('http://www.saramin.co.kr/zf_user/jobs/relay/view?rec_idx=38689139&amp;view_type=list');" onmousedown="try{n_trackEvent('relay_view', 'top', 'copyurl', '' );}catch(e){}"><span class="blind">URL복사</span></button></li><li><button type="button" class="spr_jview send_sms" title="이 공고 내 폰으로 전송하기" onclick="Saramin.showQuickLogin();" onmousedown="try{n_trackEvent('relay_view', 'top', 'sendsms', '');}catch(e){}"><span class="blind">SMS발송</span></button></li></ul></div></li></ul></div></div><div class="jv_cont jv_detail"><div class="jv_title blind">상세요강</div><div class="cont"><iframe name="iframe_content_1" id="iframe_content_1" class="iframe_content" width="860" scrolling="no" frameborder="0" marginheight="0" marginwidth="0" src="/zf_user/jobs/relay/view-detail?rec_idx=38689139&amp;rec_seq=1" title="상세요강" height="2877px"></iframe></div></div><script type="text/javascript">
    var i;

    window.onload = function () {
        var aTagList = document.querySelectorAll('.user_content a,area');
        for (i = 0; i < aTagList.length; i++ ){
            aTagList[i].addEventListener('mousedown', function (e) {
                var item = e.currentTarget;
                var href = item.getAttribute('href') || '';

                checkUpdateHomepage(href);
            });
        }

        var checkUpdateHomepage = function (href) {
            var isFile = false,
                urlLastSpiceByDot = href.split('.').pop().toLowerCase(),
                fileExtWord = ['hwp', 'doc', 'docx', 'ppt', 'pptx', 'pdf', 'xls', 'xlsx', 'rtf', 'gul'],
                fileExtCompress = ['zip', 'alz', 'rar', 'lzh', 'arj', 'egg', 'tar', 'sit'],
                fileExtImageFlash = ['jpg', 'gif', 'png', 'psd', 'fla', 'ai', 'jpe', 'jpeg', 'tif', 'tiff', 'pcx', 'swf'],
                fileExt;

            fileExt = fileExtWord.concat(fileExtCompress).concat(fileExtImageFlash);
            isFile = (fileExt.indexOf(urlLastSpiceByDot) !== -1);

            if (href != '' && isFile === false && href.indexOf('mailto:') === -1
                && href.indexOf('pds.saramin.co.kr') === -1 && href.indexOf('uf.daum.net') === -1 && href.indexOf('drive.google.com') === -1
            ) {
                try { Saramin.updateHomepageLink('38689139', 'homepage'); } catch (e) {}
            }
        }
    }
</script><div class="jv_cont jv_howto"><div class="jv_title">접수기간 및 방법</div><div class="cont box"><div class="status"><div class="info_timer" data-remain-time="205880"><span class="txt">남은 기간</span><span class="day">2</span><span class="txt_day">일</span><span class="time">09:11:11</span></div><dl class="info_period"><dt>시작일</dt><dd>2020.08.28 00:00</dd><dt class="end">마감일</dt><dd>2020.09.11 23:59</dd></dl><button class="sri_btn_lg for_btn_event" title="클릭 하면 입사지원할 수 있는 창이 뜹니다." onclick="try{quickApplyForm('38689139','','t_category=relay_view&amp;t_content=relay_view_list&amp;t_ref=relay_view&amp;t_ref_content=SRI_050_VIEW_MTRX_RCT_NOINFO&amp;t_ref_scnid=747&amp;dpId=&amp;inner_source=saramin&amp;inner_medium=pattern&amp;inner_campaign=relay_view_apply_1&amp;inner_term=list', ''); return false;} catch (e) {}; return false;" onmousedown="try{n_trackEvent('relay_view','contacts','quick_apply_bt','');}catch(e){}"><span class="sri_btn_immediately">즉시지원</span></button></div><dl class="guide"><dt>지원방법</dt><dd class="method"><button class="sri_btn_1 for_btn_event" title="클릭하면 입사지원할 수 있는 창이 뜹니다." onclick="try{quickApplyForm('38689139','','t_category=relay_view&amp;t_content=relay_view_list&amp;t_ref=relay_view&amp;t_ref_content=SRI_050_VIEW_MTRX_RCT_NOINFO&amp;t_ref_scnid=747&amp;dpId=&amp;inner_source=saramin&amp;inner_medium=pattern&amp;inner_campaign=relay_view_apply_1&amp;inner_term=list', ''); return false;} catch (e) {}; return false;" onmousedown="try{n_trackEvent('relay_view','contacts','quick_apply','');}catch(e){}"><span class="sri_btn_immediately">사람인 즉시지원</span></button></dd><dt>접수양식</dt><dd class="template"><div class="toolTipWrap"><button type="button" title="제출서류 보기" class="spr_jview btn_jview btn_tooltip"><span>제출서류 보기</span></button><div class="toolTip"><span class="tail tail_top_center"></span><div class="toolTipCont txtLeft"><strong class="toolTipTit">제출서류</strong><p>이력서, 자기소개서</p></div><button type="button" class="btnClose"><span class="blind">닫기</span></button></div></div></dd><dt>담당자</dt><dd class="manager">안형근</dd><dt>연락처</dt><dd class="info">027360269</dd></dl><p class="noti">마감일은 기업의 사정, 조기마감 등으로 변경될  수 있습니다.</p></div></div><div class="jv_cont jv_statics"><div class="jv_title">지원자 통계</div><div class="cont"><div class="layer_group"><div class="layer"><div class="box_chart narrow count sub"><dl class="total"><dt>지원자수</dt><dd><span>10</span>명</dd></dl><div class="scroll"><dl class="detail"><dt title="SW 중급기술자">SW 중급기술자</dt><dd><span>10</span>명</dd></dl></div></div><div class="box_chart narrow"><strong class="tit_stats">경력별 현황</strong><div class="chart_line "><div class="col "><em class="legend">신입</em><div class="bar"><div class="fill" style="height:20%"><span class="value">2</span></div></div></div><div class="col "><em class="legend">1년 미만</em><div class="bar"><div class="fill" style="height:0%"><span class="value">0</span></div></div></div><div class="col "><em class="legend">1~3년</em><div class="bar"><div class="fill" style="height:10%"><span class="value">1</span></div></div></div><div class="col "><em class="legend">3~5년</em><div class="bar"><div class="fill" style="height:10%"><span class="value">1</span></div></div></div><div class="col emph"><em class="legend">5년 이상</em><div class="bar"><div class="fill" style="height:60%"><span class="value">6</span></div></div></div></div></div><div class="box_chart narrow"><strong class="tit_stats">연봉별 현황</strong><div class="chart_line "><div class="col "><em class="legend">2,200<br>미만</em><div class="bar"><div class="fill" style="height:0%"><span class="value">0</span></div></div></div><div class="col "><em class="legend">2,200<br>~2,600</em><div class="bar"><div class="fill" style="height:0%"><span class="value">0</span></div></div></div><div class="col "><em class="legend">2,600<br>~3,000</em><div class="bar"><div class="fill" style="height:0%"><span class="value">0</span></div></div></div><div class="col "><em class="legend">3,000<br>~4,000</em><div class="bar"><div class="fill" style="height:10%"><span class="value">1</span></div></div></div><div class="col emph"><em class="legend">4,000<br>이상</em><div class="bar"><div class="fill" style="height:20%"><span class="value">2</span></div></div></div></div></div><div class="box_chart "><strong class="tit_stats">성별 현황</strong><div class="chart_donut"><!-- donut chart 일때 --><svg class="donut" width="172" height="172" viewBox="0 0 172 172"><circle cx="86" cy="86" r="76" fill="transparent" stroke-width="20" stroke="#acd9f8"></circle><circle cx="86" cy="86" r="76" fill="transparent" stroke-width="20" stroke="#fa6a71" stroke-dasharray="477.521984" stroke-dashoffset="334.2653888"></circle><rect x="151" y="84" width="22" height="4" fill="white"></rect><rect x="151" y="84" width="22" height="4" fill="white" transform="rotate(108 86 86)"></rect></svg><div class="legend"><div class="total"><span>지원자수</span></div><dl class="male"><dt class="spr_jview">남자</dt><dd class="perc"><span>70</span>%</dd><dd>7 명</dd></dl><dl class="female"><dt class="spr_jview">여자</dt><dd class="perc"><span>30</span>%</dd><dd>3 명</dd></dl></div></div></div><div class="box_chart "><strong class="tit_stats">연령별 현황</strong><div class="chart_line "><div class="col "><em class="legend">20대</em><div class="bar"><div class="fill" style="height:20%"><span class="value">2</span></div></div></div><div class="col emph"><em class="legend">30대</em><div class="bar"><div class="fill" style="height:40%"><span class="value">4</span></div></div></div><div class="col "><em class="legend">40대</em><div class="bar"><div class="fill" style="height:30%"><span class="value">3</span></div></div></div><div class="col "><em class="legend">50대</em><div class="bar"><div class="fill" style="height:0%"><span class="value">0</span></div></div></div><div class="col "><em class="legend">60대 이상</em><div class="bar"><div class="fill" style="height:10%"><span class="value">1</span></div></div></div></div></div><div class="box_chart "><strong class="tit_stats">학력별 현황</strong><div class="chart_line "><div class="col "><em class="legend">고졸이하</em><div class="bar"><div class="fill" style="height:0%"><span class="value">0</span></div></div></div><div class="col "><em class="legend">2~3년제</em><div class="bar"><div class="fill" style="height:20%"><span class="value">2</span></div></div></div><div class="col emph"><em class="legend">4년제</em><div class="bar"><div class="fill" style="height:50%"><span class="value">5</span></div></div></div><div class="col "><em class="legend">석사</em><div class="bar"><div class="fill" style="height:30%"><span class="value">3</span></div></div></div><div class="col "><em class="legend">박사</em><div class="bar"><div class="fill" style="height:0%"><span class="value">0</span></div></div></div></div></div><div class="box_chart "><strong class="tit_stats">외국어 현황</strong><div class="chart_line sub"><div class="col "><em class="legend">TOEIC</em><div class="bar"><div class="fill" style="height:25%"><span class="value">1</span></div></div></div><div class="col "><em class="legend">TOEFL</em><div class="bar"><div class="fill" style="height:0%"><span class="value">0</span></div></div></div><div class="col "><em class="legend">TEPS</em><div class="bar"><div class="fill" style="height:0%"><span class="value">0</span></div></div></div><div class="col "><em class="legend">TOEIC Speaking</em><div class="bar"><div class="fill" style="height:0%"><span class="value">0</span></div></div></div><div class="col "><em class="legend">OPIC</em><div class="bar"><div class="fill" style="height:25%"><span class="value">1</span></div></div></div><div class="col "><em class="legend">JPT</em><div class="bar"><div class="fill" style="height:0%"><span class="value">0</span></div></div></div><div class="col "><em class="legend">HSK</em><div class="bar"><div class="fill" style="height:0%"><span class="value">0</span></div></div></div><div class="col emph"><em class="legend">기타</em><div class="bar"><div class="fill" style="height:50%"><span class="value">2</span></div></div></div></div></div><div class="box_chart "><strong class="tit_stats">TOEIC</strong><div class="chart_line sub"><div class="col "><em class="legend">600<br>미만</em><div class="bar"><div class="fill" style="height:0%"><span class="value">0</span></div></div></div><div class="col "><em class="legend">700<br>미만</em><div class="bar"><div class="fill" style="height:0%"><span class="value">0</span></div></div></div><div class="col "><em class="legend">800<br>미만</em><div class="bar"><div class="fill" style="height:0%"><span class="value">0</span></div></div></div><div class="col "><em class="legend">900<br>미만</em><div class="bar"><div class="fill" style="height:0%"><span class="value">0</span></div></div></div><div class="col emph"><em class="legend">900<br>이상</em><div class="bar"><div class="fill" style="height:100%"><span class="value">1</span></div></div></div></div></div><div class="box_chart "><strong class="tit_stats">OPIC</strong><div class="chart_line sub"><div class="col emph"><em class="legend">IL이하</em><div class="bar"><div class="fill" style="height:100%"><span class="value">1</span></div></div></div><div class="col "><em class="legend">IM1</em><div class="bar"><div class="fill" style="height:0%"><span class="value">0</span></div></div></div><div class="col "><em class="legend">IM2</em><div class="bar"><div class="fill" style="height:0%"><span class="value">0</span></div></div></div><div class="col "><em class="legend">IM3</em><div class="bar"><div class="fill" style="height:0%"><span class="value">0</span></div></div></div><div class="col "><em class="legend">IH</em><div class="bar"><div class="fill" style="height:0%"><span class="value">0</span></div></div></div><div class="col "><em class="legend">AL</em><div class="bar"><div class="fill" style="height:0%"><span class="value">0</span></div></div></div></div></div></div></div><button type="button" class="btn_more_cont" onmousedown="try{n_trackEvent('relay_view', 'statistics', 'statistics_more', '');}catch(e){}"><span class="spr_jview">내용 전체보기</span></button></div></div><div class="jv_cont jv_company"><div class="jv_title">기업정보
                </div><div class="cont box"><div class="logo"><img id="(재)국가관세종합정보망운영연합회" alt="(재)국가관세종합정보망운영연합회" src="http://pds.saramin.co.kr/company/logo/201902/26/pnhoop_qddc-0_logo.jpg" width="160" height="33"></div><div class="wrap_info"><div class="title"><span class="company_name">(재)국가관세종합정보망운영연합회</span><button type="button" csn="1208208049" title="관심기업 등록" del_fl="n" class="btn_jview spr_jview btn_interest" onclick="try{Saramin.btnJob('favor', this, '', 'quick_login');}catch(e){}" onmousedown="try {n_trackEvent('relay_view', 'companyinfo', 'favor', '');}catch(e){}" first_nudge="off"><span>관심기업 등록</span></button><a href="/zf_user/company-info/view?csn=1208208049" title="기업정보로 이동" class="spr_jview btn_jview btn_link" onclick="window.open(this.href, ''); return false;" onmousedown="try{n_trackEvent('relay_view', 'companyinfo', 'company_more', '');}catch(e){}"><strong>기업정보</strong></a><a target="_blank" href="/zf_user/salaries/total-salary/view?csn=1208208049" title="연봉정보 이동" class="spr_jview btn_jview btn_link" onmousedown="try{n_trackEvent('relay_view', 'salary', 'salary_more', '');}catch(e){}"><span>연봉정보</span></a></div><div class="info"><dl><dt>기업형태</dt><dd>기타, 재단법인, 비영리단체/협회</dd></dl><dl><dt>사 원수</dt><dd>151 명 <span>
                             (2020년 기준)</span></dd></dl><dl><dt>업종</dt><dd>시스템 소프트웨어 개발 및 공급업</dd></dl><dl><dt>설립일</dt><dd>2006년 8월 2일 (업력 14년) </dd></dl><dl><dt>매출액</dt><dd>
                                 400억 9,345만원                                                                                                    <span>(2019년 기준)</span></dd></dl><dl><dt>대표자명</dt><dd>정일석</dd></dl><dl><dt>홈페이 지</dt><dd><a href="http://www.unipass.or.kr" target="_blank">
                                    www.unipass.or.kr                                </a></dd></dl><dl class="wide"><dt>기업주소</dt><dd>서울 종로구 새문안로3길 30</dd></dl></div></div></div></div><div class="wrap_recommend_slide type02 hot_slide" id="hot100-top10-list-38689139"><div class="hot_slide_tit">
    <h4 class="tit">웹개발 <em>HOT100</em></h4>
    <a href="/zf_user/jobs/hot100?cat_cd=404&amp;career_cd=2" target="_blank" class="more_btn hot1000-more" title="더보 기" onmousedown="try{ gtmDataLayerPush('ga_lead', 'hot100', 'jobcategory_recruit', 'more');} catch(e){}">더보기</a>
</div>
<div class="box_recommend_slide">
    <p class="slide_num"><em>1</em>/<span class="slide_total">3</span></p>
    <button type="button" id="recom_btn_prev" class="btn_prev" style="display: none;"><span class="blind">이전</span></button>
    <div class="recommend_list">
        <ul class="list_recomm" style="width: 2628px;">
                                                    <li class="recruit_summary_basic">
                    <a href="/zf_user/jobs/relay/view?rec_idx=38723747&amp;t_ref=jobcategory_recruit&amp;t_ref_content=hot100" class="link_recomm" target="_blank" title="[카카오뱅크] 개발자 공개채용 2020" onmousedown="try{ gtmDataLayerPush('ga_lead', 'hot100', 'jobcategory_recruit', 'view');} catch(e){}"></a>
                    <strong class="recomm_name">(주)카카오뱅크</strong>
                    <span class="recomm_desc">[카카오뱅크] 개발자 공개채용 2020</span>
                    <span class="recomm_info">
                        <span class="txt_info"><span class="blind">직종</span>#정규직</span>
                        <span class="txt_info"><span class="blind">지역</span>#경기 성남시</span>
                    </span>
                                        <a title="스크랩" style="cursor:pointer" onclick="Saramin.btnJob('scrap',this,'','list');" scraped="n" imgtype="" rec_idx="38723747" class="btn_scrap scrap-38723747">
                        <img src="//www.saraminimage.co.kr/common/bul_sri_star.png">
                    </a>
                    <span class="recruit_func">
                        <span class="blind">공고 마감일</span>
                        <span class="num_dday last">~ 09/13(일)</span>
                        <a class="sri_btn_xs" href="/zf_user/jobs/relay/view?view_type=list&amp;rec_idx=38723747" target="_blank" title="접수방법 확인" onclick="try{s_trackApply(this, 'relay_view', 'hot100');}catch(e){};" onmousedown="try{ pushDataLayer('ga.lead', 'hot100',jobcategory_recruit, 'apply') } catch(e){}"><span class="sri_btn_apply_confirm">접수방법 확인</span></a>                    </span>
                </li>
                                        <li class="recruit_summary_basic">
                    <a href="/zf_user/jobs/relay/view?rec_idx=38733187&amp;t_ref=jobcategory_recruit&amp;t_ref_content=hot100" class="link_recomm" target="_blank" title="[주식회사 라이브플레이] 각 부문별 정규직 채용" onmousedown="try{ gtmDataLayerPush('ga_lead', 'hot100', 'jobcategory_recruit', 'view');} catch(e){}"></a>
                    <strong class="recomm_name">주식회사 라이브플레이</strong>
                    <span class="recomm_desc">[주식회사 라이브플레이] 각 부문별 정규직 채용</span>
                    <span class="recomm_info">
                        <span class="txt_info"><span class="blind">직종</span>#정규직 · 계약직</span>
                        <span class="txt_info"><span class="blind">지역</span>#서울 강남구</span>
                    </span>
                                        <a title="스크랩" style="cursor:pointer" onclick="Saramin.btnJob('scrap',this,'','list');" scraped="n" imgtype="" rec_idx="38733187" class="btn_scrap scrap-38733187">
                        <img src="//www.saraminimage.co.kr/common/bul_sri_star.png">
                    </a>
                    <span class="recruit_func">
                        <span class="blind">공고 마감일</span>
                        <span class="num_dday last">~ 09/22(화)</span>
                        <button class="sri_btn_xs" title="클릭하면 입사지원할 수 있는 창이 뜹니다." onclick="try{quickApplyForm('38733187','','t_category=relay_view&amp;t_content=hot100', ''); return false;} catch (e) {}; return false;" onmousedown="try{n_trackEvent('apply','list','quick_apply');}catch(e){}"><span class="sri_btn_immediately">즉시지원</span></button>                    </span>
                </li>
                                        <li class="recruit_summary_basic">
                    <a href="/zf_user/jobs/relay/view?rec_idx=38728432&amp;t_ref=jobcategory_recruit&amp;t_ref_content=hot100" class="link_recomm" target="_blank" title="2020년 부문별 경력직 수시채용" onmousedown="try{ gtmDataLayerPush('ga_lead', 'hot100', 'jobcategory_recruit', 'view');} catch(e){}"></a>
                    <strong class="recomm_name">(주)한라</strong>
                    <span class="recomm_desc">2020년 부문별 경력직 수시채용</span>
                    <span class="recomm_info">
                        <span class="txt_info"><span class="blind">직종</span>#정규직</span>
                        <span class="txt_info"><span class="blind">지역</span>#서울 송파구</span>
                    </span>
                                        <a title="스크랩" style="cursor:pointer" onclick="Saramin.btnJob('scrap',this,'','list');" scraped="n" imgtype="" rec_idx="38728432" class="btn_scrap scrap-38728432">
                        <img src="//www.saraminimage.co.kr/common/bul_sri_star.png">
                    </a>
                    <span class="recruit_func">
                        <span class="blind">공고 마감일</span>
                        <span class="num_dday last">~ 09/13(일)</span>
                        <a class="sri_btn_xs" href="/zf_user/jobs/relay/view?view_type=list&amp;rec_idx=38728432" target="_blank" title="홈페이지 지원" onclick="try{s_trackApply(this, 'relay_view', 'hot100');}catch(e){};" onmousedown="try{ pushDataLayer('ga.lead', 'hot100',jobcategory_recruit, 'apply') } catch(e){}"><span class="sri_btn_homepage_apply">홈페 이지 지원</span></a>                    </span>
                </li>
                                        <li class="recruit_summary_basic">
                    <a href="/zf_user/jobs/relay/view?rec_idx=38734141&amp;t_ref=jobcategory_recruit&amp;t_ref_content=hot100" class="link_recomm" target="_blank" title="[판교] 아이브릭스 하반기 채용공고" onmousedown="try{ gtmDataLayerPush('ga_lead', 'hot100', 'jobcategory_recruit', 'view');} catch(e){}"></a>
                    <strong class="recomm_name">(주)아이브릭스</strong>
                    <span class="recomm_desc">[판교] 아이브릭스 하반기 채용공고</span>
                    <span class="recomm_info">
                        <span class="txt_info"><span class="blind">직종</span>#정규직</span>
                        <span class="txt_info"><span class="blind">지역</span>#경기 성남시 분당구</span>
                    </span>
                                        <a title="스크랩" style="cursor:pointer" onclick="Saramin.btnJob('scrap',this,'','list');" scraped="n" imgtype="" rec_idx="38734141" class="btn_scrap scrap-38734141">
                        <img src="//www.saraminimage.co.kr/common/bul_sri_star.png">
                    </a>
                    <span class="recruit_func">
                        <span class="blind">공고 마감일</span>
                        <span class="num_dday last">~ 09/20(일)</span>
                        <button class="sri_btn_xs" title="클릭하면 입사지원할 수 있는 창이 뜹니다." onclick="try{quickApplyForm('38734141','','t_category=relay_view&amp;t_content=hot100', ''); return false;} catch (e) {}; return false;" onmousedown="try{n_trackEvent('apply','list','quick_apply');}catch(e){}"><span class="sri_btn_immediately">즉시지원</span></button>                    </span>
                </li>
                                        <li class="recruit_summary_basic">
                    <a href="/zf_user/jobs/relay/view?rec_idx=38722331&amp;t_ref=jobcategory_recruit&amp;t_ref_content=hot100" class="link_recomm" target="_blank" title="NDS 2020년 하반기 경력 채용 공고" onmousedown="try{ gtmDataLayerPush('ga_lead', 'hot100', 'jobcategory_recruit', 'view');} catch(e){}"></a>
                    <strong class="recomm_name">(주)엔디에스</strong>
                    <span class="recomm_desc">NDS 2020년 하반기 경력 채용 공고</span>
                    <span class="recomm_info">
                        <span class="txt_info"><span class="blind">직종</span>#정규직</span>
                        <span class="txt_info"><span class="blind">지역</span>#서울전체</span>
                    </span>
                                        <a title="스크랩" style="cursor:pointer" onclick="Saramin.btnJob('scrap',this,'','list');" scraped="n" imgtype="" rec_idx="38722331" class="btn_scrap scrap-38722331">
                        <img src="//www.saraminimage.co.kr/common/bul_sri_star.png">
                    </a>
                    <span class="recruit_func">
                        <span class="blind">공고 마감일</span>
                        <span class="num_dday last">~ 09/15(화)</span>
                        <a class="sri_btn_xs" href="/zf_user/jobs/relay/view?view_type=list&amp;rec_idx=38722331" target="_blank" title="홈페이지 지원" onclick="try{s_trackApply(this, 'relay_view', 'hot100');}catch(e){};" onmousedown="try{ pushDataLayer('ga.lead', 'hot100',jobcategory_recruit, 'apply') } catch(e){}"><span class="sri_btn_homepage_apply">홈페 이지 지원</span></a>                    </span>
                </li>
                                        <li class="recruit_summary_basic">
                    <a href="/zf_user/jobs/relay/view?rec_idx=38715533&amp;t_ref=jobcategory_recruit&amp;t_ref_content=hot100" class="link_recomm" target="_blank" title="[인프라웨어 계열사] I&amp;V Games 게임 부문별 채용" onmousedown="try{ gtmDataLayerPush('ga_lead', 'hot100', 'jobcategory_recruit', 'view');} catch(e){}"></a>
                    <strong class="recomm_name">(주)인프라웨어</strong>
                    <span class="recomm_desc">[인프라웨어 계열사] I&amp;V Games 게임 부문별 채용</span>
                    <span class="recomm_info">
                        <span class="txt_info"><span class="blind">직종</span>#정규직</span>
                        <span class="txt_info"><span class="blind">지역</span>#서울 금천구</span>
                    </span>
                                        <a title="스크랩" style="cursor:pointer" onclick="Saramin.btnJob('scrap',this,'','list');" scraped="n" imgtype="" rec_idx="38715533" class="btn_scrap scrap-38715533">
                        <img src="//www.saraminimage.co.kr/common/bul_sri_star.png">
                    </a>
                    <span class="recruit_func">
                        <span class="blind">공고 마감일</span>
                        <span class="num_dday last">~ 10/10(토)</span>
                        <button class="sri_btn_xs" title="클릭하면 입사지원할 수 있는 창이 뜹니다." onclick="try{quickApplyForm('38715533','','t_category=relay_view&amp;t_content=hot100', ''); return false;} catch (e) {}; return false;" onmousedown="try{n_trackEvent('apply','list','quick_apply');}catch(e){}"><span class="sri_btn_immediately">즉시지원</span></button>                    </span>
                </li>
                                        <li class="recruit_summary_basic">
                    <a href="/zf_user/jobs/relay/view?rec_idx=38476546&amp;t_ref=jobcategory_recruit&amp;t_ref_content=hot100" class="link_recomm" target="_blank" title="전 개발직군 대규모 채용중" onmousedown="try{ gtmDataLayerPush('ga_lead', 'hot100', 'jobcategory_recruit', 'view');} catch(e){}"></a>
                    <strong class="recomm_name">(유)딜리버리히어로 코리아</strong>
                    <span class="recomm_desc">전 개발직군 대규모 채용중</span>
                    <span class="recomm_info">
                        <span class="txt_info"><span class="blind">직종</span>#정규직</span>
                        <span class="txt_info"><span class="blind">지역</span>#서울 서초구</span>
                    </span>
                                        <a title="스크랩" style="cursor:pointer" onclick="Saramin.btnJob('scrap',this,'','list');" scraped="n" imgtype="" rec_idx="38476546" class="btn_scrap scrap-38476546">
                        <img src="//www.saraminimage.co.kr/common/bul_sri_star.png">
                    </a>
                    <span class="recruit_func">
                        <span class="blind">공고 마감일</span>
                        <span class="num_dday last">~ 09/30(수)</span>
                        <a class="sri_btn_xs" href="/zf_user/jobs/relay/view?view_type=list&amp;rec_idx=38476546" target="_blank" title="홈페이지 지원" onclick="try{s_trackApply(this, 'relay_view', 'hot100');}catch(e){};" onmousedown="try{ pushDataLayer('ga.lead', 'hot100',jobcategory_recruit, 'apply') } catch(e){}"><span class="sri_btn_homepage_apply">홈페 이지 지원</span></a>                    </span>
                </li>
                                        <li class="recruit_summary_basic">
                    <a href="/zf_user/jobs/relay/view?rec_idx=38738644&amp;t_ref=jobcategory_recruit&amp;t_ref_content=hot100" class="link_recomm" target="_blank" title="코렌스 각 부문 경력직원 모집" onmousedown="try{ gtmDataLayerPush('ga_lead', 'hot100', 'jobcategory_recruit', 'view');} catch(e){}"></a>
                    <strong class="recomm_name">(주)코렌스</strong>
                    <span class="recomm_desc">코렌스 각 부문 경력직원 모집</span>
                    <span class="recomm_info">
                        <span class="txt_info"><span class="blind">직종</span>#정규직</span>
                        <span class="txt_info"><span class="blind">지역</span>#경남 양산시</span>
                    </span>
                                        <a title="스크랩" style="cursor:pointer" onclick="Saramin.btnJob('scrap',this,'','list');" scraped="n" imgtype="" rec_idx="38738644" class="btn_scrap scrap-38738644">
                        <img src="//www.saraminimage.co.kr/common/bul_sri_star.png">
                    </a>
                    <span class="recruit_func">
                        <span class="blind">공고 마감일</span>
                        <span class="num_dday last">~ 09/20(일)</span>
                        <button class="sri_btn_xs" title="클릭하면 입사지원할 수 있는 창이 뜹니다." onclick="try{quickApplyForm('38738644','','t_category=relay_view&amp;t_content=hot100', ''); return false;} catch (e) {}; return false;" onmousedown="try{n_trackEvent('apply','list','quick_apply');}catch(e){}"><span class="sri_btn_immediately">즉시지원</span></button>                    </span>
                </li>
                                        <li class="recruit_summary_basic">
                    <a href="/zf_user/jobs/relay/view?rec_idx=38708343&amp;t_ref=jobcategory_recruit&amp;t_ref_content=hot100" class="link_recomm" target="_blank" title="2020년 경력사원 채용공고" onmousedown="try{ gtmDataLayerPush('ga_lead', 'hot100', 'jobcategory_recruit', 'view');} catch(e){}"></a>
                    <strong class="recomm_name">쌍용정보통신(주)</strong>
                    <span class="recomm_desc">2020년 경력사원 채용공고</span>
                    <span class="recomm_info">
                        <span class="txt_info"><span class="blind">직종</span>#정규직</span>
                        <span class="txt_info"><span class="blind">지역</span>#서울 중구</span>
                    </span>
                                        <a title="스크랩" style="cursor:pointer" onclick="Saramin.btnJob('scrap',this,'','list');" scraped="n" imgtype="" rec_idx="38708343" class="btn_scrap scrap-38708343">
                        <img src="//www.saraminimage.co.kr/common/bul_sri_star.png">
                    </a>
                    <span class="recruit_func">
                        <span class="blind">공고 마감일</span>
                        <span class="num_dday last">~ 09/17(목)</span>
                        <a class="sri_btn_xs" href="/zf_user/jobs/relay/view?view_type=list&amp;rec_idx=38708343" target="_blank" title="접수방법 확인" onclick="try{s_trackApply(this, 'relay_view', 'hot100');}catch(e){};" onmousedown="try{ pushDataLayer('ga.lead', 'hot100',jobcategory_recruit, 'apply') } catch(e){}"><span class="sri_btn_apply_confirm">접수방법 확인</span></a>                    </span>
                </li>
                    </ul>
    </div>
    <button type="button" id="recom_btn_next" class="btn_next on"><span class="blind">다음</span></button>
</div>
</div><script type="text/javascript">
$j(document).ready(function () {
    var data = JSON.parse('{"t_ref":"jobcategory_recruit","t_ref_content":"hot100","t_category":"relay_view","t_content":"hot100","cat_cd":"404","career_cd":"2","rec_idx":"38689139"}') || {};
    var paramStr = '';

    if (Object.keys(data).length > 0) {
        Object.keys(data).forEach(function (key) {
            var prefix = (paramStr !== '') ? '&' : '';
            paramStr += prefix + key + '=' + data[key];
        });
    }
    var recIdx = (data.rec_idx !== '' && typeof data.rec_idx !== 'undefined') ? ('-' + data.rec_idx) : '';
    var params = ((paramStr !== '') ? ('?' + paramStr) : '');
    var pageCount = recIdx ? 9 : 10; // 공고뷰는 3개씩 보여줘서 9개만 요청

    $j.ajax({
        type: 'get',
        url: '/zf_user/jobs/hot100/get-top10' + params + (((params !== '') ? '&' : '?') + 'page_count=' + pageCount),
        dataType: 'json',
        success: function (response) {
            if (response.result === 'success') {
                $j('#hot100-top10-list' + recIdx).html(response.content);
                slideEventBind();
            }
        },
        fail: function (error) {
            console.log(error);
        }
    });

    var slideEventBind = function () {
        var slideElement = $j('.list_recomm', '#hot100-top10-list' + recIdx);
        var recruitBox = $j('.recruit_summary_basic', slideElement),
            recruitLength = recruitBox.size(),
            boxWrap = slideElement.parents('.box_recommend_slide');

        var box = recruitBox.outerWidth(),
            visibleCount = Math.ceil(boxWrap.outerWidth() / box),
            btnNext = boxWrap.find('.btn_next'),
            btnPrev = boxWrap.find('.btn_prev');

        if (recruitLength <= visibleCount) {
            return;
        }
        var num = (recruitLength / visibleCount) - 1,
            count = 0,
            moving = false,
            slideNum = 1,
            totalPage = Math.ceil(recruitLength / visibleCount),
            term = 1,
            totalText = boxWrap.find('.slide_total');

        totalText.html(totalPage);
        slideElement.css('width', (box * recruitLength) + (term * (recruitLength)));
        btnNext.addClass('on');

        btnNext.on('click', function () {
            btnPrev.show();
            if (moving) {
                return false;
            }
            moving = true;
            slide(1);
            if (count >= Math.ceil(num)) {
                $j(this).hide();
            }
        });

        btnPrev.on('click', function () {
            btnNext.show();
            if (moving) {
                return false;
            }
            moving = true;
            slide(-1);
            if (count === 0) {
                $j(this).hide();
            }
        });

        var slide = function (dir) {
            count = count + dir;
            var leftValue = ((box * (visibleCount - 1)) * -count) - (term * visibleCount * -count) + (count > 0 ? -1 : 0) + 'px';
            if (recIdx !== '') {
                leftValue = ((box * visibleCount - 1) * -count) - (term * visibleCount * -count) + 'px';
            }
            slideElement.stop().animate({ left: leftValue }, {
                complete: function () {
                    moving = false;
                }
            });
            slideNum = slideNum + dir;
            boxWrap.find('em').html(slideNum);
        };
    }
});
</script><div class="jv_cont jv_footer"><div class="jv_title blind">관련 태그</div><div class="cont"><div class="tags"><ul class="scroll"><li><a href="/zf_user/jobs/list/job-category?cat_bcd=4" target="_blank" onmousedown="try{n_trackEvent('relay_view', 'tag', 'occupation', '');}catch(e){}">#IT·인터넷</a></li><li><a href="/zf_user/jobs/list/job-category?cat_cd=404" target="_blank" onmousedown="try{n_trackEvent('relay_view', 'tag', 'occupation', '');}catch(e){}">#웹개발</a></li><li><a href="/zf_user/jobs/list/job-category?cat_key=40404" target="_blank" onmousedown="try{n_trackEvent('relay_view', 'tag', 'occupation', '');}catch(e){}">#Java·JSP</a></li><li><a href="/zf_user/jobs/list/job-category?cat_cd=407" target="_blank" onmousedown="try{n_trackEvent('relay_view', 'tag', 'occupation', '');}catch(e){}">#응용프로그램개발</a></li><li><a href="/zf_user/jobs/list/job-category?cat_key=40701" target="_blank" onmousedown="try{n_trackEvent('relay_view', 'tag', 'occupation', '');}catch(e){}">#IOS앱개발</a></li><li><a href="/zf_user/jobs/list/job-category?cat_key=40702" target="_blank" onmousedown="try{n_trackEvent('relay_view', 'tag', 'occupation', '');}catch(e){}">#Android앱개발</a></li><li><a href="/zf_user/jobs/list/job-category?cat_key=40708" target="_blank" onmousedown="try{n_trackEvent('relay_view', 'tag', 'occupation', '');}catch(e){}">#Linux</a></li><li><a href="/zf_user/jobs/list/job-category?cat_key=40716" target="_blank" onmousedown="try{n_trackEvent('relay_view', 'tag', 'occupation', '');}catch(e){}">#Java</a></li><li><a href="/zf_user/jobs/list/job-category?cat_key=40722" target="_blank" onmousedown="try{n_trackEvent('relay_view', 'tag', 'occupation', '');}catch(e){}">#.NET</a></li><li><a href="/zf_user/jobs/list/job-category?cat_cd=408" target="_blank" onmousedown="try{n_trackEvent('relay_view', 'tag', 'occupation', '');}catch(e){}">#시스템개발</a></li><li><a href="/zf_user/jobs/list/job-category?cat_key=40802" target="_blank" onmousedown="try{n_trackEvent('relay_view', 'tag', 'occupation', '');}catch(e){}">#어셈블리</a></li><li><a href="/zf_user/jobs/list/job-category?cat_key=40805" target="_blank" onmousedown="try{n_trackEvent('relay_view', 'tag', 'occupation', '');}catch(e){}">#Embedded</a></li><li><a href="/zf_user/jobs/list/job-category?cat_key=40806" target="_blank" onmousedown="try{n_trackEvent('relay_view', 'tag', 'occupation', '');}catch(e){}">#펌웨어</a></li><li><a href="/zf_user/jobs/list/job-category?cat_key=40808" target="_blank" onmousedown="try{n_trackEvent('relay_view', 'tag', 'occupation', '');}catch(e){}">#HMI·PLC</a></li><li><a href="/zf_user/jobs/list/job-category?cat_key=40812" target="_blank" onmousedown="try{n_trackEvent('relay_view', 'tag', 'occupation', '');}catch(e){}">#CTI</a></li><li><a href="/zf_user/jobs/list/job-category?cat_cd=411" target="_blank" onmousedown="try{n_trackEvent('relay_view', 'tag', 'occupation', '');}catch(e){}">#하드웨어·소프트웨어</a></li><li><a href="/zf_user/jobs/list/job-category?cat_key=41105" target="_blank" onmousedown="try{n_trackEvent('relay_view', 'tag', 'occupation', '');}catch(e){}">#SW(소프트웨 어)</a></li><li><a href="/zf_user/jobs/list/job-category?cat_cd=402" target="_blank" onmousedown="try{n_trackEvent('relay_view', 'tag', 'occupation', '');}catch(e){}">#서버·네트워크·보안</a></li><li><a href="/zf_user/jobs/list/job-category?cat_key=40234" target="_blank" onmousedown="try{n_trackEvent('relay_view', 'tag', 'occupation', '');}catch(e){}">#시스템운영</a></li><li><a href="/zf_user/jobs/list/domestic?loc_cd=105000" target="_blank" onmousedown="try{n_trackEvent('relay_view', 'tag', 'area', '');}catch(e){}">#대전</a></li><li><a href="/zf_user/jobs/list/domestic?loc_cd=105030" target="_blank" onmousedown="try{n_trackEvent('relay_view', 'tag', 'area', '');}catch(e){}">#서구</a></li></ul><button type="button" class="btn_tags" style="display: inline-block;"><span class="blind">태그 더보기</span></button></div><div class="utils"><p class="copy">본 채용 정보에 불법·허위·과장 또는 잘못된 내용이 있을 경우 <a target="_blank" href="/zf_user/help/inquery/email-inquiry-write?rec_idx=38689139&amp;view_type=list" onmousedown="try{n_trackEvent('relay_view', 'warning', 'report', '');}catch(e){}">문의</a>해 주세요!</p><div class="share"><button type="button" class="spr_jview btn_jview btn_share"><span>공유하기</span></button><ul class="spr_jview list_share"><li><a href="http://www.facebook.com/share.php?api_key=137906922916817&amp;display=popup&amp;u=http%3A%2F%2Fwww.saramin.co.kr%2Fzf_user%2Fjobs%2Frelay%2Fview%3Frec_idx%3D38689139%26view_type%3Dlist" class="spr_jview facebook" onclick="window.open(this.href, this.target, 'width=578,height=380'); return false;" onmousedown="try{n_trackEvent('relay_view', 'bottom', 'facebook', '');}catch(e){}" title="페이스북 공유하기"><span class="blind">페이스북</span></a></li><li><a href="http://twitter.com/share?url=http%3A%2F%2Fwww.saramin.co.kr%2Fzf_user%2Fjobs%2Frelay%2Fview%3Frec_idx%3D38689139%26view_type%3Dlist&amp;text=%EB%8C%80%EC%A0%84%20%EA%B4%80%EC%84%B8%EC%B2%AD%20%EC%A0%84%EC%9E%90%ED%86%B5%EA%B4%80%EC%8B%9C%EC%8A%A4%ED%85%9C%20%EC%9A%B4%EC%98%81%28%EA%B0%9C%EB%B0%9C%29%20%EA%B2%BD%EB%A0%A5%EC%A7%81%EC%9B%90%20%EC%B1%84%EC%9A%A9%20-%20%28%EC%9E%AC%29%EA%B5%AD%EA%B0%80%EA%B4%80%EC%84%B8%EC%A2%85%ED%95%A9%EC%A0%95%EB%B3%B4%EB%A7%9D%EC%9A%B4%EC%98%81%EC%97%B0%ED%95%A9%ED%9A%8C%20%23saramin" class="spr_jview twitter" onclick="window.open(this.href, this.target, 'width=554,height=454'); return false;" onmousedown="try{n_trackEvent('relay_view', 'bottom', 'twitter', '');}catch(e){}" title="트위터 공유하기"><span class="blind">트위터</span></a></li><li><button type="button" class="spr_jview copy_url" title="공고 주소 복사하기" onclick="JobsView.copyUrl('http://www.saramin.co.kr/zf_user/jobs/relay/view?rec_idx=38689139&amp;view_type=list');" onmousedown="try{n_trackEvent('relay_view', 'bottom', 'copyurl', '' );}catch(e){}"><span class="blind">URL복사</span></button></li><li><button type="button" class="spr_jview send_sms" title="이 공고 내 폰으로 전송하기" onclick="Saramin.showQuickLogin();" onmousedown="try{n_trackEvent('relay_view', 'bottom', 'sendsms', '');}catch(e){}"><span class="blind">SMS발송</span></button></li></ul></div><button type="button" class="spr_jview btn_jview btn_print" onmousedown="try{n_trackEvent('relay_view', 'bottom', 'print', '');}catch(e){}"><span>인쇄하기</span></button></div></div></div></div><div class="jv_ads bottom_ads"><div class="div-gpt-ad-1400664864294-23-wrapper" style="width:728px; height:90px;"><div class="google-standby-banner"><a href="http://www.saramin.co.kr/avatar-branding/?inner_source=saramin&amp;inner_medium=banner&amp;inner_campaign=Waiting_Main_BigBanner&amp;inner_term=avatar_introduce" target="_blank"><img src="http://www.saraminbanner.co.kr/adserver/default/2019/01/pm0hyu_6urf-2rxiej_pekafl4i9h2rxelk728x90.png" alt="인공지능 취업플랫폼 사람인"></a></div><div class="div-gpt-ad-1400664864294-23-inner" style="display:none;"><div class="div-gpt-ad-1400664864294-23"></div></div></div></div>
    </div></div>

    <div class="jv_remote shrink" style="transform: translate(120px, 0px);">
        <div class="links"><button type="button" class="spr_jview jv_detail ready on" title="채용공고" onmousedown="try{n_trackEvent('relay_view', 'remote_control', 'detail_position', '');}catch(e){}"><span>채용공고</span></button><button type="button" class="spr_jview jv_howto ready" title="접수방법" onmousedown="try{n_trackEvent('relay_view', 'remote_control', 'howto', '');}catch(e){}"><span>접수방법</span></button><button type="button" class="spr_jview jv_statics ready" title="지원자통계" onmousedown="try{n_trackEvent('relay_view', 'remote_control', 'statistics', '');}catch(e){}"><span>지원자통계</span></button><button type="button" class="spr_jview jv_company ready" title="기업정보" onmousedown="try{n_trackEvent('relay_view', 'remote_control', 'companyinfo', '');}catch(e){}"><span>기업정보</span></button><button type="button" class="spr_jview jv_reference" title="합격자료" onmousedown="try{n_trackEvent('relay_view', 'remote_control', 'passdata', '');}catch(e){}"><span>합격자료</span></button></div>
        <div class="nav" style="display: block;">
            <button type="button" class="spr_jview btn_prev" onmousedown="try{n_trackEvent('relay_view', 'remote_control', 'before', '');}catch(e){}"><span>이전공고</span></button>
            <button type="button" class="spr_jview btn_next ready" onmousedown="try{n_trackEvent('relay_view', 'remote_control', 'after', '');}catch(e){}"><span>다음공고</span></button>
        </div>
    </div>

<div class="jview_floating jview">
    <div class="inner" style="transform: translateX(120px);">
        <div class="jv_header_float"></div>
                    <div class="jv_util">
                                    <div class="links login">
                        <a href="/zf_user/auth?url=%2Fzf_user%2Fjobs%2Frelay%2Fview%3FisMypage%3Dno%26rec_idx%3D38655001%26recommend_ids%3DeJxNj8ERAzEIA6vJH5AR8E4h7r%252BL2PGNuecyEixIZilqxohPfPHCOf6DMCZsevlBBbUmiwcBpjdaaEmHbaT4dOrTZQ656LQSrlOnyxGSu%252FugSFaHRwTULlK5RBojodHIFOC1yrfz1RBQsiUvPh%252FTuFx6WS0vtPVKu15rB5bYxh8IoEhm%26view_type%3Dlist%26gz%3D1"><span>로그인</span></a>
                        <a href="/zf_user/member/registration/join"><span>회원가입</span></a>
                    </div>
                                <div class="menu">
                    <button type="button" class="btn_menu" onmousedown="try{n_trackEvent('relay_view', 'title', 'menu', '');}catch(e){}"><span>메뉴</span></button>
                    <div class="spr_jview layer_menu">
                        <ul class="nav">
                            <li><a href="/">HOME</a></li>
                            <li><a href="/zf_user/recruit">전체 채용정보</a></li>
                            <li><a href="/zf_user/jobs/list/domestic">지역별</a></li>
                            <li><a href="/zf_user/jobs/list/job-category">직업별</a></li>
                            <li><a href="/zf_user/jobs/hot100">HOT100</a></li>
                            <li><a href="/zf_user/jobs/public/list">공채</a></li>
                            <li><a href="/zf_user/member/avatar/list">추천</a></li>
                            <li><a href="/zf_user/companylab">기업연구소</a></li>
                        </ul>
<!--                        <span>최근본메뉴</span>-->
<!--                        <ul class="lately"></ul>-->
                    </div>
                    <button type="button" class="btn_close"><span>닫기</span></button>
                </div>
            </div>
            </div>
</div><div class="jview_wing" style="transform: translateX(120px);">
    <div class="scroller">
        <div class="inner">
            <h2 class="title">
                이어보는 <strong>추천 채용정보</strong>
                <div class="toolTipWrap">
                    <button type="button" class="spr_jview btn_jview btn_help"><span>help</span></button>
                    <div class="toolTip">
                        <span class="tail tail_top_right"></span>
                        <div class="toolTipCont txtLeft">
                            <p>사람인 <em>인공지능 기술</em> 기반으로 맞춤 공고를 추천해드리는 사람인의 채용정보제공 서 비스입니다.</p>
                        </div>
                    </div>
                </div>
            </h2>
            <ul class="offer list"><li id="recommend_wing_0" style="display: list-item;"><a href="/zf_user/jobs/relay/view?rec_idx=38689139&amp;isMypage=no&amp;recommend_ids=38726832_595%7C38713619_696%7C38733685_696%7C38727190_595%7C38724805_561%7C38716840_561%7C38562906_746%7C38647080_596%7C38600890_561%7C38477312_561%7C38616136_561%7C38678317_561%7C38668033_596%7C38605619_561&amp;ref_dp=SRI_050_VIEW_MTRX_RCT_NOINFO&amp;view_type=list&amp;dpId=SRI_050_VIEW_MTRX_RCT_NOINFO&amp;refer=y&amp;t_ref_scnid=747&amp;rec_scn_id=747&amp;inner_source=saramin&amp;inner_medium=pattern&amp;inner_campaign=relay_view_0&amp;inner_term=list&amp;recommendRecIdx=38689139" onmousedown="try{n_trackEvent('relay_view', 'recommend', 'open', '');loggingRecommendUrl(this, 'http://rcmd-log.saramin.co.kr:9020/so-logging/log/client?custId=&amp;pcId=15996305088133198347523&amp;nonce=a8c32584fd04896f8879&amp;dpId=SRI_050_VIEW_MTRX_RCT_NOINFO&amp;scnId=747&amp;tgId=0&amp;itemSetId=0&amp;itemValue=38689139&amp;click=1', '');}catch(e){}" class="link"><span class="company">(재)국가관세종합정보망운 영연합회</span><span class="title"><span class="ico_offer">추천</span> 대전 관세청 전자통관시스템 운영(개발) 경력직원 채용</span><span class="info">대전 서구 <span class="txt_bar">|</span> 경력 3~5년 <span class="txt_bar">|</span> 초대졸↑</span></a><button class="sri_btn_xs for_btn_event" title="클릭하면 입사지원할 수 있는 창이 뜹니다." onclick="try{quickApplyForm('38689139','','t_category=relay_view&amp;t_content=relay_view_list&amp;t_ref=relay_view&amp;t_ref_content=SRI_050_VIEW_MTRX_RCT_NOINFO&amp;t_ref_scnid=747&amp;dpId=SRI_050_VIEW_MTRX_RCT_NOINFO&amp;ref_dp=SRI_050_VIEW_MTRX_RCT_NOINFO&amp;inner_source=saramin&amp;inner_medium=pattern&amp;inner_campaign=relay_view_apply_1&amp;inner_term=list', ''); return false;} catch (e) {}; return false;" onmousedown="try{n_trackEvent('relay_view','recommend','quick_apply','');}catch(e){}"><span class="sri_btn_immediately">즉시지원</span></button><span class="date">~ 9/11(금)</span><button type="button" onclick="Saramin.btnJob('scrap', this, '', 'quick_login');" scraped="n" rec_idx="38689139" class="btn_scrap scrap-38689139" imgtype="" title="공고 스크랩" onmousedown="try{n_trackEvent('relay_view', 'recommend', 'scrap' , '');}catch(e){}"><img src="http://www.saraminimage.co.kr/common/bul_sri_star.png" alt=""></button></li><li id="recommend_wing_1" style="display: list-item;"><a href="/zf_user/jobs/relay/view?rec_idx=38726832&amp;isMypage=no&amp;recommend_ids=38713619_696%7C38733685_696%7C38727190_595%7C38724805_561%7C38716840_561%7C38562906_746%7C38647080_596%7C38600890_561%7C38477312_561%7C38616136_561%7C38678317_561%7C38668033_596%7C38605619_561&amp;ref_dp=SRI_050_VIEW_MTRX_RCT_NOINFO&amp;view_type=list&amp;dpId=SRI_050_VIEW_MTRX_RCT_NOINFO&amp;refer=y&amp;t_ref_scnid=595&amp;rec_scn_id=595&amp;inner_source=saramin&amp;inner_medium=pattern&amp;inner_campaign=relay_view_1&amp;inner_term=list" onmousedown="try{n_trackEvent('relay_view', 'recommend', 'open', '');loggingRecommendUrl(this, 'http://rcmd-log.saramin.co.kr:9020/so-logging/log/client?custId=&amp;pcId=15996305088133198347523&amp;nonce=a8c32584fd04896f8879&amp;dpId=SRI_050_VIEW_MTRX_RCT_NOINFO&amp;scnId=595&amp;tgId=0&amp;itemSetId=0&amp;itemValue=38726832&amp;click=1', '');}catch(e){}" class="link"><span class="company">(주)에듀윌</span><span class="title">주4일 근무 대비 우수 인재모집</span><span class="info">서울전체 <span class="txt_bar">|</span> 신입/경력 <span class="txt_bar">|</span> 학력무관</span></a><button class="sri_btn_xs for_btn_event" title="클릭하면 입사지원할 수 있는 창이 뜹니다." onclick="try{quickApplyForm('38726832','','t_category=relay_view&amp;t_content=relay_view_list&amp;t_ref=relay_view&amp;t_ref_content=SRI_050_VIEW_MTRX_RCT_NOINFO&amp;t_ref_scnid=595&amp;dpId=SRI_050_VIEW_MTRX_RCT_NOINFO&amp;ref_dp=SRI_050_VIEW_MTRX_RCT_NOINFO&amp;inner_source=saramin&amp;inner_medium=pattern&amp;inner_campaign=relay_view_apply_2&amp;inner_term=list', ''); return false;} catch (e) {}; return false;" onmousedown="try{n_trackEvent('relay_view','recommend','quick_apply','');}catch(e){}"><span class="sri_btn_immediately">즉시지원</span></button><span class="date">~ 9/20(일)</span><button type="button" onclick="Saramin.btnJob('scrap', this, '', 'quick_login');" scraped="n" rec_idx="38726832" class="btn_scrap scrap-38726832" imgtype="" title="공고 스크랩" onmousedown="try{n_trackEvent('relay_view', 'recommend', 'scrap' , '');}catch(e){}"><img src="http://www.saraminimage.co.kr/common/bul_sri_star.png" alt=""></button></li><li id="recommend_wing_2" style="display: list-item;"><a href="/zf_user/jobs/relay/view?rec_idx=38713619&amp;isMypage=no&amp;recommend_ids=38733685_696%7C38727190_595%7C38724805_561%7C38716840_561%7C38562906_746%7C38647080_596%7C38600890_561%7C38477312_561%7C38616136_561%7C38678317_561%7C38668033_596%7C38605619_561&amp;ref_dp=SRI_050_VIEW_MTRX_RCT_NOINFO&amp;view_type=list&amp;dpId=SRI_050_VIEW_MTRX_RCT_NOINFO&amp;refer=y&amp;t_ref_scnid=696&amp;rec_scn_id=696&amp;inner_source=saramin&amp;inner_medium=pattern&amp;inner_campaign=relay_view_2&amp;inner_term=list" onmousedown="try{n_trackEvent('relay_view', 'recommend', 'open', '');loggingRecommendUrl(this, 'http://rcmd-log.saramin.co.kr:9020/so-logging/log/client?custId=&amp;pcId=15996305088133198347523&amp;nonce=a8c32584fd04896f8879&amp;dpId=SRI_050_VIEW_MTRX_RCT_NOINFO&amp;scnId=696&amp;tgId=0&amp;itemSetId=0&amp;itemValue=38713619&amp;click=1', '');}catch(e){}" class="link"><span class="company">노리시스템(주)</span><span class="title">JAVA / C# /DB 개�� 프리랜서 모집</span><span class="info">천안시 서북구 <span class="txt_bar">|</span> 경력5년↑ <span class="txt_bar">|</span> 초대졸↑</span></a><button class="sri_btn_xs for_btn_event" title="클릭하면 입사지원할 수 있는 창이 뜹니다." onclick="try{quickApplyForm('38713619','','t_category=relay_view&amp;t_content=relay_view_list&amp;t_ref=relay_view&amp;t_ref_content=SRI_050_VIEW_MTRX_RCT_NOINFO&amp;t_ref_scnid=696&amp;dpId=SRI_050_VIEW_MTRX_RCT_NOINFO&amp;ref_dp=SRI_050_VIEW_MTRX_RCT_NOINFO&amp;inner_source=saramin&amp;inner_medium=pattern&amp;inner_campaign=relay_view_apply_3&amp;inner_term=list', ''); return false;} catch (e) {}; return false;" onmousedown="try{n_trackEvent('relay_view','recommend','quick_apply','');}catch(e){}"><span class="sri_btn_immediately">즉시지원</span></button><span class="date">~ 9/30(수)</span><button type="button" onclick="Saramin.btnJob('scrap', this, '', 'quick_login');" scraped="n" rec_idx="38713619" class="btn_scrap scrap-38713619" imgtype="" title="공고 스크랩" onmousedown="try{n_trackEvent('relay_view', 'recommend', 'scrap' , '');}catch(e){}"><img src="http://www.saraminimage.co.kr/common/bul_sri_star.png" alt=""></button></li><li id="recommend_wing_3" style="display: list-item;"><a href="/zf_user/jobs/relay/view?rec_idx=38733685&amp;isMypage=no&amp;recommend_ids=38727190_595%7C38724805_561%7C38716840_561%7C38562906_746%7C38647080_596%7C38600890_561%7C38477312_561%7C38616136_561%7C38678317_561%7C38668033_596%7C38605619_561&amp;ref_dp=SRI_050_VIEW_MTRX_RCT_NOINFO&amp;view_type=list&amp;dpId=SRI_050_VIEW_MTRX_RCT_NOINFO&amp;refer=y&amp;t_ref_scnid=696&amp;rec_scn_id=696&amp;inner_source=saramin&amp;inner_medium=pattern&amp;inner_campaign=relay_view_3&amp;inner_term=list" onmousedown="try{n_trackEvent('relay_view', 'recommend', 'open', '');loggingRecommendUrl(this, 'http://rcmd-log.saramin.co.kr:9020/so-logging/log/client?custId=&amp;pcId=15996305088133198347523&amp;nonce=a8c32584fd04896f8879&amp;dpId=SRI_050_VIEW_MTRX_RCT_NOINFO&amp;scnId=696&amp;tgId=0&amp;itemSetId=0&amp;itemValue=38733685&amp;click=1', '');}catch(e){}" class="link"><span class="company">정암건설(주)</span><span class="title">[계약직]  외 경력무관 채용합니다</span><span class="info">괴산군 <span class="txt_bar">|</span> 경력무관 <span class="txt_bar">|</span> 학력무관</span></a><button class="sri_btn_xs for_btn_event" title="클릭하면 입사지원할 수 있는 창이 뜹니다." onclick="try{quickApplyForm('38733685','','t_category=relay_view&amp;t_content=relay_view_list&amp;t_ref=relay_view&amp;t_ref_content=SRI_050_VIEW_MTRX_RCT_NOINFO&amp;t_ref_scnid=696&amp;dpId=SRI_050_VIEW_MTRX_RCT_NOINFO&amp;ref_dp=SRI_050_VIEW_MTRX_RCT_NOINFO&amp;inner_source=saramin&amp;inner_medium=pattern&amp;inner_campaign=relay_view_apply_4&amp;inner_term=list', ''); return false;} catch (e) {}; return false;" onmousedown="try{n_trackEvent('relay_view','recommend','quick_apply','');}catch(e){}"><span class="sri_btn_immediately">즉시지원</span></button><span class="date">~ 11/6(금)</span><button type="button" onclick="Saramin.btnJob('scrap', this, '', 'quick_login');" scraped="n" rec_idx="38733685" class="btn_scrap scrap-38733685" imgtype="" title="공고 스크랩" onmousedown="try{n_trackEvent('relay_view', 'recommend', 'scrap' , '');}catch(e){}"><img src="http://www.saraminimage.co.kr/common/bul_sri_star.png" alt=""></button></li><li id="recommend_wing_4" style="display: none;"><a href="/zf_user/jobs/relay/view?rec_idx=38727190&amp;isMypage=no&amp;recommend_ids=38724805_561%7C38716840_561%7C38562906_746%7C38647080_596%7C38600890_561%7C38477312_561%7C38616136_561%7C38678317_561%7C38668033_596%7C38605619_561&amp;ref_dp=SRI_050_VIEW_MTRX_RCT_NOINFO&amp;view_type=list&amp;dpId=SRI_050_VIEW_MTRX_RCT_NOINFO&amp;refer=y&amp;t_ref_scnid=595&amp;rec_scn_id=595&amp;inner_source=saramin&amp;inner_medium=pattern&amp;inner_campaign=relay_view_4&amp;inner_term=list" onmousedown="try{n_trackEvent('relay_view', 'recommend', 'open', '');loggingRecommendUrl(this, 'http://rcmd-log.saramin.co.kr:9020/so-logging/log/client?custId=&amp;pcId=15996305088133198347523&amp;nonce=a8c32584fd04896f8879&amp;dpId=SRI_050_VIEW_MTRX_RCT_NOINFO&amp;scnId=595&amp;tgId=0&amp;itemSetId=0&amp;itemValue=38727190&amp;click=1', '');}catch(e){}" class="link"><span class="company">오티아이(주)</span><span class="title">오티아이㈜ 각 부문 신입 및 경력직 채용</span><span class="info">서울전체 <span class="txt_bar">|</span> 신입/경력 <span class="txt_bar">|</span> 대졸↑</span></a><button class="sri_btn_xs for_btn_event" title="클릭하면 입사지원할 수 있는 창이 뜹니다." onclick="try{quickApplyForm('38727190','','t_category=relay_view&amp;t_content=relay_view_list&amp;t_ref=relay_view&amp;t_ref_content=SRI_050_VIEW_MTRX_RCT_NOINFO&amp;t_ref_scnid=595&amp;dpId=SRI_050_VIEW_MTRX_RCT_NOINFO&amp;ref_dp=SRI_050_VIEW_MTRX_RCT_NOINFO&amp;inner_source=saramin&amp;inner_medium=pattern&amp;inner_campaign=relay_view_apply_5&amp;inner_term=list', ''); return false;} catch (e) {}; return false;" onmousedown="try{n_trackEvent('relay_view','recommend','quick_apply','');}catch(e){}"><span class="sri_btn_immediately">즉시지원</span></button><span class="date">~ 9/20(일)</span><button type="button" onclick="Saramin.btnJob('scrap', this, '', 'quick_login');" scraped="n" rec_idx="38727190" class="btn_scrap scrap-38727190" imgtype="" title="공고 스크랩" onmousedown="try{n_trackEvent('relay_view', 'recommend', 'scrap' , '');}catch(e){}"><img src="http://www.saraminimage.co.kr/common/bul_sri_star.png" alt=""></button></li><li id="recommend_wing_5" style="display: none;"><a href="/zf_user/jobs/relay/view?rec_idx=38724805&amp;isMypage=no&amp;recommend_ids=38716840_561%7C38562906_746%7C38647080_596%7C38600890_561%7C38477312_561%7C38616136_561%7C38678317_561%7C38668033_596%7C38605619_561&amp;ref_dp=SRI_050_VIEW_MTRX_RCT_NOINFO&amp;view_type=list&amp;dpId=SRI_050_VIEW_MTRX_RCT_NOINFO&amp;refer=y&amp;t_ref_scnid=561&amp;rec_scn_id=561&amp;inner_source=saramin&amp;inner_medium=pattern&amp;inner_campaign=relay_view_5&amp;inner_term=list" onmousedown="try{n_trackEvent('relay_view', 'recommend', 'open', '');loggingRecommendUrl(this, 'http://rcmd-log.saramin.co.kr:9020/so-logging/log/client?custId=&amp;pcId=15996305088133198347523&amp;nonce=a8c32584fd04896f8879&amp;dpId=SRI_050_VIEW_MTRX_RCT_NOINFO&amp;scnId=561&amp;tgId=0&amp;itemSetId=0&amp;itemValue=38724805&amp;click=1', '');}catch(e){}" class="link"><span class="company">(주)에이직스</span><span class="title">(인턴채용) Java 웹 프로그램 개발 (채용연계형)</span><span class="info">유성구 <span class="txt_bar">|</span> 경력무관 <span class="txt_bar">|</span> 학력무관</span></a><button class="sri_btn_xs for_btn_event" title="클릭하면 입사지원할 수 있는 창이 뜹니다." onclick="try{quickApplyForm('38724805','','t_category=relay_view&amp;t_content=relay_view_list&amp;t_ref=relay_view&amp;t_ref_content=SRI_050_VIEW_MTRX_RCT_NOINFO&amp;t_ref_scnid=561&amp;dpId=SRI_050_VIEW_MTRX_RCT_NOINFO&amp;ref_dp=SRI_050_VIEW_MTRX_RCT_NOINFO&amp;inner_source=saramin&amp;inner_medium=pattern&amp;inner_campaign=relay_view_apply_6&amp;inner_term=list', ''); return false;} catch (e) {}; return false;" onmousedown="try{n_trackEvent('relay_view','recommend','quick_apply','');}catch(e){}"><span class="sri_btn_immediately">즉시지원</span></button><span class="date">~ 11/3(화)</span><button type="button" onclick="Saramin.btnJob('scrap', this, '', 'quick_login');" scraped="n" rec_idx="38724805" class="btn_scrap scrap-38724805" imgtype="" title="공고 스크랩" onmousedown="try{n_trackEvent('relay_view', 'recommend', 'scrap' , '');}catch(e){}"><img src="http://www.saraminimage.co.kr/common/bul_sri_star.png" alt=""></button></li><li id="recommend_wing_6" style="display: none;"><a href="/zf_user/jobs/relay/view?rec_idx=38716840&amp;isMypage=no&amp;recommend_ids=38562906_746%7C38647080_596%7C38600890_561%7C38477312_561%7C38616136_561%7C38678317_561%7C38668033_596%7C38605619_561&amp;ref_dp=SRI_050_VIEW_MTRX_RCT_NOINFO&amp;view_type=list&amp;dpId=SRI_050_VIEW_MTRX_RCT_NOINFO&amp;refer=y&amp;t_ref_scnid=561&amp;rec_scn_id=561&amp;inner_source=saramin&amp;inner_medium=pattern&amp;inner_campaign=relay_view_6&amp;inner_term=list" onmousedown="try{n_trackEvent('relay_view', 'recommend', 'open', '');loggingRecommendUrl(this, 'http://rcmd-log.saramin.co.kr:9020/so-logging/log/client?custId=&amp;pcId=15996305088133198347523&amp;nonce=a8c32584fd04896f8879&amp;dpId=SRI_050_VIEW_MTRX_RCT_NOINFO&amp;scnId=561&amp;tgId=0&amp;itemSetId=0&amp;itemValue=38716840&amp;click=1', '');}catch(e){}" class="link"><span class="company">주식회사 베니페</span><span class="title">[신입] 웹 사이트 개발 좋아하는 사람 모집</span><span class="info">유성구 <span class="txt_bar">|</span> 신입 <span class="txt_bar">|</span> 대졸↑</span></a><button class="sri_btn_xs for_btn_event" title="클릭하면 입사지원할 수 있는 창이 뜹니다." onclick="try{quickApplyForm('38716840','','t_category=relay_view&amp;t_content=relay_view_list&amp;t_ref=relay_view&amp;t_ref_content=SRI_050_VIEW_MTRX_RCT_NOINFO&amp;t_ref_scnid=561&amp;dpId=SRI_050_VIEW_MTRX_RCT_NOINFO&amp;ref_dp=SRI_050_VIEW_MTRX_RCT_NOINFO&amp;inner_source=saramin&amp;inner_medium=pattern&amp;inner_campaign=relay_view_apply_7&amp;inner_term=list', ''); return false;} catch (e) {}; return false;" onmousedown="try{n_trackEvent('relay_view','recommend','quick_apply','');}catch(e){}"><span class="sri_btn_immediately">즉 시지원</span></button><span class="date">~ 10/2(금)</span><button type="button" onclick="Saramin.btnJob('scrap', this, '', 'quick_login');" scraped="n" rec_idx="38716840" class="btn_scrap scrap-38716840" imgtype="" title="공고 스크랩" onmousedown="try{n_trackEvent('relay_view', 'recommend', 'scrap' , '');}catch(e){}"><img src="http://www.saraminimage.co.kr/common/bul_sri_star.png" alt=""></button></li><li id="recommend_wing_7" style="display: none;"><a href="/zf_user/jobs/relay/view?rec_idx=38562906&amp;isMypage=no&amp;recommend_ids=38647080_596%7C38600890_561%7C38477312_561%7C38616136_561%7C38678317_561%7C38668033_596%7C38605619_561&amp;ref_dp=SRI_050_VIEW_MTRX_RCT_NOINFO&amp;view_type=list&amp;dpId=SRI_050_VIEW_MTRX_RCT_NOINFO&amp;refer=y&amp;t_ref_scnid=746&amp;rec_scn_id=746&amp;inner_source=saramin&amp;inner_medium=pattern&amp;inner_campaign=relay_view_7&amp;inner_term=list" onmousedown="try{n_trackEvent('relay_view', 'recommend', 'open', '');loggingRecommendUrl(this, 'http://rcmd-log.saramin.co.kr:9020/so-logging/log/client?custId=&amp;pcId=15996305088133198347523&amp;nonce=a8c32584fd04896f8879&amp;dpId=SRI_050_VIEW_MTRX_RCT_NOINFO&amp;scnId=746&amp;tgId=0&amp;itemSetId=0&amp;itemValue=38562906&amp;click=1', '');}catch(e){}" class="link"><span class="company">(주)인핸스유</span><span class="title">웹솔루션 개발자 모집(대전)</span><span class="info">대덕구 <span class="txt_bar">|</span> 경력무관 <span class="txt_bar">|</span> 초대졸↑</span></a><button class="sri_btn_xs for_btn_event" title="클릭하면 입사지원할 수 있는 창이 뜹니 다." onclick="try{quickApplyForm('38562906','','t_category=relay_view&amp;t_content=relay_view_list&amp;t_ref=relay_view&amp;t_ref_content=SRI_050_VIEW_MTRX_RCT_NOINFO&amp;t_ref_scnid=746&amp;dpId=SRI_050_VIEW_MTRX_RCT_NOINFO&amp;ref_dp=SRI_050_VIEW_MTRX_RCT_NOINFO&amp;inner_source=saramin&amp;inner_medium=pattern&amp;inner_campaign=relay_view_apply_8&amp;inner_term=list', ''); return false;} catch (e) {}; return false;" onmousedown="try{n_trackEvent('relay_view','recommend','quick_apply','');}catch(e){}"><span class="sri_btn_immediately">즉시지원</span></button><span class="date">~ 9/30(수)</span><button type="button" onclick="Saramin.btnJob('scrap', this, '', 'quick_login');" scraped="n" rec_idx="38562906" class="btn_scrap scrap-38562906" imgtype="" title="공고 스크랩" onmousedown="try{n_trackEvent('relay_view', 'recommend', 'scrap' , '');}catch(e){}"><img src="http://www.saraminimage.co.kr/common/bul_sri_star.png" alt=""></button></li><li id="recommend_wing_8" style="display: none;"><a href="/zf_user/jobs/relay/view?rec_idx=38647080&amp;isMypage=no&amp;recommend_ids=38600890_561%7C38477312_561%7C38616136_561%7C38678317_561%7C38668033_596%7C38605619_561&amp;ref_dp=SRI_050_VIEW_MTRX_RCT_NOINFO&amp;view_type=list&amp;dpId=SRI_050_VIEW_MTRX_RCT_NOINFO&amp;refer=y&amp;t_ref_scnid=596&amp;rec_scn_id=596&amp;inner_source=saramin&amp;inner_medium=pattern&amp;inner_campaign=relay_view_8&amp;inner_term=list" onmousedown="try{n_trackEvent('relay_view', 'recommend', 'open', '');loggingRecommendUrl(this, 'http://rcmd-log.saramin.co.kr:9020/so-logging/log/client?custId=&amp;pcId=15996305088133198347523&amp;nonce=a8c32584fd04896f8879&amp;dpId=SRI_050_VIEW_MTRX_RCT_NOINFO&amp;scnId=596&amp;tgId=0&amp;itemSetId=0&amp;itemValue=38647080&amp;click=1', '');}catch(e){}" class="link"><span class="company">(주)새올정보기술</span><span class="title">소프트웨어 부문 개발자 모집</span><span class="info">대전  중구 <span class="txt_bar">|</span> 신입/경력 <span class="txt_bar">|</span> 초대졸↑</span></a><button class="sri_btn_xs for_btn_event" title="클릭하면 입사지원할 수 있는 창이 뜹니다." onclick="try{quickApplyForm('38647080','','t_category=relay_view&amp;t_content=relay_view_list&amp;t_ref=relay_view&amp;t_ref_content=SRI_050_VIEW_MTRX_RCT_NOINFO&amp;t_ref_scnid=596&amp;dpId=SRI_050_VIEW_MTRX_RCT_NOINFO&amp;ref_dp=SRI_050_VIEW_MTRX_RCT_NOINFO&amp;inner_source=saramin&amp;inner_medium=pattern&amp;inner_campaign=relay_view_apply_9&amp;inner_term=list', ''); return false;} catch (e) {}; return false;" onmousedown="try{n_trackEvent('relay_view','recommend','quick_apply','');}catch(e){}"><span class="sri_btn_immediately">즉시지원</span></button><span class="date">채용시</span><button type="button" onclick="Saramin.btnJob('scrap', this, '', 'quick_login');" scraped="n" rec_idx="38647080" class="btn_scrap scrap-38647080" imgtype="" title="공고 스크랩" onmousedown="try{n_trackEvent('relay_view', 'recommend', 'scrap' , '');}catch(e){}"><img src="http://www.saraminimage.co.kr/common/bul_sri_star.png" alt=""></button></li><li id="recommend_wing_9" style="display: none;"><a href="/zf_user/jobs/relay/view?rec_idx=38600890&amp;isMypage=no&amp;recommend_ids=38477312_561%7C38616136_561%7C38678317_561%7C38668033_596%7C38605619_561&amp;ref_dp=SRI_050_VIEW_MTRX_RCT_NOINFO&amp;view_type=list&amp;dpId=SRI_050_VIEW_MTRX_RCT_NOINFO&amp;refer=y&amp;t_ref_scnid=561&amp;rec_scn_id=561&amp;inner_source=saramin&amp;inner_medium=pattern&amp;inner_campaign=relay_view_9&amp;inner_term=list" onmousedown="try{n_trackEvent('relay_view', 'recommend', 'open', '');loggingRecommendUrl(this, 'http://rcmd-log.saramin.co.kr:9020/so-logging/log/client?custId=&amp;pcId=15996305088133198347523&amp;nonce=a8c32584fd04896f8879&amp;dpId=SRI_050_VIEW_MTRX_RCT_NOINFO&amp;scnId=561&amp;tgId=0&amp;itemSetId=0&amp;itemValue=38600890&amp;click=1', '');}catch(e){}" class="link"><span class="company">(주)에이치포테크</span><span class="title">빅데이터 처리 및 웹 소프트웨어 개발 신입/경력 채용(정규직)</span><span class="info">유성구 <span class="txt_bar">|</span> 경력무관 <span class="txt_bar">|</span> 학력무관</span></a><button class="sri_btn_xs for_btn_event" title="클릭하면 입사지원할 수 있는 창이 뜹니다." onclick="try{quickApplyForm('38600890','','t_category=relay_view&amp;t_content=relay_view_list&amp;t_ref=relay_view&amp;t_ref_content=SRI_050_VIEW_MTRX_RCT_NOINFO&amp;t_ref_scnid=561&amp;dpId=SRI_050_VIEW_MTRX_RCT_NOINFO&amp;ref_dp=SRI_050_VIEW_MTRX_RCT_NOINFO&amp;inner_source=saramin&amp;inner_medium=pattern&amp;inner_campaign=relay_view_apply_10&amp;inner_term=list', ''); return false;} catch (e) {}; return false;" onmousedown="try{n_trackEvent('relay_view','recommend','quick_apply','');}catch(e){}"><span class="sri_btn_immediately">즉시지원</span></button><span class="date">~ 9/25(금)</span><button type="button" onclick="Saramin.btnJob('scrap', this, '', 'quick_login');" scraped="n" rec_idx="38600890" class="btn_scrap scrap-38600890" imgtype="" title="공고 스크랩" onmousedown="try{n_trackEvent('relay_view', 'recommend', 'scrap' , '');}catch(e){}"><img src="http://www.saraminimage.co.kr/common/bul_sri_star.png" alt=""></button></li><li id="recommend_wing_10" style="display: none;"><a href="/zf_user/jobs/relay/view?rec_idx=38477312&amp;isMypage=no&amp;recommend_ids=38616136_561%7C38678317_561%7C38668033_596%7C38605619_561&amp;ref_dp=SRI_050_VIEW_MTRX_RCT_NOINFO&amp;view_type=list&amp;dpId=SRI_050_VIEW_MTRX_RCT_NOINFO&amp;refer=y&amp;t_ref_scnid=561&amp;rec_scn_id=561&amp;inner_source=saramin&amp;inner_medium=pattern&amp;inner_campaign=relay_view_10&amp;inner_term=list" onmousedown="try{n_trackEvent('relay_view', 'recommend', 'open', '');loggingRecommendUrl(this, 'http://rcmd-log.saramin.co.kr:9020/so-logging/log/client?custId=&amp;pcId=15996305088133198347523&amp;nonce=a8c32584fd04896f8879&amp;dpId=SRI_050_VIEW_MTRX_RCT_NOINFO&amp;scnId=561&amp;tgId=0&amp;itemSetId=0&amp;itemValue=38477312&amp;click=1', '');}catch(e){}" class="link"><span class="company">(주)이데아인포</span><span class="title">시스템통합/웹 개발자 채용 공고</span><span class="info">대전 서구 <span class="txt_bar">|</span> 신입/경력 <span class="txt_bar">|</span> 초대졸↑</span></a><button class="sri_btn_xs for_btn_event" title="클릭하면 입사지원할 수 있는 창이 뜹니다." onclick="try{quickApplyForm('38477312','','t_category=relay_view&amp;t_content=relay_view_list&amp;t_ref=relay_view&amp;t_ref_content=SRI_050_VIEW_MTRX_RCT_NOINFO&amp;t_ref_scnid=561&amp;dpId=SRI_050_VIEW_MTRX_RCT_NOINFO&amp;ref_dp=SRI_050_VIEW_MTRX_RCT_NOINFO&amp;inner_source=saramin&amp;inner_medium=pattern&amp;inner_campaign=relay_view_apply_11&amp;inner_term=list', ''); return false;} catch (e) {}; return false;" onmousedown="try{n_trackEvent('relay_view','recommend','quick_apply','');}catch(e){}"><span class="sri_btn_immediately">즉시지원</span></button><span class="date">~ 9/15(화)</span><button type="button" onclick="Saramin.btnJob('scrap', this, '', 'quick_login');" scraped="n" rec_idx="38477312" class="btn_scrap scrap-38477312" imgtype="" title="공고 스크랩" onmousedown="try{n_trackEvent('relay_view', 'recommend', 'scrap' , '');}catch(e){}"><img src="http://www.saraminimage.co.kr/common/bul_sri_star.png" alt=""></button></li><li id="recommend_wing_11" style="display: none;"><a href="/zf_user/jobs/relay/view?rec_idx=38616136&amp;isMypage=no&amp;recommend_ids=38678317_561%7C38668033_596%7C38605619_561&amp;ref_dp=SRI_050_VIEW_MTRX_RCT_NOINFO&amp;view_type=list&amp;dpId=SRI_050_VIEW_MTRX_RCT_NOINFO&amp;refer=y&amp;t_ref_scnid=561&amp;rec_scn_id=561&amp;inner_source=saramin&amp;inner_medium=pattern&amp;inner_campaign=relay_view_11&amp;inner_term=list" onmousedown="try{n_trackEvent('relay_view', 'recommend', 'open', '');loggingRecommendUrl(this, 'http://rcmd-log.saramin.co.kr:9020/so-logging/log/client?custId=&amp;pcId=15996305088133198347523&amp;nonce=a8c32584fd04896f8879&amp;dpId=SRI_050_VIEW_MTRX_RCT_NOINFO&amp;scnId=561&amp;tgId=0&amp;itemSetId=0&amp;itemValue=38616136&amp;click=1', '');}catch(e){}" class="link"><span class="company">(주)지에스지</span><span class="title">R&amp;D 및 용역 소프트웨어 개발·유지보수 채용(C, JAVA, Python)</span><span class="info">대덕구 <span class="txt_bar">|</span> 경력무관 <span class="txt_bar">|</span> 대졸↑</span></a><button class="sri_btn_xs for_btn_event" title="클릭하면 입사지원할 수 있는 창이 뜹니다." onclick="try{quickApplyForm('38616136','','t_category=relay_view&amp;t_content=relay_view_list&amp;t_ref=relay_view&amp;t_ref_content=SRI_050_VIEW_MTRX_RCT_NOINFO&amp;t_ref_scnid=561&amp;dpId=SRI_050_VIEW_MTRX_RCT_NOINFO&amp;ref_dp=SRI_050_VIEW_MTRX_RCT_NOINFO&amp;inner_source=saramin&amp;inner_medium=pattern&amp;inner_campaign=relay_view_apply_12&amp;inner_term=list', ''); return false;} catch (e) {}; return false;" onmousedown="try{n_trackEvent('relay_view','recommend','quick_apply','');}catch(e){}"><span class="sri_btn_immediately">즉시지원</span></button><span class="date">채용시</span><button type="button" onclick="Saramin.btnJob('scrap', this, '', 'quick_login');" scraped="n" rec_idx="38616136" class="btn_scrap scrap-38616136" imgtype="" title="공고 스크랩" onmousedown="try{n_trackEvent('relay_view', 'recommend', 'scrap' , '');}catch(e){}"><img src="http://www.saraminimage.co.kr/common/bul_sri_star.png" alt=""></button></li><li id="recommend_wing_12" style="display: none;"><a href="/zf_user/jobs/relay/view?rec_idx=38678317&amp;isMypage=no&amp;recommend_ids=38668033_596%7C38605619_561&amp;ref_dp=SRI_050_VIEW_MTRX_RCT_NOINFO&amp;view_type=list&amp;dpId=SRI_050_VIEW_MTRX_RCT_NOINFO&amp;refer=y&amp;t_ref_scnid=561&amp;rec_scn_id=561&amp;inner_source=saramin&amp;inner_medium=pattern&amp;inner_campaign=relay_view_12&amp;inner_term=list" onmousedown="try{n_trackEvent('relay_view', 'recommend', 'open', '');loggingRecommendUrl(this, 'http://rcmd-log.saramin.co.kr:9020/so-logging/log/client?custId=&amp;pcId=15996305088133198347523&amp;nonce=a8c32584fd04896f8879&amp;dpId=SRI_050_VIEW_MTRX_RCT_NOINFO&amp;scnId=561&amp;tgId=0&amp;itemSetId=0&amp;itemValue=38678317&amp;click=1', '');}catch(e){}" class="link"><span class="company">(주)엔에스이</span><span class="title">열정이 넘치는 프로그래머, 개발자를 모십시다.</span><span class="info">유성구 <span class="txt_bar">|</span> 경력무관 <span class="txt_bar">|</span> 대졸↑</span></a><button class="sri_btn_xs for_btn_event" title="클릭하면 입사지원할 수 있는 창이 뜹니다." onclick="try{quickApplyForm('38678317','','t_category=relay_view&amp;t_content=relay_view_list&amp;t_ref=relay_view&amp;t_ref_content=SRI_050_VIEW_MTRX_RCT_NOINFO&amp;t_ref_scnid=561&amp;dpId=SRI_050_VIEW_MTRX_RCT_NOINFO&amp;ref_dp=SRI_050_VIEW_MTRX_RCT_NOINFO&amp;inner_source=saramin&amp;inner_medium=pattern&amp;inner_campaign=relay_view_apply_13&amp;inner_term=list', ''); return false;} catch (e) {}; return false;" onmousedown="try{n_trackEvent('relay_view','recommend','quick_apply','');}catch(e){}"><span class="sri_btn_immediately">즉시지원</span></button><span class="date">~ 10/25(일)</span><button type="button" onclick="Saramin.btnJob('scrap', this, '', 'quick_login');" scraped="n" rec_idx="38678317" class="btn_scrap scrap-38678317" imgtype="" title="공고 스크랩" onmousedown="try{n_trackEvent('relay_view', 'recommend', 'scrap' , '');}catch(e){}"><img src="http://www.saraminimage.co.kr/common/bul_sri_star.png" alt=""></button></li><li id="recommend_wing_13" style="display: none;"><a href="/zf_user/jobs/relay/view?rec_idx=38668033&amp;isMypage=no&amp;recommend_ids=38605619_561&amp;ref_dp=SRI_050_VIEW_MTRX_RCT_NOINFO&amp;view_type=list&amp;dpId=SRI_050_VIEW_MTRX_RCT_NOINFO&amp;refer=y&amp;t_ref_scnid=596&amp;rec_scn_id=596&amp;inner_source=saramin&amp;inner_medium=pattern&amp;inner_campaign=relay_view_13&amp;inner_term=list" onmousedown="try{n_trackEvent('relay_view', 'recommend', 'open', '');loggingRecommendUrl(this, 'http://rcmd-log.saramin.co.kr:9020/so-logging/log/client?custId=&amp;pcId=15996305088133198347523&amp;nonce=a8c32584fd04896f8879&amp;dpId=SRI_050_VIEW_MTRX_RCT_NOINFO&amp;scnId=596&amp;tgId=0&amp;itemSetId=0&amp;itemValue=38668033&amp;click=1', '');}catch(e){}" class="link"><span class="company">(주)와이티</span><span class="title">Java 웹개발자 채용 [경력직]</span><span class="info">대덕구 <span class="txt_bar">|</span> 신입/경력 <span class="txt_bar">|</span> 초대졸↑</span></a><button class="sri_btn_xs for_btn_event" title="클릭하면 입사지원할 수 있는 창이 뜹니다." onclick="try{quickApplyForm('38668033','','t_category=relay_view&amp;t_content=relay_view_list&amp;t_ref=relay_view&amp;t_ref_content=SRI_050_VIEW_MTRX_RCT_NOINFO&amp;t_ref_scnid=596&amp;dpId=SRI_050_VIEW_MTRX_RCT_NOINFO&amp;ref_dp=SRI_050_VIEW_MTRX_RCT_NOINFO&amp;inner_source=saramin&amp;inner_medium=pattern&amp;inner_campaign=relay_view_apply_14&amp;inner_term=list', ''); return false;} catch (e) {}; return false;" onmousedown="try{n_trackEvent('relay_view','recommend','quick_apply','');}catch(e){}"><span class="sri_btn_immediately">즉시지원</span></button><span class="date">~ 10/24(토)</span><button type="button" onclick="Saramin.btnJob('scrap', this, '', 'quick_login');" scraped="n" rec_idx="38668033" class="btn_scrap scrap-38668033" imgtype="" title="공고 스크랩" onmousedown="try{n_trackEvent('relay_view', 'recommend', 'scrap' , '');}catch(e){}"><img src="http://www.saraminimage.co.kr/common/bul_sri_star.png" alt=""></button></li><li id="recommend_wing_14" style="display: none;"><a href="/zf_user/jobs/relay/view?rec_idx=38605619&amp;isMypage=no&amp;recommend_ids=none&amp;ref_dp=SRI_050_VIEW_MTRX_RCT_NOINFO&amp;view_type=list&amp;dpId=SRI_050_VIEW_MTRX_RCT_NOINFO&amp;refer=y&amp;t_ref_scnid=561&amp;rec_scn_id=561&amp;inner_source=saramin&amp;inner_medium=pattern&amp;inner_campaign=relay_view_14&amp;inner_term=list" onmousedown="try{n_trackEvent('relay_view', 'recommend', 'open', '');loggingRecommendUrl(this, 'http://rcmd-log.saramin.co.kr:9020/so-logging/log/client?custId=&amp;pcId=15996305088133198347523&amp;nonce=a8c32584fd04896f8879&amp;dpId=SRI_050_VIEW_MTRX_RCT_NOINFO&amp;scnId=561&amp;tgId=0&amp;itemSetId=0&amp;itemValue=38605619&amp;click=1', '');}catch(e){}" class="link"><span class="company">주식회사 에즈웰</span><span class="title">[경력] (주)에즈웰 연구소 응용프로그래머 모집(WEB, APP개발자)</span><span class="info">유성구 <span class="txt_bar">|</span> 경력무관 <span class="txt_bar">|</span> 학력무관</span></a><button class="sri_btn_xs for_btn_event" title="클릭하면 입사지원할 수 있는 창이 뜹니다." onclick="try{quickApplyForm('38605619','','t_category=relay_view&amp;t_content=relay_view_list&amp;t_ref=relay_view&amp;t_ref_content=SRI_050_VIEW_MTRX_RCT_NOINFO&amp;t_ref_scnid=561&amp;dpId=SRI_050_VIEW_MTRX_RCT_NOINFO&amp;ref_dp=SRI_050_VIEW_MTRX_RCT_NOINFO&amp;inner_source=saramin&amp;inner_medium=pattern&amp;inner_campaign=relay_view_apply_15&amp;inner_term=list', ''); return false;} catch (e) {}; return false;" onmousedown="try{n_trackEvent('relay_view','recommend','quick_apply','');}catch(e){}"><span class="sri_btn_immediately">즉시지원</span></button><span class="date">~ 10/11(일)</span><button type="button" onclick="Saramin.btnJob('scrap', this, '', 'quick_login');" scraped="n" rec_idx="38605619" class="btn_scrap scrap-38605619" imgtype="" title="공고 스크랩" onmousedown="try{n_trackEvent('relay_view', 'recommend', 'scrap' , '');}catch(e){}"><img src="http://www.saraminimage.co.kr/common/bul_sri_star.png" alt=""></button></li><li class="related" style="display: none;"><a href="/zf_user/jobs/relay/view?rec_idx=38689139&amp;isMypage=no&amp;view_type=list&amp;refer=y&amp;rec_scn_id=&amp;inner_source=saramin&amp;inner_medium=pattern&amp;inner_campaign=relay_view_add_1&amp;inner_term=related_list&amp;t_category=relay_view&amp;t_content=relay_view_list&amp;t_ref=relay_view&amp;t_ref_content=SRI_050_VIEW_MIX_RCT_ADD&amp;t_ref_scnid=" onmousedown="try{n_trackEvent('relay_view', 'recommend', 'open', '');loggingRecommendUrl(this, '');}catch(e){}" class="link"><span class="related">함께 많이 본 <strong>공고!</strong></span><span class="company">(재)국가관세종합정보망운영연합회</span><span class="title">대전 관세청 전자통관시스템 운영(개발) 경력직원 채용</span><span class="info">대전 서 구 <span class="txt_bar">|</span> 경력 3~5년 <span class="txt_bar">|</span> 초대졸↑</span></a><button class="sri_btn_xs for_btn_event" title="클릭하면 입사지원할 수 있는 창이 뜹니다." onclick="try{quickApplyForm('38689139','','t_category=relay_view&amp;t_content=relay_view_list&amp;t_ref=relay_view&amp;t_ref_content=SRI_050_VIEW_MIX_RCT_ADD&amp;t_ref_scnid=747&amp;dpId=SRI_050_VIEW_MIX_RCT_ADD&amp;ref_dp=SRI_050_VIEW_MIX_RCT_ADD&amp;inner_source=saramin&amp;inner_medium=pattern&amp;inner_campaign=relay_view_apply_1&amp;inner_term=list', ''); return false;} catch (e) {}; return false;" onmousedown="try{n_trackEvent('relay_view','recommend','quick_apply','');}catch(e){}"><span class="sri_btn_immediately">즉시지 원</span></button><span class="date">~ 9/11(금)</span><button type="button" onclick="Saramin.btnJob('scrap', this, '', 'quick_login');" scraped="n" rec_idx="38689139" class="btn_scrap scrap-38689139" imgtype="" title="공고 스크랩" onmousedown="try{n_trackEvent('relay_view', 'recommend', 'scrap' , '');}catch(e){}"><img src="http://www.saraminimage.co.kr/common/bul_sri_star.png" alt=""></button></li><li class="related" style="display: none;"><a href="/zf_user/jobs/relay/view?rec_idx=38521891&amp;isMypage=no&amp;view_type=list&amp;refer=y&amp;rec_scn_id=&amp;inner_source=saramin&amp;inner_medium=pattern&amp;inner_campaign=relay_view_add_2&amp;inner_term=related_list&amp;t_category=relay_view&amp;t_content=relay_view_list&amp;t_ref=relay_view&amp;t_ref_content=SRI_050_VIEW_MIX_RCT_ADD&amp;t_ref_scnid=" onmousedown="try{n_trackEvent('relay_view', 'recommend', 'open', '');loggingRecommendUrl(this, '');}catch(e){}" class="link"><span class="related">함 께 많이 본 <strong>공고!</strong></span><span class="company">㈜와이즈넛</span><span class="title">[와이즈넛] 솔루션개발직 중부지사 채용 공고 건</span><span class="info">대전 서구 <span class="txt_bar">|</span> 경력2년↑ <span class="txt_bar">|</span> 초대졸↑</span></a><button class="sri_btn_xs for_btn_event" title="클릭하면 입사지원할 수 있는 창이 뜹니다." onclick="try{quickApplyForm('38521891','','t_category=relay_view&amp;t_content=relay_view_list&amp;t_ref=relay_view&amp;t_ref_content=SRI_050_VIEW_MIX_RCT_ADD&amp;t_ref_scnid=&amp;dpId=empty&amp;ref_dp=&amp;inner_source=saramin&amp;inner_medium=pattern&amp;inner_campaign=relay_view_apply_2&amp;inner_term=list', ''); return false;} catch (e) {}; return false;" onmousedown="try{n_trackEvent('relay_view','recommend','quick_apply','');}catch(e){}"><span class="sri_btn_immediately">즉시지원</span></button><span class="date">~ 9/25(금)</span><button type="button" onclick="Saramin.btnJob('scrap', this, '', 'quick_login');" scraped="n" rec_idx="38521891" class="btn_scrap scrap-38521891" imgtype="" title="공고 스크랩" onmousedown="try{n_trackEvent('relay_view', 'recommend', 'scrap' , '');}catch(e){}"><img src="http://www.saraminimage.co.kr/common/bul_sri_star.png" alt=""></button></li><li class="related" style="display: none;"><a href="/zf_user/jobs/relay/view?rec_idx=38713619&amp;isMypage=no&amp;view_type=list&amp;refer=y&amp;rec_scn_id=&amp;inner_source=saramin&amp;inner_medium=pattern&amp;inner_campaign=relay_view_add_3&amp;inner_term=related_list&amp;t_category=relay_view&amp;t_content=relay_view_list&amp;t_ref=relay_view&amp;t_ref_content=SRI_050_VIEW_MIX_RCT_ADD&amp;t_ref_scnid=" onmousedown="try{n_trackEvent('relay_view', 'recommend', 'open', '');loggingRecommendUrl(this, '');}catch(e){}" class="link"><span class="related">함께 많이 본 <strong>공고!</strong></span><span class="company">노리시스템(주)</span><span class="title">JAVA / C# /DB 개발 프리랜서 모집</span><span class="info">천안시 서북구 <span class="txt_bar">|</span> 경력5년↑ <span class="txt_bar">|</span> 초대졸↑</span></a><button class="sri_btn_xs for_btn_event" title="클릭하면 입사지원할 수 있는 창이 뜹니 다." onclick="try{quickApplyForm('38713619','','t_category=relay_view&amp;t_content=relay_view_list&amp;t_ref=relay_view&amp;t_ref_content=SRI_050_VIEW_MIX_RCT_ADD&amp;t_ref_scnid=696&amp;dpId=SRI_050_VIEW_MIX_RCT_ADD&amp;ref_dp=SRI_050_VIEW_MIX_RCT_ADD&amp;inner_source=saramin&amp;inner_medium=pattern&amp;inner_campaign=relay_view_apply_3&amp;inner_term=list', ''); return false;} catch (e) {}; return false;" onmousedown="try{n_trackEvent('relay_view','recommend','quick_apply','');}catch(e){}"><span class="sri_btn_immediately">즉시지원</span></button><span class="date">~ 9/30(수)</span><button type="button" onclick="Saramin.btnJob('scrap', this, '', 'quick_login');" scraped="n" rec_idx="38713619" class="btn_scrap scrap-38713619" imgtype="" title="공고 스크랩" onmousedown="try{n_trackEvent('relay_view', 'recommend', 'scrap' , '');}catch(e){}"><img src="http://www.saraminimage.co.kr/common/bul_sri_star.png" alt=""></button></li></ul>
                <div class="jv_ads">
        <div id="div-gpt-ad-1547596188605-0-wrapper" style="width:250px; height:250px;">
            <div class="google-standby-banner" style="display: none;">
                                                            <a href="http://www.saramin.co.kr/avatar-branding/?inner_source=saramin&amp;inner_medium=banner&amp;inner_campaign=Waiting_Main_BigBanner&amp;inner_term=avatar_introduce" target="_blank"><img src="http://www.saraminbanner.co.kr/adserver/default/2019/01/plvhfs_bvaz-2rxiek_BIPC250x250.png" alt="인공지능 취업플랫폼 사람인"></a>
                                                </div>
            <div id="div-gpt-ad-1547596188605-0-inner" style="">
                <div id="div-gpt-ad-1547596188605-0" data-google-query-id="CK7j34aw2-sCFYETlgodhOkIhw">
                    <div id="google_ads_iframe_/61280259/recruit-view_250x250_0__container__" style="border: 0pt none; display: inline-block; width: 250px; height: 250px;"><iframe frameborder="0" src="https://tpc.googlesyndication.com/safeframe/1-0-37/html/container.html" id="google_ads_iframe_/61280259/recruit-view_250x250_0" title="3rd party ad content" name="" scrolling="no" marginwidth="0" marginheight="0" width="250" height="250" data-is-safeframe="true" sandbox="allow-forms allow-pointer-lock allow-popups allow-popups-to-escape-sandbox allow-same-origin allow-scripts allow-top-navigation-by-user-activation" data-google-container-id="1" style="border: 0px; vertical-align: bottom;" data-load-complete="true"></iframe></div>
                </div>
            </div>
        </div>
    </div>
        </div>
    </div>
</div>
    <button type="button" class="spr_jview jview_top" onmousedown="try{n_trackEvent('relay_view', 'bottom', 'top', '');}catch(e){}" style="display: none;"><span>TOP</span></button>
    <div class="jview_toast"></div>

    <iframe id="downloadFrame" name="downloadFrame" scrolling="no" frameborder="0" style="display:none;position:absolute;top:0px;left:0px;"></iframe>
    <input type="hidden" id="goStatistic" name="goStatistic" value="stop">

    <script type="text/javascript" src="/js/jobs-view.js?ts=20200908163120"></script>
    <script type="text/javascript">
        var jv_options = {
            'is_seo' : 'no',
            'is_mypage' : 'no',
            'is_popup' : 'no',
            'is_print' : '',
            'view_type' : 'list',
            'view_category' : 'relay_view',
            'requestUrl' : '/zf_user/jobs/relay/view-ajax',
            'recruit_idxs' : [{"rec_idx":"38655001","t_ref_scnid":""},{"rec_idx":"38689139","t_ref_scnid":"747"},{"rec_idx":"38726832","t_ref_scnid":"595"},{"rec_idx":"38713619","t_ref_scnid":"696"},{"rec_idx":"38733685","t_ref_scnid":"696"},{"rec_idx":"38727190","t_ref_scnid":"595"},{"rec_idx":"38724805","t_ref_scnid":"561"},{"rec_idx":"38716840","t_ref_scnid":"561"},{"rec_idx":"38562906","t_ref_scnid":"746"},{"rec_idx":"38647080","t_ref_scnid":"596"},{"rec_idx":"38600890","t_ref_scnid":"561"},{"rec_idx":"38477312","t_ref_scnid":"561"},{"rec_idx":"38616136","t_ref_scnid":"561"},{"rec_idx":"38678317","t_ref_scnid":"561"},{"rec_idx":"38668033","t_ref_scnid":"596"},{"rec_idx":"38605619","t_ref_scnid":"561"}],
            'recruit_list' : [{"rec_idx":"38689139","mcom_idx":"7669697","ccom_idx":"51807","bbs_gb":"0","company_nm":"(\uc7ac)\uad6d\uac00\uad00\uc138\uc885\ud569\uc815\ubcf4\ub9dd\uc6b4\uc601\uc5f0\ud569\ud68c","title":"\ub300\uc804 \uad00\uc138\uccad \uc804\uc790\ud1b5\uad00\uc2dc\uc2a4\ud15c \uc6b4\uc601(\uac1c\ubc1c) \uacbd\ub825\uc9c1\uc6d0 \ucc44\uc6a9","company_cd":"0","education_cd":"7","sales_rank":"0","group_level":"","stock_gb":"","career_cd":"2","career_min":"3","career_max":"5","sex_lim":"ignore","age_min":"0","age_max":"0","collect_cnt":"0","salary_cd":"0","job_type":"1","subway_cd":"80108","read_cnt":"980","bold_color_fl":"n","edit_date":"1598591066","closing_dt":"1599836399","area_code":"105030","area_mcode":"105000","ukeyword":"30101|30118","jkeyword":"40234|40404|40701|40702|40708|40716|40722|40802|40805|40806|40808|40812|41105","upjong_cd":"301","jikjong_cd":"402,404,407,408,411","welfare_cd":"","preferential_cd":"","top_fl":"n","upjong_mcode":"3","jikjong_mcode":"4","opening_dt":"1598540400","category":"focus_fix_m,logo_focus_fix","ccompany_cd":"nonprofit","apply_cnt":"10","info_open_fl":"y","grab_source_cd":"","reg_dt":"1598590374","homepage":"www.unipass.or.kr","keyword":"SI\u00b7\uc2dc\uc2a4\ud15c\ud1b5\ud569,\uc18c\ud504\ud2b8\uc6e8\uc5b4\uac1c\ubc1c,.NET,Android\uc571\uac1c\ubc1c,CTI,Embedded,HMI\u00b7PLC,IOS\uc571\uac1c\ubc1c,Java,Java\u00b7JSP,Linux,SW(\uc18c\ud504\ud2b8\uc6e8\uc5b4),\uc2dc\uc2a4\ud15c\uc6b4\uc601,\uc5b4\uc148\ube14\ub9ac,\ud38c\uc6e8\uc5b4","valuestatement":"","com_photo":"n","personnel_manager_fl":"n","group_nm":"","reply_cnt":"0","area_bcode":"105030","item_id":"ai_rcmd_plus2,ai_rcmd_plus_m2,background_color_m,bold5,bold_m2,rank_up11,rank_up6_m2","hr_answer_cd":"","salary":"0","kindness_expired_dt":"","education_comment":"","x_coordinate":"0","y_coordinate":"0","description":"\uc77c\ubc18\uc9c1(\uc2dc\uc2a4\ud15c \uc6b4\uc601)","expect_graduation_available":"n","apply_gb":"email","company_file_fl":"n","hidden_star_main_contents":"","theme_category":"","cert_class":"","hidden_star_rec_fl":"n","pc_sort_dt":"1599621362","mobile_sort_dt":"1599621364","service_start_dt":"1598540459","rec_manage_cd":"C,ITM,ADS,S,ZR","paid_fl":"y","special_code":"","special_bcode":"null","special_top_fl_code":"","scale":"\uae30\ud0c0","csn_num":"120-82-08049","main_area_kcode":"125","company_score":"31","logo_src":"","ROWID":44731,"score":0,"recParam":{"t_category":"relay_view","t_content":"relay_view_list","t_ref":"relay_view","t_ref_content":"SRI_050_VIEW_MTRX_RCT_NOINFO","t_ref_scnid":"747","dpId":"SRI_050_VIEW_MTRX_RCT_NOINFO","ref_dp":"SRI_050_VIEW_MTRX_RCT_NOINFO","trackEventAvatar":"","loggingRecommend":"loggingRecommendUrl(this, 'http:\/\/rcmd-log.saramin.co.kr:9020\/so-logging\/log\/client?custId=&pcId=15996305088133198347523&nonce=a8c32584fd04896f8879&dpId=SRI_050_VIEW_MTRX_RCT_NOINFO&scnId=747&tgId=0&itemSetId=0&itemValue=38689139&click=1', '');","scrapBtn":"<button type=\"button\" onclick=\"Saramin.btnJob('scrap', this, '', 'quick_login');\" scraped=\"n\" rec_idx=\"38689139\" class=\"btn_scrap scrap-38689139\" imgtype=\"\" title=\"\uacf5\uace0 \uc2a4\ud06c\ub7a9\" onmousedown=\"try{n_trackEvent('relay_view', 'recommend', 'scrap' , '');}catch(e){}\"><img src=\"http:\/\/www.saraminimage.co.kr\/common\/bul_sri_star.png\" alt=\"\"><\/button>","quickApplyOptions":{"trackEvent":{"category":"relay_view","action":"recommend","opt_label":"quick_apply","opt_value":""},"applyTrackEvent":{"t_category":"relay_view","t_content":"relay_view_list","t_ref":"relay_view","t_ref_content":"SRI_050_VIEW_MTRX_RCT_NOINFO","t_ref_scnid":"747","dpId":"SRI_050_VIEW_MTRX_RCT_NOINFO","ref_dp":"SRI_050_VIEW_MTRX_RCT_NOINFO","inner_source":"saramin","inner_medium":"pattern","inner_campaign":"relay_view_apply_1","inner_term":"list"}}},"summary_str":"\ub300\uc804 \uc11c\uad6c <span class=\"txt_bar\">|<\/span> \uacbd\ub825 3~5\ub144 <span class=\"txt_bar\">|<\/span> \ucd08\ub300\uc878\u2191","closing_str":"~ 9\/11(\uae08)","recommend_ids_list":"38726832_595%7C38713619_696%7C38733685_696%7C38727190_595%7C38724805_561%7C38716840_561%7C38562906_746%7C38647080_596%7C38600890_561%7C38477312_561%7C38616136_561%7C38678317_561%7C38668033_596%7C38605619_561","quickApplyBtn":"<button  class=\"sri_btn_xs for_btn_event\" title=\"\ud074\ub9ad\ud558\uba74 \uc785\uc0ac\uc9c0\uc6d0\ud560 \uc218 \uc788\ub294 \ucc3d\uc774 \ub739\ub2c8\ub2e4.\" onclick=\"try{quickApplyForm(&#39;38689139&#39;,&#39;&#39;,&#39;t_category=relay_view&t_content=relay_view_list&t_ref=relay_view&t_ref_content=SRI_050_VIEW_MTRX_RCT_NOINFO&t_ref_scnid=747&dpId=SRI_050_VIEW_MTRX_RCT_NOINFO&ref_dp=SRI_050_VIEW_MTRX_RCT_NOINFO&inner_source=saramin&inner_medium=pattern&inner_campaign=relay_view_apply_1&inner_term=list&#39;, &#39;&#39;); return false;} catch (e) {}; return false;\" onmousedown=\"try{n_trackEvent(&#39;relay_view&#39;,&#39;recommend&#39;,&#39;quick_apply&#39;,&#39;&#39;);}catch(e){}\"><span class=\"sri_btn_immediately\" >\uc989\uc2dc\uc9c0\uc6d0<\/span><\/button>","favorBtn":"<button  type=\"button\" csn=\"1208208049\" title=\"\uad00\uc2ec\uae30\uc5c5 \ub4f1\ub85d\" del_fl=\"n\" class=\"btn_jview spr_jview btn_interest\" onclick=\"try{Saramin.btnJob(&#39;favor&#39;, this, &#39;&#39;, &#39;quick_login&#39;);}catch(e){}\" onmousedown=\"try {n_trackEvent(&#39;relay_view&#39;, &#39;recommend&#39;, &#39;favor&#39;, &#39;&#39;);}catch(e){}\" first_nudge=\"off\"><span class=\"blind\">\uad00\uc2ec\uae30\uc5c5 \ub4f1\ub85d<\/span><\/button>","txtRegDt":"12\uc77c \uc804 \ub4f1\ub85d"},{"rec_idx":"38726832","mcom_idx":"2501978","ccom_idx":"22655","bbs_gb":"1","company_nm":"(\uc8fc)\uc5d0\ub4c0\uc70c","title":"\uc8fc4\uc77c \uadfc\ubb34 \ub300\ube44 \uc6b0\uc218 \uc778\uc7ac\ubaa8\uc9d1","company_cd":"1","education_cd":"0","sales_rank":"0","group_level":"","stock_gb":"","career_cd":"3","career_min":"0","career_max":"0","sex_lim":"ignore","age_min":"0","age_max":"0","collect_cnt":"00","salary_cd":"0","job_type":"1","subway_cd":"0","read_cnt":"7255","bold_color_fl":"n","edit_date":"1599541881","closing_dt":"1600613999","area_code":"101000,101070,101120,102000,102180,104000,105000,108000,108060","area_mcode":"101000,102000,104000,105000,108000","ukeyword":"60501","jkeyword":"10101|10102|10108|10207|10401|10414|11301|11317|11417|11902|11908|11912|11914|11921|20208|20902|20903|20906|20910|21001|21002|21010|21101|21117|21127|21201|21202|21303|21304|21308|40305|40310|40324|40402|40404|40601|40603|40609|40614|40916|41203|41213|41224|41303|41405|50405|60101|60107|60903|60905|60906|60908|70305|100502|120903|120906","upjong_cd":"605","jikjong_cd":"1005,101,102,104,113,114,119,1209,202,209,210,211,212,213,403,404,406,409,412,413,414,504,601,609,703","welfare_cd":"","preferential_cd":"","top_fl":"n","upjong_mcode":"6","jikjong_mcode":"1,2,4,5,6,7,10,12","opening_dt":"1599404400","category":"logo_premium,narae,nuri2,premium_alpha_m,premium_mobile,special_banner,special_mobile","ccompany_cd":"ex_audit,venture,school,innobiz","apply_cnt":"76","info_open_fl":"y","grab_source_cd":"","reg_dt":"1599197639","homepage":"www.eduwill.net","keyword":"\uae30\ub2a5\ud559\uc6d0,ASP,CS,CS\uac15\uc0ac\u00b7\uad50\uc721,Java\u00b7JSP,PM,QAA\u00b7\ud1b5\ud654\ud488\uc9c8,TM,UI\u00b7UX\ub514\uc790\uc778,VOC\uad00\ub9ac\u00b7\ubd84\uc11d,\uac70\ub798\ucc98\uad00\ub9ac,\uacbd\uc601\uae30\ud68d,\uacbd\uc601\uc9c0\uc6d0,\uace0\uac1d\uc0c1\ub2f4,\uad11\uace0,\uad11\uace0\uad00\ub9ac,\uad11\uace0\uae30\ud68d,\uad11\uace0\ub514\uc790\uc778,\uad50\uc721\uae30\ud68d,\uad50\uc721\uc0c1\ub2f4\u00b7\uc548\ub0b4,\uad50\uc7ac\u00b7\ucee8\ud150\uce20\uac1c\ubc1c,\uae30\ud68d,\ub9c8\ucf00\ud305\uc804\ub7b5\u00b7\uae30\ud68d,\ubc30\ub108\u00b7\uc778\ud130\ub137\uad11\uace0,\uc0ac\uc774\ud2b8\uc6b4\uc601,\uc0c1\ud488\uae30\ud68d\u00b7\uac1c\ubc1c,\uc218\uac15\uc0dd\uad00\ub9ac,\uc2dc\uc2a4\ud15c\uc5d4\uc9c0\ub2c8\uc5b4(SE),\uc544\uc6c3\ubc14\uc6b4\ub4dc,\uc601\uc0c1\ud3b8\uc9d1,\uc601\uc5c5\uad00\ub9ac,\uc601\uc5c5\uae30\ud68d,\uc601\uc5c5\uc9c0\uc6d0,\uc628\ub77c\uc778\ub9c8\ucf00\ud305,\uc6d0\uc0dd\uad00\ub9ac\u00b7\uc720\uce58,\uc6f9UI,\uc6f9\uc11c\ube44\uc2a4\uae30\ud68d,\uc778\ubc14\uc6b4\ub4dc,\uc778\uc0ac,\uc778\uc0ac\uae30\ud68d,\uc77c\ubc18\uc601\uc5c5,\uc785\uc18c\ubb38\u00b7\ubc14\uc774\ub7f4,\uc804\ub7b5\uae30\ud68d,\uc9c1\uc5c5\uc0c1\ub2f4\uc0ac,\ucd1d\ubb34,\uce74\ud398\u00b7\ube14\ub85c\uadf8\uad00\ub9ac,\ucee8\ud150\uce20\uae30\ud68d,\ucee8\ud150\uce20\uc6b4\uc601,\ucee8\ud150\uce20\uc81c\uc791,\ud37c\ube14\ub9ac\uc154,\ud3ec\ud1a0\uc0f5,\ud559\uc2b5\uc9c0\u00b7\ucd9c\ud310,\ud559\uc6d0\u00b7\uc720\ud559\uc6d0,\ud559\uc6d0\uc6b4\uc601,\ud64d\ubcf4","valuestatement":"","com_photo":"n","personnel_manager_fl":"s,n,81","group_nm":"","reply_cnt":"0","area_bcode":"101000,101070,101120,102000,102180,104000,105000,108000,108060","item_id":"rank_up3_m2","hr_answer_cd":"","salary":"0","kindness_expired_dt":"","education_comment":"","x_coordinate":"0","y_coordinate":"0","description":"","expect_graduation_available":"n","apply_gb":"email,homepage","company_file_fl":"n","hidden_star_main_contents":"","theme_category":"","cert_class":"venture,innobiz,goodcompany","hidden_star_rec_fl":"n","pc_sort_dt":"1599620748","mobile_sort_dt":"1599620736","service_start_dt":"1599404400","rec_manage_cd":"C,ITM,ADS,S,ZR","paid_fl":"y","special_code":"","special_bcode":"null","special_top_fl_code":"","scale":"\uc911\uacac\uae30\uc5c5","csn_num":"119-81-54852","main_area_kcode":"8","company_score":"21","logo_src":"22655_logo_1.png","ROWID":9203,"score":1,"recParam":{"t_category":"relay_view","t_content":"relay_view_list","t_ref":"relay_view","t_ref_content":"SRI_050_VIEW_MTRX_RCT_NOINFO","t_ref_scnid":"595","dpId":"SRI_050_VIEW_MTRX_RCT_NOINFO","ref_dp":"SRI_050_VIEW_MTRX_RCT_NOINFO","inner_source":"saramin","inner_medium":"pattern","inner_campaign":"relay_view_apply_1","inner_term":"list","trackEventAvatar":"","loggingRecommend":"loggingRecommendUrl(this, 'http:\/\/rcmd-log.saramin.co.kr:9020\/so-logging\/log\/client?custId=&pcId=15996305088133198347523&nonce=a8c32584fd04896f8879&dpId=SRI_050_VIEW_MTRX_RCT_NOINFO&scnId=595&tgId=0&itemSetId=0&itemValue=38726832&click=1', '');","scrapBtn":"<button type=\"button\" onclick=\"Saramin.btnJob('scrap', this, '', 'quick_login');\" scraped=\"n\" rec_idx=\"38726832\" class=\"btn_scrap scrap-38726832\" imgtype=\"\" title=\"\uacf5\uace0 \uc2a4\ud06c\ub7a9\" onmousedown=\"try{n_trackEvent('relay_view', 'recommend', 'scrap' , '');}catch(e){}\"><img src=\"http:\/\/www.saraminimage.co.kr\/common\/bul_sri_star.png\" alt=\"\"><\/button>","quickApplyOptions":{"trackEvent":{"category":"relay_view","action":"recommend","opt_label":"quick_apply","opt_value":""},"applyTrackEvent":{"t_category":"relay_view","t_content":"relay_view_list","t_ref":"relay_view","t_ref_content":"SRI_050_VIEW_MTRX_RCT_NOINFO","t_ref_scnid":"595","dpId":"SRI_050_VIEW_MTRX_RCT_NOINFO","ref_dp":"SRI_050_VIEW_MTRX_RCT_NOINFO","inner_source":"saramin","inner_medium":"pattern","inner_campaign":"relay_view_apply_2","inner_term":"list"}}},"summary_str":"\uc11c\uc6b8\uc804\uccb4 <span class=\"txt_bar\">|<\/span> \uc2e0\uc785\/\uacbd\ub825 <span class=\"txt_bar\">|<\/span> \ud559\ub825\ubb34\uad00","closing_str":"~ 9\/20(\uc77c)","recommend_ids_list":"38713619_696%7C38733685_696%7C38727190_595%7C38724805_561%7C38716840_561%7C38562906_746%7C38647080_596%7C38600890_561%7C38477312_561%7C38616136_561%7C38678317_561%7C38668033_596%7C38605619_561","quickApplyBtn":"<button  class=\"sri_btn_xs for_btn_event\" title=\"\ud074\ub9ad\ud558\uba74 \uc785\uc0ac\uc9c0\uc6d0\ud560 \uc218 \uc788\ub294 \ucc3d\uc774 \ub739\ub2c8\ub2e4.\" onclick=\"try{quickApplyForm(&#39;38726832&#39;,&#39;&#39;,&#39;t_category=relay_view&t_content=relay_view_list&t_ref=relay_view&t_ref_content=SRI_050_VIEW_MTRX_RCT_NOINFO&t_ref_scnid=595&dpId=SRI_050_VIEW_MTRX_RCT_NOINFO&ref_dp=SRI_050_VIEW_MTRX_RCT_NOINFO&inner_source=saramin&inner_medium=pattern&inner_campaign=relay_view_apply_2&inner_term=list&#39;, &#39;&#39;); return false;} catch (e) {}; return false;\" onmousedown=\"try{n_trackEvent(&#39;relay_view&#39;,&#39;recommend&#39;,&#39;quick_apply&#39;,&#39;&#39;);}catch(e){}\"><span class=\"sri_btn_immediately\" >\uc989\uc2dc\uc9c0\uc6d0<\/span><\/button>","favorBtn":"<button  type=\"button\" csn=\"1198154852\" title=\"\uad00\uc2ec\uae30\uc5c5 \ub4f1\ub85d\" del_fl=\"n\" class=\"btn_jview spr_jview btn_interest\" onclick=\"try{Saramin.btnJob(&#39;favor&#39;, this, &#39;&#39;, &#39;quick_login&#39;);}catch(e){}\" onmousedown=\"try {n_trackEvent(&#39;relay_view&#39;, &#39;recommend&#39;, &#39;favor&#39;, &#39;&#39;);}catch(e){}\" first_nudge=\"off\"><span class=\"blind\">\uad00\uc2ec\uae30\uc5c5 \ub4f1\ub85d<\/span><\/button>","txtRegDt":"5\uc77c \uc804 \ub4f1\ub85d"},{"rec_idx":"38713619","mcom_idx":"5517055","ccom_idx":"0","bbs_gb":"0","company_nm":"\ub178\ub9ac\uc2dc\uc2a4\ud15c(\uc8fc)","title":"JAVA \/ C# \/DB \uac1c\ubc1c \ud504\ub9ac\ub79c\uc11c \ubaa8\uc9d1","company_cd":"1","education_cd":"7","sales_rank":"","group_level":"","stock_gb":"","career_cd":"2","career_min":"5","career_max":"0","sex_lim":"ignore","age_min":"0","age_max":"0","collect_cnt":"0","salary_cd":"99","job_type":"10,2,9","subway_cd":"0","read_cnt":"52","bold_color_fl":"n","edit_date":"1599034774","closing_dt":"1601477999","area_code":"115135","area_mcode":"115000","ukeyword":"31301","jkeyword":"40716|40720|40728|41602|41603|41604","upjong_cd":"313","jikjong_cd":"407,416","welfare_cd":"corp300,corp303,corp410,corp414,corp433,corp446,corp449,corp466,corp472,corp483,corp485,corp509","preferential_cd":"","top_fl":"n","upjong_mcode":"3","jikjong_mcode":"4","opening_dt":"1599019200","category":"","ccompany_cd":"stock","apply_cnt":"0","info_open_fl":"y","grab_source_cd":"","reg_dt":"1599022192","homepage":"www.norisystem.co.kr","keyword":"IT\ucee8\uc124\ud305,C#,Java,MS-SQL,MySQL,Oracle","valuestatement":"","com_photo":"n","personnel_manager_fl":"y","group_nm":"","reply_cnt":"0","area_bcode":"115135","item_id":"keyword6,keyword_m7","hr_answer_cd":"","salary":"0","kindness_expired_dt":"","education_comment":"","x_coordinate":"1271110869","y_coordinate":"368238185","description":"JAVA \uac1c\ubc1c\uc790\/ C# \uac1c\ubc1c\uc790","expect_graduation_available":"n","apply_gb":"email","company_file_fl":"n","hidden_star_main_contents":"","theme_category":"","cert_class":"","hidden_star_rec_fl":"n","pc_sort_dt":"1599459338","mobile_sort_dt":"1599459328","service_start_dt":"1599027218","rec_manage_cd":"T,TT,ITM,ZA,ZS,PA,ZR","paid_fl":"y","special_code":"","special_bcode":"null","special_top_fl_code":"","scale":"\uc911\uc18c\uae30\uc5c5","csn_num":"312-86-36894","main_area_kcode":"28603","company_score":"28","logo_src":"company\/logo\/201908\/13\/pw5jg5_4qht-yd17i0_logo.jpg","ROWID":29355,"score":2,"recParam":{"t_category":"relay_view","t_content":"relay_view_list","t_ref":"relay_view","t_ref_content":"SRI_050_VIEW_MTRX_RCT_NOINFO","t_ref_scnid":"696","dpId":"SRI_050_VIEW_MTRX_RCT_NOINFO","ref_dp":"SRI_050_VIEW_MTRX_RCT_NOINFO","inner_source":"saramin","inner_medium":"pattern","inner_campaign":"relay_view_apply_2","inner_term":"list","trackEventAvatar":"","loggingRecommend":"loggingRecommendUrl(this, 'http:\/\/rcmd-log.saramin.co.kr:9020\/so-logging\/log\/client?custId=&pcId=15996305088133198347523&nonce=a8c32584fd04896f8879&dpId=SRI_050_VIEW_MTRX_RCT_NOINFO&scnId=696&tgId=0&itemSetId=0&itemValue=38713619&click=1', '');","scrapBtn":"<button type=\"button\" onclick=\"Saramin.btnJob('scrap', this, '', 'quick_login');\" scraped=\"n\" rec_idx=\"38713619\" class=\"btn_scrap scrap-38713619\" imgtype=\"\" title=\"\uacf5\uace0 \uc2a4\ud06c\ub7a9\" onmousedown=\"try{n_trackEvent('relay_view', 'recommend', 'scrap' , '');}catch(e){}\"><img src=\"http:\/\/www.saraminimage.co.kr\/common\/bul_sri_star.png\" alt=\"\"><\/button>","quickApplyOptions":{"trackEvent":{"category":"relay_view","action":"recommend","opt_label":"quick_apply","opt_value":""},"applyTrackEvent":{"t_category":"relay_view","t_content":"relay_view_list","t_ref":"relay_view","t_ref_content":"SRI_050_VIEW_MTRX_RCT_NOINFO","t_ref_scnid":"696","dpId":"SRI_050_VIEW_MTRX_RCT_NOINFO","ref_dp":"SRI_050_VIEW_MTRX_RCT_NOINFO","inner_source":"saramin","inner_medium":"pattern","inner_campaign":"relay_view_apply_3","inner_term":"list"}}},"summary_str":"\ucc9c\uc548\uc2dc \uc11c\ubd81\uad6c <span class=\"txt_bar\">|<\/span> \uacbd\ub8255\ub144\u2191 <span class=\"txt_bar\">|<\/span> \ucd08\ub300\uc878\u2191","closing_str":"~ 9\/30(\uc218)","recommend_ids_list":"38733685_696%7C38727190_595%7C38724805_561%7C38716840_561%7C38562906_746%7C38647080_596%7C38600890_561%7C38477312_561%7C38616136_561%7C38678317_561%7C38668033_596%7C38605619_561","quickApplyBtn":"<button  class=\"sri_btn_xs for_btn_event\" title=\"\ud074\ub9ad\ud558\uba74 \uc785\uc0ac\uc9c0\uc6d0\ud560 \uc218 \uc788\ub294 \ucc3d\uc774 \ub739\ub2c8\ub2e4.\" onclick=\"try{quickApplyForm(&#39;38713619&#39;,&#39;&#39;,&#39;t_category=relay_view&t_content=relay_view_list&t_ref=relay_view&t_ref_content=SRI_050_VIEW_MTRX_RCT_NOINFO&t_ref_scnid=696&dpId=SRI_050_VIEW_MTRX_RCT_NOINFO&ref_dp=SRI_050_VIEW_MTRX_RCT_NOINFO&inner_source=saramin&inner_medium=pattern&inner_campaign=relay_view_apply_3&inner_term=list&#39;, &#39;&#39;); return false;} catch (e) {}; return false;\" onmousedown=\"try{n_trackEvent(&#39;relay_view&#39;,&#39;recommend&#39;,&#39;quick_apply&#39;,&#39;&#39;);}catch(e){}\"><span class=\"sri_btn_immediately\" >\uc989\uc2dc\uc9c0\uc6d0<\/span><\/button>","favorBtn":"<button  type=\"button\" csn=\"3128636894\" title=\"\uad00\uc2ec\uae30\uc5c5 \ub4f1\ub85d\" del_fl=\"n\" class=\"btn_jview spr_jview btn_interest\" onclick=\"try{Saramin.btnJob(&#39;favor&#39;, this, &#39;&#39;, &#39;quick_login&#39;);}catch(e){}\" onmousedown=\"try {n_trackEvent(&#39;relay_view&#39;, &#39;recommend&#39;, &#39;favor&#39;, &#39;&#39;);}catch(e){}\" first_nudge=\"off\"><span class=\"blind\">\uad00\uc2ec\uae30\uc5c5 \ub4f1\ub85d<\/span><\/button>","txtRegDt":"7\uc77c \uc804 \ub4f1\ub85d"},{"rec_idx":"38733685","mcom_idx":"7844880","ccom_idx":"0","bbs_gb":"0","company_nm":"\uc815\uc554\uac74\uc124(\uc8fc)","title":"[\uacc4\uc57d\uc9c1]  \uc678 \uacbd\ub825\ubb34\uad00 \ucc44\uc6a9\ud569\ub2c8\ub2e4","company_cd":"1","education_cd":"0","sales_rank":"","group_level":"","stock_gb":"","career_cd":"0","career_min":"0","career_max":"0","sex_lim":"ignore","age_min":"0","age_max":"0","collect_cnt":"0","salary_cd":"0","job_type":"10,2","subway_cd":"0","read_cnt":"27","bold_color_fl":"n","edit_date":"1599441972","closing_dt":"1604674799","area_code":"114010","area_mcode":"114000","ukeyword":"90109","jkeyword":"90104","upjong_cd":"901","jikjong_cd":"901","welfare_cd":"","preferential_cd":"","top_fl":"n","upjong_mcode":"9","jikjong_mcode":"9","opening_dt":"1599440400","category":"","ccompany_cd":"","apply_cnt":"1","info_open_fl":"y","grab_source_cd":"","reg_dt":"1599441972","homepage":"","keyword":"\uac74\uc124\ud604\uc7a5,\uce21\ub7c9\u00b7\uacc4\uce21","valuestatement":"","com_photo":"n","personnel_manager_fl":"n","group_nm":"","reply_cnt":"0","area_bcode":"114010","item_id":"","hr_answer_cd":"","salary":"0","kindness_expired_dt":"","education_comment":"","x_coordinate":"1277882081","y_coordinate":"368011532","description":"\uce21\ub7c9","expect_graduation_available":"n","apply_gb":"email","company_file_fl":"n","hidden_star_main_contents":"","theme_category":"","cert_class":"","hidden_star_rec_fl":"n","pc_sort_dt":"1599441972","mobile_sort_dt":"1599441972","service_start_dt":"0","rec_manage_cd":"T,TT,ZI,ZA,ZS,ZP,ZR","paid_fl":"n","special_code":"","special_bcode":"null","special_top_fl_code":"","scale":"\uc911\uc18c\uae30\uc5c5","csn_num":"361-87-00847","main_area_kcode":"258","company_score":"14","logo_src":"","ROWID":15213,"score":3,"recParam":{"t_category":"relay_view","t_content":"relay_view_list","t_ref":"relay_view","t_ref_content":"SRI_050_VIEW_MTRX_RCT_NOINFO","t_ref_scnid":"696","dpId":"SRI_050_VIEW_MTRX_RCT_NOINFO","ref_dp":"SRI_050_VIEW_MTRX_RCT_NOINFO","inner_source":"saramin","inner_medium":"pattern","inner_campaign":"relay_view_apply_3","inner_term":"list","trackEventAvatar":"","loggingRecommend":"loggingRecommendUrl(this, 'http:\/\/rcmd-log.saramin.co.kr:9020\/so-logging\/log\/client?custId=&pcId=15996305088133198347523&nonce=a8c32584fd04896f8879&dpId=SRI_050_VIEW_MTRX_RCT_NOINFO&scnId=696&tgId=0&itemSetId=0&itemValue=38733685&click=1', '');","scrapBtn":"<button type=\"button\" onclick=\"Saramin.btnJob('scrap', this, '', 'quick_login');\" scraped=\"n\" rec_idx=\"38733685\" class=\"btn_scrap scrap-38733685\" imgtype=\"\" title=\"\uacf5\uace0 \uc2a4\ud06c\ub7a9\" onmousedown=\"try{n_trackEvent('relay_view', 'recommend', 'scrap' , '');}catch(e){}\"><img src=\"http:\/\/www.saraminimage.co.kr\/common\/bul_sri_star.png\" alt=\"\"><\/button>","quickApplyOptions":{"trackEvent":{"category":"relay_view","action":"recommend","opt_label":"quick_apply","opt_value":""},"applyTrackEvent":{"t_category":"relay_view","t_content":"relay_view_list","t_ref":"relay_view","t_ref_content":"SRI_050_VIEW_MTRX_RCT_NOINFO","t_ref_scnid":"696","dpId":"SRI_050_VIEW_MTRX_RCT_NOINFO","ref_dp":"SRI_050_VIEW_MTRX_RCT_NOINFO","inner_source":"saramin","inner_medium":"pattern","inner_campaign":"relay_view_apply_4","inner_term":"list"}}},"summary_str":"\uad34\uc0b0\uad70 <span class=\"txt_bar\">|<\/span> \uacbd\ub825\ubb34\uad00 <span class=\"txt_bar\">|<\/span> \ud559\ub825\ubb34\uad00","closing_str":"~ 11\/6(\uae08)","recommend_ids_list":"38727190_595%7C38724805_561%7C38716840_561%7C38562906_746%7C38647080_596%7C38600890_561%7C38477312_561%7C38616136_561%7C38678317_561%7C38668033_596%7C38605619_561","quickApplyBtn":"<button  class=\"sri_btn_xs for_btn_event\" title=\"\ud074\ub9ad\ud558\uba74 \uc785\uc0ac\uc9c0\uc6d0\ud560 \uc218 \uc788\ub294 \ucc3d\uc774 \ub739\ub2c8\ub2e4.\" onclick=\"try{quickApplyForm(&#39;38733685&#39;,&#39;&#39;,&#39;t_category=relay_view&t_content=relay_view_list&t_ref=relay_view&t_ref_content=SRI_050_VIEW_MTRX_RCT_NOINFO&t_ref_scnid=696&dpId=SRI_050_VIEW_MTRX_RCT_NOINFO&ref_dp=SRI_050_VIEW_MTRX_RCT_NOINFO&inner_source=saramin&inner_medium=pattern&inner_campaign=relay_view_apply_4&inner_term=list&#39;, &#39;&#39;); return false;} catch (e) {}; return false;\" onmousedown=\"try{n_trackEvent(&#39;relay_view&#39;,&#39;recommend&#39;,&#39;quick_apply&#39;,&#39;&#39;);}catch(e){}\"><span class=\"sri_btn_immediately\" >\uc989\uc2dc\uc9c0\uc6d0<\/span><\/button>","favorBtn":"<button  type=\"button\" csn=\"3618700847\" title=\"\uad00\uc2ec\uae30\uc5c5 \ub4f1\ub85d\" del_fl=\"n\" class=\"btn_jview spr_jview btn_interest\" onclick=\"try{Saramin.btnJob(&#39;favor&#39;, this, &#39;&#39;, &#39;quick_login&#39;);}catch(e){}\" onmousedown=\"try {n_trackEvent(&#39;relay_view&#39;, &#39;recommend&#39;, &#39;favor&#39;, &#39;&#39;);}catch(e){}\" first_nudge=\"off\"><span class=\"blind\">\uad00\uc2ec\uae30\uc5c5 \ub4f1\ub85d<\/span><\/button>","txtRegDt":"2\uc77c \uc804 \ub4f1\ub85d"},{"rec_idx":"38727190","mcom_idx":"6695712","ccom_idx":"36810","bbs_gb":"0","company_nm":"\uc624\ud2f0\uc544\uc774(\uc8fc)","title":"\uc624\ud2f0\uc544\uc774\u321c \uac01 \ubd80\ubb38 \uc2e0\uc785 \ubc0f \uacbd\ub825\uc9c1 \ucc44\uc6a9","company_cd":"0","education_cd":"8","sales_rank":"0","group_level":"","stock_gb":"","career_cd":"3","career_min":"0","career_max":"0","sex_lim":"ignore","age_min":"0","age_max":"0","collect_cnt":"00","salary_cd":"0","job_type":"1,2,9","subway_cd":"10225","read_cnt":"978","bold_color_fl":"n","edit_date":"1599526236","closing_dt":"1600613999","area_code":"101000,101150,102180,102190,105000,105030,114090,118000","area_mcode":"101000,102000,105000,114000,118000","ukeyword":"30101|30118|30120","jkeyword":"10207|10210|10217|10218|10802|10803|10804|10805|10807|40305|40310|40319|40321|40324|40402|40404|40409|40413|40416|40420|40421|40701|40702|40706|40716|40720|40728|41105|41602|41603|41604|41619","upjong_cd":"301","jikjong_cd":"102,108,403,404,407,411,416","welfare_cd":"corp400,corp406,corp417,corp432,corp433,corp434,corp451,corp466,corp472,corp482,corp489,corp499,corp509","preferential_cd":"","top_fl":"n","upjong_mcode":"3","jikjong_mcode":"1,4","opening_dt":"1599404400","category":"logo_premium,premium_mobile","ccompany_cd":"","apply_cnt":"10","info_open_fl":"n","grab_source_cd":"","reg_dt":"1599200209","homepage":"","keyword":"SI\u00b7\uc2dc\uc2a4\ud15c\ud1b5\ud569,SM,\uc18c\ud504\ud2b8\uc6e8\uc5b4\uac1c\ubc1c,.NET,Ajax,Android\uc571\uac1c\ubc1c,APM,ASP,C#,DBA,Excel\u00b7\ub3c4\ud45c,HTML,IOS\uc571\uac1c\ubc1c,Java,Java\u00b7JSP,MS-SQL,MySQL,OA,Oracle,PM,PowerPoint,SW(\uc18c\ud504\ud2b8\uc6e8\uc5b4),Windows,XML,\ubaa8\ubc14\uc77c\uae30\ud68d,\ubb38\uc11c\uad00\ub9ac,\ube44\ud488\uad00\ub9ac,\uc0ac\ubb34,\uc6cc\ub4dc\u00b7\ubb38\uc11c\uc791\uc131,\uc6f9\uc11c\ube44\uc2a4\uae30\ud68d,\uc804\uc0b0\uc785\ub825\u00b7\ud3b8\uc9d1,\uc81c\uc548\u00b7\ucee8\uc124\ud305,\ucd1d\ubb34,\ucee8\ud150\uce20\uae30\ud68d","valuestatement":"","com_photo":"n","personnel_manager_fl":"n","group_nm":"","reply_cnt":"0","area_bcode":"101000,101150,102180,102190,105000,105030,114090,118000","item_id":"background_color_m,bold5,bold_m2,rank_up11,rank_up6_m2","hr_answer_cd":"","salary":"0","kindness_expired_dt":"","education_comment":"","x_coordinate":"0","y_coordinate":"0","description":"","expect_graduation_available":"n","apply_gb":"email","company_file_fl":"n","hidden_star_main_contents":"","theme_category":"","cert_class":"goodcompany","hidden_star_rec_fl":"n","pc_sort_dt":"1599621960","mobile_sort_dt":"1599621364","service_start_dt":"1599404400","rec_manage_cd":"C,ITM,ADS,S,ZR","paid_fl":"y","special_code":"","special_bcode":"null","special_top_fl_code":"","scale":"\uc911\uc18c\uae30\uc5c5","csn_num":"220-86-57703","main_area_kcode":"46","company_score":"0","logo_src":"36810_logo.gif","ROWID":8351,"score":4,"recParam":{"t_category":"relay_view","t_content":"relay_view_list","t_ref":"relay_view","t_ref_content":"SRI_050_VIEW_MTRX_RCT_NOINFO","t_ref_scnid":"595","dpId":"SRI_050_VIEW_MTRX_RCT_NOINFO","ref_dp":"SRI_050_VIEW_MTRX_RCT_NOINFO","inner_source":"saramin","inner_medium":"pattern","inner_campaign":"relay_view_apply_4","inner_term":"list","trackEventAvatar":"","loggingRecommend":"loggingRecommendUrl(this, 'http:\/\/rcmd-log.saramin.co.kr:9020\/so-logging\/log\/client?custId=&pcId=15996305088133198347523&nonce=a8c32584fd04896f8879&dpId=SRI_050_VIEW_MTRX_RCT_NOINFO&scnId=595&tgId=0&itemSetId=0&itemValue=38727190&click=1', '');","scrapBtn":"<button type=\"button\" onclick=\"Saramin.btnJob('scrap', this, '', 'quick_login');\" scraped=\"n\" rec_idx=\"38727190\" class=\"btn_scrap scrap-38727190\" imgtype=\"\" title=\"\uacf5\uace0 \uc2a4\ud06c\ub7a9\" onmousedown=\"try{n_trackEvent('relay_view', 'recommend', 'scrap' , '');}catch(e){}\"><img src=\"http:\/\/www.saraminimage.co.kr\/common\/bul_sri_star.png\" alt=\"\"><\/button>","quickApplyOptions":{"trackEvent":{"category":"relay_view","action":"recommend","opt_label":"quick_apply","opt_value":""},"applyTrackEvent":{"t_category":"relay_view","t_content":"relay_view_list","t_ref":"relay_view","t_ref_content":"SRI_050_VIEW_MTRX_RCT_NOINFO","t_ref_scnid":"595","dpId":"SRI_050_VIEW_MTRX_RCT_NOINFO","ref_dp":"SRI_050_VIEW_MTRX_RCT_NOINFO","inner_source":"saramin","inner_medium":"pattern","inner_campaign":"relay_view_apply_5","inner_term":"list"}}},"summary_str":"\uc11c\uc6b8\uc804\uccb4 <span class=\"txt_bar\">|<\/span> \uc2e0\uc785\/\uacbd\ub825 <span class=\"txt_bar\">|<\/span> \ub300\uc878\u2191","closing_str":"~ 9\/20(\uc77c)","recommend_ids_list":"38724805_561%7C38716840_561%7C38562906_746%7C38647080_596%7C38600890_561%7C38477312_561%7C38616136_561%7C38678317_561%7C38668033_596%7C38605619_561","quickApplyBtn":"<button  class=\"sri_btn_xs for_btn_event\" title=\"\ud074\ub9ad\ud558\uba74 \uc785\uc0ac\uc9c0\uc6d0\ud560 \uc218 \uc788\ub294 \ucc3d\uc774 \ub739\ub2c8\ub2e4.\" onclick=\"try{quickApplyForm(&#39;38727190&#39;,&#39;&#39;,&#39;t_category=relay_view&t_content=relay_view_list&t_ref=relay_view&t_ref_content=SRI_050_VIEW_MTRX_RCT_NOINFO&t_ref_scnid=595&dpId=SRI_050_VIEW_MTRX_RCT_NOINFO&ref_dp=SRI_050_VIEW_MTRX_RCT_NOINFO&inner_source=saramin&inner_medium=pattern&inner_campaign=relay_view_apply_5&inner_term=list&#39;, &#39;&#39;); return false;} catch (e) {}; return false;\" onmousedown=\"try{n_trackEvent(&#39;relay_view&#39;,&#39;recommend&#39;,&#39;quick_apply&#39;,&#39;&#39;);}catch(e){}\"><span class=\"sri_btn_immediately\" >\uc989\uc2dc\uc9c0\uc6d0<\/span><\/button>","favorBtn":"<button  type=\"button\" csn=\"2208657703\" title=\"\uad00\uc2ec\uae30\uc5c5 \ub4f1\ub85d\" del_fl=\"n\" class=\"btn_jview spr_jview btn_interest\" onclick=\"try{Saramin.btnJob(&#39;favor&#39;, this, &#39;&#39;, &#39;quick_login&#39;);}catch(e){}\" onmousedown=\"try {n_trackEvent(&#39;relay_view&#39;, &#39;recommend&#39;, &#39;favor&#39;, &#39;&#39;);}catch(e){}\" first_nudge=\"off\"><span class=\"blind\">\uad00\uc2ec\uae30\uc5c5 \ub4f1\ub85d<\/span><\/button>","txtRegDt":"4\uc77c \uc804 \ub4f1\ub85d"},{"rec_idx":"38724805","mcom_idx":"7778347","ccom_idx":"0","bbs_gb":"0","company_nm":"(\uc8fc)\uc5d0\uc774\uc9c1\uc2a4","title":"(\uc778\ud134\ucc44\uc6a9) Java \uc6f9 \ud504\ub85c\uadf8\ub7a8 \uac1c\ubc1c (\ucc44\uc6a9\uc5f0\uacc4\ud615)","company_cd":"1","education_cd":"0","sales_rank":"","group_level":"","stock_gb":"","career_cd":"0","career_min":"0","career_max":"0","sex_lim":"ignore","age_min":"0","age_max":"0","collect_cnt":"0","salary_cd":"0","job_type":"11,4","subway_cd":"80113","read_cnt":"113","bold_color_fl":"n","edit_date":"1599184215","closing_dt":"1604415599","area_code":"105040","area_mcode":"105000","ukeyword":"30101|30113|30116|30118|30120","jkeyword":"40402|40404|40407|40413|40421|40707|40708|40716|40721|41701|41702|41711|41712","upjong_cd":"301","jikjong_cd":"404,407,417","welfare_cd":"","preferential_cd":"pre015,pre043","top_fl":"n","upjong_mcode":"3","jikjong_mcode":"4","opening_dt":"1599181200","category":"","ccompany_cd":"stock","apply_cnt":"5","info_open_fl":"y","grab_source_cd":"","reg_dt":"1599184153","homepage":"www.agics.co.kr","keyword":"SI\u00b7\uc2dc\uc2a4\ud15c\ud1b5\ud569,SM,\uc18c\ud504\ud2b8\uc6e8\uc5b4\uac1c\ubc1c,\uc194\ub8e8\uc158\uc5c5\uccb4,\uc2dc\uc2a4\ud15c\uad00\ub9ac,Ajax,ASP,HTML,Java,Java\u00b7JSP,Linux,PHP,Python,TensorFlow,Unix,\ube45\ub370\uc774\ud130,\uc778\uacf5\uc9c0\ub2a5(AI)","valuestatement":"","com_photo":"n","personnel_manager_fl":"y","group_nm":"","reply_cnt":"0","area_bcode":"105040","item_id":"","hr_answer_cd":"","salary":"0","kindness_expired_dt":"","education_comment":"","x_coordinate":"1273161080","y_coordinate":"363870145","description":"\u318d\uacf5\uacf5\uae30\uad00 SI \ud504\ub85c\uc81d\ud2b8 \uc218\ud589 \ubcf4\uc870 \u318d\uc6f9\ud504\ub85c\uadf8\ub798\ubc0d \ubc0f \uc751\uc6a9 S\/W \ubd84\uc57c \uac1c\ubc1c \uc5c5\ubb34 (JAVA Spring Framework \uae30\ubc18) \u318d\uac1c\ubc1c\uc0b0\ucd9c\ubb3c \uad00\ub828 \uc0ac\ubb34\uc5c5\ubb34","expect_graduation_available":"y","apply_gb":"email","company_file_fl":"n","hidden_star_main_contents":"","theme_category":"","cert_class":"","hidden_star_rec_fl":"n","pc_sort_dt":"1599184153","mobile_sort_dt":"1599184153","service_start_dt":"0","rec_manage_cd":"T,TT,ZI,ZA,ZS,PA,ZR","paid_fl":"n","special_code":"","special_bcode":"null","special_top_fl_code":"","scale":"\uc911\uc18c\uae30\uc5c5","csn_num":"508-88-00574","main_area_kcode":"126","company_score":"19","logo_src":"company\/logo\/201912\/24\/q30bhk_a93j-1crym29_logo.png","ROWID":6305,"score":5,"recParam":{"t_category":"relay_view","t_content":"relay_view_list","t_ref":"relay_view","t_ref_content":"SRI_050_VIEW_MTRX_RCT_NOINFO","t_ref_scnid":"561","dpId":"SRI_050_VIEW_MTRX_RCT_NOINFO","ref_dp":"SRI_050_VIEW_MTRX_RCT_NOINFO","inner_source":"saramin","inner_medium":"pattern","inner_campaign":"relay_view_apply_5","inner_term":"list","trackEventAvatar":"","loggingRecommend":"loggingRecommendUrl(this, 'http:\/\/rcmd-log.saramin.co.kr:9020\/so-logging\/log\/client?custId=&pcId=15996305088133198347523&nonce=a8c32584fd04896f8879&dpId=SRI_050_VIEW_MTRX_RCT_NOINFO&scnId=561&tgId=0&itemSetId=0&itemValue=38724805&click=1', '');","scrapBtn":"<button type=\"button\" onclick=\"Saramin.btnJob('scrap', this, '', 'quick_login');\" scraped=\"n\" rec_idx=\"38724805\" class=\"btn_scrap scrap-38724805\" imgtype=\"\" title=\"\uacf5\uace0 \uc2a4\ud06c\ub7a9\" onmousedown=\"try{n_trackEvent('relay_view', 'recommend', 'scrap' , '');}catch(e){}\"><img src=\"http:\/\/www.saraminimage.co.kr\/common\/bul_sri_star.png\" alt=\"\"><\/button>","quickApplyOptions":{"trackEvent":{"category":"relay_view","action":"recommend","opt_label":"quick_apply","opt_value":""},"applyTrackEvent":{"t_category":"relay_view","t_content":"relay_view_list","t_ref":"relay_view","t_ref_content":"SRI_050_VIEW_MTRX_RCT_NOINFO","t_ref_scnid":"561","dpId":"SRI_050_VIEW_MTRX_RCT_NOINFO","ref_dp":"SRI_050_VIEW_MTRX_RCT_NOINFO","inner_source":"saramin","inner_medium":"pattern","inner_campaign":"relay_view_apply_6","inner_term":"list"}}},"summary_str":"\uc720\uc131\uad6c <span class=\"txt_bar\">|<\/span> \uacbd\ub825\ubb34\uad00 <span class=\"txt_bar\">|<\/span> \ud559\ub825\ubb34\uad00","closing_str":"~ 11\/3(\ud654)","recommend_ids_list":"38716840_561%7C38562906_746%7C38647080_596%7C38600890_561%7C38477312_561%7C38616136_561%7C38678317_561%7C38668033_596%7C38605619_561","quickApplyBtn":"<button  class=\"sri_btn_xs for_btn_event\" title=\"\ud074\ub9ad\ud558\uba74 \uc785\uc0ac\uc9c0\uc6d0\ud560 \uc218 \uc788\ub294 \ucc3d\uc774 \ub739\ub2c8\ub2e4.\" onclick=\"try{quickApplyForm(&#39;38724805&#39;,&#39;&#39;,&#39;t_category=relay_view&t_content=relay_view_list&t_ref=relay_view&t_ref_content=SRI_050_VIEW_MTRX_RCT_NOINFO&t_ref_scnid=561&dpId=SRI_050_VIEW_MTRX_RCT_NOINFO&ref_dp=SRI_050_VIEW_MTRX_RCT_NOINFO&inner_source=saramin&inner_medium=pattern&inner_campaign=relay_view_apply_6&inner_term=list&#39;, &#39;&#39;); return false;} catch (e) {}; return false;\" onmousedown=\"try{n_trackEvent(&#39;relay_view&#39;,&#39;recommend&#39;,&#39;quick_apply&#39;,&#39;&#39;);}catch(e){}\"><span class=\"sri_btn_immediately\" >\uc989\uc2dc\uc9c0\uc6d0<\/span><\/button>","favorBtn":"<button  type=\"button\" csn=\"5088800574\" title=\"\uad00\uc2ec\uae30\uc5c5 \ub4f1\ub85d\" del_fl=\"n\" class=\"btn_jview spr_jview btn_interest\" onclick=\"try{Saramin.btnJob(&#39;favor&#39;, this, &#39;&#39;, &#39;quick_login&#39;);}catch(e){}\" onmousedown=\"try {n_trackEvent(&#39;relay_view&#39;, &#39;recommend&#39;, &#39;favor&#39;, &#39;&#39;);}catch(e){}\" first_nudge=\"off\"><span class=\"blind\">\uad00\uc2ec\uae30\uc5c5 \ub4f1\ub85d<\/span><\/button>","txtRegDt":"5\uc77c \uc804 \ub4f1\ub85d"},{"rec_idx":"38716840","mcom_idx":"5773012","ccom_idx":"0","bbs_gb":"0","company_nm":"\uc8fc\uc2dd\ud68c\uc0ac \ubca0\ub2c8\ud398","title":"[\uc2e0\uc785] \uc6f9 \uc0ac\uc774\ud2b8 \uac1c\ubc1c \uc88b\uc544\ud558\ub294 \uc0ac\ub78c \ubaa8\uc9d1","company_cd":"1","education_cd":"8","sales_rank":"","group_level":"","stock_gb":"","career_cd":"1","career_min":"0","career_max":"0","sex_lim":"ignore","age_min":"0","age_max":"0","collect_cnt":"0","salary_cd":"9","job_type":"1","subway_cd":"80119","read_cnt":"136","bold_color_fl":"n","edit_date":"1599048128","closing_dt":"1601650799","area_code":"105040","area_mcode":"105000","ukeyword":"30116|30118","jkeyword":"40404|40407|40413|40421|40427|40701|40702|41301|41305","upjong_cd":"301","jikjong_cd":"404,407,413","welfare_cd":"corp100,corp204,corp210,corp300,corp301,corp302,corp303,corp304,corp305,corp306,corp308,corp431,corp432,corp433,corp449,corp466,corp472,corp477,corp499","preferential_cd":"pre043,pre994","top_fl":"n","upjong_mcode":"3","jikjong_mcode":"4","opening_dt":"1599044400","category":"","ccompany_cd":"stock,ex_audit","apply_cnt":"6","info_open_fl":"y","grab_source_cd":"","reg_dt":"1599048128","homepage":"benife.com","keyword":"\uc18c\ud504\ud2b8\uc6e8\uc5b4\uac1c\ubc1c,\uc194\ub8e8\uc158\uc5c5\uccb4,Ajax,Android\uc571\uac1c\ubc1c,HTML,HTML\ucf54\ub529,IOS\uc571\uac1c\ubc1c,Java\u00b7JSP,PHP,\uc790\ubc14\uc2a4\ud06c\ub9bd\ud2b8,\ud504\ub860\ud2b8\uc5d4\ub4dc","valuestatement":"","com_photo":"n","personnel_manager_fl":"y","group_nm":"","reply_cnt":"0","area_bcode":"105040","item_id":"","hr_answer_cd":"","salary":"0","kindness_expired_dt":"1549515157","education_comment":"","x_coordinate":"1273429086","y_coordinate":"363590655","description":"HTML, CSS, JavaScript\uc744 \uc774\uc6a9\ud55c \uc6f9 \uc11c\ube44\uc2a4 \uac1c\ubc1c, Flutter\ub97c \uc774\uc6a9\ud55c \uc571 UI \uac1c\ubc1c","expect_graduation_available":"y","apply_gb":"email","company_file_fl":"n","hidden_star_main_contents":"","theme_category":"","cert_class":"","hidden_star_rec_fl":"n","pc_sort_dt":"1599048128","mobile_sort_dt":"1599048128","service_start_dt":"0","rec_manage_cd":"T,TT,ZI,ZA,ZS,ZP,ZR","paid_fl":"n","special_code":"","special_bcode":"null","special_top_fl_code":"","scale":"\uc911\uc18c\uae30\uc5c5","csn_num":"314-86-37507","main_area_kcode":"126","company_score":"24","logo_src":"company\/logo\/201311\/01\/1383270321_dfad-7094f10f_logo.jpg","ROWID":28747,"score":6,"recParam":{"t_category":"relay_view","t_content":"relay_view_list","t_ref":"relay_view","t_ref_content":"SRI_050_VIEW_MTRX_RCT_NOINFO","t_ref_scnid":"561","dpId":"SRI_050_VIEW_MTRX_RCT_NOINFO","ref_dp":"SRI_050_VIEW_MTRX_RCT_NOINFO","inner_source":"saramin","inner_medium":"pattern","inner_campaign":"relay_view_apply_6","inner_term":"list","trackEventAvatar":"","loggingRecommend":"loggingRecommendUrl(this, 'http:\/\/rcmd-log.saramin.co.kr:9020\/so-logging\/log\/client?custId=&pcId=15996305088133198347523&nonce=a8c32584fd04896f8879&dpId=SRI_050_VIEW_MTRX_RCT_NOINFO&scnId=561&tgId=0&itemSetId=0&itemValue=38716840&click=1', '');","scrapBtn":"<button type=\"button\" onclick=\"Saramin.btnJob('scrap', this, '', 'quick_login');\" scraped=\"n\" rec_idx=\"38716840\" class=\"btn_scrap scrap-38716840\" imgtype=\"\" title=\"\uacf5\uace0 \uc2a4\ud06c\ub7a9\" onmousedown=\"try{n_trackEvent('relay_view', 'recommend', 'scrap' , '');}catch(e){}\"><img src=\"http:\/\/www.saraminimage.co.kr\/common\/bul_sri_star.png\" alt=\"\"><\/button>","quickApplyOptions":{"trackEvent":{"category":"relay_view","action":"recommend","opt_label":"quick_apply","opt_value":""},"applyTrackEvent":{"t_category":"relay_view","t_content":"relay_view_list","t_ref":"relay_view","t_ref_content":"SRI_050_VIEW_MTRX_RCT_NOINFO","t_ref_scnid":"561","dpId":"SRI_050_VIEW_MTRX_RCT_NOINFO","ref_dp":"SRI_050_VIEW_MTRX_RCT_NOINFO","inner_source":"saramin","inner_medium":"pattern","inner_campaign":"relay_view_apply_7","inner_term":"list"}}},"summary_str":"\uc720\uc131\uad6c <span class=\"txt_bar\">|<\/span> \uc2e0\uc785 <span class=\"txt_bar\">|<\/span> \ub300\uc878\u2191","closing_str":"~ 10\/2(\uae08)","recommend_ids_list":"38562906_746%7C38647080_596%7C38600890_561%7C38477312_561%7C38616136_561%7C38678317_561%7C38668033_596%7C38605619_561","quickApplyBtn":"<button  class=\"sri_btn_xs for_btn_event\" title=\"\ud074\ub9ad\ud558\uba74 \uc785\uc0ac\uc9c0\uc6d0\ud560 \uc218 \uc788\ub294 \ucc3d\uc774 \ub739\ub2c8\ub2e4.\" onclick=\"try{quickApplyForm(&#39;38716840&#39;,&#39;&#39;,&#39;t_category=relay_view&t_content=relay_view_list&t_ref=relay_view&t_ref_content=SRI_050_VIEW_MTRX_RCT_NOINFO&t_ref_scnid=561&dpId=SRI_050_VIEW_MTRX_RCT_NOINFO&ref_dp=SRI_050_VIEW_MTRX_RCT_NOINFO&inner_source=saramin&inner_medium=pattern&inner_campaign=relay_view_apply_7&inner_term=list&#39;, &#39;&#39;); return false;} catch (e) {}; return false;\" onmousedown=\"try{n_trackEvent(&#39;relay_view&#39;,&#39;recommend&#39;,&#39;quick_apply&#39;,&#39;&#39;);}catch(e){}\"><span class=\"sri_btn_immediately\" >\uc989\uc2dc\uc9c0\uc6d0<\/span><\/button>","favorBtn":"<button  type=\"button\" csn=\"3148637507\" title=\"\uad00\uc2ec\uae30\uc5c5 \ub4f1\ub85d\" del_fl=\"n\" class=\"btn_jview spr_jview btn_interest\" onclick=\"try{Saramin.btnJob(&#39;favor&#39;, this, &#39;&#39;, &#39;quick_login&#39;);}catch(e){}\" onmousedown=\"try {n_trackEvent(&#39;relay_view&#39;, &#39;recommend&#39;, &#39;favor&#39;, &#39;&#39;);}catch(e){}\" first_nudge=\"off\"><span class=\"blind\">\uad00\uc2ec\uae30\uc5c5 \ub4f1\ub85d<\/span><\/button>","txtRegDt":"6\uc77c \uc804 \ub4f1\ub85d"},{"rec_idx":"38562906","mcom_idx":"5088285","ccom_idx":"0","bbs_gb":"0","company_nm":"(\uc8fc)\uc778\ud578\uc2a4\uc720","title":"\uc6f9\uc194\ub8e8\uc158 \uac1c\ubc1c\uc790 \ubaa8\uc9d1(\ub300\uc804)","company_cd":"1","education_cd":"7","sales_rank":"","group_level":"","stock_gb":"","career_cd":"3","career_min":"99","career_max":"0","sex_lim":"ignore","age_min":"0","age_max":"0","collect_cnt":"0","salary_cd":"0","job_type":"1","subway_cd":"0","read_cnt":"250","bold_color_fl":"n","edit_date":"1596548809","closing_dt":"1601477999","area_code":"105010,105030,105040,105050","area_mcode":"105000","ukeyword":"30118","jkeyword":"40407|40421|40427|40430|40530","upjong_cd":"301","jikjong_cd":"404,405","welfare_cd":"corp102,corp210,corp300,corp301,corp302,corp432,corp433,corp477,corp480,corp499,corp526","preferential_cd":"pre043","top_fl":"n","upjong_mcode":"3","jikjong_mcode":"4","opening_dt":"1596546000","category":"","ccompany_cd":"stock","apply_cnt":"15","info_open_fl":"y","grab_source_cd":"","reg_dt":"1596547806","homepage":"http:\/\/www.enhanceU.com","keyword":"\uc18c\ud504\ud2b8\uc6e8\uc5b4\uac1c\ubc1c,Ajax,PHP,\uac8c\uc784\uac1c\ubc1c,\ubc31\uc5d4\ub4dc,\ud504\ub860\ud2b8\uc5d4\ub4dc","valuestatement":"","com_photo":"n","personnel_manager_fl":"s,n","group_nm":"","reply_cnt":"0","area_bcode":"105010,105030,105040,105050","item_id":"","hr_answer_cd":"","salary":"0","kindness_expired_dt":"1440031935","education_comment":"","x_coordinate":"1274074056","y_coordinate":"364189948","description":"AI \ucc44\uc6a9\uba74\uc811, \uc5ed\ub7c9\uac80\uc0ac \uac8c\uc784, \ubaa8\uc758\uba74\uc811, \ud654\uc0c1\uba74\uc811 \uc194\ub8e8\uc158 \uac1c\ubc1c \ubc0f \uc720\uc9c0\ubcf4\uc218","expect_graduation_available":"y","apply_gb":"email","company_file_fl":"n","hidden_star_main_contents":"","theme_category":"","cert_class":"","hidden_star_rec_fl":"n","pc_sort_dt":"1596547806","mobile_sort_dt":"1596547806","service_start_dt":"0","rec_manage_cd":"T,TT,ZI,ZA,ZS,ZP,ZR","paid_fl":"n","special_code":"","special_bcode":"null","special_top_fl_code":"","scale":"\uc911\uc18c\uae30\uc5c5","csn_num":"101-86-52090","main_area_kcode":"126","company_score":"0","logo_src":"company\/logo\/201904\/22\/pqct5s_g728-gdn3rt_logo.png","ROWID":26478,"score":7,"recParam":{"t_category":"relay_view","t_content":"relay_view_list","t_ref":"relay_view","t_ref_content":"SRI_050_VIEW_MTRX_RCT_NOINFO","t_ref_scnid":"746","dpId":"SRI_050_VIEW_MTRX_RCT_NOINFO","ref_dp":"SRI_050_VIEW_MTRX_RCT_NOINFO","inner_source":"saramin","inner_medium":"pattern","inner_campaign":"relay_view_apply_7","inner_term":"list","trackEventAvatar":"","loggingRecommend":"loggingRecommendUrl(this, 'http:\/\/rcmd-log.saramin.co.kr:9020\/so-logging\/log\/client?custId=&pcId=15996305088133198347523&nonce=a8c32584fd04896f8879&dpId=SRI_050_VIEW_MTRX_RCT_NOINFO&scnId=746&tgId=0&itemSetId=0&itemValue=38562906&click=1', '');","scrapBtn":"<button type=\"button\" onclick=\"Saramin.btnJob('scrap', this, '', 'quick_login');\" scraped=\"n\" rec_idx=\"38562906\" class=\"btn_scrap scrap-38562906\" imgtype=\"\" title=\"\uacf5\uace0 \uc2a4\ud06c\ub7a9\" onmousedown=\"try{n_trackEvent('relay_view', 'recommend', 'scrap' , '');}catch(e){}\"><img src=\"http:\/\/www.saraminimage.co.kr\/common\/bul_sri_star.png\" alt=\"\"><\/button>","quickApplyOptions":{"trackEvent":{"category":"relay_view","action":"recommend","opt_label":"quick_apply","opt_value":""},"applyTrackEvent":{"t_category":"relay_view","t_content":"relay_view_list","t_ref":"relay_view","t_ref_content":"SRI_050_VIEW_MTRX_RCT_NOINFO","t_ref_scnid":"746","dpId":"SRI_050_VIEW_MTRX_RCT_NOINFO","ref_dp":"SRI_050_VIEW_MTRX_RCT_NOINFO","inner_source":"saramin","inner_medium":"pattern","inner_campaign":"relay_view_apply_8","inner_term":"list"}}},"summary_str":"\ub300\ub355\uad6c <span class=\"txt_bar\">|<\/span> \uacbd\ub825\ubb34\uad00 <span class=\"txt_bar\">|<\/span> \ucd08\ub300\uc878\u2191","closing_str":"~ 9\/30(\uc218)","recommend_ids_list":"38647080_596%7C38600890_561%7C38477312_561%7C38616136_561%7C38678317_561%7C38668033_596%7C38605619_561","quickApplyBtn":"<button  class=\"sri_btn_xs for_btn_event\" title=\"\ud074\ub9ad\ud558\uba74 \uc785\uc0ac\uc9c0\uc6d0\ud560 \uc218 \uc788\ub294 \ucc3d\uc774 \ub739\ub2c8\ub2e4.\" onclick=\"try{quickApplyForm(&#39;38562906&#39;,&#39;&#39;,&#39;t_category=relay_view&t_content=relay_view_list&t_ref=relay_view&t_ref_content=SRI_050_VIEW_MTRX_RCT_NOINFO&t_ref_scnid=746&dpId=SRI_050_VIEW_MTRX_RCT_NOINFO&ref_dp=SRI_050_VIEW_MTRX_RCT_NOINFO&inner_source=saramin&inner_medium=pattern&inner_campaign=relay_view_apply_8&inner_term=list&#39;, &#39;&#39;); return false;} catch (e) {}; return false;\" onmousedown=\"try{n_trackEvent(&#39;relay_view&#39;,&#39;recommend&#39;,&#39;quick_apply&#39;,&#39;&#39;);}catch(e){}\"><span class=\"sri_btn_immediately\" >\uc989\uc2dc\uc9c0\uc6d0<\/span><\/button>","favorBtn":"<button  type=\"button\" csn=\"1018652090\" title=\"\uad00\uc2ec\uae30\uc5c5 \ub4f1\ub85d\" del_fl=\"n\" class=\"btn_jview spr_jview btn_interest\" onclick=\"try{Saramin.btnJob(&#39;favor&#39;, this, &#39;&#39;, &#39;quick_login&#39;);}catch(e){}\" onmousedown=\"try {n_trackEvent(&#39;relay_view&#39;, &#39;recommend&#39;, &#39;favor&#39;, &#39;&#39;);}catch(e){}\" first_nudge=\"off\"><span class=\"blind\">\uad00\uc2ec\uae30\uc5c5 \ub4f1\ub85d<\/span><\/button>","txtRegDt":"35\uc77c \uc804 \ub4f1\ub85d"},{"rec_idx":"38647080","mcom_idx":"7093184","ccom_idx":"0","bbs_gb":"0","company_nm":"(\uc8fc)\uc0c8\uc62c\uc815\ubcf4\uae30\uc220","title":"\uc18c\ud504\ud2b8\uc6e8\uc5b4 \ubd80\ubb38 \uac1c\ubc1c\uc790 \ubaa8\uc9d1","company_cd":"1","education_cd":"7","sales_rank":"","group_level":"","stock_gb":"","career_cd":"3","career_min":"1","career_max":"3","sex_lim":"ignore","age_min":"0","age_max":"0","collect_cnt":"0","salary_cd":"99","job_type":"1,11,4","subway_cd":"0","read_cnt":"232","bold_color_fl":"n","edit_date":"1597908189","closing_dt":"1988118000","area_code":"105050","area_mcode":"105000","ukeyword":"30118","jkeyword":"40404|40716|41301|41303|41305","upjong_cd":"301","jikjong_cd":"404,407,413","welfare_cd":"corp407,corp415,corp466,corp471,corp499","preferential_cd":"pre032","top_fl":"n","upjong_mcode":"3","jikjong_mcode":"4","opening_dt":"1597903200","category":"","ccompany_cd":"","apply_cnt":"9","info_open_fl":"y","grab_source_cd":"","reg_dt":"1597907861","homepage":"","keyword":"\uc18c\ud504\ud2b8\uc6e8\uc5b4\uac1c\ubc1c,HTML\ucf54\ub529,Java,Java\u00b7JSP,\uc790\ubc14\uc2a4\ud06c\ub9bd\ud2b8,\ud37c\ube14\ub9ac\uc154","valuestatement":"","com_photo":"n","personnel_manager_fl":"y","group_nm":"","reply_cnt":"0","area_bcode":"105050","item_id":"","hr_answer_cd":"","salary":"0","kindness_expired_dt":"1527581924","education_comment":"","x_coordinate":"1274003434","y_coordinate":"363194154","description":"\uc18c\ud504\ud2b8\uc6e8\uc5b4 \ubd80\ubb38 \uac1c\ubc1c(\uc790\ubc14) \/ \uc18c\ud504\ud2b8\uc6e8\uc5b4 \uc720\uc9c0\ubcf4\uc218","expect_graduation_available":"y","apply_gb":"email","company_file_fl":"n","hidden_star_main_contents":"","theme_category":"","cert_class":"","hidden_star_rec_fl":"n","pc_sort_dt":"1597907861","mobile_sort_dt":"1597907861","service_start_dt":"0","rec_manage_cd":"T,TT,ZI,ZA,ZS,ZP,ZR","paid_fl":"n","special_code":"","special_bcode":"null","special_top_fl_code":"","scale":"\uc911\uc18c\uae30\uc5c5","csn_num":"311-81-40288","main_area_kcode":"127","company_score":"19","logo_src":"","ROWID":106025,"score":8,"recParam":{"t_category":"relay_view","t_content":"relay_view_list","t_ref":"relay_view","t_ref_content":"SRI_050_VIEW_MTRX_RCT_NOINFO","t_ref_scnid":"596","dpId":"SRI_050_VIEW_MTRX_RCT_NOINFO","ref_dp":"SRI_050_VIEW_MTRX_RCT_NOINFO","inner_source":"saramin","inner_medium":"pattern","inner_campaign":"relay_view_apply_8","inner_term":"list","trackEventAvatar":"","loggingRecommend":"loggingRecommendUrl(this, 'http:\/\/rcmd-log.saramin.co.kr:9020\/so-logging\/log\/client?custId=&pcId=15996305088133198347523&nonce=a8c32584fd04896f8879&dpId=SRI_050_VIEW_MTRX_RCT_NOINFO&scnId=596&tgId=0&itemSetId=0&itemValue=38647080&click=1', '');","scrapBtn":"<button type=\"button\" onclick=\"Saramin.btnJob('scrap', this, '', 'quick_login');\" scraped=\"n\" rec_idx=\"38647080\" class=\"btn_scrap scrap-38647080\" imgtype=\"\" title=\"\uacf5\uace0 \uc2a4\ud06c\ub7a9\" onmousedown=\"try{n_trackEvent('relay_view', 'recommend', 'scrap' , '');}catch(e){}\"><img src=\"http:\/\/www.saraminimage.co.kr\/common\/bul_sri_star.png\" alt=\"\"><\/button>","quickApplyOptions":{"trackEvent":{"category":"relay_view","action":"recommend","opt_label":"quick_apply","opt_value":""},"applyTrackEvent":{"t_category":"relay_view","t_content":"relay_view_list","t_ref":"relay_view","t_ref_content":"SRI_050_VIEW_MTRX_RCT_NOINFO","t_ref_scnid":"596","dpId":"SRI_050_VIEW_MTRX_RCT_NOINFO","ref_dp":"SRI_050_VIEW_MTRX_RCT_NOINFO","inner_source":"saramin","inner_medium":"pattern","inner_campaign":"relay_view_apply_9","inner_term":"list"}}},"summary_str":"\ub300\uc804 \uc911\uad6c <span class=\"txt_bar\">|<\/span> \uc2e0\uc785\/\uacbd\ub825 <span class=\"txt_bar\">|<\/span> \ucd08\ub300\uc878\u2191","closing_str":"\ucc44\uc6a9\uc2dc","recommend_ids_list":"38600890_561%7C38477312_561%7C38616136_561%7C38678317_561%7C38668033_596%7C38605619_561","quickApplyBtn":"<button  class=\"sri_btn_xs for_btn_event\" title=\"\ud074\ub9ad\ud558\uba74 \uc785\uc0ac\uc9c0\uc6d0\ud560 \uc218 \uc788\ub294 \ucc3d\uc774 \ub739\ub2c8\ub2e4.\" onclick=\"try{quickApplyForm(&#39;38647080&#39;,&#39;&#39;,&#39;t_category=relay_view&t_content=relay_view_list&t_ref=relay_view&t_ref_content=SRI_050_VIEW_MTRX_RCT_NOINFO&t_ref_scnid=596&dpId=SRI_050_VIEW_MTRX_RCT_NOINFO&ref_dp=SRI_050_VIEW_MTRX_RCT_NOINFO&inner_source=saramin&inner_medium=pattern&inner_campaign=relay_view_apply_9&inner_term=list&#39;, &#39;&#39;); return false;} catch (e) {}; return false;\" onmousedown=\"try{n_trackEvent(&#39;relay_view&#39;,&#39;recommend&#39;,&#39;quick_apply&#39;,&#39;&#39;);}catch(e){}\"><span class=\"sri_btn_immediately\" >\uc989\uc2dc\uc9c0\uc6d0<\/span><\/button>","favorBtn":"<button  type=\"button\" csn=\"3118140288\" title=\"\uad00\uc2ec\uae30\uc5c5 \ub4f1\ub85d\" del_fl=\"n\" class=\"btn_jview spr_jview btn_interest\" onclick=\"try{Saramin.btnJob(&#39;favor&#39;, this, &#39;&#39;, &#39;quick_login&#39;);}catch(e){}\" onmousedown=\"try {n_trackEvent(&#39;relay_view&#39;, &#39;recommend&#39;, &#39;favor&#39;, &#39;&#39;);}catch(e){}\" first_nudge=\"off\"><span class=\"blind\">\uad00\uc2ec\uae30\uc5c5 \ub4f1\ub85d<\/span><\/button>","txtRegDt":"19\uc77c \uc804 \ub4f1\ub85d"},{"rec_idx":"38600890","mcom_idx":"7778282","ccom_idx":"0","bbs_gb":"0","company_nm":"(\uc8fc)\uc5d0\uc774\uce58\ud3ec\ud14c\ud06c","title":"\ube45\ub370\uc774\ud130 \ucc98\ub9ac \ubc0f \uc6f9 \uc18c\ud504\ud2b8\uc6e8\uc5b4 \uac1c\ubc1c \uc2e0\uc785\/\uacbd\ub825 \ucc44\uc6a9(\uc815\uaddc\uc9c1)","company_cd":"1","education_cd":"0","sales_rank":"","group_level":"","stock_gb":"","career_cd":"3","career_min":"99","career_max":"0","sex_lim":"ignore","age_min":"0","age_max":"0","collect_cnt":"0","salary_cd":"11","job_type":"1","subway_cd":"0","read_cnt":"434","bold_color_fl":"n","edit_date":"1597200906","closing_dt":"1601020800","area_code":"105040","area_mcode":"105000","ukeyword":"30108|30118","jkeyword":"40404|40426|40427|40430|40716|40721|40745|41702|41703|41705|41706","upjong_cd":"301","jikjong_cd":"404,407,417","welfare_cd":"","preferential_cd":"","top_fl":"n","upjong_mcode":"3","jikjong_mcode":"4","opening_dt":"1597179600","category":"","ccompany_cd":"","apply_cnt":"24","info_open_fl":"y","grab_source_cd":"","reg_dt":"1597181031","homepage":"h4tech.co.kr","keyword":"DataMining,\uc18c\ud504\ud2b8\uc6e8\uc5b4\uac1c\ubc1c,DataAnalysis,Java,Java\u00b7JSP,MySQL,Python,\uba38\uc2e0\ub7ec\ub2dd,\ubc31\uc5d4\ub4dc,\ube45\ub370\uc774\ud130,\uc0ac\ubb3c\uc778\ud130\ub137(IoT),\ud504\ub860\ud2b8\uc5d4\ub4dc","valuestatement":"","com_photo":"n","personnel_manager_fl":"n","group_nm":"","reply_cnt":"0","area_bcode":"105040","item_id":"","hr_answer_cd":"","salary":"0","kindness_expired_dt":"","education_comment":"","x_coordinate":"1273876575","y_coordinate":"364299444","description":"\ube45\ub370\uc774\ud130 \uc2dc\uc2a4\ud15c \uac1c\ubc1c, \uba38\uc2e0\ub7ec\ub2dd, \ub525\ub7ec\ub2dd \uad00\ub828 \uac1c\ubc1c,\uc6f9 \uc194\ub8e8\uc158 \uac1c\ubc1c, \uc6f9 \uc751\uc6a9\uc18c\ud504\ud2b8\uc6e8\uc5b4 \uac1c\ubc1c","expect_graduation_available":"y","apply_gb":"email","company_file_fl":"n","hidden_star_main_contents":"","theme_category":"","cert_class":"","hidden_star_rec_fl":"n","pc_sort_dt":"1597181031","mobile_sort_dt":"1597181031","service_start_dt":"0","rec_manage_cd":"T,TT,ZI,ZA,ZS,ZP,ZR","paid_fl":"n","special_code":"","special_bcode":"null","special_top_fl_code":"","scale":"\uc911\uc18c\uae30\uc5c5","csn_num":"720-88-01265","main_area_kcode":"126","company_score":"17","logo_src":"","ROWID":60668,"score":9,"recParam":{"t_category":"relay_view","t_content":"relay_view_list","t_ref":"relay_view","t_ref_content":"SRI_050_VIEW_MTRX_RCT_NOINFO","t_ref_scnid":"561","dpId":"SRI_050_VIEW_MTRX_RCT_NOINFO","ref_dp":"SRI_050_VIEW_MTRX_RCT_NOINFO","inner_source":"saramin","inner_medium":"pattern","inner_campaign":"relay_view_apply_9","inner_term":"list","trackEventAvatar":"","loggingRecommend":"loggingRecommendUrl(this, 'http:\/\/rcmd-log.saramin.co.kr:9020\/so-logging\/log\/client?custId=&pcId=15996305088133198347523&nonce=a8c32584fd04896f8879&dpId=SRI_050_VIEW_MTRX_RCT_NOINFO&scnId=561&tgId=0&itemSetId=0&itemValue=38600890&click=1', '');","scrapBtn":"<button type=\"button\" onclick=\"Saramin.btnJob('scrap', this, '', 'quick_login');\" scraped=\"n\" rec_idx=\"38600890\" class=\"btn_scrap scrap-38600890\" imgtype=\"\" title=\"\uacf5\uace0 \uc2a4\ud06c\ub7a9\" onmousedown=\"try{n_trackEvent('relay_view', 'recommend', 'scrap' , '');}catch(e){}\"><img src=\"http:\/\/www.saraminimage.co.kr\/common\/bul_sri_star.png\" alt=\"\"><\/button>","quickApplyOptions":{"trackEvent":{"category":"relay_view","action":"recommend","opt_label":"quick_apply","opt_value":""},"applyTrackEvent":{"t_category":"relay_view","t_content":"relay_view_list","t_ref":"relay_view","t_ref_content":"SRI_050_VIEW_MTRX_RCT_NOINFO","t_ref_scnid":"561","dpId":"SRI_050_VIEW_MTRX_RCT_NOINFO","ref_dp":"SRI_050_VIEW_MTRX_RCT_NOINFO","inner_source":"saramin","inner_medium":"pattern","inner_campaign":"relay_view_apply_10","inner_term":"list"}}},"summary_str":"\uc720\uc131\uad6c <span class=\"txt_bar\">|<\/span> \uacbd\ub825\ubb34\uad00 <span class=\"txt_bar\">|<\/span> \ud559\ub825\ubb34\uad00","closing_str":"~ 9\/25(\uae08)","recommend_ids_list":"38477312_561%7C38616136_561%7C38678317_561%7C38668033_596%7C38605619_561","quickApplyBtn":"<button  class=\"sri_btn_xs for_btn_event\" title=\"\ud074\ub9ad\ud558\uba74 \uc785\uc0ac\uc9c0\uc6d0\ud560 \uc218 \uc788\ub294 \ucc3d\uc774 \ub739\ub2c8\ub2e4.\" onclick=\"try{quickApplyForm(&#39;38600890&#39;,&#39;&#39;,&#39;t_category=relay_view&t_content=relay_view_list&t_ref=relay_view&t_ref_content=SRI_050_VIEW_MTRX_RCT_NOINFO&t_ref_scnid=561&dpId=SRI_050_VIEW_MTRX_RCT_NOINFO&ref_dp=SRI_050_VIEW_MTRX_RCT_NOINFO&inner_source=saramin&inner_medium=pattern&inner_campaign=relay_view_apply_10&inner_term=list&#39;, &#39;&#39;); return false;} catch (e) {}; return false;\" onmousedown=\"try{n_trackEvent(&#39;relay_view&#39;,&#39;recommend&#39;,&#39;quick_apply&#39;,&#39;&#39;);}catch(e){}\"><span class=\"sri_btn_immediately\" >\uc989\uc2dc\uc9c0\uc6d0<\/span><\/button>","favorBtn":"<button  type=\"button\" csn=\"7208801265\" title=\"\uad00\uc2ec\uae30\uc5c5 \ub4f1\ub85d\" del_fl=\"n\" class=\"btn_jview spr_jview btn_interest\" onclick=\"try{Saramin.btnJob(&#39;favor&#39;, this, &#39;&#39;, &#39;quick_login&#39;);}catch(e){}\" onmousedown=\"try {n_trackEvent(&#39;relay_view&#39;, &#39;recommend&#39;, &#39;favor&#39;, &#39;&#39;);}catch(e){}\" first_nudge=\"off\"><span class=\"blind\">\uad00\uc2ec\uae30\uc5c5 \ub4f1\ub85d<\/span><\/button>","txtRegDt":"28\uc77c \uc804 \ub4f1\ub85d"},{"rec_idx":"38477312","mcom_idx":"5758599","ccom_idx":"0","bbs_gb":"0","company_nm":"(\uc8fc)\uc774\ub370\uc544\uc778\ud3ec","title":"\uc2dc\uc2a4\ud15c\ud1b5\ud569\/\uc6f9 \uac1c\ubc1c\uc790 \ucc44\uc6a9 \uacf5\uace0","company_cd":"1","education_cd":"7","sales_rank":"","group_level":"","stock_gb":"","career_cd":"3","career_min":"1","career_max":"0","sex_lim":"ignore","age_min":"0","age_max":"0","collect_cnt":"00","salary_cd":"99","job_type":"1","subway_cd":"0","read_cnt":"335","bold_color_fl":"n","edit_date":"1595829573","closing_dt":"1600181999","area_code":"105030","area_mcode":"105000","ukeyword":"30101|30118","jkeyword":"40404|40716|40720","upjong_cd":"301","jikjong_cd":"404,407","welfare_cd":"corp101,corp102,corp201,corp204,corp301,corp304,corp402,corp404,corp406,corp418,corp434,corp499","preferential_cd":"pre021,pre054","top_fl":"n","upjong_mcode":"3","jikjong_mcode":"4","opening_dt":"1594980000","category":"","ccompany_cd":"stock","apply_cnt":"16","info_open_fl":"y","grab_source_cd":"","reg_dt":"1594983422","homepage":"http:\/\/www.ideainfo.kr","keyword":"SI\u00b7\uc2dc\uc2a4\ud15c\ud1b5\ud569,\uc18c\ud504\ud2b8\uc6e8\uc5b4\uac1c\ubc1c,Java,Java\u00b7JSP,Oracle","valuestatement":"","com_photo":"n","personnel_manager_fl":"y,s","group_nm":"","reply_cnt":"0","area_bcode":"105030","item_id":"","hr_answer_cd":"","salary":"0","kindness_expired_dt":"","education_comment":"","x_coordinate":"1273805164","y_coordinate":"363687492","description":"\uc6f9\uac1c\ubc1c(java\/jsp\/\uc804\uc790\uc815\ubd80\ud45c\uc900\ud504\ub808\uc784\uc6cc\ud06c)","expect_graduation_available":"n","apply_gb":"email","company_file_fl":"n","hidden_star_main_contents":"","theme_category":"","cert_class":"venture,mainbiz,innobiz,w-small-giant,family-friendly","hidden_star_rec_fl":"n","pc_sort_dt":"1595829573","mobile_sort_dt":"1595829573","service_start_dt":"0","rec_manage_cd":"T,TT,ZI,ZA,ZS,ZP,ZR","paid_fl":"n","special_code":"","special_bcode":"null","special_top_fl_code":"","scale":"\uc911\uc18c\uae30\uc5c5","csn_num":"314-86-33286","main_area_kcode":"125","company_score":"30","logo_src":"company\/logo\/201302\/26\/1361856385_46ff-6e2dc212_logo.jpg","ROWID":65729,"score":10,"recParam":{"t_category":"relay_view","t_content":"relay_view_list","t_ref":"relay_view","t_ref_content":"SRI_050_VIEW_MTRX_RCT_NOINFO","t_ref_scnid":"561","dpId":"SRI_050_VIEW_MTRX_RCT_NOINFO","ref_dp":"SRI_050_VIEW_MTRX_RCT_NOINFO","inner_source":"saramin","inner_medium":"pattern","inner_campaign":"relay_view_apply_10","inner_term":"list","trackEventAvatar":"","loggingRecommend":"loggingRecommendUrl(this, 'http:\/\/rcmd-log.saramin.co.kr:9020\/so-logging\/log\/client?custId=&pcId=15996305088133198347523&nonce=a8c32584fd04896f8879&dpId=SRI_050_VIEW_MTRX_RCT_NOINFO&scnId=561&tgId=0&itemSetId=0&itemValue=38477312&click=1', '');","scrapBtn":"<button type=\"button\" onclick=\"Saramin.btnJob('scrap', this, '', 'quick_login');\" scraped=\"n\" rec_idx=\"38477312\" class=\"btn_scrap scrap-38477312\" imgtype=\"\" title=\"\uacf5\uace0 \uc2a4\ud06c\ub7a9\" onmousedown=\"try{n_trackEvent('relay_view', 'recommend', 'scrap' , '');}catch(e){}\"><img src=\"http:\/\/www.saraminimage.co.kr\/common\/bul_sri_star.png\" alt=\"\"><\/button>","quickApplyOptions":{"trackEvent":{"category":"relay_view","action":"recommend","opt_label":"quick_apply","opt_value":""},"applyTrackEvent":{"t_category":"relay_view","t_content":"relay_view_list","t_ref":"relay_view","t_ref_content":"SRI_050_VIEW_MTRX_RCT_NOINFO","t_ref_scnid":"561","dpId":"SRI_050_VIEW_MTRX_RCT_NOINFO","ref_dp":"SRI_050_VIEW_MTRX_RCT_NOINFO","inner_source":"saramin","inner_medium":"pattern","inner_campaign":"relay_view_apply_11","inner_term":"list"}}},"summary_str":"\ub300\uc804 \uc11c\uad6c <span class=\"txt_bar\">|<\/span> \uc2e0\uc785\/\uacbd\ub825 <span class=\"txt_bar\">|<\/span> \ucd08\ub300\uc878\u2191","closing_str":"~ 9\/15(\ud654)","recommend_ids_list":"38616136_561%7C38678317_561%7C38668033_596%7C38605619_561","quickApplyBtn":"<button  class=\"sri_btn_xs for_btn_event\" title=\"\ud074\ub9ad\ud558\uba74 \uc785\uc0ac\uc9c0\uc6d0\ud560 \uc218 \uc788\ub294 \ucc3d\uc774 \ub739\ub2c8\ub2e4.\" onclick=\"try{quickApplyForm(&#39;38477312&#39;,&#39;&#39;,&#39;t_category=relay_view&t_content=relay_view_list&t_ref=relay_view&t_ref_content=SRI_050_VIEW_MTRX_RCT_NOINFO&t_ref_scnid=561&dpId=SRI_050_VIEW_MTRX_RCT_NOINFO&ref_dp=SRI_050_VIEW_MTRX_RCT_NOINFO&inner_source=saramin&inner_medium=pattern&inner_campaign=relay_view_apply_11&inner_term=list&#39;, &#39;&#39;); return false;} catch (e) {}; return false;\" onmousedown=\"try{n_trackEvent(&#39;relay_view&#39;,&#39;recommend&#39;,&#39;quick_apply&#39;,&#39;&#39;);}catch(e){}\"><span class=\"sri_btn_immediately\" >\uc989\uc2dc\uc9c0\uc6d0<\/span><\/button>","favorBtn":"<button  type=\"button\" csn=\"3148633286\" title=\"\uad00\uc2ec\uae30\uc5c5 \ub4f1\ub85d\" del_fl=\"n\" class=\"btn_jview spr_jview btn_interest\" onclick=\"try{Saramin.btnJob(&#39;favor&#39;, this, &#39;&#39;, &#39;quick_login&#39;);}catch(e){}\" onmousedown=\"try {n_trackEvent(&#39;relay_view&#39;, &#39;recommend&#39;, &#39;favor&#39;, &#39;&#39;);}catch(e){}\" first_nudge=\"off\"><span class=\"blind\">\uad00\uc2ec\uae30\uc5c5 \ub4f1\ub85d<\/span><\/button>","txtRegDt":"53\uc77c \uc804 \ub4f1\ub85d"},{"rec_idx":"38616136","mcom_idx":"7752524","ccom_idx":"0","bbs_gb":"0","company_nm":"(\uc8fc)\uc9c0\uc5d0\uc2a4\uc9c0","title":"R&D \ubc0f \uc6a9\uc5ed \uc18c\ud504\ud2b8\uc6e8\uc5b4 \uac1c\ubc1c\u00b7\uc720\uc9c0\ubcf4\uc218 \ucc44\uc6a9(C, JAVA, Python)","company_cd":"1","education_cd":"8","sales_rank":"","group_level":"","stock_gb":"","career_cd":"0","career_min":"0","career_max":"0","sex_lim":"ignore","age_min":"0","age_max":"1997","collect_cnt":"0","salary_cd":"99","job_type":"1","subway_cd":"0","read_cnt":"192","bold_color_fl":"n","edit_date":"1598430169","closing_dt":"1988118000","area_code":"105010","area_mcode":"105000","ukeyword":"20205","jkeyword":"40404|40426|40712|40716|40721|40745","upjong_cd":"202","jikjong_cd":"404,407","welfare_cd":"corp201,corp209,corp300,corp301,corp302,corp303,corp306,corp402,corp406,corp407,corp416,corp432,corp434,corp451,corp477,corp499,corp509,corp510,corp523","preferential_cd":"pre022,pre043","top_fl":"n","upjong_mcode":"2","jikjong_mcode":"4","opening_dt":"1597330800","category":"","ccompany_cd":"","apply_cnt":"5","info_open_fl":"y","grab_source_cd":"","reg_dt":"1597371814","homepage":"","keyword":"\uae30\uacc4,C\u00b7C++,Java,Java\u00b7JSP,MySQL,Python","valuestatement":"","com_photo":"n","personnel_manager_fl":"y","group_nm":"","reply_cnt":"0","area_bcode":"105010","item_id":"","hr_answer_cd":"","salary":"0","kindness_expired_dt":"","education_comment":"","x_coordinate":"1274130919","y_coordinate":"364380844","description":"\uc81c\uc5b4\u00b7\uacc4\uce21 \uc18c\ud504\ud2b8\uc6e8\uc5b4(C\u00b7C++, JAVA, Python \uc911 1\uc774\uc0c1) \uac1c\ubc1c\u00b7\uc720\uc9c0\ubcf4\uc218, \uc2dc\uc2a4\ud15c \uac1c\ubc1c\u00b7\uc720\uc9c0\ubcf4\uc218","expect_graduation_available":"y","apply_gb":"email","company_file_fl":"n","hidden_star_main_contents":"","theme_category":"","cert_class":"","hidden_star_rec_fl":"n","pc_sort_dt":"1598422748","mobile_sort_dt":"1598422748","service_start_dt":"0","rec_manage_cd":"T,TT,ZI,ZA,ZS,PA,ZR","paid_fl":"n","special_code":"","special_bcode":"null","special_top_fl_code":"","scale":"\uc911\uc18c\uae30\uc5c5","csn_num":"897-87-00706","main_area_kcode":"123","company_score":"16","logo_src":"company\/logo\/201909\/05\/pxcndv_3y8v-1crykqc_logo.png","ROWID":97795,"score":11,"recParam":{"t_category":"relay_view","t_content":"relay_view_list","t_ref":"relay_view","t_ref_content":"SRI_050_VIEW_MTRX_RCT_NOINFO","t_ref_scnid":"561","dpId":"SRI_050_VIEW_MTRX_RCT_NOINFO","ref_dp":"SRI_050_VIEW_MTRX_RCT_NOINFO","inner_source":"saramin","inner_medium":"pattern","inner_campaign":"relay_view_apply_11","inner_term":"list","trackEventAvatar":"","loggingRecommend":"loggingRecommendUrl(this, 'http:\/\/rcmd-log.saramin.co.kr:9020\/so-logging\/log\/client?custId=&pcId=15996305088133198347523&nonce=a8c32584fd04896f8879&dpId=SRI_050_VIEW_MTRX_RCT_NOINFO&scnId=561&tgId=0&itemSetId=0&itemValue=38616136&click=1', '');","scrapBtn":"<button type=\"button\" onclick=\"Saramin.btnJob('scrap', this, '', 'quick_login');\" scraped=\"n\" rec_idx=\"38616136\" class=\"btn_scrap scrap-38616136\" imgtype=\"\" title=\"\uacf5\uace0 \uc2a4\ud06c\ub7a9\" onmousedown=\"try{n_trackEvent('relay_view', 'recommend', 'scrap' , '');}catch(e){}\"><img src=\"http:\/\/www.saraminimage.co.kr\/common\/bul_sri_star.png\" alt=\"\"><\/button>","quickApplyOptions":{"trackEvent":{"category":"relay_view","action":"recommend","opt_label":"quick_apply","opt_value":""},"applyTrackEvent":{"t_category":"relay_view","t_content":"relay_view_list","t_ref":"relay_view","t_ref_content":"SRI_050_VIEW_MTRX_RCT_NOINFO","t_ref_scnid":"561","dpId":"SRI_050_VIEW_MTRX_RCT_NOINFO","ref_dp":"SRI_050_VIEW_MTRX_RCT_NOINFO","inner_source":"saramin","inner_medium":"pattern","inner_campaign":"relay_view_apply_12","inner_term":"list"}}},"summary_str":"\ub300\ub355\uad6c <span class=\"txt_bar\">|<\/span> \uacbd\ub825\ubb34\uad00 <span class=\"txt_bar\">|<\/span> \ub300\uc878\u2191","closing_str":"\ucc44\uc6a9\uc2dc","recommend_ids_list":"38678317_561%7C38668033_596%7C38605619_561","quickApplyBtn":"<button  class=\"sri_btn_xs for_btn_event\" title=\"\ud074\ub9ad\ud558\uba74 \uc785\uc0ac\uc9c0\uc6d0\ud560 \uc218 \uc788\ub294 \ucc3d\uc774 \ub739\ub2c8\ub2e4.\" onclick=\"try{quickApplyForm(&#39;38616136&#39;,&#39;&#39;,&#39;t_category=relay_view&t_content=relay_view_list&t_ref=relay_view&t_ref_content=SRI_050_VIEW_MTRX_RCT_NOINFO&t_ref_scnid=561&dpId=SRI_050_VIEW_MTRX_RCT_NOINFO&ref_dp=SRI_050_VIEW_MTRX_RCT_NOINFO&inner_source=saramin&inner_medium=pattern&inner_campaign=relay_view_apply_12&inner_term=list&#39;, &#39;&#39;); return false;} catch (e) {}; return false;\" onmousedown=\"try{n_trackEvent(&#39;relay_view&#39;,&#39;recommend&#39;,&#39;quick_apply&#39;,&#39;&#39;);}catch(e){}\"><span class=\"sri_btn_immediately\" >\uc989\uc2dc\uc9c0\uc6d0<\/span><\/button>","favorBtn":"<button  type=\"button\" csn=\"8978700706\" title=\"\uad00\uc2ec\uae30\uc5c5 \ub4f1\ub85d\" del_fl=\"n\" class=\"btn_jview spr_jview btn_interest\" onclick=\"try{Saramin.btnJob(&#39;favor&#39;, this, &#39;&#39;, &#39;quick_login&#39;);}catch(e){}\" onmousedown=\"try {n_trackEvent(&#39;relay_view&#39;, &#39;recommend&#39;, &#39;favor&#39;, &#39;&#39;);}catch(e){}\" first_nudge=\"off\"><span class=\"blind\">\uad00\uc2ec\uae30\uc5c5 \ub4f1\ub85d<\/span><\/button>","txtRegDt":"26\uc77c \uc804 \ub4f1\ub85d"},{"rec_idx":"38678317","mcom_idx":"5211577","ccom_idx":"0","bbs_gb":"0","company_nm":"(\uc8fc)\uc5d4\uc5d0\uc2a4\uc774","title":"\uc5f4\uc815\uc774 \ub118\uce58\ub294 \ud504\ub85c\uadf8\ub798\uba38, \uac1c\ubc1c\uc790\ub97c \ubaa8\uc2ed\uc2dc\ub2e4.","company_cd":"1","education_cd":"8","sales_rank":"","group_level":"","stock_gb":"","career_cd":"0","career_min":"0","career_max":"0","sex_lim":"ignore","age_min":"0","age_max":"0","collect_cnt":"0","salary_cd":"10","job_type":"1,19,3","subway_cd":"0","read_cnt":"196","bold_color_fl":"n","edit_date":"1598861906","closing_dt":"1603637999","area_code":"105040","area_mcode":"105000","ukeyword":"30116|30118","jkeyword":"40404|40409|40416|40716|40728","upjong_cd":"301","jikjong_cd":"404,407","welfare_cd":"corp100,corp102,corp204,corp209,corp210,corp300,corp301,corp302,corp303,corp305,corp306,corp307,corp401,corp404,corp406,corp407,corp413,corp418,corp432,corp433,corp434,corp435,corp440,corp449,corp451,corp466,corp472,corp477,corp479,corp486,corp499,corp509","preferential_cd":"pre004,pre056","top_fl":"n","upjong_mcode":"3","jikjong_mcode":"4","opening_dt":"1598425200","category":"","ccompany_cd":"stock,laboratory","apply_cnt":"5","info_open_fl":"y","grab_source_cd":"","reg_dt":"1598426762","homepage":"http:\/\/www.nsetec.com","keyword":"\uc18c\ud504\ud2b8\uc6e8\uc5b4\uac1c\ubc1c,\uc194\ub8e8\uc158\uc5c5\uccb4,.NET,C#,Java,Java\u00b7JSP,XML","valuestatement":"","com_photo":"y","personnel_manager_fl":"y","group_nm":"","reply_cnt":"0","area_bcode":"105040","item_id":"","hr_answer_cd":"","salary":"0","kindness_expired_dt":"1475932139","education_comment":"","x_coordinate":"1273697084","y_coordinate":"363839841","description":"\uc6f9\uae30\ubc18 \uc194\ub8e8\uc158 \uac1c\ubc1c","expect_graduation_available":"y","apply_gb":"email","company_file_fl":"n","hidden_star_main_contents":"","theme_category":"","cert_class":"","hidden_star_rec_fl":"n","pc_sort_dt":"1598861906","mobile_sort_dt":"1598861906","service_start_dt":"0","rec_manage_cd":"T,TT,ZI,ZA,ZS,ZP,ZR","paid_fl":"n","special_code":"","special_bcode":"null","special_top_fl_code":"","scale":"\uc911\uc18c\uae30\uc5c5","csn_num":"314-86-20423","main_area_kcode":"126","company_score":"22","logo_src":"company\/logo\/201501\/27\/1422321976_4db5-1f56289_logo.jpg","ROWID":6079,"score":12,"recParam":{"t_category":"relay_view","t_content":"relay_view_list","t_ref":"relay_view","t_ref_content":"SRI_050_VIEW_MTRX_RCT_NOINFO","t_ref_scnid":"561","dpId":"SRI_050_VIEW_MTRX_RCT_NOINFO","ref_dp":"SRI_050_VIEW_MTRX_RCT_NOINFO","inner_source":"saramin","inner_medium":"pattern","inner_campaign":"relay_view_apply_12","inner_term":"list","trackEventAvatar":"","loggingRecommend":"loggingRecommendUrl(this, 'http:\/\/rcmd-log.saramin.co.kr:9020\/so-logging\/log\/client?custId=&pcId=15996305088133198347523&nonce=a8c32584fd04896f8879&dpId=SRI_050_VIEW_MTRX_RCT_NOINFO&scnId=561&tgId=0&itemSetId=0&itemValue=38678317&click=1', '');","scrapBtn":"<button type=\"button\" onclick=\"Saramin.btnJob('scrap', this, '', 'quick_login');\" scraped=\"n\" rec_idx=\"38678317\" class=\"btn_scrap scrap-38678317\" imgtype=\"\" title=\"\uacf5\uace0 \uc2a4\ud06c\ub7a9\" onmousedown=\"try{n_trackEvent('relay_view', 'recommend', 'scrap' , '');}catch(e){}\"><img src=\"http:\/\/www.saraminimage.co.kr\/common\/bul_sri_star.png\" alt=\"\"><\/button>","quickApplyOptions":{"trackEvent":{"category":"relay_view","action":"recommend","opt_label":"quick_apply","opt_value":""},"applyTrackEvent":{"t_category":"relay_view","t_content":"relay_view_list","t_ref":"relay_view","t_ref_content":"SRI_050_VIEW_MTRX_RCT_NOINFO","t_ref_scnid":"561","dpId":"SRI_050_VIEW_MTRX_RCT_NOINFO","ref_dp":"SRI_050_VIEW_MTRX_RCT_NOINFO","inner_source":"saramin","inner_medium":"pattern","inner_campaign":"relay_view_apply_13","inner_term":"list"}}},"summary_str":"\uc720\uc131\uad6c <span class=\"txt_bar\">|<\/span> \uacbd\ub825\ubb34\uad00 <span class=\"txt_bar\">|<\/span> \ub300\uc878\u2191","closing_str":"~ 10\/25(\uc77c)","recommend_ids_list":"38668033_596%7C38605619_561","quickApplyBtn":"<button  class=\"sri_btn_xs for_btn_event\" title=\"\ud074\ub9ad\ud558\uba74 \uc785\uc0ac\uc9c0\uc6d0\ud560 \uc218 \uc788\ub294 \ucc3d\uc774 \ub739\ub2c8\ub2e4.\" onclick=\"try{quickApplyForm(&#39;38678317&#39;,&#39;&#39;,&#39;t_category=relay_view&t_content=relay_view_list&t_ref=relay_view&t_ref_content=SRI_050_VIEW_MTRX_RCT_NOINFO&t_ref_scnid=561&dpId=SRI_050_VIEW_MTRX_RCT_NOINFO&ref_dp=SRI_050_VIEW_MTRX_RCT_NOINFO&inner_source=saramin&inner_medium=pattern&inner_campaign=relay_view_apply_13&inner_term=list&#39;, &#39;&#39;); return false;} catch (e) {}; return false;\" onmousedown=\"try{n_trackEvent(&#39;relay_view&#39;,&#39;recommend&#39;,&#39;quick_apply&#39;,&#39;&#39;);}catch(e){}\"><span class=\"sri_btn_immediately\" >\uc989\uc2dc\uc9c0\uc6d0<\/span><\/button>","favorBtn":"<button  type=\"button\" csn=\"3148620423\" title=\"\uad00\uc2ec\uae30\uc5c5 \ub4f1\ub85d\" del_fl=\"n\" class=\"btn_jview spr_jview btn_interest\" onclick=\"try{Saramin.btnJob(&#39;favor&#39;, this, &#39;&#39;, &#39;quick_login&#39;);}catch(e){}\" onmousedown=\"try {n_trackEvent(&#39;relay_view&#39;, &#39;recommend&#39;, &#39;favor&#39;, &#39;&#39;);}catch(e){}\" first_nudge=\"off\"><span class=\"blind\">\uad00\uc2ec\uae30\uc5c5 \ub4f1\ub85d<\/span><\/button>","txtRegDt":"13\uc77c \uc804 \ub4f1\ub85d"},{"rec_idx":"38668033","mcom_idx":"6739192","ccom_idx":"","bbs_gb":"","company_nm":"(\uc8fc)\uc640\uc774\ud2f0","title":"Java \uc6f9\uac1c\ubc1c\uc790 \ucc44\uc6a9 [\uacbd\ub825\uc9c1]","company_cd":"1","education_cd":"7","sales_rank":"","group_level":"","stock_gb":"0","career_cd":"3","career_min":"2","career_max":"10","sex_lim":"ignore","age_min":"0","age_max":"0","collect_cnt":"0","salary_cd":"0","job_type":"1","subway_cd":"0","read_cnt":"136","bold_color_fl":"n","edit_date":"1598319500","closing_dt":"1603551599","area_code":"105010,105020,105030,105040,105050,118000","area_mcode":"105000,118000","ukeyword":"30101","jkeyword":"40404","upjong_cd":"301","jikjong_cd":"404","welfare_cd":"corp102,corp103,corp300,corp302,corp400,corp401,corp406,corp407,corp434,corp445,corp499","preferential_cd":"pre043","top_fl":"n","upjong_mcode":"3","jikjong_mcode":"4","opening_dt":"1598317200","category":"","ccompany_cd":"","apply_cnt":"6","info_open_fl":"y","grab_source_cd":"","reg_dt":"1598319500","homepage":"","keyword":"SI\u00b7\uc2dc\uc2a4\ud15c\ud1b5\ud569,Java\u00b7JSP","valuestatement":"","com_photo":"n","personnel_manager_fl":"n","group_nm":"","reply_cnt":"0","area_bcode":"105010,105020,105030,105040,105050,118000","item_id":"","hr_answer_cd":"","salary":"0","kindness_expired_dt":"","education_comment":"","x_coordinate":"1272980544","y_coordinate":"363497011","description":"\ud504\ub85c\uadf8\ub7a8\uac1c\ubc1c, \uc6f9\uac1c\ubc1c","expect_graduation_available":"n","apply_gb":"email,phone,nae","company_file_fl":"n","hidden_star_main_contents":"","theme_category":"","cert_class":"","hidden_star_rec_fl":"n","pc_sort_dt":"1598319501","mobile_sort_dt":"1598319501","service_start_dt":"0","rec_manage_cd":"T,TT,ZI,ZA,ZS,ZP,ZR","paid_fl":"n","special_code":"","special_bcode":"null","special_top_fl_code":"","scale":"\uc911\uc18c\uae30\uc5c5","csn_num":"314-86-21228","main_area_kcode":"126","company_score":"18","logo_src":"company\/logo\/201601\/05\/1451970768_2f23-79866a58_logo.jpg","ROWID":385,"score":13,"recParam":{"t_category":"relay_view","t_content":"relay_view_list","t_ref":"relay_view","t_ref_content":"SRI_050_VIEW_MTRX_RCT_NOINFO","t_ref_scnid":"596","dpId":"SRI_050_VIEW_MTRX_RCT_NOINFO","ref_dp":"SRI_050_VIEW_MTRX_RCT_NOINFO","inner_source":"saramin","inner_medium":"pattern","inner_campaign":"relay_view_apply_13","inner_term":"list","trackEventAvatar":"","loggingRecommend":"loggingRecommendUrl(this, 'http:\/\/rcmd-log.saramin.co.kr:9020\/so-logging\/log\/client?custId=&pcId=15996305088133198347523&nonce=a8c32584fd04896f8879&dpId=SRI_050_VIEW_MTRX_RCT_NOINFO&scnId=596&tgId=0&itemSetId=0&itemValue=38668033&click=1', '');","scrapBtn":"<button type=\"button\" onclick=\"Saramin.btnJob('scrap', this, '', 'quick_login');\" scraped=\"n\" rec_idx=\"38668033\" class=\"btn_scrap scrap-38668033\" imgtype=\"\" title=\"\uacf5\uace0 \uc2a4\ud06c\ub7a9\" onmousedown=\"try{n_trackEvent('relay_view', 'recommend', 'scrap' , '');}catch(e){}\"><img src=\"http:\/\/www.saraminimage.co.kr\/common\/bul_sri_star.png\" alt=\"\"><\/button>","quickApplyOptions":{"trackEvent":{"category":"relay_view","action":"recommend","opt_label":"quick_apply","opt_value":""},"applyTrackEvent":{"t_category":"relay_view","t_content":"relay_view_list","t_ref":"relay_view","t_ref_content":"SRI_050_VIEW_MTRX_RCT_NOINFO","t_ref_scnid":"596","dpId":"SRI_050_VIEW_MTRX_RCT_NOINFO","ref_dp":"SRI_050_VIEW_MTRX_RCT_NOINFO","inner_source":"saramin","inner_medium":"pattern","inner_campaign":"relay_view_apply_14","inner_term":"list"}}},"summary_str":"\ub300\ub355\uad6c <span class=\"txt_bar\">|<\/span> \uc2e0\uc785\/\uacbd\ub825 <span class=\"txt_bar\">|<\/span> \ucd08\ub300\uc878\u2191","closing_str":"~ 10\/24(\ud1a0)","recommend_ids_list":"38605619_561","quickApplyBtn":"<button  class=\"sri_btn_xs for_btn_event\" title=\"\ud074\ub9ad\ud558\uba74 \uc785\uc0ac\uc9c0\uc6d0\ud560 \uc218 \uc788\ub294 \ucc3d\uc774 \ub739\ub2c8\ub2e4.\" onclick=\"try{quickApplyForm(&#39;38668033&#39;,&#39;&#39;,&#39;t_category=relay_view&t_content=relay_view_list&t_ref=relay_view&t_ref_content=SRI_050_VIEW_MTRX_RCT_NOINFO&t_ref_scnid=596&dpId=SRI_050_VIEW_MTRX_RCT_NOINFO&ref_dp=SRI_050_VIEW_MTRX_RCT_NOINFO&inner_source=saramin&inner_medium=pattern&inner_campaign=relay_view_apply_14&inner_term=list&#39;, &#39;&#39;); return false;} catch (e) {}; return false;\" onmousedown=\"try{n_trackEvent(&#39;relay_view&#39;,&#39;recommend&#39;,&#39;quick_apply&#39;,&#39;&#39;);}catch(e){}\"><span class=\"sri_btn_immediately\" >\uc989\uc2dc\uc9c0\uc6d0<\/span><\/button>","favorBtn":"<button  type=\"button\" csn=\"3148621228\" title=\"\uad00\uc2ec\uae30\uc5c5 \ub4f1\ub85d\" del_fl=\"n\" class=\"btn_jview spr_jview btn_interest\" onclick=\"try{Saramin.btnJob(&#39;favor&#39;, this, &#39;&#39;, &#39;quick_login&#39;);}catch(e){}\" onmousedown=\"try {n_trackEvent(&#39;relay_view&#39;, &#39;recommend&#39;, &#39;favor&#39;, &#39;&#39;);}catch(e){}\" first_nudge=\"off\"><span class=\"blind\">\uad00\uc2ec\uae30\uc5c5 \ub4f1\ub85d<\/span><\/button>","txtRegDt":"15\uc77c \uc804 \ub4f1\ub85d"},{"rec_idx":"38605619","mcom_idx":"5228666","ccom_idx":"0","bbs_gb":"0","company_nm":"\uc8fc\uc2dd\ud68c\uc0ac \uc5d0\uc988\uc6f0","title":"[\uacbd\ub825] (\uc8fc)\uc5d0\uc988\uc6f0 \uc5f0\uad6c\uc18c \uc751\uc6a9\ud504\ub85c\uadf8\ub798\uba38 \ubaa8\uc9d1(WEB, APP\uac1c\ubc1c\uc790)","company_cd":"1","education_cd":"0","sales_rank":"","group_level":"","stock_gb":"","career_cd":"0","career_min":"0","career_max":"0","sex_lim":"ignore","age_min":"0","age_max":"0","collect_cnt":"0","salary_cd":"0","job_type":"1","subway_cd":"0","read_cnt":"263","bold_color_fl":"n","edit_date":"1598864460","closing_dt":"1602428399","area_code":"105040","area_mcode":"105000","ukeyword":"30118","jkeyword":"40404|40427|40430|40708|40716","upjong_cd":"301","jikjong_cd":"404,407","welfare_cd":"corp300,corp303,corp400,corp421,corp422,corp425,corp466,corp471,corp478,corp482","preferential_cd":"pre043","top_fl":"n","upjong_mcode":"3","jikjong_mcode":"4","opening_dt":"1597215600","category":"","ccompany_cd":"stock","apply_cnt":"12","info_open_fl":"y","grab_source_cd":"","reg_dt":"1597216483","homepage":"http:\/\/www.azwellsys.com","keyword":"\uc18c\ud504\ud2b8\uc6e8\uc5b4\uac1c\ubc1c,Java,Java\u00b7JSP,Linux,\ubc31\uc5d4\ub4dc,\ud504\ub860\ud2b8\uc5d4\ub4dc","valuestatement":"","com_photo":"n","personnel_manager_fl":"y","group_nm":"","reply_cnt":"0","area_bcode":"105040","item_id":"","hr_answer_cd":"","salary":"0","kindness_expired_dt":"1351901579","education_comment":"","x_coordinate":"1274071560","y_coordinate":"364232721","description":"\uc790\uc0ac \uc18c\ud504\ud2b8\uc6e8\uc5b4 \uac1c\ubc1c \ubc0f \uc6b4\uc601 ( Java  \uc0ac\uc6a9), \uc571 \uac1c\ubc1c\uc790, \uc6f9 \uac1c\ubc1c \uacbd\ud5d8\uc790","expect_graduation_available":"n","apply_gb":"email","company_file_fl":"n","hidden_star_main_contents":"","theme_category":"","cert_class":"goodcompany","hidden_star_rec_fl":"n","pc_sort_dt":"1598864460","mobile_sort_dt":"1598864460","service_start_dt":"0","rec_manage_cd":"T,TT,ZI,ZA,ZS,ZP,ZR","paid_fl":"n","special_code":"","special_bcode":"null","special_top_fl_code":"","scale":"\uc911\uc18c\uae30\uc5c5","csn_num":"314-86-00301","main_area_kcode":"126","company_score":"31","logo_src":"company\/logo\/202001\/08\/q3ro23_9vd8-xrtqva_logo.png","ROWID":33592,"score":14,"recParam":{"t_category":"relay_view","t_content":"relay_view_list","t_ref":"relay_view","t_ref_content":"SRI_050_VIEW_MTRX_RCT_NOINFO","t_ref_scnid":"561","dpId":"SRI_050_VIEW_MTRX_RCT_NOINFO","ref_dp":"SRI_050_VIEW_MTRX_RCT_NOINFO","inner_source":"saramin","inner_medium":"pattern","inner_campaign":"relay_view_apply_14","inner_term":"list","trackEventAvatar":"","loggingRecommend":"loggingRecommendUrl(this, 'http:\/\/rcmd-log.saramin.co.kr:9020\/so-logging\/log\/client?custId=&pcId=15996305088133198347523&nonce=a8c32584fd04896f8879&dpId=SRI_050_VIEW_MTRX_RCT_NOINFO&scnId=561&tgId=0&itemSetId=0&itemValue=38605619&click=1', '');","scrapBtn":"<button type=\"button\" onclick=\"Saramin.btnJob('scrap', this, '', 'quick_login');\" scraped=\"n\" rec_idx=\"38605619\" class=\"btn_scrap scrap-38605619\" imgtype=\"\" title=\"\uacf5\uace0 \uc2a4\ud06c\ub7a9\" onmousedown=\"try{n_trackEvent('relay_view', 'recommend', 'scrap' , '');}catch(e){}\"><img src=\"http:\/\/www.saraminimage.co.kr\/common\/bul_sri_star.png\" alt=\"\"><\/button>","quickApplyOptions":{"trackEvent":{"category":"relay_view","action":"recommend","opt_label":"quick_apply","opt_value":""},"applyTrackEvent":{"t_category":"relay_view","t_content":"relay_view_list","t_ref":"relay_view","t_ref_content":"SRI_050_VIEW_MTRX_RCT_NOINFO","t_ref_scnid":"561","dpId":"SRI_050_VIEW_MTRX_RCT_NOINFO","ref_dp":"SRI_050_VIEW_MTRX_RCT_NOINFO","inner_source":"saramin","inner_medium":"pattern","inner_campaign":"relay_view_apply_15","inner_term":"list"}}},"summary_str":"\uc720\uc131\uad6c <span class=\"txt_bar\">|<\/span> \uacbd\ub825\ubb34\uad00 <span class=\"txt_bar\">|<\/span> \ud559\ub825\ubb34\uad00","closing_str":"~ 10\/11(\uc77c)","recommend_ids_list":"none","quickApplyBtn":"<button  class=\"sri_btn_xs for_btn_event\" title=\"\ud074\ub9ad\ud558\uba74 \uc785\uc0ac\uc9c0\uc6d0\ud560 \uc218 \uc788\ub294 \ucc3d\uc774 \ub739\ub2c8\ub2e4.\" onclick=\"try{quickApplyForm(&#39;38605619&#39;,&#39;&#39;,&#39;t_category=relay_view&t_content=relay_view_list&t_ref=relay_view&t_ref_content=SRI_050_VIEW_MTRX_RCT_NOINFO&t_ref_scnid=561&dpId=SRI_050_VIEW_MTRX_RCT_NOINFO&ref_dp=SRI_050_VIEW_MTRX_RCT_NOINFO&inner_source=saramin&inner_medium=pattern&inner_campaign=relay_view_apply_15&inner_term=list&#39;, &#39;&#39;); return false;} catch (e) {}; return false;\" onmousedown=\"try{n_trackEvent(&#39;relay_view&#39;,&#39;recommend&#39;,&#39;quick_apply&#39;,&#39;&#39;);}catch(e){}\"><span class=\"sri_btn_immediately\" >\uc989\uc2dc\uc9c0\uc6d0<\/span><\/button>","favorBtn":"<button  type=\"button\" csn=\"3148600301\" title=\"\uad00\uc2ec\uae30\uc5c5 \ub4f1\ub85d\" del_fl=\"n\" class=\"btn_jview spr_jview btn_interest\" onclick=\"try{Saramin.btnJob(&#39;favor&#39;, this, &#39;&#39;, &#39;quick_login&#39;);}catch(e){}\" onmousedown=\"try {n_trackEvent(&#39;relay_view&#39;, &#39;recommend&#39;, &#39;favor&#39;, &#39;&#39;);}catch(e){}\" first_nudge=\"off\"><span class=\"blind\">\uad00\uc2ec\uae30\uc5c5 \ub4f1\ub85d<\/span><\/button>","txtRegDt":"27\uc77c \uc804 \ub4f1\ub85d"}],
            'related_list' : [{"job_type":"1","company_type":"foundation,nonprofit","exp_min":"3","cat_bcd":"4","csn_num":"120-82-08049","description":"\uc77c\ubc18\uc9c1(\uc2dc\uc2a4\ud15c \uc6b4\uc601)","company_file_fl":"n","title":"\ub300\uc804 \uad00\uc138\uccad \uc804\uc790\ud1b5\uad00\uc2dc\uc2a4\ud15c \uc6b4\uc601(\uac1c\ubc1c) \uacbd\ub825\uc9c1\uc6d0 \ucc44\uc6a9","mcom_idx":"7669697","logo_src":"","personnel_manager_fl":"n","read_cnt":"980","group_nm":"","sales_rank":"0","reg_dt":"1598590374","apply_cnt":"10","cat_cd":"402,404,407,408,411","loc_cd":"105030","valuestatement":"n","apply_gb":"email","edu_cd":"7","subway_cd":"80108","cert_class":"","info_open_fl":"y","opening_dt":"1598540400","com_idx":"51807","grab_source_cd":"","sal_cd":"0","kindness_expired_dt":"","closing_dt":"1599836399","loc_mcd":"105000","item_id":"ai_rcmd_plus2,ai_rcmd_plus_m2,background_color_m,bold5,bold_m2,rank_up11,rank_up6_m2","cat_key":"40234|40404|40701|40702|40708|40716|40722|40802|40805|40806|40808|40812|41105","rec_manage_cd":"C,ITM,ADS,S,ZR","exp_cd":"2","com_photo":"n","stock_gb":"","loc_bcd":"105030","exp_max":"5","rec_idx":"38689139","bbs_gb":"0","company_nm":"(\uc7ac)\uad6d\uac00\uad00\uc138\uc885\ud569\uc815\ubcf4\ub9dd\uc6b4\uc601\uc5f0\ud569\ud68c","category":"focus_fix_m,logo_focus_fix","pc_sort_dt":"1599621362","homepage":"www.unipass.or.kr","recParam":{"t_category":"relay_view","t_content":"relay_view_list","t_ref":"relay_view","t_ref_content":"SRI_050_VIEW_MIX_RCT_ADD","t_ref_scnid":"747","dpId":"SRI_050_VIEW_MIX_RCT_ADD","ref_dp":"SRI_050_VIEW_MIX_RCT_ADD","trackEventAvatar":"","loggingRecommend":"loggingRecommendUrl(this, 'http:\/\/rcmd-log.saramin.co.kr:9020\/so-logging\/log\/client?custId=&pcId=15996305088133198347523&nonce=a8c32584fd04896f8879&dpId=SRI_050_VIEW_MIX_RCT_ADD&scnId=747&tgId=0&itemSetId=0&itemValue=38689139&click=1', '');","scrapBtn":"<button type=\"button\" onclick=\"Saramin.btnJob('scrap', this, '', 'quick_login');\" scraped=\"n\" rec_idx=\"38689139\" class=\"btn_scrap scrap-38689139\" imgtype=\"\" title=\"\uacf5\uace0 \uc2a4\ud06c\ub7a9\" onmousedown=\"try{n_trackEvent('relay_view', 'recommend', 'scrap' , '');}catch(e){}\"><img src=\"http:\/\/www.saraminimage.co.kr\/common\/bul_sri_star.png\" alt=\"\"><\/button>","quickApplyOptions":{"trackEvent":{"category":"relay_view","action":"recommend","opt_label":"quick_apply","opt_value":""},"applyTrackEvent":{"t_category":"relay_view","t_content":"relay_view_list","t_ref":"relay_view","t_ref_content":"SRI_050_VIEW_MIX_RCT_ADD","t_ref_scnid":"747","dpId":"SRI_050_VIEW_MIX_RCT_ADD","ref_dp":"SRI_050_VIEW_MIX_RCT_ADD","inner_source":"saramin","inner_medium":"pattern","inner_campaign":"relay_view_apply_1","inner_term":"list"}}},"summary_str":"\ub300\uc804 \uc11c\uad6c <span class=\"txt_bar\">|<\/span> \uacbd\ub825 3~5\ub144 <span class=\"txt_bar\">|<\/span> \ucd08\ub300\uc878\u2191","closing_str":"~ 9\/11(\uae08)","recommend_ids_list":"38726832_595%7C38713619_696%7C38733685_696%7C38727190_595%7C38724805_561%7C38716840_561%7C38562906_746%7C38647080_596%7C38600890_561%7C38477312_561%7C38616136_561%7C38678317_561%7C38668033_596%7C38605619_561","quickApplyBtn":"<button  class=\"sri_btn_xs for_btn_event\" title=\"\ud074\ub9ad\ud558\uba74 \uc785\uc0ac\uc9c0\uc6d0\ud560 \uc218 \uc788\ub294 \ucc3d\uc774 \ub739\ub2c8\ub2e4.\" onclick=\"try{quickApplyForm(&#39;38689139&#39;,&#39;&#39;,&#39;t_category=relay_view&t_content=relay_view_list&t_ref=relay_view&t_ref_content=SRI_050_VIEW_MIX_RCT_ADD&t_ref_scnid=747&dpId=SRI_050_VIEW_MIX_RCT_ADD&ref_dp=SRI_050_VIEW_MIX_RCT_ADD&inner_source=saramin&inner_medium=pattern&inner_campaign=relay_view_apply_1&inner_term=list&#39;, &#39;&#39;); return false;} catch (e) {}; return false;\" onmousedown=\"try{n_trackEvent(&#39;relay_view&#39;,&#39;recommend&#39;,&#39;quick_apply&#39;,&#39;&#39;);}catch(e){}\"><span class=\"sri_btn_immediately\" >\uc989\uc2dc\uc9c0\uc6d0<\/span><\/button>","favorBtn":"<button  type=\"button\" csn=\"1208208049\" title=\"\uad00\uc2ec\uae30\uc5c5 \ub4f1\ub85d\" del_fl=\"n\" class=\"btn_jview spr_jview btn_interest\" onclick=\"try{Saramin.btnJob(&#39;favor&#39;, this, &#39;&#39;, &#39;quick_login&#39;);}catch(e){}\" onmousedown=\"try {n_trackEvent(&#39;relay_view&#39;, &#39;recommend&#39;, &#39;favor&#39;, &#39;&#39;);}catch(e){}\" first_nudge=\"off\"><span class=\"blind\">\uad00\uc2ec\uae30\uc5c5 \ub4f1\ub85d<\/span><\/button>","txtRegDt":"12\uc77c \uc804 \ub4f1\ub85d"},{"job_type":"1","company_type":"venture,goodcompany,w-small-giant,cooperator,ex_audit","exp_min":"2","cat_bcd":"4","csn_num":"211-86-98485","description":"","company_file_fl":"n","title":"[\uc640\uc774\uc988\ub11b] \uc194\ub8e8\uc158\uac1c\ubc1c\uc9c1 \uc911\ubd80\uc9c0\uc0ac \ucc44\uc6a9 \uacf5\uace0 \uac74","mcom_idx":"31713","logo_src":"company\/logo\/200904\/06\/1239014245_logo.jpg","personnel_manager_fl":"s,n","read_cnt":"573","group_nm":"\uc640\uc774\uc988\ub11b","sales_rank":"","reg_dt":"1595840179","apply_cnt":"12","cat_cd":"404","loc_cd":"105030","valuestatement":"","apply_gb":"email","edu_cd":"7","subway_cd":"80104","cert_class":"venture,goodcompany,w-small-giant,cooperator","info_open_fl":"y","opening_dt":"1595836800","com_idx":"0","grab_source_cd":"","sal_cd":"0","kindness_expired_dt":"1447891909","closing_dt":"1601045999","loc_mcd":"105000","item_id":"","cat_key":"40404","rec_manage_cd":"T,TT,ZI,ZA,ZS,ZP,ZR","exp_cd":"2","com_photo":"n","stock_gb":"","loc_bcd":"105030","exp_max":"0","rec_idx":"38521891","bbs_gb":"0","company_nm":"\u321c\uc640\uc774\uc988\ub11b","category":"","pc_sort_dt":"1597370852","homepage":"www.wisenut.co.kr","recParam":{"t_category":"relay_view","t_content":"relay_view_list","t_ref":"relay_view","t_ref_content":"SRI_050_VIEW_MIX_RCT_ADD","t_ref_scnid":"","dpId":"empty","ref_dp":"","inner_source":"saramin","inner_medium":"pattern","inner_campaign":"relay_view_apply_1","inner_term":"list","trackEventAvatar":"","loggingRecommend":"loggingRecommendUrl(this, '', '');","scrapBtn":"<button type=\"button\" onclick=\"Saramin.btnJob('scrap', this, '', 'quick_login');\" scraped=\"n\" rec_idx=\"38521891\" class=\"btn_scrap scrap-38521891\" imgtype=\"\" title=\"\uacf5\uace0 \uc2a4\ud06c\ub7a9\" onmousedown=\"try{n_trackEvent('relay_view', 'recommend', 'scrap' , '');}catch(e){}\"><img src=\"http:\/\/www.saraminimage.co.kr\/common\/bul_sri_star.png\" alt=\"\"><\/button>","quickApplyOptions":{"trackEvent":{"category":"relay_view","action":"recommend","opt_label":"quick_apply","opt_value":""},"applyTrackEvent":{"t_category":"relay_view","t_content":"relay_view_list","t_ref":"relay_view","t_ref_content":"SRI_050_VIEW_MIX_RCT_ADD","t_ref_scnid":"","dpId":"empty","ref_dp":"","inner_source":"saramin","inner_medium":"pattern","inner_campaign":"relay_view_apply_2","inner_term":"list"}}},"summary_str":"\ub300\uc804 \uc11c\uad6c <span class=\"txt_bar\">|<\/span> \uacbd\ub8252\ub144\u2191 <span class=\"txt_bar\">|<\/span> \ucd08\ub300\uc878\u2191","closing_str":"~ 9\/25(\uae08)","recommend_ids_list":"38713619_696%7C38733685_696%7C38727190_595%7C38724805_561%7C38716840_561%7C38562906_746%7C38647080_596%7C38600890_561%7C38477312_561%7C38616136_561%7C38678317_561%7C38668033_596%7C38605619_561","quickApplyBtn":"<button  class=\"sri_btn_xs for_btn_event\" title=\"\ud074\ub9ad\ud558\uba74 \uc785\uc0ac\uc9c0\uc6d0\ud560 \uc218 \uc788\ub294 \ucc3d\uc774 \ub739\ub2c8\ub2e4.\" onclick=\"try{quickApplyForm(&#39;38521891&#39;,&#39;&#39;,&#39;t_category=relay_view&t_content=relay_view_list&t_ref=relay_view&t_ref_content=SRI_050_VIEW_MIX_RCT_ADD&t_ref_scnid=&dpId=empty&ref_dp=&inner_source=saramin&inner_medium=pattern&inner_campaign=relay_view_apply_2&inner_term=list&#39;, &#39;&#39;); return false;} catch (e) {}; return false;\" onmousedown=\"try{n_trackEvent(&#39;relay_view&#39;,&#39;recommend&#39;,&#39;quick_apply&#39;,&#39;&#39;);}catch(e){}\"><span class=\"sri_btn_immediately\" >\uc989\uc2dc\uc9c0\uc6d0<\/span><\/button>","favorBtn":"<button  type=\"button\" csn=\"2118698485\" title=\"\uad00\uc2ec\uae30\uc5c5 \ub4f1\ub85d\" del_fl=\"n\" class=\"btn_jview spr_jview btn_interest\" onclick=\"try{Saramin.btnJob(&#39;favor&#39;, this, &#39;&#39;, &#39;quick_login&#39;);}catch(e){}\" onmousedown=\"try {n_trackEvent(&#39;relay_view&#39;, &#39;recommend&#39;, &#39;favor&#39;, &#39;&#39;);}catch(e){}\" first_nudge=\"off\"><span class=\"blind\">\uad00\uc2ec\uae30\uc5c5 \ub4f1\ub85d<\/span><\/button>","txtRegDt":"43\uc77c \uc804 \ub4f1\ub85d"},{"job_type":"10,2,9","company_type":"stock","exp_min":"5","cat_bcd":"4","csn_num":"312-86-36894","description":"JAVA \uac1c\ubc1c\uc790\/ C# \uac1c\ubc1c\uc790","company_file_fl":"n","title":"JAVA \/ C# \/DB \uac1c\ubc1c \ud504\ub9ac\ub79c\uc11c \ubaa8\uc9d1","mcom_idx":"5517055","logo_src":"company\/logo\/201908\/13\/pw5jg5_4qht-yd17i0_logo.jpg","personnel_manager_fl":"y","read_cnt":"52","group_nm":"","sales_rank":"","reg_dt":"1599022192","apply_cnt":"0","cat_cd":"407,416","loc_cd":"115135","valuestatement":"","apply_gb":"email","edu_cd":"7","subway_cd":"0","cert_class":"","info_open_fl":"y","opening_dt":"1599019200","com_idx":"0","grab_source_cd":"","sal_cd":"99","kindness_expired_dt":"","closing_dt":"1601477999","loc_mcd":"115000","item_id":"keyword6,keyword_m7","cat_key":"40716|40720|40728|41602|41603|41604","rec_manage_cd":"T,TT,ITM,ZA,ZS,PA,ZR","exp_cd":"2","com_photo":"n","stock_gb":"","loc_bcd":"115135","exp_max":"0","rec_idx":"38713619","bbs_gb":"0","company_nm":"\ub178\ub9ac\uc2dc\uc2a4\ud15c(\uc8fc)","category":"","pc_sort_dt":"1599459338","homepage":"www.norisystem.co.kr","recParam":{"t_category":"relay_view","t_content":"relay_view_list","t_ref":"relay_view","t_ref_content":"SRI_050_VIEW_MIX_RCT_ADD","t_ref_scnid":"696","dpId":"SRI_050_VIEW_MIX_RCT_ADD","ref_dp":"SRI_050_VIEW_MIX_RCT_ADD","inner_source":"saramin","inner_medium":"pattern","inner_campaign":"relay_view_apply_2","inner_term":"list","trackEventAvatar":"","loggingRecommend":"loggingRecommendUrl(this, 'http:\/\/rcmd-log.saramin.co.kr:9020\/so-logging\/log\/client?custId=&pcId=15996305088133198347523&nonce=a8c32584fd04896f8879&dpId=SRI_050_VIEW_MIX_RCT_ADD&scnId=696&tgId=0&itemSetId=0&itemValue=38713619&click=1', '');","scrapBtn":"<button type=\"button\" onclick=\"Saramin.btnJob('scrap', this, '', 'quick_login');\" scraped=\"n\" rec_idx=\"38713619\" class=\"btn_scrap scrap-38713619\" imgtype=\"\" title=\"\uacf5\uace0 \uc2a4\ud06c\ub7a9\" onmousedown=\"try{n_trackEvent('relay_view', 'recommend', 'scrap' , '');}catch(e){}\"><img src=\"http:\/\/www.saraminimage.co.kr\/common\/bul_sri_star.png\" alt=\"\"><\/button>","quickApplyOptions":{"trackEvent":{"category":"relay_view","action":"recommend","opt_label":"quick_apply","opt_value":""},"applyTrackEvent":{"t_category":"relay_view","t_content":"relay_view_list","t_ref":"relay_view","t_ref_content":"SRI_050_VIEW_MIX_RCT_ADD","t_ref_scnid":"696","dpId":"SRI_050_VIEW_MIX_RCT_ADD","ref_dp":"SRI_050_VIEW_MIX_RCT_ADD","inner_source":"saramin","inner_medium":"pattern","inner_campaign":"relay_view_apply_3","inner_term":"list"}}},"summary_str":"\ucc9c\uc548\uc2dc \uc11c\ubd81\uad6c <span class=\"txt_bar\">|<\/span> \uacbd\ub8255\ub144\u2191 <span class=\"txt_bar\">|<\/span> \ucd08\ub300\uc878\u2191","closing_str":"~ 9\/30(\uc218)","recommend_ids_list":"38733685_696%7C38727190_595%7C38724805_561%7C38716840_561%7C38562906_746%7C38647080_596%7C38600890_561%7C38477312_561%7C38616136_561%7C38678317_561%7C38668033_596%7C38605619_561","quickApplyBtn":"<button  class=\"sri_btn_xs for_btn_event\" title=\"\ud074\ub9ad\ud558\uba74 \uc785\uc0ac\uc9c0\uc6d0\ud560 \uc218 \uc788\ub294 \ucc3d\uc774 \ub739\ub2c8\ub2e4.\" onclick=\"try{quickApplyForm(&#39;38713619&#39;,&#39;&#39;,&#39;t_category=relay_view&t_content=relay_view_list&t_ref=relay_view&t_ref_content=SRI_050_VIEW_MIX_RCT_ADD&t_ref_scnid=696&dpId=SRI_050_VIEW_MIX_RCT_ADD&ref_dp=SRI_050_VIEW_MIX_RCT_ADD&inner_source=saramin&inner_medium=pattern&inner_campaign=relay_view_apply_3&inner_term=list&#39;, &#39;&#39;); return false;} catch (e) {}; return false;\" onmousedown=\"try{n_trackEvent(&#39;relay_view&#39;,&#39;recommend&#39;,&#39;quick_apply&#39;,&#39;&#39;);}catch(e){}\"><span class=\"sri_btn_immediately\" >\uc989\uc2dc\uc9c0\uc6d0<\/span><\/button>","favorBtn":"<button  type=\"button\" csn=\"3128636894\" title=\"\uad00\uc2ec\uae30\uc5c5 \ub4f1\ub85d\" del_fl=\"n\" class=\"btn_jview spr_jview btn_interest\" onclick=\"try{Saramin.btnJob(&#39;favor&#39;, this, &#39;&#39;, &#39;quick_login&#39;);}catch(e){}\" onmousedown=\"try {n_trackEvent(&#39;relay_view&#39;, &#39;recommend&#39;, &#39;favor&#39;, &#39;&#39;);}catch(e){}\" first_nudge=\"off\"><span class=\"blind\">\uad00\uc2ec\uae30\uc5c5 \ub4f1\ub85d<\/span><\/button>","txtRegDt":"7\uc77c \uc804 \ub4f1\ub85d"}],
            'related_scenarioIds' : [],
            'related_loggingUrls' : [],
            'scrap_cnt' : '0',
            'readjob_cnt' : '0',
            'pay_recruit' : {"38689139":{"pay_fl":"paid"},"38703608":{"pay_fl":"paid"}},
            'pay_recruit_related' : [],
            'recruits' : []
        };

        for (var i = 0; i < jv_options.recruit_idxs.length; i++) {
            jv_options.recruits.push({
                loadStart: false,
                loadEnd: false,
                logged: false,
                params: {
                    'rec_idx' : jv_options.recruit_idxs[i]['rec_idx'],
                    'rec_seq' : i,
                    'utm_source': '',
                    'utm_medium': '',
                    'utm_term': '',
                    'utm_campaign': '',
                    'view_type' : 'list',
                    't_ref': '',
                    't_ref_content': '',
                    't_ref_scnid': jv_options.recruit_idxs[i]['t_ref_scnid'],
                    'refer': '',
                    'searchType': '',
                    'searchword': '',
                    'ref_dp': 'SRI_050_VIEW_MTRX_RCT_NOINFO',
                    'dpId': i === 0 ? '' : '',
                    'recommendRecIdx': ''
                }
            });
        }

        JobsView.init(jv_options);
    </script>

                            </div>
        </div>
                        <footer id="sri_footer" class="sri_footer">
    <div class="wrap_footer">
        <div class="links">
    <strong class="blind">바로가기</strong>
    <ul>
        <li class="first"><a href="http://www.saraminhr.co.kr/" target="_blank" rel="noopener" title="회사소개 새창열기">회사소개</a></li>
        <li><a href="http://www.saraminhr.co.kr/open_content/pr/press_release.php" target="_blank" rel="noopener" title="보도기사 새창열기">보도기사</a></li>
        <li><a href="http://www.saraminhr.co.kr/open_content/hr/location.php" target="_blank" rel="noopener" title="찾아오시는길 새창열기">찾아오시는길</a></li>
        <li><a href="/zf_user/help/terms-of-service" title="회원약관 바로가기">회원약관</a></li>
        <li class="bold"><a href="/zf_user/help/privacy" title="개인정보처리방침 바로가기">개인정보처리방침</a></li>
        <li><a href="http://www.saramin.co.kr/zf_user/popup/email-refuse" onclick="window.open(this.href, '이메일무단수 집거부', 'width=380,height=200,left=0,top=0'); return false;" rel="noopener" title="이메일무단수집거부 바로가기">이메일 무단수집거부</a></li>
        <li><a href="https://oapi.saramin.co.kr/" target="_blank" rel="noopener" title="채용정보 API">채용정보 API</a></li>
        <li><a href="/zf_user/help/inquery/partnership-inquiry-write" target="_self" rel="noopener" title="제휴문의">제 휴문의</a></li>
        <li><a href="http://www.saramin.co.kr/zf_user/help" title="고객센터 바로가기">고객센터</a></li>
    </ul>
</div>        <div class="copyright">
    <p>(주)사람인HR, 우 : 08378, 서울특별시 구로구 디지털로34길 43, 201호(구로동), 대표 : 김용환<br>사업자등록 : 113-86-00917, 직업정보제공사업 : 서울 관악 제 2005-6호, 통신판매업 : 제 2339호, Copyright (c) (주)사람인HR. All rights reserved.</p>
</div>    </div>
</footer>
    </div>
<div id="dimmed" class="sri_dimmed" style="display:none"></div>
<script type="text/javascript">
var isPersonLogin = false;
var isCompanyLogin = false;
</script>

<script type="text/javascript">
var wwwBaseUrl = '';
var isNullRealNameVerified = '1';

//상세 입사지원 팝업
var isIE = function() {
    var ua = window.navigator.userAgent;
    var msie = ua.indexOf('MSIE ');
    if (msie > 0) {
        return true;
    }
    var trident = ua.indexOf('Trident/');
    if (trident > 0) {
        return true;
    }
    var edge = ua.indexOf('Edge/');
    if (edge > 0) {
        return false;
    }
    return false;
}
var closeAppSetupLayer = function(s) {
    if ( s == 'balloon-layer' ) {
        document.getElementById(s).style.display = 'none';
    } else {
        var layerEl = document.getElementById('app-setup-layer');
        layerEl.style.display = 'none';
    }
};
var isQuirksIE = isIE() && document.compatMode!=='CSS1Compat' ? true : false;

var loadingLayer = false;
// 즉시지원 1Form
var quickApplyForm = function(rec_idx, company_nm, track_url, search_url, category) {
    if (loadingLayer) {
        alert('즉시지원 프로세스가 실행중입니다. 잠시만 기다려 주세요.');
        return false;
    }

    var category = category || '';
    var rec_idx  = rec_idx || '';
    var quick_apply_frame = document.getElementById('quick_apply_frame');

    if (isCompanyLogin) {
        if ( !confirm('기업회원으로 로그인되어 있어 이용하실 수 없습니다.\n\n개인회원으로 로그인하시겠습니까?') ) {
            return;
        }
    }

    var spec = 'apply_status=y&reg_source_type=pc';

    if (category != 'scrap' && category != 'favor' && category != 'quick_login' && category != 'ask_manager') {
        Saramin.readJob(rec_idx, spec);
    }

    if (!isPersonLogin) {
        if (!!category && category == 'quick_login') {
            category = 'scrap';
        }

        quick_apply_frame.setAttribute('showLayer', 'y');
        var loginUrl = '/zf_user/member/apply/login-form?rec_idx=' + rec_idx + '&category=' + category;
        if (track_url) {
            loginUrl += '&' + track_url;
        }
        if (search_url) {
            loginUrl += '&' + search_url;
        }
        quick_apply_frame.style.display = 'none';
        quick_apply_frame.contentWindow.location.replace(loginUrl);
        showQuickApplyLayer();
        return;
    }

    if (isPersonLogin && isNullRealNameVerified) {
        alert('휴대폰 또는 이메일 인증을 완료하신 후에 입사지원이 가능합니다.');
        return false;
    }

    quick_apply_frame.style.display = 'none';
    showQuickApplyLayer();

    var quickApplyUrl = '/zf_user/member/apply?rec_idx=' + rec_idx;
    if ( track_url ) {
        quickApplyUrl += '&' + track_url;
    }
    if (search_url) {
        quickApplyUrl += '&' + search_url;
    }
    quick_apply_frame.setAttribute('showLayer', 'y');
    loadingLayer = true;
    quick_apply_frame.contentWindow.location.replace(quickApplyUrl);
};

var showQuickApplyLayer = function() {
    if (!!document.getElementById('pop_login_layer')) {
        document.getElementById('pop_login_layer').style.display = 'none';
    }

    document.getElementsByTagName('html')[0].style.overflow = 'hidden';
    document.getElementsByTagName('html')[0].style.height = '100%';
    if(isQuirksIE) document.getElementsByTagName('body')[0].style.overflow = 'hidden';
    document.getElementsByTagName('body')[0].style.height = '100%';

    setQuickApplyLayerPosition();

    document.getElementById('iframe_layer').style.display = '';
};

var setQuickApplyLayerPosition = function() {
    var layerEl = document.getElementById('iframe_layer');

    var sheight = document.body.scrollTop;
    if (sheight == 0) {
        sheight = document.documentElement.scrollTop;
    }

    var sLeft = document.body.scrollLeft == 0 ? document.documentElement.scrollLeft : document.body.scrollLeft,
        window_w = window.innerWidth || document.documentElement.clientWidth || document.body.clientWidth;

    layerEl.style.top = sheight + 'px';
    layerEl.style.width = (window_w + sLeft) + 'px';

    var layerWidth = function(evt){
        sLeft = document.body.scrollLeft == 0 ? document.documentElement.scrollLeft : document.body.scrollLeft;
        window_w = window.innerWidth || document.documentElement.clientWidth || document.body.clientWidth;
        layerEl.style.width = (window_w + sLeft) + 'px';
    };
    function addEvent(obj, evType, fn) {
        if(obj.addEventListener) {
            obj.addEventListener(evType, fn, true);
            return true;
        } else if(obj.attachEvent) {
            var r = obj.attachEvent("on" + evType, fn);  return r;
        } else {
            return false;
        }
    }
    addEvent(window, 'resize', layerWidth, true);
};

var closeQuickApplyLayer = function(onlayer) {
    if (loadingLayer && onlayer != 'y') {
        alert('입사지원 프로세스가 실행중입니다. 잠시만 기다려주세요.');
        return false;
    }

    var quick_apply_frame = document.getElementById('quick_apply_frame'),
        iframeLayerEl = document.getElementById('iframe_layer'),
        reloadFl = document.getElementById('quick_apply_layer').getAttribute('reload');

    quick_apply_frame.setAttribute('showLayer', 'n');

    iframeLayerEl.style.display = 'none';

    document.getElementsByTagName('html')[0].style.overflow = '';
    if(isQuirksIE) document.getElementsByTagName('body')[0].style.overflow = '';
    quick_apply_frame.contentWindow.location.replace('about:blank');

    try {
        if (reloadFl == 'y' && global_rec_idx) {
            location.reload();
        }

        var statisticEl = window.parent.document.getElementById('goStatistic');

        if (typeof(statisticEl) != 'undefined' && statisticEl.value == 'go') {
            var d = new Date();
            d.setTime(d.getTime() + 60000);
            var expires = "expires="+d.toUTCString();
            document.cookie = "relay_view_to=statistics;" + expires + ";path=/;"
            location.reload();
        }
    } catch (e) {}
};

var showRecommendRecruitLayer = function (rec_idx, recruitapply_idx) {
    document.getElementById('iframe_layer').style.display = 'none';

    showQuickApplyLayer();

    //loadingLayer = true;

    var quick_apply_frame = document.getElementById('quick_apply_frame');
    quick_apply_frame.style.display = 'none';
    quick_apply_frame.setAttribute('showLayer', 'y');
    quick_apply_frame.contentWindow.location.replace('/zf_user/member/apply/recommend-recruit-list?rec_idx=' + rec_idx + '&recruitapply_idx=' + recruitapply_idx + '&apply_type=applyStatus');
};

var goResumeManage = function () {
    if (confirm('이력서가 등록되지 않았습니다.\n지금 등록하시겠습니까?')) {
        location.href = wwwBaseUrl + '/zf_user/member/resume-manage/select-template';
    }
};

var setReload = function(flag) {
    document.getElementById('quick_apply_layer').setAttribute('reload', flag);
};

var applyListener = function() {
    if (window.isApplyListened) return false;
    window.addEventListener('message',function(event) {
        if (!!(event.origin.match(/^https:\/\/.+?\.saramin\.co\.kr/))) {
            eval(event.data);
        }
        else {
            return false;
        }
        return;
    }, false);
    window.isApplyListened = true;
}

</script>

<div id="iframe_layer" class="iframe_layer" style="display: none;">
    <div id="quick_apply_layer" class="once_layer" reload="n">
        <div id="quick_apply_layer_loading" class="layer_loading" style="display:none"><img src="//www.saraminimage.co.kr/js/libs/images/loading.gif"></div>
        <iframe id="quick_apply_frame" name="quick_apply_frame" src="about:blank" width="540" height="0" scrolling="no" frameborder="0" allowtransparency="true" title="입사지원" showlayer="n" style=""></iframe>
        <a href="#close" onclick="closeQuickApplyLayer(); return false;" class="once_ly_close">
            <img src="http://www.saraminimage.co.kr/sri/common/btn/btn_layer_close.png" alt="닫기">
        </a>
    </div>
</div><div id="pop_login_layer_dimmed" style="display:none;position:fixed;top:0;left:0;width:100%;height:100%;background:url(//www.saraminimage.co.kr/event_2014/0708_rank1/bg_dimmed.png) repeat 0 0;z-index:9998;"></div>
<div id="pop_login_layer" class="pop_login_layer" style="display: none; position: absolute; top: 280px;">
    <div class="outer">
        <form name="loginFrm" id="loginFrm" action="https://www.saramin.co.kr/zf_user/auth/login" method="post" onsubmit="return loginCheckMainLayer(this);">
            <input type="hidden" name="page_url" id="page_url" value="">
            <input type="hidden" name="url" value="">
            <input type="hidden" name="allowType" value="">
            <input type="hidden" name="ut" value="">
            <input type="hidden" name="layerScrapIdx" value="">
            <input type="hidden" name="layerFavorIdx" value="">
            <input type="hidden" name="rec_apply_fl" value="n">
            <fieldset class="inner">
                <legend><strong>개인회원로그인</strong>이 필요한 서비스입니다.</legend>
                <div class="setting">
                    <input id="ly_autologin" name="autologin" type="checkbox">
                    <label for="ly_autologin"> 로그인 유지 </label>
                    <div class="dsc_ly" id="tooltip_autologin" style="display: none;">
                        <button class="btn_ly_close" id="auto_login_close" type="button">닫기</button>
                        <span class="dsc_arr"></span>
                        <p class="dsc_txt">
                            <strong>[개인회원 전용]</strong><br>
                            개인정보 보호를 위해 개인 PC에서만 이용해 주세요.
                        </p>
                    </div>
                    <input id="ly_id_save" name="id_save" class="ly_id_save" type="checkbox">
                    <label for="ly_id_save">아이디 저장</label>
                </div>
                <div id="login_form" class="login-form">
                    <div id="id_input_form" class="id-input-box focus">
                        <label id="ly-id-label" for="ly_id"><span>아이디</span></label>
                        <input type="text" name="id" id="ly_id" value="">
                    </div>
                    <div id="pw_input_form" class="pw-input-box">
                        <label id="ly-password-label" for="ly_password"><span>비밀번호</span></label>
                        <input type="password" name="password" id="ly_password" value="">
                    </div>
                                        <button type="submit" class="btn-login" onmousedown="loggingEventAndTagManager(['login','pc_login_layer','per_login',''],['ga_lead','login','pc_login_layer','per_login'])"><span>로그인</span></button>
                </div>
                <p class="signup-forgotten">
                                        <a href="/zf_user/member/registration/join" target="_blank" class="sign-up">회원가입</a>
                    <span></span>
                    <a href="/zf_user/helpdesk/idpw-find" target="_blank" class="forgotten">아이디/비밀번호 찾기</a>
                </p>
                                    <ul class="social_login_layer" style="display: inline-block;">
                                                <li class="_social_login">
                            <a href="/zf_user/auth/sign-in-with?provider=naver.com&amp;display=popup&amp;url=%2Fzf_user%2Fjobs%2Frelay%2Fview%3FisMypage%3Dno%26rec_idx%3D38655001%26recommend_ids%3DeJxNj8ERAzEIA6vJH5AR8E4h7r%252BL2PGNuecyEixIZilqxohPfPHCOf6DMCZsevlBBbUmiwcBpjdaaEmHbaT4dOrTZQ656LQSrlOnyxGSu%252FugSFaHRwTULlK5RBojodHIFOC1yrfz1RBQsiUvPh%252FTuFx6WS0vtPVKu15rB5bYxh8IoEhm%26view_type%3Dlist%26gz%3D1&amp;login_type=p" data-provider="naver" class="popup_login sl_naver" onmousedown="loggingEventAndTagManager(['login','pc_login_layer','per_login_naver',''],['ga_lead','login','pc_login_layer','per_login_naver'])">네이버 로그인</a></li>
                                                <li class="_social_login">
                            <a href="/zf_user/auth/sign-in-with?provider=facebook.com&amp;display=popup&amp;url=%2Fzf_user%2Fjobs%2Frelay%2Fview%3FisMypage%3Dno%26rec_idx%3D38655001%26recommend_ids%3DeJxNj8ERAzEIA6vJH5AR8E4h7r%252BL2PGNuecyEixIZilqxohPfPHCOf6DMCZsevlBBbUmiwcBpjdaaEmHbaT4dOrTZQ656LQSrlOnyxGSu%252FugSFaHRwTULlK5RBojodHIFOC1yrfz1RBQsiUvPh%252FTuFx6WS0vtPVKu15rB5bYxh8IoEhm%26view_type%3Dlist%26gz%3D1&amp;login_type=p" data-provider="facebook" class="popup_login sl_facebook" onmousedown="loggingEventAndTagManager(['login','pc_login_layer','per_login_facebook',''],['ga_lead','login','pc_login_layer','per_login_facebook'])">페이스북 로그인</a></li>
                                                <li class="_social_login">
                            <a href="/zf_user/auth/sign-in-with?provider=kakao.com&amp;display=popup&amp;url=%2Fzf_user%2Fjobs%2Frelay%2Fview%3FisMypage%3Dno%26rec_idx%3D38655001%26recommend_ids%3DeJxNj8ERAzEIA6vJH5AR8E4h7r%252BL2PGNuecyEixIZilqxohPfPHCOf6DMCZsevlBBbUmiwcBpjdaaEmHbaT4dOrTZQ656LQSrlOnyxGSu%252FugSFaHRwTULlK5RBojodHIFOC1yrfz1RBQsiUvPh%252FTuFx6WS0vtPVKu15rB5bYxh8IoEhm%26view_type%3Dlist%26gz%3D1&amp;login_type=p" data-provider="kakao" class="popup_login sl_kakao" onmousedown="loggingEventAndTagManager(['login','pc_login_layer','per_login_kakao',''],['ga_lead','login','pc_login_layer','per_login_kakao'])">카카오 로그인</a></li>
                                                <li class="_social_login">
                            <a href="/zf_user/auth/sign-in-with?provider=google.com&amp;display=popup&amp;url=%2Fzf_user%2Fjobs%2Frelay%2Fview%3FisMypage%3Dno%26rec_idx%3D38655001%26recommend_ids%3DeJxNj8ERAzEIA6vJH5AR8E4h7r%252BL2PGNuecyEixIZilqxohPfPHCOf6DMCZsevlBBbUmiwcBpjdaaEmHbaT4dOrTZQ656LQSrlOnyxGSu%252FugSFaHRwTULlK5RBojodHIFOC1yrfz1RBQsiUvPh%252FTuFx6WS0vtPVKu15rB5bYxh8IoEhm%26view_type%3Dlist%26gz%3D1&amp;login_type=p" data-provider="google" class="popup_login sl_google" onmousedown="loggingEventAndTagManager(['login','pc_login_layer','per_login_google',''],['ga_lead','login','pc_login_layer','per_login_google'])">구글 로그인</a></li>
                                                <li class="_social_login">
                            <a href="/zf_user/auth/sign-in-with?provider=apple.com&amp;display=popup&amp;url=%2Fzf_user%2Fjobs%2Frelay%2Fview%3FisMypage%3Dno%26rec_idx%3D38655001%26recommend_ids%3DeJxNj8ERAzEIA6vJH5AR8E4h7r%252BL2PGNuecyEixIZilqxohPfPHCOf6DMCZsevlBBbUmiwcBpjdaaEmHbaT4dOrTZQ656LQSrlOnyxGSu%252FugSFaHRwTULlK5RBojodHIFOC1yrfz1RBQsiUvPh%252FTuFx6WS0vtPVKu15rB5bYxh8IoEhm%26view_type%3Dlist%26gz%3D1&amp;login_type=p" data-provider="apple" class="popup_login sl_apple" onmousedown="loggingEventAndTagManager(['login','pc_login_layer','per_login_apple',''],['ga_lead','login','pc_login_layer','per_login_apple'])">애플 로그인</a></li>
                                            </ul>
                            </fieldset>
        </form>
        <button class="pop_login_layer_close" id="pop_login_layer_close">닫기</button>
    </div>
    <script type="text/javascript">

        var getId = (function () {
            var elCache = {};
            return function (id) {
                if (!elCache[id]) {
                    elCache[id] = document.getElementById(id);
                }
                return elCache[id];
            }
        })();

        var page_url = '';
        var autoLoginCheck = getId('pop_login_layer').querySelector('form').ly_autologin;

        function addEvent(ele, eventType, func) {
            var obj = typeof ele === 'string' ? getId(ele) : ele;
            if (obj.addEventListener) {
                obj.addEventListener(eventType, func, false);
            } else if (obj.attachEvent) {//IE
                obj.attachEvent('on' + eventType, func);
            }
        }

        //아이디
        addEvent("ly_id", "focus", function () {
            getId('ly-id-label').style.display = 'none';
        });
        addEvent("ly_id", "blur", function () {
            if (getId('ly_id').value === '') {
                getId('ly-id-label').style.display = 'block';
            }
        });

        //패스워드
        addEvent("ly_password", "focus", function () {
            getId('ly-password-label').style.display = 'none';
        });
        addEvent("ly_password", "blur", function () {
            if (getId('ly_password').value === '') {
                getId('ly-password-label').style.display = 'block';
            }
        });

        //창닫기
        addEvent("pop_login_layer_close", "click", function () {
            getId('page_url').value = page_url;
            getId('pop_login_layer').style.display = 'none';
            getId('pop_login_layer_dimmed').style.display = 'none';
        });

        //로그인 유지 창닫기
        addEvent("auto_login_close", "click", function () {
            getId('tooltip_autologin').style.display = 'none';
        });


        //로그인 유지 안내 팝업
        addEvent(autoLoginCheck, 'click', function () {
            getId('tooltip_autologin').style.display = autoLoginCheck.checked ? 'block' : 'none';
        });

        //폼  체크
        function loginCheckMainLayer(form) {
            if (form.id.value === "") {
                alert("아이디를 입력하세요.");
                form.id.focus();
                return false;
            }
            if (form.id.value.indexOf(" ") > 0) {
                alert("아이디에 공백에 있습니다. 공백을 제거해주세요");
                form.id.focus();
                return false;
            }
            if (form.id.value.length < 4) {
                alert("아이디는 4자이상이어야 합니다");
                form.id.focus();
                return false;
            }
            if (form.password.value === "") {
                alert("비밀번호를 입력하세요");
                form.password.focus();
                return false;
            }
            if (form.password.value.length < 4 || form.password.value.length > 32) {
                alert("비밀번호는 영문,숫자,특수문자 조합 6~32자 입니다.");
                form.password.focus();
                return false;
            }
            return true;
        }

        //페이지 로딩시 초기화 시켜 준다.
        setTimeout(function () {
            var idInPut = getId('ly_id');
            var pwInput = getId('ly_password');
            if (!getId('ly_id').value) {
                idInPut.value = '';
                idInPut.blur();
            }
            pwInput.value = '';
            pwInput.blur();
        }, 50);

        (function ($) {
            $('._social_login').on('click', 'a', function (e) {
                e.preventDefault();
                e.stopPropagation();
                var link =  $(e.currentTarget).attr('href'),
                    provider = $(e.currentTarget).data('provider');
                if((navigator.userAgent.toLowerCase().indexOf("msie") !== -1) && provider === 'apple'){
                    if(confirm('IE10이하 버전의 인터넷 익스플로러에서는 Apple 로그인이 정상 작동하지 않을 수 있습니다.\n' +
                        '인터넷 익스플로러를 최신 버전으로 업데이트 해주세요'))
                    {
                        window.open(link, '_blank', 'width=480,height=640');
                    }
                    return;
                }
                window.open(link, '_blank', 'width=480,height=640');
            });
        })(jQuery);
    </script>
</div>
<script type="text/javascript">
    //<!--

    var searchWordInputId              = "combineSearchWord", // 검색어 input ID
        searchAutoCompleteResultWrapId = "wrapAutoComplete", // 검색결과 자동완성 Wrap ID
        searchRecruitmentKey           = 0, // key
        urlBanner                      = "//www.saraminbanner.co.kr/", // 로고 url
        urlPds                         = "//pds.saramin.co.kr/", // 로고원본 url
        urlWebPds                      = "//webpds.saramin.co.kr/pds/", // 로고원본 webpds url
        inlineCss                      = "", // 특정 css
        pageType                       = "";
    //-->
</script>
<script type="text/javascript" src="/js/search/search-auto-complete.js?v=20200908163120"></script><script type="text/javascript">
(function() {
  var pszProto = (("https:" == document.location.protocol) ? "https://www.saramin.co.kr/js/" : "//www.saraminimage.co.kr/js/");
  document.write(unescape("%3Cscript src='" + pszProto + "wl6.js' type='text/javascript'%3E%3C/script%3E"));
})();
</script><script src="//www.saraminimage.co.kr/js/wl6.js" type="text/javascript"></script>

<script type="text/javascript">
    // 1.
_n_sid = "saramin";
_n_uid_cookie = "UID";
_n_info1_cookie = "Mtype";
n_logging();
</script>

<script type="text/javascript">

        function n_trackEvent(category, action, opt_label, opt_value, opt_noninteraction) {
            var l = document.location;
            var url = l.protocol + '//' + l.host + '/trackEvent?category=' + category + '&action=' + action;
            var label = opt_label || '';
            var value = opt_value || '';
            url = url + '&opt_label=' + label + '&opt_value=' + value;
            n_click_logging(url, l.href);
            try {
                _gaq.push(['_trackEvent', category, action, opt_label, opt_value, opt_noninteraction]);
                ga('send', 'event', category, action, opt_label, opt_value, opt_noninteraction);
            } catch (_e) {}
        }

        function pushDataLayer(event, category, event_flow, event_label) {
            try {
            dataLayer.push({
                'event': event || 'ga_lead',
                'category': category || '',
                'event-flow': event_flow || '',
                'event-label': event_label || ''
            });

        }catch (e) {

        }
    }

    // 클릭 이벤트 + 구글 태그매니져 로깅
    function loggingEventAndTagManager(trackEventAttr, tagManagerAttr) {
        n_trackEvent(trackEventAttr[0], trackEventAttr[1], trackEventAttr[2], trackEventAttr[3]);
        pushDataLayer(tagManagerAttr[0], tagManagerAttr[1], tagManagerAttr[2], tagManagerAttr[3]);
    }


    function promotionPushDataLayer(log_event, log_id, log_name, log_creative, log_position) {
            try{
            var ecommerce_type = log_event === 'promotionClick' ? 'promoClick' : 'promoView';
            var promotion_log = {};
            promotion_log[ecommerce_type] = {
                'promotions': [
                    {
                        'id': log_id,
                        'name': log_name,
                        'creative': log_creative,
                        'position': log_position
                    }
                ]
            };

            var log_data = {
                'event': log_event,
                'ecommerce': promotion_log
            };

            dataLayer.push(log_data);
        } catch (e) {

        }
    }


        function _hwaClick(cc) {
                n_trackEvent('ADs', 'Click-' + cc);
        }

    function applyTrackEvent(el, opt_category, opt_content, opt_ref, opt_ref_content) {

        try {
            var url         = el.href;
            var category    = opt_category || '';
            var content     = opt_content || '';
            var ref         = opt_ref || '';
            var ref_content = opt_ref_content || '';
            var anchor      = '';

            if ( url.indexOf('#') != -1 ) {
                var splitUrl = url.split('#');
                url = splitUrl[0];
                anchor = splitUrl[1];
            }

            if( url.indexOf('?') < 0 ) {
                url = url + '?t_category=' + category + '&t_content=' + content + '&t_ref=' + ref + '&t_ref_content=' + ref_content;
            } else {
                url = url + '&t_category=' + category + '&t_content=' + content + '&t_ref=' + ref + '&t_ref_content=' + ref_content;
            }

            if ( anchor != '' ) {
                url += '#' + anchor;
            }

            el.href = url;
        } catch (e) {
        }
    }

    function s_trackApply(el, opt_ref, opt_ref_content, opt_ref_scnid, opt_ref_area, opt_etc) {

        try {
            var url         = el.href;
            var ref         = opt_ref || '';
            var ref_content = opt_ref_content || '';
            var ref_scnid   = opt_ref_scnid || '';
            var ref_area   = opt_ref_area || '';
            var anchor      = '';

            var opt = opt_etc || {};

            if( url.indexOf('t_ref') > 0 ) return;

            if ( url.indexOf('#') != -1 ) {
                var splitUrl = url.split('#');
                url = splitUrl[0];
                anchor = splitUrl[1];
            }

            if( url.indexOf('?') < 0 ) {
                url = url + '?t_ref=' + ref + '&t_ref_content=' + ref_content;
            } else {
                url = url + '&t_ref=' + ref + '&t_ref_content=' + ref_content;
            }

            if (!!ref_scnid) {
                                url += '&t_ref_scnid=' + ref_scnid;
            }

            if (!!ref_area) {
                                url += '&t_ref_area=' + ref_area;
            }

            if ( anchor != '' ) {
                url += '#' + anchor;
            }

            if (opt.constructor === Object) {
                for (k in opt) {
                    if (opt.hasOwnProperty(k)) {
                        url += '&' + k + '=' + opt[k];
                    }
                }
            }

            el.href = url;

        } catch (e) {
        }
    }
</script>


<script type="text/javascript" src="//wcs.naver.net/wcslog.js"></script>

<script type="text/javascript">
if (!wcs_add) var wcs_add={};
wcs_add["wa"] = "s_1d3a45fb0bfe";
if (!_nasa) var _nasa={};
wcs.inflow();
wcs_do(_nasa);
</script>
<!-- Google Tag Manager -->
<script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
        new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
        j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
        'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
    })(window,document,'script','dataLayer','GTM-MK2GBBH');</script>
<!-- End Google Tag Manager -->
<!-- Google Tag Manager (noscript) -->
<noscript><iframe src="https://www.googletagmanager.com/ns.html?id=GTM-MK2GBBH"
                  height="0" width="0" style="display:none;visibility:hidden"></iframe></noscript>
<!-- End Google Tag Manager (noscript) -->
<div id="_sticky_warp"><div class="sticky_assist" id="_sticky_layer" data-num="edge1">

    <div class="assist_contents">
        <div class="wrap_header" id="sticky_contents_header">
    <strong class="title">알림</strong>
    <button type="button" class="btn_close_layer"><span class="blind">닫기</span></button>
</div>
        <section class="section_view notification" id="sticky_contents_notification"></section>
        <section class="section_view recommend" id="sticky_contents_recommend"></section>
        <section class="section_view help" id="sticky_contents_help"></section>
    </div>


    <div class="wrap_tooltip">
        <div class="inner">
            <p class="txt">지금 보고 계신 공고 어떠세요?<br>
<b class="point">로그인</b> 하시고 지원해보세요</p>
        </div>
        <button type="button" class="btn_close"><span class="blind">닫기</span></button>
    </div>


    <div class="wrap_btns">

    <button type="button" class="btn_assist notification on" data-cate="notification" title="알림센터 열기"><span class="blind">알림센터</span></button>

    <a href="javascript:void(0);" class="btn_close sticky_speech_bubble_close" data-cate="close"><span class="blind">오 늘 하루동안 메시지 보지 않기</span></a>

    </div>

</div>
<script type="text/template" id="sticky_layer_template">
    {{assist_contents}}
    {{assist_tooltip}}
    {{assist_btns}}
</script>
<script type="text/template" id="sticky_contents_template">
    <div class="assist_contents">
        <div class="wrap_header" id="sticky_contents_header">{{contents_header}}</div>
        <section class="section_view notification" id="sticky_contents_notification"></section>
        <section class="section_view recommend" id="sticky_contents_recommend"></section>
        <section class="section_view help" id="sticky_contents_help" ></section>
    </div>
</script>
<script type="text/template" id="sticky_contents_header_template">
    <strong class="title">{{contents_title}}</strong>
    <button type="button" class="btn_close_layer"><span class="blind">닫기</span></button>
</script>
<script type="text/template" id="sticky_contents_header_help_template">
    <strong class="title">{{contents_title}}</strong>
    <button type="button" class="btn_back" style="display:none;"><span class="blind">뒤로가기</span></button>
    <button type="button" class="btn_close_layer"><span class="blind">닫기</span></button>
</script>
<script type="text/template" id="sticky_tooltip_template">
    <div class="wrap_tooltip">
        <div class="inner">
            <p class="txt">{{tooltip_message}}</p>
        </div>
        <button type="button" class="btn_close"><span class="blind">닫기</span></button>
    </div>
</script>
<script type="text/template" id="sticky_boost_tooltip_template">
    <div class="wrap_tooltip recommend_notice">
        <p class="title">{{tooltip_message}}</p>
        <div class="inner recommend_info">
            <div class="table_box">
                <a href="javascript:void(0);" class="link_box" logging_url="{{logging_url}}" title="{{rec_title}}"></a>
                {{logo_img}}
                <div class="table_cell txt">
                    <div>
                        <span class="company_name">{{company_nm}}</span>
                        <span class="recommend_name">{{rec_title}}</span>
                        <span class="d_day">{{rec_dday}}</span>
                    </div>
                </div>
            </div>
            {{rec_applybtn}}
        </div>
        <button type="button" class="btn_close"><span class="blind">닫기</span></button>
    </div>
</script>
<script type="text/template" id="sticky_btns_template">
    <div class="wrap_btns">
        {{button_tab}}
    </div>
</script>
<script type="text/template" id="sticky_btn_template">
    <button type="button" class="btn_assist {{category}} {{category_selected}}" data-cate="{{category_data}}" title="{{category_name}} 열기"><span class="blind">{{category_name}}</span></button>
</script>
<script type="text/template" id="sticky_btn_close_template">
    <a href="javascript:void(0);" class="btn_close sticky_speech_bubble_close" data-cate="close"><span class="blind">오 늘 하루동안 메시지 보지 않기</span></a>
</script>


<script type="text/template" id="sticky_need_login_template">
    <h4 class="blind">로그인 안내</h4>
    <div class="box_tit">
        로그인 후 사용해 주세요.
        <p class="txt">해당 서비스는 로그인이<br>필요한 서비스 입니다.</p>
    </div>
    <div class="area_btn">
        <button
            type="button"
            id="sticky_resume_update_btn"
            class="sriBtnL bgBlack"
            onclick="location.href='{{login_url}}'">로그인 하기</button>
    </div>
</script>
<script type="text/template" id="sticky_error_info_template">
    <h4 class="blind">{{title}} 안내</h4>
    <div class="box_tit">
        {{error_msg}}
        <p class="txt">{{error_detail_msg}}</p>
    </div>
    <div class="area_btn">
        <button
            type="button"
            id="sticky_error_btn"
            class="sriBtnL bgBlack"
            onclick="{{error_event}}">확인</button>
    </div>
</script>
<script type="text/template" id="sticky_complete_layer_template">
    <div class="box_tit complete">신청이 완료되었습니다.</div>
    <div class="area_btn">
        <a href="#" id="sticky_complete_btn" class="sriBtnL bgBlack">닫기</a>
    </div>
</script>
</div>



<script src="/js/sticky/construct.js?ts=20200908163120"></script><script type="text/javascript">window.NREUM||(NREUM={});NREUM.info={"beacon":"bam.nr-data.net","licenseKey":"03a1f7dfe5","applicationID":"443261373","transactionName":"YFJaMkNTDBIFAUJfWVkYeQVFWw0PSwhZVEUYRV0KUEtNFw0HQQ==","queueTime":0,"applicationTime":462,"atts":"TBVZRAtJHxw=","errorBeacon":"bam.nr-data.net","agent":""}</script>

<script type="text/javascript" id="">window.dataLayer=window.dataLayer||[];dataLayer.push({event:"Event_Sampling",random_page:"1467380108"});</script>
        <div style="display: none; visibility: hidden;"><script>var cookie="\/zf_user\/jobs\/relay\/view",cookieName="mkt_ecommerce_pagepath",cookieValue=cookie,expirationTime=1800;expirationTime*=1E3;var date=new Date,dateTimeNow=date.getTime();date.setTime(dateTimeNow+expirationTime);date=date.toUTCString();document.cookie=cookieName+"\x3d"+cookieValue+"; expires\x3d"+date+"; path\x3d/; domain\x3d."+location.hostname.replace(/^www\./i,"");</script></div><script type="text/javascript" id="">window.dataLayer=window.dataLayer||[];dataLayer.push({userId:"undefined"});</script>
        <script src="/js/sticky/main.js?ts=1599630518260"></script><iframe id="google_osd_static_frame_5099338431276" name="google_osd_static_frame" style="display: none; width: 0px; height: 0px;"></iframe>
<script type="text/javascript" id="">dataLayer.push({event:"jobs_view",ecommerce:{currencyCode:"KOR",impressions:[{name:"undefined",id:"undefined",price:0,brand:"\/zf_user\/jobs\/relay\/view",category:"undefined",variant:"undefined",list:"\/zf_user\/jobs\/relay\/view",position:"38655001"}]}});</script></body></html>"""
